# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint

# %%
house_dict = []

linked = 'https://www.zillow.com/ca/duplex/?searchQueryState={%22pagination%22:{},%22usersSearchTerm%22:%22ca%22,%22mapBounds%22:{%22west%22:-127.94190190625,%22east%22:-110.67139409375,%22south%22:32.12531172436746,%22north%22:42.36335181945167},%22regionSelection%22:[{%22regionId%22:9,%22regionType%22:2}],%22isMapVisible%22:true,%22mapZoom%22:6,%22filterState%22:{%22isComingSoon%22:{%22value%22:false},%22isAuction%22:{%22value%22:false},%22isPreMarketForeclosure%22:{%22value%22:false},%22isPreMarketPreForeclosure%22:{%22value%22:false},%22isMakeMeMove%22:{%22value%22:false},%22isSingleFamily%22:{%22value%22:false},%22isManufactured%22:{%22value%22:false},%22isLotLand%22:{%22value%22:false},%22isTownhouse%22:{%22value%22:false},%22isCondo%22:{%22value%22:false},%22isMultiFamily%22:{%22value%22:false}},%22isListVisible%22:true}'
user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
headers = {'User-Agent': user_agent}
response = requests.get(linked, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
results = soup.find_all('article', class_='list-card')
    
    
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return housing weblink
        house_website = str(result.a.get('href'))
        # Identify and return house data
        listing_type = str(result.a.get('aria-label').split(",")[0])
        price = result.find('div', class_="list-card-price").text
        full_address = result.find('h3', class_="list-card-addr").text
        street = result.find('h3', class_="list-card-addr").text.split(",")[0]
        city = result.find('h3', class_="list-card-addr").text.split(",")[1].replace(" ", "")
        state = result.find('h3', class_="list-card-addr").text.split(",")[2].split(" ")[1]
        try:
            zip_code = result.find('h3', class_="list-card-addr").text.split(",")[2].split(" ")[2]
        except IndexError:
            zip_code = 'null'
        bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
        bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
        house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
        # Loop inside each house website and get more house data
        loop_response = requests.get(house_website, headers=headers)
        loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
        loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
        house_type = loop_result1.select('li')[0].text.split(":")[1]
        year_build = loop_result1.select('li')[1].text.split(":")[1]
#             lot = loop_result1.select('li')[5].text.split(":")[1]
#             if (str(lot.split(" ")[1]) == "sqft"):
#                 lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""))
#             elif (str(lot.split(" ")[1]) == "acres"):
#                 lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', "")) * 43560
        zillow_price_per_sqft = loop_result1.select('li')[5].text.split(":")[1]
        zestimate = loop_soup.find('span', class_="ds-estimate-value").text

            
            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
        house_obj = {
                "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "House_type": house_type,
                "Year_build": year_build,
#                 "Lot": lot,
#                 "Lot_conversion_to_sqft": lot_conversion_to_sqft,
                "Zestimate": zestimate,
                "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
            }

        #Continue to add data into collection house_dict
        house_dict.append(house_obj)
            
    except AttributeError as e:
        continue

print(house_dict)
# Out:
# [{'Listing_type': 'Apartment for sale', 'Price': '$278,000', 'Full_address': '1700 Lynne Dr UNIT 52, Santa Maria, CA 93454', 'Street': '1700 Lynne Dr UNIT 52', 'City': 'SantaMaria', 'State': 'CA', 'Zip_code': '93454', 'Bed': '3', 'Bath': '3', 'Square_Feet': '1,226', 'House_type': 'Apartment', 'Year_build': '1979', 'Zestimate': '$271,034', 'Zillow_price/sqft': '$227', 'House_website': 'https://www.zillow.com/homedetails/1700-Lynne-Dr-UNIT-52-Santa-Maria-CA-93454/15952177_zpid/'}, {'Listing_type': 'For sale by owner', 'Price': '$2,099,000', 'Full_address': '3570 Camino Arena, Carlsbad, CA 92009', 'Street': '3570 Camino Arena', 'City': 'Carlsbad', 'State': 'CA', 'Zip_code': '92009', 'Bed': 'Studio', 'Bath': '6', 'Square_Feet': '4,868', 'House_type': 'Apartment', 'Year_build': '2000', 'Zestimate': 'None', 'Zillow_price/sqft': '$431', 'House_website': 'https://www.zillow.com/homedetails/3570-Camino-Arena-Carlsbad-CA-92009/16730128_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$3,975,000', 'Full_address': '444 N Sycamore Ave, Los Angeles, CA 90036', 'Street': '444 N Sycamore Ave', 'City': 'LosAngeles', 'State': 'CA', 'Zip_code': '90036', 'Bed': 'Studio', 'Bath': '--', 'Square_Feet': '7,220', 'House_type': 'Apartment', 'Year_build': '1928', 'Zestimate': '$3,975,883', 'Zillow_price/sqft': '$551', 'House_website': 'https://www.zillow.com/homedetails/444-N-Sycamore-Ave-Los-Angeles-CA-90036/2125417632_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$394,000', 'Full_address': '4025 4027 Renick Way, North Highlands, CA 95660', 'Street': '4025 4027 Renick Way', 'City': 'NorthHighlands', 'State': 'CA', 'Zip_code': '95660', 'Bed': '6', 'Bath': '4', 'Square_Feet': '2,116', 'House_type': 'Apartment', 'Year_build': '1979', 'Zestimate': 'None', 'Zillow_price/sqft': '$186', 'House_website': 'https://www.zillow.com/homedetails/4025-4027-Renick-Way-North-Highlands-CA-95660/2082342331_zpid/'}, {'Listing_type': 'For sale by owner', 'Price': '$45,000', 'Full_address': '17900 Ocean Dr SPC 57, Fort Bragg, CA 95437', 'Street': '17900 Ocean Dr SPC 57', 'City': 'FortBragg', 'State': 'CA', 'Zip_code': '95437', 'Bed': '3', 'Bath': '2', 'Square_Feet': '1,020', 'House_type': 'Apartment', 'Year_build': '1976', 'Zestimate': 'None', 'Zillow_price/sqft': '$44', 'House_website': 'https://www.zillow.com/homedetails/17900-Ocean-Dr-SPC-57-Fort-Bragg-CA-95437/2083772680_zpid/'}, {'Listing_type': 'For sale by owner', 'Price': '$3,100,000', 'Full_address': '706 W 29th St, San Pedro, CA 90731', 'Street': '706 W 29th St', 'City': 'SanPedro', 'State': 'CA', 'Zip_code': '90731', 'Bed': '3', 'Bath': '3', 'Square_Feet': '2,350', 'House_type': 'Apartment', 'Year_build': '1958', 'Zestimate': 'None', 'Zillow_price/sqft': '$1,319', 'House_website': 'https://www.zillow.com/homedetails/706-W-29th-St-San-Pedro-CA-90731/21313169_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$519,000', 'Full_address': '319 321 Tahoe Ave, Roseville, CA 95678', 'Street': '319 321 Tahoe Ave', 'City': 'Roseville', 'State': 'CA', 'Zip_code': '95678', 'Bed': '4', 'Bath': '3', 'Square_Feet': '1,996', 'House_type': 'Apartment', 'Year_build': '1937', 'Zestimate': 'None', 'Zillow_price/sqft': '$260', 'House_website': 'https://www.zillow.com/homedetails/319-321-Tahoe-Ave-Roseville-CA-95678/2082477067_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$529,000', 'Full_address': '130 130.5 Nevada Ave, Roseville, CA 95678', 'Street': '130 130.5 Nevada Ave', 'City': 'Roseville', 'State': 'CA', 'Zip_code': '95678', 'Bed': '4', 'Bath': '2', 'Square_Feet': '2,042', 'House_type': 'Apartment', 'Year_build': '1933', 'Zestimate': 'None', 'Zillow_price/sqft': '$259', 'House_website': 'https://www.zillow.com/homedetails/130-130-5-Nevada-Ave-Roseville-CA-95678/2082477068_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$750,000', 'Full_address': '6910 6912 Folsom Oaks Ct, Granite Bay, CA 95746', 'Street': '6910 6912 Folsom Oaks Ct', 'City': 'GraniteBay', 'State': 'CA', 'Zip_code ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#    Bath     Bed               City  \
# 0     3       3         SantaMaria
# 1     6  Studio           Carlsbad
# 2    --  Studio         LosAngeles
# 3     4       6     NorthHighlands
# 4     2       3          FortBragg
# 5     3       3           SanPedro
# 6     3       4          Roseville
# 7     2       4          Roseville
# 8     4       4         GraniteBay
# 9     2       2         DiamondBar
# 10    3       5         Sacramento
# 11  2.5       3    RanchoCucamonga
# 12   --  Studio         PlumasLake
# 13    1       3         Ridgecrest
# 14    2       4      RanchoCordova
# 15    4       2         Sacramento
# 16    3       2         LosAngeles
# 17    4       4         Sacramento
# 18    4       4         NHollywood
# 19    3       2  SanJuanCapistrano
# 20    2       2      WestHollywood
# 21    1       1              Indio
# 22    2       3         LosAngeles
# 23    1       1        WoodlandHls
# 24    6       4             Kyburz
# 25    2       3           FairOaks
# 26    2       3         Sacramento
# 27    4       6      RanchoCordova
# 28    8      12      RanchoCordova
# 29    4       6        YuccaValley
# 30    4       5             Auburn
# 31   16      14        SantaMonica
#
#                                          Full_address House_type  \
# 0        1700 Lynne Dr UNIT 52, Santa Maria, CA 93454  Apartment
# 1               3570 Camino Arena, Carlsbad, CA 92009  Apartment
# 2           444 N Sycamore Ave, Los Angeles, CA 90036  Apartment
# 3     4025 4027 Renick Way, North Highlands, CA 95660  Apartment
# 4         17900 Ocean Dr SPC 57, Fort Bragg, CA 95437  Apartment
# 5                  706 W 29th St, San Pedro, CA 90731  Apartment
# 6              319 321 Tahoe Ave, Roseville, CA 95678  Apartment
# 7           130 130.5 Nevada Ave, Roseville, CA 95678  Apartment
# 8     6910 6912 Folsom Oaks Ct, Granite Bay, CA 95746  Apartment
# 9   22852 Hilton Head Dr UNIT 164, Diamond Bar, CA...  Apartment
# 10                    1701 P St, Sacramento, CA 95811  Apartment
# 11  11221 Terra Vista Pkwy APT D, Rancho Cucamonga...  Apartment
# 12     2233 Sheridan Ranch Cir, Plumas Lake, CA 95961  Apartment
# 29  https://www.zillow.com/homedetails/7354-Joshua...   For sale by owner
# 30  https://www.zillow.com/homedetails/15691-Lake-...  Apartment for sale
# 31  https://www.zillow.com/homedetails/941-10th-St...  Apartment for sale
#
#          Price Square_Feet State                          Street Year_build  \
# 0     $278,000       1,226    CA           1700 Lynne Dr UNIT 52       1979
# 1   $2,099,000       4,868    CA               3570 Camino Arena       2000
# 2   $3,975,000       7,220    CA              444 N Sycamore Ave       1928
# 3     $394,000       2,116    CA            4025 4027 Renick Way       1979
# 4      $45,000       1,020    CA           17900 Ocean Dr SPC 57       1976
# 5   $3,100,000       2,350    CA                   706 W 29th St       1958
# 6     $519,000       1,996    CA               319 321 Tahoe Ave       1937
# 7     $529,000       2,042    CA            130 130.5 Nevada Ave       1933
# 8     $750,000       2,214    CA        6910 6912 Folsom Oaks Ct       1977
# 9     $335,000         934    CA   22852 Hilton Head Dr UNIT 164       1981
# 10    $825,000       2,474    CA                       1701 P St       1890
# 11    $412,000       1,417    CA    11221 Terra Vista Pkwy APT D       1994
# 12    $450,000       2,439    CA         2233 Sheridan Ranch Cir       2003
# 13     $50,000       1,015    CA                   309 Sahara Dr       1954
# 14    $395,000       1,600    CA     10300 10302 S White Rock Rd       1962
# 15    $675,000       2,238    CA                     931 36th St       1923
# 16  $1,150,000       1,730    CA     6250 Hollywood Blvd UNIT 8N       2009
# 17    $975,000       2,216    CA                    1115 22nd St       1919
# 18  $1,200,000         600    CA          5225 Satsuma Ave APT 4    No Data
# 19    $579,900       1,680    CA          27062 Via Cocida APT A       1964
# 20  $1,299,999       1,679    CA  1155 N La Cienega Blvd APT 202       1964
# 21    $149,999         720    CA          44260 Monroe St APT 46       1979
# 22  $1,570,000       1,776    CA                 624 S Orange Dr       1920
# 23    $300,000         599    CA     22100 Burbank Blvd UNIT 218       1979
# 24    $580,000       9,490    CA                13672 Highway 50       1930
# 25    $325,000       1,657    CA               4841 San Juan Ave       1955
# 26    $299,000       1,796    CA                  1536 South Ave       1945
# 27    $425,000       2,134    CA          10301 Mills Station Rd       1972
# 28    $850,000       4,268    CA          10303 Mills Station Rd       1972
# 29    $345,000       2,432    CA                  7354 Joshua Ln       1957
# 30    $750,000       2,250    CA            15691 Lake Arthur Rd       1940
# 31  $5,500,000       8,738    CA                     941 10th St       1965
#
#      Zestimate Zillow_price/sqft Zip_code
# 0     $271,034              $227    93454
# 1         None              $431    92009
# 2   $3,975,883              $551    90036
# 3         None              $186    95660
# 4         None               $44    95437
# 5         None            $1,319    90731
# 6         None              $260    95678
# 7         None              $259    95678
# 8         None              $339    95746
# 9         None              $359    91765
# 10        None              $333    95811
# 11        None              $291    91730
# 12    $412,070              $185    95961
# 13        None               $49    93555
# 14        None              $247    95670
# 15        None              $302    95816
# 16        None              $665    90028
# 17        None              $440    95816
# 18        None            $2,000    91601
# 19        None              $345    92675
# 20  $1,299,943              $774    90069
# 21        None              $208    92201
# 22        None              $884    90036
# 23        None              $501    91367
# 24        None               $61    95720
# 25        None              $196    95628
# 26        None              $166    95838
# 27        None              $199    95670
# 28        None              $199    95670
# 29        None              $142    92284
# 30        None              $333    95602
# 31        None              $629    90403

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Q4-2019_Apartment_page1.csv", index=False, header=True)
