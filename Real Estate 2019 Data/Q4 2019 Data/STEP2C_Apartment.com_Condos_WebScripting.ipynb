# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
# Testing 2
for page in range(1,2):
    link = 'https://www.apartments.com/condos/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='prosumer placard')

    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        pprint(new_results)
# Out:
# <div class="mainWrapper">
# <div class="profileHeaderWrapper profileHeaderProsumerWrapper js-profileHeaderStickyWrapper" id="profileHeaderWrapper">
# <header class="hasBackToResults mainHeader" id="mainHeader">
# <nav class="mainHeaderNavigation" id="mainHeaderNavigation">
# <div class="backToResultsSection">
# <a class="backToResults" href="https://www.apartments.com/condos/glendale-ca/" id="backToResults">
# <i class="leftArrowIcon"></i>
# <span class="mapText">Map</span>
# </a>
# </div>
# <div class="menuSection">
# <button class="dropdownToggle primary homeBtn" id="headerMenuLink" type="button">
# <i class="hamburgerIcon"></i><span>Menu</span>
# </button>
# <div class="menuNavWrapper" id="menuNavWrapper">
# <div id="menuNavContainer">
# <div class="menuOpenWrapper">
# <span class="menuHeader" id="menuHeader"><i class="hamburgerIcon"></i><span class="menuText">Menu</span></span>
# <ul class="menuNavigation" id="menuNavigation">
# <li>
# <a class="expandable" data-requirelogin="false" href="#">Renter Tools<i class="profileCarouselArrowRightIcon"></i></a>
# <ul class="submenu tools">
# <li><a href="https://www.apartments.com/my-account/#FavoriteListings">Favorites</a></li>
# <li><a href="https://www.apartments.com/my-account/#SavedSearches">Saved Searches</a></li>
# </ul>
# </li>
# <li id="menuNavLnkUserNotificationSettings">
# <a href="https://www.apartments.com/customers/" rel="nofollow">Customer Tools</a>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/">Apartments For Rent<i class="profileCarouselArrowRightIcon"></i><i class="viewMoreIcon"></i></a>
# <ul class="submenu properties">
# <li><a href="https://www.apartments.com/austin-tx/">Austin Apartments</a></li>
# <li><a href="https://www.apartments.com/boston-ma/">Boston Apartments</a></li>
# <li><a href="https://www.apartments.com/charlotte-nc/">Charlotte Apartments</a></li>
# <li><a href="https://www.apartments.com/chicago-il/">Chicago Apartments</a></li>
# <li><a href="https://www.apartments.com/houston-tx/">Houston Apartments</a></li>
# <li><a href="https://www.apartments.com/las-vegas-nv/">Las Vegas Apartments</a></li>
# <li><a href="https://www.apartments.com/los-angeles-ca/">Los Angeles Apartments</a></li>
# <li><a href="https://www.apartments.com/new-york-ny/">New York City Apartments</a></li>
# <li><a href="https://www.apartments.com/san-diego-ca/">San Diego Apartments</a></li>
# <li><a href="https://www.apartments.com/seattle-wa/">Seattle Apartments</a></li>
# </ul>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/houses/">Homes For Rent<i class="profileCarouselArrowRightIcon"></i><i class="viewMoreIcon"></i></a>
# <ul class="submenu properties">
# <li><a href="https://www.apartments.com/houses/charlotte-nc/">Charlotte Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/dallas-tx/">Dallas Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/fresno-ca/">Fresno Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/houston-tx/">Houston Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/louisville-ky/">Louisville Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/memphis-tn/">Memphis Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/nashville-tn/">Nashville Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/phoenix-az/">Phoenix Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/san-antonio-tx/">San Antonio Houses for Rent</a></li>
# <li><a href="https://www.apartments.com/houses/tampa-fl/">Tampa Houses for Rent</a></li>
# </ul>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/condos/">Condos For Rent<i class="profileCarouselArrowRightIcon"></i><i class="viewMoreIcon"></i></a>
# <ul class="submenu properties">
# <li><a href="https://www.apartments.com/condos/atlanta-ga/">Atlanta Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/charlotte-nc/">Charlotte Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/chicago-il/">Chicago Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/houston-tx/">Houston Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/jacksonville-fl/">Jacksonville Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/las-vegas-nv/">Las Vegas Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/miami-fl/">Miami Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/nashville-tn/">Nashville Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/orlando-fl/">Orlando Condos for Rent</a></li>
# <li><a href="https://www.apartments.com/condos/san-diego-ca/">San Diego Condos for Rent</a></li>
# </ul>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/townhomes/">Townhomes For Rent<i class="profileCarouselArrowRightIcon"></i><i class="viewMoreIcon"></i></a>
# <ul class="submenu properties">
# <li><a href="https://www.apartments.com/townhomes/atlanta-ga/">Atlanta Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/charlotte-nc/">Charlotte Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/dallas-tx/">Dallas Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/denver-co/">Denver Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/houston-tx/">Houston Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/jacksonville-fl/">Jacksonville Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/nashville-tn/">Nashville Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/omaha-ne/">Omaha Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/raleigh-nc/">Raleigh Townhomes for Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/san-antonio-tx/">San Antonio Townhomes for Rent</a></li>
# </ul>
# </li>
# <li>
# <a data-requirelogin="false" href="https://helpcenter.apartments.com" id="menuNavHelpCenter" target="_blank">Help Center</a>
# </li>
# <li>
# <a data-requirelogin="false" href="https://www.apartments.com/mobile/" id="menuNavLnkMobileApps" target="_blank">Mobile Apps</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="headerSwitchLanguageWrapper">
# <a class="headerSwitchLanguage" data-culture="es-US" data-url="https://www.apartments.com/es/1935-alpha-rd-glendale-ca-unidad-341/l8ghtqd/" href="https://www.apartments.com/es/1935-alpha-rd-glendale-ca-unidad-341/l8ghtqd/" title="Español"><i class="worldIcon"></i>Español</a>
# </div>
# <div class="logoSpacer"></div>
# <div class="logo">
# <a href="https://www.apartments.com/">
# <img alt="Apartments.com Logo" src="/a/4d9af0/content/images/apartments-for-rent-logo.png"/>
# </a>
# </div>
# <div class="loginPrevNextWrapper">
# <div class="loginSection" id="headerLoginSection">
# <a class="js-headerSignUp headerSignUp" href="javascript:void(0);" title="Sign Up">Sign Up</a>
# <span>/</span>
# <a class="js-headerSignin headerSignIn" href="javascript:void(0);" title="Sign In">Sign In</a>
# </div>
# </div>
# </nav>
# </header>
# <header class="propertyHeader prosumer " id="propertyHeader">
# <div class="propertyInformationColumn">
# <div class="propertyLocation">
# <div class="propertyNameRow">
# <h1 class="propertyName">
#                         1935 Alpha Rd Unit 341
#                     </h1>
# </div>
# <div class="propertyAddressRow">
# <div class="propertyAddress">
# <h2>
# <span>Glendale</span>,
#                             <span>CA</span>
# <span>91208</span>
# </h2>
# <div class="neighborhoodAddress">
# <span class="neighborhood">–</span>
# <a class="neighborhood" href="https://www.apartments.com/condos/verdugo-woodlands-glendale-ca/">Verdugo Woodlands</a>
# </div>
# </div>
# </div>
# </div>
# <div class="favoriteBox">
# <a class="heartOutlineIcon neutral js-propertyHeaderFavorite" href="javascript:void(0);" icon-position="right"></a>
# </div>
# </div>
# <div class="leadColumn">
# <div class="leadColumnContainer">
# <div class="leadGen">
# <a class="primary js-checkAvailability" href="javascript:void(0)" rel="nofollow" role="button" title="Contact Property">
# <i class="emailIcon"></i>
# <span class="contact">Contact</span>
# </a>
# <span class="phoneNumber">
# <i class="phoneIcon"></i>
# <span>213-348-5117</span>
# </span>
# </div>
# </div>
# </div>
# </header>
# <div class="rentRollupsWrapper screen">
# <div class="rentRollups" id="rentRollups">
# <div class="rentRollupContainer">
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
#                         $2,100
#                     </span>
# <div class="leadFavScamContainer">
# <div class="prosumerLeadPhone">
# <i class="phoneIcon"></i>
# <span>213-348-5117</span>
# </div>
# <div class="prosumerLeadEmail">
# <a class="checkAvailability js-checkAvailabilityModified" href="javascript:void(0)" rel="nofollow" role="button" title="Contact Property">
# <i class="emailIcon"></i>
# </a>
# </div>
# <div class="prosumerFavoriteBox">
# <a class="heartOutlineIcon neutral js-propertyHeaderFavorite" href="javascript:void(0);" icon-position="right"></a>
# </div>
# <div class="prosumerFlag">
# <a class="prosumerflagButton js-openFlagModal" href="javascript:void(0);"><i class="flagIcon"></i></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <main data-listingid="l8ghtqd">
# <section class="profileApp" id="profileApp">
# <div class="profileAppWrapper prosumer" id="profileWrapper">
# <div class="profileProsumer clearfix" id="profileProsumer">
# <aside class="contactLead" id="contactLead">
# <div class="lead-form-container">
# <div class="inlineDlfWrapper" id="inlineDlfWrapper">
# <div class="contactLeadWrapper " id="contactLeadForm">
# <input id="DlfConfiguration" type="hidden" value='{"DynamicLeadFormId":0,"DynamicLeadFormType":0,"ListingId":0,"HasContactVia":false,"HasMaxRent":false,"HasBedsBaths":false,"HasReasonForMoving":false,"IsPhoneRequired":false,"IsContactViaRequired":false,"IsMaxRentRequired":false,"IsBedsRequired":false,"IsReasonForMovingRequired":false,"HasOnlineScheduling":false,"HasCustomHours":false,"OnlineSchedulingProviderType":0}'/>
# <header class="property-title-header">
# <h3>
# <i class="phoneTransparentIcon"></i>
# <span class="contactPhone" id="ctn">213-348-5117</span>
# </h3>
# </header>
# <div class="contactForm" id="contactForm">
# <div class="cell-xs-6 first-input">
# <label class="input-label">First Name *</label>
# <input class="contactFormFirstName input-override" id="contactFormFirstName" type="text"/>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Last Name *</label>
# <input class="contactFormLastName input-override" id="contactFormLastName" type="text"/>
# </div>
# <div class="cell-xs-12">
# <label class="input-label">Email Address *</label>
# <input class="contactFormEmail input-override" id="contactFormEmail" type="email"/>
# </div>
# <div class="cell-xs-6 first-input calendar-input-wrapper">
# <div class="calendar-input moveIn-calendar-input" id="MoveInDateContainer">
# <label class="input-label">Move-in Date *</label>
# <i class="calendarOutlineIcon"></i>
# <input class="contactFormMoveInDate input-override" id="MoveInDate" placeholder="Move-in Date *" type="text" value="11/01/2019">
# </input></div>
# </div>
# <div class="cell-xs-6 last-input phone-input-wrapper">
# <label class="input-label">Phone</label>
# <input class="contactFormPhoneNumber input-override" id="phone" placeholder="" type="tel" value=""/>
# </div>
# <div class="cell-xs-12 preference-wrapper" id="preference-wrapper">
# <h4>I would like to...</h4>
# <div class="checkbox-section">
# <input class="primaryCheckbox schedule-tour" id="schedule-tour-inline" type="checkbox"/>
# <label for="schedule-tour-inline" title="Schedule a Tour">
# <span>Schedule a Tour</span>
# </label>
# <input class="primaryCheckbox fill-out-application" id="fill-out-application-inline" type="checkbox"/>
# <label for="fill-out-application-inline" title="Request Application">
# <span>Request Application</span>
# </label>
# <input class="primaryCheckbox confirm-availability" id="confirm-availability-inline" type="checkbox"/>
# <label for="confirm-availability-inline" title="Confirm Availability">
# <span>Confirm Availability</span>
# </label>
# <input class="primaryCheckbox custom-message" id="custom-message-inline" type="checkbox"/>
# <label for="custom-message-inline" title="Custom Message">
# <span>Custom Message</span>
# </label>
# <div class="cell-xs-12 contactFormMessageWrapper">
# <label class="input-label full-label">Message</label>
# <span class="counter-wrapper">
# <span id="contactFormMessageCounter"></span>
# </span>
# <textarea class="contactFormMessage input-override" id="contactFormMessage" maxlength="400" placeholder=""></textarea>
# </div>
# </div>
# </div>
# <div class="cell-xs-12 submitError">
# <input id="submitGeneralError" type="hidden">
# </input></div>
# <a class="primary contactFormAction" href="javascript:void(0);" id="contactFormAction">
# <span class="default-send-title">Send Message</span>
# </a>
# <div class="email-listing-checkbox">
# <input checked="" class="optin primaryCheckbox emailListings" id="emailListingsInline" type="checkbox">
# <label class="emailListingsLabel" for="emailListingsInline">
# <span class="emailListing">Email me listings and apartment related info.</span>
# </label>
# </input></div>
# </div>
# </div>
# </div>
# <div id="submitSpinnerModalWrapper">
# <div class="submitRequestSpinner fade modalContainer" data-backdrop="static" id="submitRequestSpinner">
# <div class="spinner"></div>
# <p>Submitting Request</p>
# </div>
# </div>
# <div id="successModalWrapper">
# <div class="fade out successModal modalContainer" data-backdrop="static" id="successModal">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3 id="successModalHeader">Thank You</h3>
# <p class="message" id="successModalMsg">Thank you! Your email has been sent.</p>
# </div>
# </div>
# </div>
# </aside>
# <div class="profileContent">
# <span class="lastUpdated">
# <i class="rotateRightIcon" title="Last Updated"></i>
# <span>Today</span>
# </span>
# <div class="mapNavBreadcrumb" id="mapNavBreadcrumb">
# <div class="crumbs" id="breadcrumbs-container">
# <span class="crumb">
# <a data-type="condos" href="https://www.apartments.com/condos/" title="Condos">Condos</a>
# </span>
# <span class="crumb">
# <a data-type="state" href="https://www.apartments.com/condos/ca/" title="California">California</a>
# </span>
# <span class="crumb">
# <a data-type="city" href="https://www.apartments.com/condos/glendale-ca/" title="Glendale">Glendale</a>
# </span>
# <span>1935 Alpha Rd Unit 341</span>
# </div>
# </div>
# <div id="profileMediaViewer">
# <div class="profileMediaViewerWrapper fade modal" id="profileMediaViewerWrapper">
# <div class="header">
# <div class="propertyName">
# <span>
#                 1935 Alpha Rd |
#             </span>
# </div>
# <span class="propertyPhoneNumber">
#             213-348-5117
#         </span>
# <a class="checkAvailability js-checkavailability" href="javascript:void(0);" rel="nofollow" role="button">
# <span>
# <i class="emailIcon"></i>
#                 Contact Property
#             </span>
# </a>
# <div class="headerUtilities" id="headerUtilities">
# <span class="viewToggle active" id="gridToggle">
# <a data-modeid="0" href="javascript:void(0);">
# <i class="gridIcon" data-modeid="0"></i>
#                     Gallery
#                 </a>
# </span>
# <span class="viewToggle" id="singleViewToggle">
# <a data-modeid="1" href="javascript:void(0);">
# <i class="singleViewIcon" data-modeid="1"></i>
#                     Single View
#                 </a>
# </span>
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# </div>
# </div>
# <div class="viewerContent" id="viewerContent">
# <div class="singleGalleryWrapper active" id="singleGalleryWrapper">
# <div class="singleGalleryContent" id="singleGalleryContent" style="visibility: hidden"></div>
# </div>
# <div class="gridGalleryWrapper" id="gridGalleryWrapper">
# <div class="gridGalleryContent" data-bind="with: mediaViewer" id="gridGalleryContent">
# <div class="nano nano-fixed">
# <ul class="nano-content">
# <!-- ko foreach: attachments -->
# <li>
# <div class="gridImageWrapper aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <!-- ko if: $data.MediaType === 3 || $data.MediaType === 4 -->
# <button class="videoPlayIconLarge" data-bind="attr: {'data-attachmentid': Id}" type="button"></button>
# <!-- /ko -->
# <div class="aspectRatioImage" data-bind="style: {backgroundImage: 'url(' + Uri + ')'}, attr: {'data-attachmentid': Id, 'data-tabid': $index}">
# <img class="gridImage" data-bind="attr: {src: Uri}">
# </img></div>
# <span class="description" data-bind="text: Caption"></span>
# </div>
# </div>
# </li>
# <!-- /ko -->
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="carouselSection carousel hasProvider" id="carouselSection">
# <div class="navigationControl">
# <button class="leftNav js-leftNav"><i class="profileCarouselArrowLeftIcon"></i></button>
# <button class="rightNav js-rightNav"><i class="profileCarouselArrowRightIcon"></i></button>
# </div>
# <ul class="carouselContent js-carouselContent">
# <li class="item active" data-image-idx="0">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="1" data-attachmenttypeid="3" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/-I22kafkzM66dhI4yeG4Hxh_KXONS1KZociis6nYoX0/111/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg');">
# <img alt="inside the complex - 1935 Alpha Rd" src="https://images1.apartments.com/i2/-I22kafkzM66dhI4yeG4Hxh_KXONS1KZociis6nYoX0/111/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">inside the complex</span>
# </li>
# <li class="item " data-image-idx="1">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="2" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/NQ_OG4EfiobNwdJ9Xh6bJg19wjlThUDByp59XHJVXgI/117/1935-alpha-rd-unit-341-glendale-ca-front-gate.jpg');">
# <img alt="Front gate - 1935 Alpha Rd" src="https://images1.apartments.com/i2/NQ_OG4EfiobNwdJ9Xh6bJg19wjlThUDByp59XHJVXgI/117/1935-alpha-rd-unit-341-glendale-ca-front-gate.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Front gate</span>
# </li>
# </ul>
# <ul class="carouselImages" id="fullCarouselCollection">
# <li class="item" data-image-idx="0">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="1" data-attachmenttypeid="3" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/-I22kafkzM66dhI4yeG4Hxh_KXONS1KZociis6nYoX0/111/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg');">
# <img alt="inside the complex - 1935 Alpha Rd" src="https://images1.apartments.com/i2/-I22kafkzM66dhI4yeG4Hxh_KXONS1KZociis6nYoX0/111/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">inside the complex</span>
# </li>
# <li class="item" data-image-idx="1">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="2" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/NQ_OG4EfiobNwdJ9Xh6bJg19wjlThUDByp59XHJVXgI/117/1935-alpha-rd-unit-341-glendale-ca-front-gate.jpg');">
# <img alt="Front gate - 1935 Alpha Rd" src="https://images1.apartments.com/i2/NQ_OG4EfiobNwdJ9Xh6bJg19wjlThUDByp59XHJVXgI/117/1935-alpha-rd-unit-341-glendale-ca-front-gate.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Front gate</span>
# </li>
# <li class="item" data-image-idx="2">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="3" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/r9-LCnJ-sNdu8WTO5RjKq5-fJr_Km3QujYY_6yojFLo/117/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg');">
# <img alt="inside the complex - 1935 Alpha Rd" src="https://images1.apartments.com/i2/r9-LCnJ-sNdu8WTO5RjKq5-fJr_Km3QujYY_6yojFLo/117/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">inside the complex</span>
# </li>
# <li class="item" data-image-idx="3">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="4" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/6Yj0E04yo9Vy0ee08fEQnC5s3zCDbWkfPlRGT-0zhwA/117/1935-alpha-rd-unit-341-glendale-ca-pool-area.jpg');">
# <img alt="Pool area - 1935 Alpha Rd" src="https://images1.apartments.com/i2/6Yj0E04yo9Vy0ee08fEQnC5s3zCDbWkfPlRGT-0zhwA/117/1935-alpha-rd-unit-341-glendale-ca-pool-area.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Pool area</span>
# </li>
# <li class="item" data-image-idx="4">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="5" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/myqVKPMlf_qqEW21FR8FboY2ii-QNyaswULEqt82Wnw/117/1935-alpha-rd-unit-341-glendale-ca-pool-jacuzzie.jpg');">
# <img alt="pool jacuzzie - 1935 Alpha Rd" src="https://images1.apartments.com/i2/myqVKPMlf_qqEW21FR8FboY2ii-QNyaswULEqt82Wnw/117/1935-alpha-rd-unit-341-glendale-ca-pool-jacuzzie.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">pool jacuzzie</span>
# </li>
# <li class="item" data-image-idx="5">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="6" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/CFQ5IA8SUoEA9RlRlmT2cJBVfIyRguc9hbekoWqHrDU/117/1935-alpha-rd-unit-341-glendale-ca-living-room.jpg');">
# <img alt="Living room - 1935 Alpha Rd" src="https://images1.apartments.com/i2/CFQ5IA8SUoEA9RlRlmT2cJBVfIyRguc9hbekoWqHrDU/117/1935-alpha-rd-unit-341-glendale-ca-living-room.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Living room</span>
# </li>
# <li class="item" data-image-idx="6">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="7" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/9RhvPuug7GuZ7PD1GY801t0x19AEYv9XstWPw86zA8U/117/1935-alpha-rd-unit-341-glendale-ca-balcony-left.jpg');">
# <img alt="Balcony-Left - 1935 Alpha Rd" src="https://images1.apartments.com/i2/9RhvPuug7GuZ7PD1GY801t0x19AEYv9XstWPw86zA8U/117/1935-alpha-rd-unit-341-glendale-ca-balcony-left.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Balcony-Left</span>
# </li>
# <li class="item" data-image-idx="7">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="8" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/WjC1n5rVdqCQjl44uQCTVyRVPe3vhBToC5vAedQ23gQ/117/1935-alpha-rd-unit-341-glendale-ca-balcony-right.jpg');">
# <img alt="Balcony-Right - 1935 Alpha Rd" src="https://images1.apartments.com/i2/WjC1n5rVdqCQjl44uQCTVyRVPe3vhBToC5vAedQ23gQ/117/1935-alpha-rd-unit-341-glendale-ca-balcony-right.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Balcony-Right</span>
# </li>
# <li class="item" data-image-idx="8">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="9" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/knBnRaMxYscnEd-yWSLtuaTvfL65VoILiqktPoskqtQ/117/1935-alpha-rd-unit-341-glendale-ca-bedroom.jpg');">
# <img alt="Bedroom - 1935 Alpha Rd" src="https://images1.apartments.com/i2/knBnRaMxYscnEd-yWSLtuaTvfL65VoILiqktPoskqtQ/117/1935-alpha-rd-unit-341-glendale-ca-bedroom.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Bedroom</span>
# </li>
# <li class="item" data-image-idx="9">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="10" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/Uk0Rzf3SIkZrE6waX1LPZ1iN59iZkGyVQq9QnAjjQSU/117/1935-alpha-rd-unit-341-glendale-ca-bathroom.jpg');">
# <img alt="Bathroom - 1935 Alpha Rd" src="https://images1.apartments.com/i2/Uk0Rzf3SIkZrE6waX1LPZ1iN59iZkGyVQq9QnAjjQSU/117/1935-alpha-rd-unit-341-glendale-ca-bathroom.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Bathroom</span>
# </li>
# <li class="item" data-image-idx="10">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="11" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/zQ2GzZpQVm2FpgpX0CDnnddh2JILin9Kj_HEO569tnk/117/1935-alpha-rd-unit-341-glendale-ca-laundrydryer.jpg');">
# <img alt="Laundry/Dryer - 1935 Alpha Rd" src="https://images1.apartments.com/i2/zQ2GzZpQVm2FpgpX0CDnnddh2JILin9Kj_HEO569tnk/117/1935-alpha-rd-unit-341-glendale-ca-laundrydryer.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Laundry/Dryer</span>
# </li>
# <li class="item" data-image-idx="11">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="12" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/EAr3c0Fk2Jz5FBkfMZv9mc8NSJ3-vzTX9UQh67JZzUI/117/1935-alpha-rd-unit-341-glendale-ca-pool-jacuzzi.jpg');">
# <img alt="Pool-Jacuzzi - 1935 Alpha Rd" src="https://images1.apartments.com/i2/EAr3c0Fk2Jz5FBkfMZv9mc8NSJ3-vzTX9UQh67JZzUI/117/1935-alpha-rd-unit-341-glendale-ca-pool-jacuzzi.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <span class="caption">Pool-Jacuzzi</span>
# </li>
# <li class="item" data-image-idx="12">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="13" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/7iQUpUH_xUofYIYYEPyZGhe2B3KQNCCHYsxpzDFS0-A/117/1935-alpha-rd-unit-341-glendale-ca-building-photo.jpg');">
# <img alt="Building Photo - 1935 Alpha Rd" src="https://images1.apartments.com/i2/7iQUpUH_xUofYIYYEPyZGhe2B3KQNCCHYsxpzDFS0-A/117/1935-alpha-rd-unit-341-glendale-ca-building-photo.jpg"/>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </section>
# <section class="carouselSection carousel prosumer print">
# <div class="row carouselContent">
# <div class="carouselColumn col-50">
# <div class="carouselItem">
# <div class="imageContainer">
# <img src="https://images1.apartments.com/i2/-I22kafkzM66dhI4yeG4Hxh_KXONS1KZociis6nYoX0/111/1935-alpha-rd-unit-341-glendale-ca-inside-the-complex.jpg"/>
# </div>
# </div>
# </div>
# <div class="carouselColumn col-50">
# <div class="carouselItem">
# <div class="imageContainer">
# <img src="https://images1.apartments.com/i2/NQ_OG4EfiobNwdJ9Xh6bJg19wjlThUDByp59XHJVXgI/117/1935-alpha-rd-unit-341-glendale-ca-front-gate.jpg"/>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section id="listingProviderWrapper">
# <p>Listing provided by</p>
# <img class="providerLogo" src="/a/0a7270/content/images/wsr-logo.svg"/>
# </section>
# <section class="availabilitySection js-viewAnalyticsSection" data-analytics-name="unit_mix_grid" id="availabilitySection">
# <div class="js-expandableContainer expandableContainer">
# <table class="availabilityTable basic oneRental">
# <tbody>
# <tr class="oneRental">
# <th>Beds</th>
# <th>Baths</th>
# <th>Rent</th>
# <th class="depositHeading ">Deposit</th>
# <th>Unit #</th>
# <th>Sq Ft</th>
# <th class="leaseLengthHeading">Lease Length</th>
# <th></th>
# <th>Available</th>
# </tr>
# <tr class="rentalGridRow bold first" data-baths="1" data-beds="1" data-maxrent="2100" data-model="" data-rentalkey="xnrhc6p" data-rentaltype="2" data-unit="341">
# <td class="beds">
# <span class="longText">
#             1 Bedroom
#         </span>
# <span class="mediumText">
#             1 Bed
#         </span>
# <span class="shortText">
#             1 BR
#         </span>
# </td>
# <td class="baths">
# <span class="longText">
#             1 Bathroom
#         </span>
# <span class="mediumText">
#             1 Bath
#         </span>
# <span class="shortText">
#             1 BA
#         </span>
# </td>
# <td class="rent">
#         $2,100
#     </td>
# <td class="deposit ">$2,100 </td>
# <td class="unit ">341</td>
# <td class="sqft">700 Sq Ft</td>
# <td class="leaseLength">12 Month Lease</td>
# <td class="name collapsed"></td>
# <td class="available">
#         Available Now
#     </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="disclaimer">Prices and availability subject to change without notice.</div>
# </section>
# <section class="descriptionSection js-viewAnalyticsSection" data-analytics-name="about" id="descriptionSection">
# <h3>About 1935 Alpha Rd Glendale, CA 91208</h3>
# <p>Dreamy one bedroom ( its an absolute Paradise)
# We can always change the inside for you, but you never can change the outside
# Location- Location - Location
# 1. Top floor (Finally no one walks over you..!), Everything NEW,
# 2. Brand New sterling hardwood floor, car covered Parking. storage for all your extras,
# 3. Side by side refrigerator, near corner unit, Gated community, best unit in the complex by far......
# 4. Hilltop, surrounded by mountains, breathe fresh air 24/7
# 5. North of Glendale near city of Montrose, extremely Safe/Green/Quiet/Romantic &amp; Private
# 6. Finally no noise of Cars, Planes, Trains, Ambulance, Motorcycle etc., dead-end Street.
# 7. Gorgeous view of the forest, breakfast/dinner in the balcony is heaven..!
# 8. Private road, Pool, Jacuzzi, sauna, Gym, laundry machine, 110% privacy
# 9. Ten min to downtown LA, ABC,NBC, or JPL, 5 min to GCC, or to shops in City of Montrose.
# 10. Excellent for Artists, poets/writers, Graduates, Retires. managers, if you are working at home.
# 11. New kitchen, new cooktop, new dishwasher, new oven, new shower door, new GD, new A/C ,
#      new bathroom/kitchen countertop, ... new paint plus more.....
# 12. Enjoy life among civilized people, the trees, birds &amp; deer Enjoy fruits in the complex like fig,
#      apricot, loquat, etc...
# Like a good movie, it's a must see. Zestimate price by Zillow.com is $1950.00/month
# Even if He / She didn't treat you well.............!!
# Don't worry we treat you like a family...!
# Enjoy life while you may............!!</p>
# </section>
# <section class="amenitiesSection anchorBuffer" id="amenitiesSection">
# <div class="js-viewAnalyticsSection js-viewAnalyticsSection" data-analytics-name="amenities">
# <h3>Condo Amenities</h3>
# <section class="specGroup js-specGroup">
# <div class="specList petPolicy js-spec">
# <span class="amenityCircle"><i class="petIcon"></i></span><h3>Pet Policy</h3>
# <div class="petPolicyDetails">
# <p>
# <span>Cats Allowed</span>
# </p>
# </div>
# </div>
# <div class="specList parking js-spec">
# <span class="amenityCircle"><i class="parkingIcon"></i></span><h3>Parking</h3>
# <div class="parkingDetails">
# <div class="parkingTypeFeeContainer">
# <h4>
#                             Covered
#                         </h4>
# </div>
# <p>
# </p>
# </div>
# </div>
# <div class="specList js-spec">
# <span class="amenityCircle"><i class="leaseIcon"></i></span><h3>Lease Length</h3>
# <ul>
# <li class="leaseLength">12 Months</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="servicesIcon"></i></span><h3>Services</h3>
# <ul>
# <li><span class="bullet">•</span>Laundry Facilities</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="propertyIcon"></i></span><h3>Features</h3>
# <ul>
# <li><span class="bullet">•</span>Wheelchair Accessible (Rooms)</li>
# </ul>
# </div>
# </section>
# </div>
# </section>
# <section class="contactSection js-viewAnalyticsSection" data-analytics-name="contact" id="contactSection">
# <h3>Contact</h3>
# <div class="contactContainer prosumer">
# <div class="contactInfo">
# <span class="contactCircle"><i class="userIcon"></i></span>
# <div class="agentFullName">
#                 Julie J
#             </div>
# <div class="phoneLeadFormContainer">
# <div class="phoneNumber">
# <span class="phoneIcon"></span> 213-348-5117
#                 </div>
# <div class="phoneNumberMobile">
# <a href="tel:2133485117">
# <span class="phoneIcon"></span> 213-348-5117
#                     </a>
# </div>
# <a class="checkAvailability" href="javascript:void(0);" id="contactFormAction"><i class="emailIcon"></i> Contact Property</a> </div>
# </div>
# </div>
# </section>
# <section class="schoolsSection" id="schoolsSection">
# <div class="schoolsModule" id="schoolsModule">
# </div>
# </section>
# <section class="ratings js-viewAnalyticsSection" data-analytics-name="walkscore" id="walkScoreSection">
# <h3> Walkability Near 1935 Alpha Rd Glendale, CA 91208</h3>
# <div class="ratingsInfo ratingsInfo-box">
# <div class="ratingCol walkScore" data-score="26">
# <div class="ratingsBox">
# <span class="scoreType">Walk Score<sup>®</sup></span>
# <div class="ratingsScore">
# <div class="walkIcon"></div>
# <div>
# <span class="score">26</span>
# <span class="scoreDescription">Car-Dependent</span>
# </div>
# </div>
# </div>
# </div>
# <div class="ratingCol transitScore" data-score="33">
# <div class="ratingsBox">
# <span class="scoreType">Transit Score<sup>®</sup></span>
# <div class="ratingsScore">
# <div class="commuteBusIcon"></div>
# <div>
# <span class="score">33</span>
# <span class="scoreDescription">Some Transit</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="cell-xs-12 js-viewAnalyticsSection" data-analytics-name="soundscore" id="soundScoreSection">
# <div class="cell-xs-12 soundScoreWrapper">
# <div class="cell-sm-3 cell-xs-12 soundScoreSummary">
# <div class="soundScoreTitle">SoundScore<span>™</span></div>
# <div class="soundScoreScore">-</div>
# <div class="soundScoreStatus">-</div>
# <div class="soundScoreBranding">Powered By HowLoud, Inc.</div>
# </div>
# <div class="cell-sm-6 cell-xs-12 soundScoreDetail">
# <ul class="labels">
# <li>
# <span class="amenityCircle">
# <i class="planeIcon"></i>
# </span>
# <label>Airport</label>
# <span class="ssAirportsData status">-</span>
# </li>
# <li>
# <span class="amenityCircle">
# <i class="car2Icon"></i>
# </span>
# <label>Traffic</label>
# <span class="ssTrafficData status">-</span>
# </li>
# <li>
# <span class="amenityCircle">
# <i class="propertyIcon"></i>
# </span>
# <label>Businesses</label>
# <span class="ssBusinessData status">-</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="gradient-wrapper">
# <div class="title-wrapper">
# <span></span>
# <span></span>
# <span></span>
# </div>
# <div class="gradient"></div>
# <div class="counter-wrapper">
# <span>50</span>
# <span>60</span>
# <span>70</span>
# <span>80</span>
# <span>90</span>
# <span>100</span>
# </div>
# </div>
# </section>
# <section class="subMarketSection js-viewAnalyticsSection" data-analytics-name="neighborhood" id="subMarketSection">
# <h3>Neighborhood - Verdugo Woodlands</h3>
# <div class="subMarketWrapper">
# <div class="row heroAndOverviewWrapper noHeroImage">
# <div class="col-50 heroImageWrapper">
# </div>
# <div class="col-50 overViewWrapper">
# <div class="overView">
# <p class="clamp">
# A neighborhood with a strong sense of community, Verdugo Woodlands lies about three miles northeast of downtown Glendale, California. Known for its character and ranch homes, Verdugo Woodlands has apartments for rent clustered around Verdugo Road, one of the area's main thoroughfares.<br/>
# <br/>
# Verdugo Park frequently holds events, and even on days it doesn't, the park still serves as a fun hangout spot for the entire family. Flame Broiler sits right next to the park so you can grab some Asian Fusion after a full day in the park.<br/>
# <br/>
# The fathers of children at Verdugo Elementary School throw one of the neighborhood's most popular annual events, Father's Follies. Taking place at the Dad's Club, the event features the fathers dressing in costume and performing to raise money for the local schools.<br/>
# <br/>
# </p>
# <p>
# <a class="localGuide" href="javascript:void(0);" title="Verdugo Woodlands Overview">
#                         Learn More about Verdugo Woodlands <i class="menuArrowRightIcon"></i>
# </a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mapSection js-viewAnalyticsSection" data-analytics-name="nearby_apartments_map" id="mapSection">
# <h3>These similar rentals nearby have available units.</h3>
# <div class="mapContainer" id="mapContainer">
# <div class="profileMap" data-profiletype="Prosumer" id="profileMap">
# <ul class="mapNavToolbar">
# <li id="zoomIn"><i class="mapZoomInIcon"></i></li>
# <li class="zoomOut" id="zoomOut"><i class="mapZoomOutIcon"></i></li>
# </ul>
# <div class="map-container-wrapper">
# <div class="mapInfoCardContainer" id="infoCardContainerRegion"></div>
# <div id="map-container">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="nearbySection js-viewAnalyticsSection" data-analytics-name="you_may_also_like" id="nearbySection">
# <h3>You May Also Like</h3>
# <div class="nearbyWrapper clearfix">
# <ul class="nearbyProperties">
# <li class="nearbyPropertiesItem" data-listingid="82g8221" data-profiletype="Prosumer">
# <div class="aspectRatioImageWrapper">
# <a class="nearbyProperty aspectRatioElement" href="https://www.apartments.com/1116-e-palmer-ave-glendale-ca-unit-1/82g8221/">
# <div class="aspectRatioImage nitem" data-image="https://images1.apartments.com/i2/1nSmP3Xd8Mb0mcqrASAiXsE8Efo14loY9bpD2ddkdt4/117/1116-e-palmer-ave-unit-1-glendale-ca-building-photo.jpg" title="Building Photo - 1116 E Palmer Ave"></div>
# <h4 class="nearbyCaption">
# <span class="caption"></span>
# <span class="distance">4.1 mi</span>
# </h4>
# </a>
# </div>
# </li>
# <li class="nearbyPropertiesItem" data-listingid="8mccjc3" data-profiletype="Prosumer">
# <div class="aspectRatioImageWrapper">
# <a class="nearbyProperty aspectRatioElement" href="https://www.apartments.com/629-traction-ave-los-angeles-ca-unit-304/8mccjc3/">
# <div class="aspectRatioImage nitem" data-image="https://images1.apartments.com/i2/OGYk0qJk7L6kNgkDCJ08WVaBRY9Am6bpesXvsDc74f0/117/629-traction-ave-unit-304-los-angeles-ca-building-photo.jpg" title="Building Photo - 629 Traction Ave"></div>
# <h4 class="nearbyCaption">
# <span class="caption"></span>
# <span class="distance">9.9 mi</span>
# </h4>
# </a>
# </div>
# </li>
# <li class="nearbyPropertiesItem" data-listingid="bn4qh4c" data-profiletype="Prosumer">
# <div class="aspectRatioImageWrapper">
# <a class="nearbyProperty aspectRatioElement" href="https://www.apartments.com/3645-cardiff-ave-los-angeles-ca-unit-111/bn4qh4c/">
# <div class="aspectRatioImage nitem" data-image="https://images1.apartments.com/i2/G9rNmVaoSd4xWdaQ_H7sxY0ZzTw6Hxw5kihtLviTW8I/117/3645-cardiff-ave-unit-111-los-angeles-ca-building-photo.jpg" title="Building Photo - 3645 Cardiff Ave"></div>
# <h4 class="nearbyCaption">
# <span class="caption"></span>
# <span class="distance">15.1 mi</span>
# </h4>
# </a>
# </div>
# </li>
# </ul>
# </div>
# </section>
# <section class="printPropertySection print">
# <div class="row printAmenities">
# <div class="col-100">
# <h3>Amenities</h3>
# <div class="col-25">
# <ul>
# <li>Laundry Facilities</li>
# </ul>
# </div>
# <div class="col-25">
# <ul>
# <li>Wheelchair Accessible (Rooms)</li>
# </ul>
# </div>
# <div class="col-25">
# <ul>
# </ul>
# </div>
# <div class="col-25">
# <ul>
# </ul>
# </div>
# </div>
# </div>
# <div class="row">
# </div>
# </section>
# <section class="avoidScams">
#             Protect yourself from scams. <a href="https://www.apartments.com/about/avoid-scams-and-fraud" target="_blank">Learn More</a>
# </section>
# <section class="flagSection">
# <a class="flagButton js-openFlagModal" href="javascript:void(0);"><span class="flagIcon"></span> Report an Issue</a>
# <div class="options">
# <a class="showSharingOptionsLink js-showSharingOptionsLink" href="javascript:void(0);" rel="nofollow" title="Share">
# <span class="shareIcon icon"></span>
# <span class="optionText">Share</span>
# </a>
# <a class="showPrintLink" href="javascript:void(0);" title="Print">
# <span class="printerIcon icon"></span>
# <span class="optionText">Print</span>
# </a>
# <a class="showBingDirectionsLink js-showBingDirectionsLink" href="https://www.google.com/maps/dir//1935+Alpha+Rd+Glendale+CA+91208" rel="nofollow" target="_blank" title="Directions">
# <span class="directionsIcon icon"></span>
# <span class="optionText">Directions</span>
# </a>
# </div>
# </section>
# </div>
# <div class="modalContactLead" id="modalContactLead">
# <div class="lead-form-container">
# <div class="contactLeadWrapper" id="contactLeadForm">
# <header class="property-title-header">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>
# <i class="phoneTransparentIcon"></i>
# <span class="contactPhone" id="ctn">213-348-5117</span>
# </h3>
# </header>
# <div class="contactForm" id="contactForm">
# <div class="cell-xs-6 first-input">
# <label class="input-label">First Name *</label>
# <input class="contactFormFirstName input-override" id="contactFormFirstName" type="text"/>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Last Name *</label>
# <input class="contactFormLastName input-override" id="contactFormLastName" type="text"/>
# </div>
# <div class="cell-xs-12">
# <label class="input-label">Email Address *</label>
# <input class="contactFormEmail input-override" id="contactFormEmail" type="email"/>
# </div>
# <div class="cell-xs-6 first-input calendar-input-wrapper">
# <div class="calendar-input moveIn-calendar-input" id="MoveInDateContainer">
# <label class="input-label">Move-in Date *</label>
# <i class="calendarOutlineIcon"></i>
# <input class="contactFormMoveInDate input-override" id="MoveInDate" placeholder="Move-in Date *" type="text" value="11/01/2019">
# </input></div>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Phone</label>
# <input class="contactFormPhoneNumber input-override" id="phone" placeholder="" type="tel" value=""/>
# </div>
# <div class="cell-xs-12 preference-wrapper" id="preference-wrapper">
# <h4>I would like to...</h4>
# <div class="checkbox-section">
# <input class="primaryCheckbox schedule-tour" id="schedule-tour" type="checkbox"/>
# <label for="schedule-tour" title="Schedule a Tour">
# <span>Schedule a Tour</span>
# </label>
# <input class="primaryCheckbox fill-out-application" id="fill-out-application" type="checkbox"/>
# <label for="fill-out-application" title="Request Application">
# <span>Request Application</span>
# </label>
# <input class="primaryCheckbox confirm-availability" id="confirm-availability" type="checkbox"/>
# <label for="confirm-availability" title="Confirm Availability">
# <span>Confirm Availability</span>
# </label>
# <input class="primaryCheckbox custom-message" id="custom-message" type="checkbox"/>
# <label for="custom-message" title="Custom Message">
# <span>Custom Message</span>
# </label>
# <div class="cell-xs-12 contactFormMessageWrapper">
# <label class="input-label full-label">Message</label>
# <span class="counter-wrapper">
# <span id="contactFormMessageCounter"></span>
# </span>
# <textarea class="contactFormMessage input-override" id="contactFormMessage" maxlength="400" placeholder=""></textarea>
# </div>
# </div>
# </div>
# <div class="cell-xs-12 submitError">
# <input id="submitGeneralError" type="hidden">
# </input></div>
# <a class="primary contactFormAction" href="javascript:void(0);" id="contactFormAction">
# <span class="default-send-title">Send Message</span>
# </a>
# <div class="email-listing-checkbox">
# <input checked="" class="optin primaryCheckbox emailListings" id="emailListingsPopup" type="checkbox">
# <label class="emailListingsLabel" for="emailListingsPopup">
# <span class="emailListing">Email me listings and apartment related info.</span>
# </label>
# </input></div>
# </div>
# </div>
# </div>
# <div id="submitSpinnerModalWrapper">
# <div class="submitRequestSpinner fade modalContainer" data-backdrop="static" id="submitRequestSpinner">
# <div class="spinner"></div>
# <p>Submitting Request</p>
# </div>
# </div>
# <div id="successModalWrapper">
# <div class="fade out successModal modalContainer" data-backdrop="static" id="successModal">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3 id="successModalHeader">Thank You</h3>
# <p class="message" id="successModalMsg">Thank you! Your email has been sent.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade errorModal" data-backdrop="static" id="profileErrorModal">
# <div class="modalContainer">
# <div class="modalContent">
# <div class="modalHeader">
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# <h2>Error</h2>
# </div>
# <div class="modalBody">
# <h3 class="errorTitle"></h3>
# <p class="errorDescription"></p>
# </div>
# </div>
# </div>
# </div>
# <div class="profileFooterWrapper" id="profileFooterWrapper">
# <div class="profileLinks js-viewAnalyticsSection" data-analytics-name="popular_searches" id="profileQuickLinks">
# <div class="quickLinks">
# <div class="propertyBlurbSection">
# <h2 class="propertyBlurbHeader">1935 Alpha Rd Area Info</h2>
# <p class="propertyBlurbContent">1935 Alpha Rd is located in <a href="https://www.apartments.com/los-angeles-county-ca/">Los Angeles County</a>, the <a href="https://www.apartments.com/glendale-ca-91208/">91208</a> ZIP Code, and the <a></a> attendance zone.</p>
# </div>
# <div class="quickLinksContent">
# <h4 class="quickLinksTitle">Popular Searches</h4>
# <div>
# <div class="nearbyAreas clearfix hideOnCollapse">
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Cities">Cities</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/la-crescenta-ca/" title="La Crescenta ">La Crescenta Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/la-canada-flintridge-ca/" title="La Canada Flintridge ">La Canada Flintridge Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/griffith-ca/" title="Griffith ">Griffith Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/burbank-ca/" title="Burbank ">Burbank Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/eagle-rock-ca/" title="Eagle Rock ">Eagle Rock Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Neighborhoods">Neighborhoods</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/verdugo-woodlands-glendale-ca/" title="Verdugo Woodlands ">Verdugo Woodlands Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/rossmoyne-glendale-ca/" title="Rossmoyne ">Rossmoyne Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/verdugo-viejo-glendale-ca/" title="Verdugo Viejo ">Verdugo Viejo Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/glenwood-glendale-ca/" title="Glenwood ">Glenwood Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/la-crescenta-montrose-montrose-ca/" title="La Crescenta-Montrose ">La Crescenta-Montrose Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="ZIP Codes">ZIP Codes</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/glendale-ca-91208/" title="91208 ">91208 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/glendale-ca-91207/" title="91207 ">91207 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/la-crescenta-ca-91214/" title="91214 ">91214 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/glendale-ca-91202/" title="91202 ">91202 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/glendale-ca-91206/" title="91206 ">91206 Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Beds">Beds</h5>
# <ul>
# ...
# <li>Controlled Access</li>
# <li>Gated</li>
# <li>Balcony</li>
# </ul>
# </div>
# <div class="col-25">
# <ul>
# <li>Sauna</li>
# <li>Pool</li>
# <li>Tennis Court</li>
# <li>Fireplace</li>
# </ul>
# </div>
# <div class="col-25">
# <ul>
# <li>Dishwasher</li>
# <li>Kitchen</li>
# <li>Oven</li>
# <li>Hardwood Floors</li>
# </ul>
# </div>
# <div class="col-25">
# <ul>
# <li>Dining Room</li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row">
# </div>
# </section>
# <section class="avoidScams">
#             Protect yourself from scams. <a href="https://www.apartments.com/about/avoid-scams-and-fraud" target="_blank">Learn More</a>
# </section>
# <section class="flagSection">
# <a class="flagButton js-openFlagModal" href="javascript:void(0);"><span class="flagIcon"></span> Report an Issue</a>
# <div class="options">
# <a class="showSharingOptionsLink js-showSharingOptionsLink" href="javascript:void(0);" rel="nofollow" title="Share">
# <span class="shareIcon icon"></span>
# <span class="optionText">Share</span>
# </a>
# <a class="showPrintLink" href="javascript:void(0);" title="Print">
# <span class="printerIcon icon"></span>
# <span class="optionText">Print</span>
# </a>
# <a class="showBingDirectionsLink js-showBingDirectionsLink" href="https://www.google.com/maps/dir//5460+White+Oak+Ave+Los+Angeles+CA+91316" rel="nofollow" target="_blank" title="Directions">
# <span class="directionsIcon icon"></span>
# <span class="optionText">Directions</span>
# </a>
# </div>
# </section>
# </div>
# <div class="modalContactLead" id="modalContactLead">
# <div class="lead-form-container">
# <div class="contactLeadWrapper" id="contactLeadForm">
# <header class="property-title-header">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>
# <i class="phoneTransparentIcon"></i>
# <span class="contactPhone" id="ctn">844-754-9395</span>
# </h3>
# </header>
# <div class="contactForm" id="contactForm">
# <div class="cell-xs-6 first-input">
# <label class="input-label">First Name *</label>
# <input class="contactFormFirstName input-override" id="contactFormFirstName" type="text"/>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Last Name *</label>
# <input class="contactFormLastName input-override" id="contactFormLastName" type="text"/>
# </div>
# <div class="cell-xs-12">
# <label class="input-label">Email Address *</label>
# <input class="contactFormEmail input-override" id="contactFormEmail" type="email"/>
# </div>
# <div class="cell-xs-6 first-input calendar-input-wrapper">
# <div class="calendar-input moveIn-calendar-input" id="MoveInDateContainer">
# <label class="input-label">Move-in Date *</label>
# <i class="calendarOutlineIcon"></i>
# <input class="contactFormMoveInDate input-override" id="MoveInDate" placeholder="Move-in Date *" type="text" value="11/01/2019">
# </input></div>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Phone</label>
# <input class="contactFormPhoneNumber input-override" id="phone" placeholder="" type="tel" value=""/>
# </div>
# <div class="cell-xs-12 preference-wrapper" id="preference-wrapper">
# <h4>I would like to...</h4>
# <div class="checkbox-section">
# <input class="primaryCheckbox schedule-tour" id="schedule-tour" type="checkbox"/>
# <label for="schedule-tour" title="Schedule a Tour">
# <span>Schedule a Tour</span>
# </label>
# <input class="primaryCheckbox fill-out-application" id="fill-out-application" type="checkbox"/>
# <label for="fill-out-application" title="Request Application">
# <span>Request Application</span>
# </label>
# <input class="primaryCheckbox confirm-availability" id="confirm-availability" type="checkbox"/>
# <label for="confirm-availability" title="Confirm Availability">
# <span>Confirm Availability</span>
# </label>
# <input class="primaryCheckbox custom-message" id="custom-message" type="checkbox"/>
# <label for="custom-message" title="Custom Message">
# <span>Custom Message</span>
# </label>
# <div class="cell-xs-12 contactFormMessageWrapper">
# <label class="input-label full-label">Message</label>
# <span class="counter-wrapper">
# <span id="contactFormMessageCounter"></span>
# </span>
# <textarea class="contactFormMessage input-override" id="contactFormMessage" maxlength="400" placeholder=""></textarea>
# </div>
# </div>
# </div>
# <div class="cell-xs-12 submitError">
# <input id="submitGeneralError" type="hidden">
# </input></div>
# <a class="primary contactFormAction" href="javascript:void(0);" id="contactFormAction">
# <span class="default-send-title">Send Message</span>
# </a>
# <div class="email-listing-checkbox">
# <input checked="" class="optin primaryCheckbox emailListings" id="emailListingsPopup" type="checkbox">
# <label class="emailListingsLabel" for="emailListingsPopup">
# <span class="emailListing">Email me listings and apartment related info.</span>
# </label>
# </input></div>
# </div>
# </div>
# </div>
# <div id="submitSpinnerModalWrapper">
# <div class="submitRequestSpinner fade modalContainer" data-backdrop="static" id="submitRequestSpinner">
# <div class="spinner"></div>
# <p>Submitting Request</p>
# </div>
# </div>
# <div id="successModalWrapper">
# <div class="fade out successModal modalContainer" data-backdrop="static" id="successModal">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3 id="successModalHeader">Thank You</h3>
# <p class="message" id="successModalMsg">Thank you! Your email has been sent.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade errorModal" data-backdrop="static" id="profileErrorModal">
# <div class="modalContainer">
# <div class="modalContent">
# <div class="modalHeader">
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# <h2>Error</h2>
# </div>
# <div class="modalBody">
# <h3 class="errorTitle"></h3>
# <p class="errorDescription"></p>
# </div>
# </div>
# </div>
# </div>
# <div class="profileFooterWrapper" id="profileFooterWrapper">
# <div class="profileLinks js-viewAnalyticsSection" data-analytics-name="popular_searches" id="profileQuickLinks">
# <div class="quickLinks">
# <div class="propertyBlurbSection">
# <h2 class="propertyBlurbHeader">5460 White Oak Ave Area Info</h2>
# <p class="propertyBlurbContent">5460 White Oak Ave is located in <a href="https://www.apartments.com/los-angeles-county-ca/">Los Angeles County</a>, the <a href="https://www.apartments.com/encino-ca-91316/">91316</a> ZIP Code, and the <a></a> attendance zone.</p>
# </div>
# <div class="quickLinksContent">
# <h4 class="quickLinksTitle">Popular Searches</h4>
# <div>
# <div class="nearbyAreas clearfix hideOnCollapse">
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Cities">Cities</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/culver-city-ca/" title="Culver City ">Culver City Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/palms-ca/" title="Palms ">Palms Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/rancho-park-ca/" title="Rancho Park ">Rancho Park Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/century-city-ca/" title="Century City ">Century City Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/mar-vista-ca/" title="Mar Vista ">Mar Vista Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Neighborhoods">Neighborhoods</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/clarkdale-culver-city-ca/" title="Clarkdale ">Clarkdale Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/cheviot-hills-los-angeles-ca/" title="Cheviot Hills ">Cheviot Hills Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/jefferson-culver-city-ca/" title="Jefferson ">Jefferson Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/rancho-park-los-angeles-ca/" title="Rancho Park ">Rancho Park Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/beverlywood-los-angeles-ca/" title="Beverlywood ">Beverlywood Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="ZIP Codes">ZIP Codes</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/culver-city-ca-90232/" title="90232 ">90232 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/los-angeles-ca-90034/" title="90034 ">90034 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/los-angeles-ca-90064/" title="90064 ">90064 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/culver-city-ca-90230/" title="90230 ">90230 Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/los-angeles-ca-90067/" title="90067 ">90067 Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Beds">Beds</h5>
# <ul>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/1-bedrooms/" title="1 Bedroom Condos in Los Angeles">1 Bedroom Condos in Los Angeles</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/2-bedrooms/" title="2 Bedroom Condos in Los Angeles">2 Bedroom Condos in Los Angeles</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/3-bedrooms/" title="3 Bedroom Condos in Los Angeles">3 Bedroom Condos in Los Angeles</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/4-bedrooms/" title="4+ Bedroom Condos in Los Angeles">4+ Bedroom Condos in Los Angeles</a></li>
# </ul>
# </div>
# </div>
# <div class="popularSearches clearfix">
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Property Style">Property Style</h5>
# <ul>
# <li class=""><a href="https://www.apartments.com/houses/los-angeles-ca/" title="Los Angeles Houses for Rent">Los Angeles Houses for Rent</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/" title="Los Angeles Condos for Rent">Los Angeles Condos for Rent</a></li>
# <li class=""><a href="https://www.apartments.com/townhomes/los-angeles-ca/" title="Los Angeles Townhomes for Rent">Los Angeles Townhomes for Rent</a></li>
# <li class=""><a href="https://www.apartments.com/houses/encino-ca-91316/" title="91316 Houses for Rent">91316 Houses for Rent</a></li>
# <li class=""><a href="https://www.apartments.com/condos/encino-ca-91316/" title="91316 Condos for Rent">91316 Condos for Rent</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/townhomes/encino-ca-91316/" title="91316 Townhomes for Rent">91316 Townhomes for Rent</a></li>
# </ul>
# </div>
# <div class="price quickLinksCol">
# <h5 class="quickLinksHeading" title="Price">Price</h5>
# <ul>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/under-1000/" title="Los Angeles Condos Under $1000">Los Angeles Condos Under $1000</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/under-1500/" title="Los Angeles Condos Under $1500">Los Angeles Condos Under $1500</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Amenity">Amenity</h5>
# <ul>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/pet-friendly/" title="Los Angeles Pet Friendly Condos">Los Angeles Pet Friendly Condos</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/washer-dryer/" title="Los Angeles Condos with Washer/Dryer">Los Angeles Condos with Washer/Dryer</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Specialty">Specialty</h5>
# <ul>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/student-housing/" title="Los Angeles Student Housing">Los Angeles Student Housing</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/senior-housing/" title="Los Angeles Senior Housing">Los Angeles Senior Housing</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/luxury/" title="Los Angeles Luxury Condos">Los Angeles Luxury Condos</a></li>
# <li class=""><a href="https://www.apartments.com/condos/los-angeles-ca/cheap/" title="Los Angeles Cheap Condos">Los Angeles Cheap Condos</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="profileFooter" id="profileFooter">
# <div class="linkRow">
# <ul>
# <li><a href="/about" title="About Apartments.com">About Us</a></li> <li><a href="/advertise">Advertise</a></li> <li><a href="/about/legal-terms">Legal Terms</a></li> <li><a href="/about/privacy-statement">Privacy Statement</a></li> <li><a href="/about/equal-opportunity-in-housing-statement" title="Equal Housing Opportunity">Equal Housing</a></li> <li><a href="/about/avoid-scams-and-fraud" title="Avoid Rental Scams and Fraud">Avoid Scams</a></li> <li><a href="/about/accessibility" title="Accessibility Commitment">Accessibility</a></li> <li><a href="/blog" title="Advice and Resources for Rental Life">Blog</a></li> <li><a href="/sitemap/condos/">Sitemap</a></li>
# </ul>
# </div>
# <div class="footerContact print">
# <div class="logo">
# </div>
# </div>
# <a class="footerLogo" href="https://www.apartments.com/">
# <img alt="Apartments.com © 2019 CoStar Group, Inc." src="/a/4d9af0/content/images/apartments-for-rent-logo.png" title="Apartments.com © 2019 CoStar Group, Inc."/>
# <span class="costarCopyright">© 2019 CoStar Group, Inc.</span>
# <p class="ehoProfileLabel print">
# <span href="https://www.apartments.com/advertise/disclaimers/equal-opportunity-in-housing-statement/" target="_blank" title="Equal Housing Opportunity">
# <i class="ehoIcon"></i>
# <span>Equal Housing Opportunity</span>
# </span>
# </p>
# </a>
# <div class="social">
# <span class="socialIcons">
# <a class="facebookIcon" href="https://facebook.com/apartments.com" target="_blank"></a>
# <a class="twitterIcon" href="https://twitter.com/apartmentscom" target="_blank"></a>
# <a class="linkedinIcon" href="https://linkedin.com/company/apartments-com" target="_blank"></a>
# <a class="pinterestIcon" href="http://pinterest.com/apartmentscom" target="_blank"></a>
# <a class="youtubeIcon" href="https://www.youtube.com/user/apartmentscom/custom" target="_blank"></a>
# <a class="blogIcon" href="https://www.apartments.com/blog/" target="_blank"></a>
# </span>
# </div>
# <p class="ehoProfileLabel screen">
# <a href="https://www.apartments.com/advertise/disclaimers/equal-opportunity-in-housing-statement/" target="_blank" title="Equal Housing Opportunity">
# <i class="ehoIcon"></i>
# <span>Equal Housing Opportunity</span>
# </a>
# </p>
# </footer>
# </div>
# <section id="profileLocalGuide"></section>
# <section id="profileApplyNow">
# <section class="ConduitFrameContainer is-modal" id="ApplyNowFrameContainer"></section>
# <section class="ConduitFrameContainer is-modal" id="EcomRenterCheckoutFrameContainer"></section>
# <section class="app-transition-spinner">
# <div class="content">
# <i class="aptsLogoMarkIcon loading-spinner"></i>
# <p i18n="">Loading...</p>
# </div>
# </section>
# </section>
# </section>
# <div class="videoPlayerWrapper fade modal" id="modalVirtualTourContainer">
# <div class="videoPlayerWrapper" id="virtualTourVideoPlayerWrapper">
# <div class="viewerContent" id="virtualTourViewerContent">
# <div class="videoPlayer active" id="virtualTourVideoPlayer">
# <div class="poweredMatterport"></div>
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# <div class="videoPlayerContent" id="virtualTourPlayerContent"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade applyNowConfirmation" data-backdrop="static" id="applyNowConfirmation">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>Online applications are here!</h3>
# <p>Great News! The manager for this property is accepting applications through Apartments.com, a brand new feature that allows you to apply quickly and securely. You'll see more listings with "apply now" buttons as this feature becomes more widely available. <a href="https://renterhelp.apartments.com/article/136-how-to-apply-to-rentals-on-apartments-com" target="_blank">Learn more about applications</a></p>
# <button class="primary" id="continueToAppButton" type="button">Continue</button>
# </div>
# </div>
# </div>
# </main>
# </div>

# %%
rent_obj = []
all_property = []

for page in range(21,29):
    link = 'https://www.apartments.com/condos/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='prosumer placard')

    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        
        full_address = result.find('div', class_ = "location").text
        city = new_results.find('div', class_ = "propertyAddress").select('span')[0].text
        state = new_results.find('div', class_ = "propertyAddress").select('span')[1].text
        zip_code = new_results.find('div', class_ = "propertyAddress").select('span')[2].text
        street = new_results.find('h1', class_ = "propertyName").text.replace('\r\n                    ', "").strip()
        bedroom_container = new_results.find('div', class_="rentRollupContainer")
        house_details = new_results.find('table', class_="availabilityTable")
        bath_number = house_details.find('td', class_="baths").find('span', class_="shortText").text.replace('\r\n                    ', "").strip()
        house_square_feet = house_details.find('td', class_="sqft").text
        square_feet = house_square_feet.split(" ")[0];
        lease_length = house_details.find('td', class_="leaseLength").text
        availability_check = house_details.find('td', class_="available").text.replace('\r\n                    ', "").strip()
        all_the_rents = bedroom_container.findAll('span', class_="rentRollup")

        bedroom_info = []
        for rent_block in all_the_rents:
            bedroom_type = rent_block.find('span', class_="shortText").text
            try:
                price = re.search('\$.* ', rent_block.text)
                price = price.group(0)[:-3]

            except:
                if "Call for Rent" in rent_block.text:
                    price = ""
                else:
                    price = re.search('\$.*', rent_block.text).group()[:-1]
            bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
        rent_obj = {
                "City_Rent": city,
                "Type": "Condos",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                "Full_Address": full_address,
                "Rent_link": find_tag,
                "Bath_Info": bath_number,
                "Square_Feet_Data": house_square_feet,
                "Square_Feet": square_feet,
                "Lease_length": lease_length,
                "Availability_check": availability_check
            }
        for room_type in bedroom_info:
            rent_obj[room_type["bedroom_type"]] = room_type["price"];
        
        all_property.append(rent_obj)
        time.sleep(1)

# %%
rent_data = pd.DataFrame(all_property)
rent_data
# Out:
#       1 Bed  2 Beds  3 Beds  4 Beds Availability_check Bath_Info  \
# 0       NaN  $4,250     NaN     NaN      Available Now     2 BAs
# 1       NaN  $2,900     NaN     NaN      Available Now     2 BAs
# 2       NaN     NaN  $3,500     NaN      Available Now     2 BAs
# 3    $3,295     NaN     NaN     NaN      Available Now      1 BA
# 4    $3,395     NaN     NaN     NaN      Available Now      1 BA
# 5       NaN  $3,400     NaN     NaN      Available Now     2 BAs
# 6       NaN  $2,500     NaN     NaN      Available Now     2 BAs
# 7       NaN     NaN  $6,000     NaN              Nov 1    2½ BAs
# 8       NaN     NaN  $3,100     NaN      Available Now    2½ BAs
# 9       NaN  $4,250     NaN     NaN      Available Now     2 BAs
# 10      NaN  $5,300     NaN     NaN      Available Now     2 BAs
# 11      NaN     NaN  $3,000     NaN      Available Now     2 BAs
# 12      NaN  $3,495     NaN     NaN      Available Now     2 BAs
# 13      NaN     NaN  $8,500     NaN      Available Now    2½ BAs
# 14      NaN     NaN  $5,100     NaN      Available Now     3 BAs
# 15      NaN  $4,800     NaN     NaN      Available Now     2 BAs
# 16      NaN  $4,500     NaN     NaN      Available Now     2 BAs
# 17      NaN  $6,000     NaN     NaN              Nov 1     2 BAs
# 18      NaN     NaN  $3,300     NaN      Available Now     2 BAs
# 19      NaN  $3,000     NaN     NaN      Available Now    2½ BAs
# 20      NaN  $1,450     NaN     NaN              Nov 1     2 BAs
# 21   $1,995     NaN     NaN     NaN      Available Now      1 BA
# 22      NaN  $4,500     NaN     NaN              Nov 1     2 BAs
# 23      NaN  $2,600     NaN     NaN             Nov 17     2 BAs
# 24   $1,550     NaN     NaN     NaN              Nov 8      1 BA
# 25      NaN  $2,300     NaN     NaN      Available Now     2 BAs
# 26      NaN  $2,550     NaN     NaN             Dec 15    2½ BAs
# 27      NaN  $2,100     NaN     NaN              Dec 1    1½ BAs
# 28      NaN  $1,800     NaN     NaN      Available Now      1 BA
# 29      NaN     NaN     NaN     NaN      Available Now      1 BA
# ..      ...     ...     ...     ...                ...       ...
# 165     NaN  $5,400     NaN     NaN             Nov 10     2 BAs
# 166     NaN  $2,800     NaN     NaN      Available Now    2½ BAs
# 167     NaN  $3,250     NaN     NaN              Nov 1     2 BAs
# 168     NaN  $2,175     NaN     NaN              Dec 1     2 BAs
# 169     NaN  $3,200     NaN     NaN      Available Now     2 BAs
# 170     NaN  $2,795     NaN     NaN      Available Now     2 BAs
# 171     NaN  $1,795     NaN     NaN      Available Now    1½ BAs
# 172     NaN  $2,900     NaN     NaN      Available Now     2 BAs
# 173     NaN  $2,900     NaN     NaN      Available Now    1½ BAs
# 174     NaN  $2,450     NaN     NaN      Available Now      1 BA
# 175  $3,150     NaN     NaN     NaN      Available Now      1 BA
# 176     NaN  $3,795     NaN     NaN      Available Now     2 BAs
# 177  $1,000     NaN     NaN     NaN      Available Now      1 BA
# 178  $1,750     NaN     NaN     NaN      Available Now      1 BA
# 179     NaN     NaN    $750     NaN      Available Now      1 BA
# 180     NaN     NaN     NaN     NaN      Available Now      1 BA
# 181     NaN     NaN  $2,200     NaN              Nov 1    2½ BAs
# 182     NaN  $2,595     NaN     NaN      Available Now     2 BAs
# 183     NaN  $2,200     NaN     NaN      Available Now      1 BA
# 184     NaN    $650     NaN     NaN      Available Now      1 BA
# 185    $650     NaN     NaN     NaN      Available Now      1 BA
# 186     NaN     NaN     NaN  $1,050      Available Now     2 BAs
# 187  $2,695     NaN     NaN     NaN      Available Now      1 BA
# 188     NaN  $3,200     NaN     NaN      Available Now     2 BAs
# 189     NaN  $1,800     NaN     NaN      Available Now      1 BA
# 190  $1,800     NaN     NaN     NaN      Available Now      1 BA
# 191     NaN  $2,150     NaN     NaN             Oct 31    2½ BAs
# 192  $1,785     NaN     NaN     NaN      Available Now      1 BA
# 193     NaN  $2,795     NaN     NaN      Available Now     2 BAs
# 194     NaN  $2,600     NaN     NaN             Nov 15     2 BAs
#
#                                         Bedroom_Info           City_Rent  \
# 0    [{'bedroom_type': '2 Beds', 'price': '$4,250'}]       Beverly Hills
# 1    [{'bedroom_type': '2 Beds', 'price': '$2,900'}]         Los Angeles
# 2    [{'bedroom_type': '3 Beds', 'price': '$3,500'}]         Los Angeles
# 3     [{'bedroom_type': '1 Bed', 'price': '$3,295'}]        Laguna Beach
# 4     [{'bedroom_type': '1 Bed', 'price': '$3,395'}]        Laguna Beach
# 5    [{'bedroom_type': '2 Beds', 'price': '$3,400'}]        Santa Monica
# 6    [{'bedroom_type': '2 Beds', 'price': '$2,500'}]              Encino
# 7    [{'bedroom_type': '3 Beds', 'price': '$6,000'}]         Los Angeles
# 8    [{'bedroom_type': '3 Beds', 'price': '$3,100'}]           Inglewood
# 9    [{'bedroom_type': '2 Beds', 'price': '$4,250'}]         Culver City
# 10   [{'bedroom_type': '2 Beds', 'price': '$5,300'}]         Los Angeles
# 11   [{'bedroom_type': '3 Beds', 'price': '$3,000'}]           Inglewood
# 12   [{'bedroom_type': '2 Beds', 'price': '$3,495'}]         Los Angeles
# 13   [{'bedroom_type': '3 Beds', 'price': '$8,500'}]        Santa Monica
# 14   [{'bedroom_type': '3 Beds', 'price': '$5,100'}]        Santa Monica
# 15   [{'bedroom_type': '2 Beds', 'price': '$4,800'}]        Santa Monica
# 16   [{'bedroom_type': '2 Beds', 'price': '$4,500'}]         Los Angeles
# 17   [{'bedroom_type': '2 Beds', 'price': '$6,000'}]         Los Angeles
# 18   [{'bedroom_type': '3 Beds', 'price': '$3,300'}]       Redondo Beach
# 19   [{'bedroom_type': '2 Beds', 'price': '$3,000'}]         Los Angeles
# 20   [{'bedroom_type': '2 Beds', 'price': '$1,450'}]            Redlands
# 21    [{'bedroom_type': '1 Bed', 'price': '$1,995'}]             Fremont
# 22   [{'bedroom_type': '2 Beds', 'price': '$4,500'}]              Irvine
# 23   [{'bedroom_type': '2 Beds', 'price': '$2,600'}]           San Ramon
# 24    [{'bedroom_type': '1 Bed', 'price': '$1,550'}]           San Diego
# 25   [{'bedroom_type': '2 Beds', 'price': '$2,300'}]         Los Angeles
# 26   [{'bedroom_type': '2 Beds', 'price': '$2,550'}]          Costa Mesa
# 27   [{'bedroom_type': '2 Beds', 'price': '$2,100'}]            Torrance
# 28   [{'bedroom_type': '2 Beds', 'price': '$1,800'}]             Vallejo
# 29   [{'bedroom_type': 'Studio', 'price': '$1,875'}]       San Francisco
# ..                                               ...                 ...
# 165  [{'bedroom_type': '2 Beds', 'price': '$5,400'}]         Los Angeles
# 166  [{'bedroom_type': '2 Beds', 'price': '$2,800'}]            Pasadena
# 167  [{'bedroom_type': '2 Beds', 'price': '$3,250'}]             Burbank
# 168  [{'bedroom_type': '2 Beds', 'price': '$2,175'}]           Oceanside
# 169  [{'bedroom_type': '2 Beds', 'price': '$3,200'}]              Novato
# 170  [{'bedroom_type': '2 Beds', 'price': '$2,795'}]            Carlsbad
# 171  [{'bedroom_type': '2 Beds', 'price': '$1,795'}]              Santee
# 172  [{'bedroom_type': '2 Beds', 'price': '$2,900'}]           San Diego
# 173  [{'bedroom_type': '2 Beds', 'price': '$2,900'}]       Santa Barbara
# 174  [{'bedroom_type': '2 Beds', 'price': '$2,450'}]            Richmond
# 175   [{'bedroom_type': '1 Bed', 'price': '$3,150'}]             Oakland
# 176  [{'bedroom_type': '2 Beds', 'price': '$3,795'}]             Oakland
# 177   [{'bedroom_type': '1 Bed', 'price': '$1,000'}]           El Centro
# 178   [{'bedroom_type': '1 Bed', 'price': '$1,750'}]           Escondido
# 179    [{'bedroom_type': '3 Beds', 'price': '$750'}]          Ridgecrest
# 180    [{'bedroom_type': 'Studio', 'price': '$855'}]  Desert Hot Springs
# 181  [{'bedroom_type': '3 Beds', 'price': '$2,200'}]            Murrieta
# 182  [{'bedroom_type': '2 Beds', 'price': '$2,595'}]            Carlsbad
# 183  [{'bedroom_type': '2 Beds', 'price': '$2,200'}]      Imperial Beach
# 184    [{'bedroom_type': '2 Beds', 'price': '$650'}]          Ridgecrest
# 185     [{'bedroom_type': '1 Bed', 'price': '$650'}]          Ridgecrest
# 186  [{'bedroom_type': '4 Beds', 'price': '$1,050'}]          Ridgecrest
# 187   [{'bedroom_type': '1 Bed', 'price': '$2,695'}]           San Mateo
# 188  [{'bedroom_type': '2 Beds', 'price': '$3,200'}]          Dana Point
# 189  [{'bedroom_type': '2 Beds', 'price': '$1,800'}]    South Lake Tahoe
# 190   [{'bedroom_type': '1 Bed', 'price': '$1,800'}]           Livermore
# 191  [{'bedroom_type': '2 Beds', 'price': '$2,150'}]               Chino
# 192   [{'bedroom_type': '1 Bed', 'price': '$1,785'}]           Santa Ana
# 193  [{'bedroom_type': '2 Beds', 'price': '$2,795'}]             Fremont
# 194  [{'bedroom_type': '2 Beds', 'price': '$2,600'}]              Moraga
#
#                                     Full_Address    Lease_length  \
# 0         321 N Palm Dr, Beverly Hills, CA 90210  12 Month Lease
# 1        100 S Alameda St, Los Angeles, CA 90012  12 Month Lease
# 2        100 S Alameda St, Los Angeles, CA 90012  12 Month Lease
# 3         240 Jasmine St, Laguna Beach, CA 92651  12 Month Lease
# 4         240 Jasmine St, Laguna Beach, CA 92651  12 Month Lease
# 5           1333 14th St, Santa Monica, CA 90404  12 Month Lease
# 6           5325 Newcastle Ave, Encino, CA 91316  12 Month Lease
# 7         12021 Guerin St, Los Angeles, CA 91604  12 Month Lease
# 8    3500 W Manchester Blvd, Inglewood, CA 90305  18 Month Lease
# 9          3833 Huron Ave, Culver City, CA 90232  12 Month Lease
# 10    10501 Wilshire Blvd, Los Angeles, CA 90024  12 Month Lease
# 11       3855 Thorncroft Ln, Inglewood, CA 90305  12 Month Lease
# 12       10650 Holman Ave, Los Angeles, CA 90024  12 Month Lease
# 13         201 Ocean Ave, Santa Monica, CA 90402  12 Month Lease
# 14           813 15th St, Santa Monica, CA 90403   1 Month Lease
# 15           813 15th St, Santa Monica, CA 90403   1 Month Lease
# 16    10535 Wilshire Blvd, Los Angeles, CA 90024  12 Month Lease
# 17      17337 Tramonto Dr, Los Angeles, CA 90272  12 Month Lease
# 18      820 Camino Real, Redondo Beach, CA 90277  12 Month Lease
# 19     5219 Newcastle Ave, Los Angeles, CA 91316  12 Month Lease
# 20                            Redlands, CA 92374  12 Month Lease
# 21                             Fremont, CA 94538  12 Month Lease
# 22                              Irvine, CA 92612  12 Month Lease
# 23                           San Ramon, CA 94582  12 Month Lease
# 24                           San Diego, CA 92108  12 Month Lease
# 25                         Los Angeles, CA 91356  12 Month Lease
# 26                          Costa Mesa, CA 92627  12 Month Lease
# 27                            Torrance, CA 90502  12 Month Lease
# 28                             Vallejo, CA 94590  11 Month Lease
# 29                       San Francisco, CA 94112  12 Month Lease
# ..                                           ...             ...
# 165                        Los Angeles, CA 90293   6 Month Lease
# 166                           Pasadena, CA 91101  12 Month Lease
# 167                            Burbank, CA 91502  12 Month Lease
# 168                          Oceanside, CA 92058  12 Month Lease
# 169                             Novato, CA 94947  12 Month Lease
# 170                           Carlsbad, CA 92011   8 Month Lease
# 171                             Santee, CA 92071  12 Month Lease
# 172                          San Diego, CA 92037  12 Month Lease
# 173                      Santa Barbara, CA 93109  12 Month Lease
# 174                           Richmond, CA 94804  12 Month Lease
# 175                            Oakland, CA 94607  12 Month Lease
# 176                            Oakland, CA 94607  12 Month Lease
# 177                          El Centro, CA 92243  12 Month Lease
# 178                          Escondido, CA 92027  12 Month Lease
# 179                         Ridgecrest, CA 93555  12 Month Lease
# 180                 Desert Hot Springs, CA 92240
# 181                           Murrieta, CA 92562  12 Month Lease
# 182                           Carlsbad, CA 92011   8 Month Lease
# 183                     Imperial Beach, CA 91932  12 Month Lease
# 184                         Ridgecrest, CA 93555  12 Month Lease
# 185                         Ridgecrest, CA 93555  12 Month Lease
# 186                         Ridgecrest, CA 93555  12 Month Lease
# 187                          San Mateo, CA 94404  12 Month Lease
# 188                         Dana Point, CA 92629  12 Month Lease
# 189                   South Lake Tahoe, CA 96150   6 Month Lease
# 190                          Livermore, CA 94550   6 Month Lease
# 191                              Chino, CA 91710  12 Month Lease
# 192                          Santa Ana, CA 92707  12 Month Lease
# 193                            Fremont, CA 94555  12 Month Lease
# 194                             Moraga, CA 94556  12 Month Lease
#
#                                              Rent_link Square_Feet  \
# 0    https://www.apartments.com/321-n-palm-dr-bever...       1,480
# 1    https://www.apartments.com/100-s-alameda-st-lo...       1,042
# 2    https://www.apartments.com/100-s-alameda-st-lo...       1,213
# 3    https://www.apartments.com/240-jasmine-st-lagu...         600
# 4    https://www.apartments.com/240-jasmine-st-lagu...         600
# 5    https://www.apartments.com/1333-14th-st-santa-...       1,055
# 6    https://www.apartments.com/5325-newcastle-ave-...       1,250
# 7    https://www.apartments.com/12021-guerin-st-los...       1,530
# 8    https://www.apartments.com/3500-w-manchester-b...       1,600
# 9    https://www.apartments.com/3833-huron-ave-culv...       1,760
# 10   https://www.apartments.com/10501-wilshire-blvd...       1,210
# 11   https://www.apartments.com/3855-thorncroft-ln-...       1,199
# 12   https://www.apartments.com/10650-holman-ave-lo...       1,560
# 13   https://www.apartments.com/201-ocean-ave-santa...       1,600
# 14   https://www.apartments.com/813-15th-st-santa-m...       1,500
# 15   https://www.apartments.com/813-15th-st-santa-m...       1,150
# 16   https://www.apartments.com/10535-wilshire-blvd...       1,352
# 17   https://www.apartments.com/17337-tramonto-dr-l...       1,776
# 18   https://www.apartments.com/820-camino-real-red...       1,290
# 19   https://www.apartments.com/5219-newcastle-ave-...       1,600
# 20   https://www.apartments.com/1206-oxford-dr-redl...         850
# 21   https://www.apartments.com/3909-stevenson-blvd...         677
# 22   https://www.apartments.com/10-nuevo-irvine-ca-...       1,507
# 23   https://www.apartments.com/775-watson-canyon-c...         914
# 24   https://www.apartments.com/6390-rancho-mission...         506
# 25   https://www.apartments.com/18350-hatteras-st-l...       1,100
# 26   https://www.apartments.com/357-w-wilson-st-cos...       1,300
# 27   https://www.apartments.com/817-w-232nd-st-torr...         843
# 28   https://www.apartments.com/1010-marin-st-valle...       1,100
# 29   https://www.apartments.com/190-edinburgh-st-sa...         350
# ..                                                 ...         ...
# 165  https://www.apartments.com/6967-trolleyway-s-l...       1,000
# 166  https://www.apartments.com/111-s-oak-knoll-ave...       1,017
# 167  https://www.apartments.com/250-n-1st-st-burban...       1,056
# 168  https://www.apartments.com/4487-brisbane-way-o...       1,141
# 169  https://www.apartments.com/852-diablo-ave-nova...       1,280
# 170  https://www.apartments.com/957-wind-drift-dr-c...       1,084
# 171  https://www.apartments.com/9821-caspi-gardens-...         962
# 172  https://www.apartments.com/6333-la-jolla-blvd-...         989
# 173  https://www.apartments.com/1031-miramonte-dr-s...       1,080
# 174  https://www.apartments.com/198-marina-lakes-dr...         850
# 175  https://www.apartments.com/222-broadway-oaklan...         760
# 176  https://www.apartments.com/311-2nd-st-oakland-...       1,097
# 177  https://www.apartments.com/444-s-4th-st-el-cen...         950
# 178  https://www.apartments.com/2094-e-grand-ave-es...         959
# 179  https://www.apartments.com/401-oasis-dr-ridgec...         975
# 180  https://www.apartments.com/66072-5th-st-desert...         600
# 181  https://www.apartments.com/41555-king-palm-ave...       1,411
# 182  https://www.apartments.com/954-sea-cliff-dr-ca...       1,145
# 183  https://www.apartments.com/1220-seacoast-dr-im...         850
# 184  https://www.apartments.com/401-oasis-dr-ridgec...         850
# 185  https://www.apartments.com/401-oasis-dr-ridgec...         850
# 186  https://www.apartments.com/401-oasis-dr-ridgec...       1,075
# 187  https://www.apartments.com/626-mariners-island...         736
# 188  https://www.apartments.com/24242-santa-clara-a...       1,058
# 189  https://www.apartments.com/1223-bonanza-ave-so...         850
# 190  https://www.apartments.com/1085-murrieta-blvd-...         760
# 191  https://www.apartments.com/6032-lyon-st-chino-...       1,446
# 192  https://www.apartments.com/1001-w-stevens-ave-...         647
# 193  https://www.apartments.com/34622-pueblo-terrac...       1,079
# 194  https://www.apartments.com/2091-ascot-dr-morag...       1,180
#
#     Square_Feet_Data State_Rent  Studio    Type Zip_code
# 0        1,480 Sq Ft         CA     NaN  Houses    90210
# 1        1,042 Sq Ft         CA     NaN  Houses    90012
# 2        1,213 Sq Ft         CA     NaN  Houses    90012
# 3          600 Sq Ft         CA     NaN  Houses    92651
# 4          600 Sq Ft         CA     NaN  Houses    92651
# 5        1,055 Sq Ft         CA     NaN  Houses    90404
# 6        1,250 Sq Ft         CA     NaN  Houses    91316
# 7        1,530 Sq Ft         CA     NaN  Houses    91604
# 8        1,600 Sq Ft         CA     NaN  Houses    90305
# 9        1,760 Sq Ft         CA     NaN  Houses    90232
# 10       1,210 Sq Ft         CA     NaN  Houses    90024
# 11       1,199 Sq Ft         CA     NaN  Houses    90305
# 12       1,560 Sq Ft         CA     NaN  Houses    90024
# 13       1,600 Sq Ft         CA     NaN  Houses    90402
# 14       1,500 Sq Ft         CA     NaN  Houses    90403
# 15       1,150 Sq Ft         CA     NaN  Houses    90403
# 16       1,352 Sq Ft         CA     NaN  Houses    90024
# 17       1,776 Sq Ft         CA     NaN  Houses    90272
# 18       1,290 Sq Ft         CA     NaN  Houses    90277
# 19       1,600 Sq Ft         CA     NaN  Houses    91316
# 20         850 Sq Ft         CA     NaN  Houses    92374
# 21         677 Sq Ft         CA     NaN  Houses    94538
# 22       1,507 Sq Ft         CA     NaN  Houses    92612
# 23         914 Sq Ft         CA     NaN  Houses    94582
# 24         506 Sq Ft         CA     NaN  Houses    92108
# 25       1,100 Sq Ft         CA     NaN  Houses    91356
# 26       1,300 Sq Ft         CA     NaN  Houses    92627
# 27         843 Sq Ft         CA     NaN  Houses    90502
# 28       1,100 Sq Ft         CA     NaN  Houses    94590
# 29         350 Sq Ft         CA  $1,875  Houses    94112
# ..               ...        ...     ...     ...      ...
# 165      1,000 Sq Ft         CA     NaN  Houses    90293
# 166      1,017 Sq Ft         CA     NaN  Houses    91101
# 167      1,056 Sq Ft         CA     NaN  Houses    91502
# 168      1,141 Sq Ft         CA     NaN  Houses    92058
# 169      1,280 Sq Ft         CA     NaN  Houses    94947
# 170      1,084 Sq Ft         CA     NaN  Houses    92011
# 171        962 Sq Ft         CA     NaN  Houses    92071
# 172        989 Sq Ft         CA     NaN  Houses    92037
# 173      1,080 Sq Ft         CA     NaN  Houses    93109
# 174        850 Sq Ft         CA     NaN  Houses    94804
# 175        760 Sq Ft         CA     NaN  Houses    94607
# 176      1,097 Sq Ft         CA     NaN  Houses    94607
# 177        950 Sq Ft         CA     NaN  Houses    92243
# 178        959 Sq Ft         CA     NaN  Houses    92027
# 179        975 Sq Ft         CA     NaN  Houses    93555
# 180        600 Sq Ft         CA    $855  Houses    92240
# 181      1,411 Sq Ft         CA     NaN  Houses    92562
# 182      1,145 Sq Ft         CA     NaN  Houses    92011
# 183        850 Sq Ft         CA     NaN  Houses    91932
# 184        850 Sq Ft         CA     NaN  Houses    93555
# 185        850 Sq Ft         CA     NaN  Houses    93555
# 186      1,075 Sq Ft         CA     NaN  Houses    93555
# 187        736 Sq Ft         CA     NaN  Houses    94404
# 188      1,058 Sq Ft         CA     NaN  Houses    92629
# 189        850 Sq Ft         CA     NaN  Houses    96150
# 190        760 Sq Ft         CA     NaN  Houses    94550
# 191      1,446 Sq Ft         CA     NaN  Houses    91710
# 192        647 Sq Ft         CA     NaN  Houses    92707
# 193      1,079 Sq Ft         CA     NaN  Houses    94555
# 194      1,180 Sq Ft         CA     NaN  Houses    94556
#
# [195 rows x 17 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
rent_data.to_csv("Output/Apartment.com/Q4-2019_Apartment.com_Condos_Data_page21-28.csv", index=False, header=True)
