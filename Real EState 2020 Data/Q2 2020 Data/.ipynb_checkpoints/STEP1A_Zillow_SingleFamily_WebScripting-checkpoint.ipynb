# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(1, 2):
    # Filter Out Coming Soon, Auction, Home Type: Houses, Days On Zillow: 90 Days
    linked = 'https://www.zillow.com/ca/houses/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-130.9521558125,"east":-107.6611401875,"south":28.570940002914515,"north":45.333552921012235},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":5,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
#     user_agent = 'Mozilla/5.0 (Windows NT 5.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
            # Identify and return housing weblink
            house_website = str(result.a.get('href'))
            print('House_website:', house_website);
#             Identify and return house data
            listing_type = result.find('div', class_="list-card-footer").text;
#             print('listing_type:', listing_type);
            price = result.find('div', class_="list-card-price").text
#             print('price:', price);
            full_address = result.find('address', class_="list-card-addr").text
#             print('full_address:', full_address);
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
#             print('street:', street);
            city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
#             print('city:', city);
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
#                 print('zip_code:', zip_code);
            except IndexError:
                zip_code = 'null'
#                 print('zip_code:', zip_code);
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
#             print('bed:', bed);
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
#             print('bath:', bath);
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
#             print('house_square_feet:', house_square_feet);
            # Loop inside each house website and get more house data
            loop_response = requests.get(house_website, headers=headers)
            loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
#             print(loop_soup, '1212121')
            loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
            loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")
            

            lot = 'null';
            house_type = 'null';
            year_build = 'null';
            parking = 'null';
            hoa = 'null';
            lot_conversion_to_sqft = 'null';
            zillow_price_per_sqft = 'null';
            
            for content in loop_result2:
                if "Lot" in content.text.split(":")[0]:
                    lot = content.text.split(":")[1];
                if "Type" in content.text.split(":")[0]:
                    house_type = content.text.split(":")[1];
                if "Year built" in content.text.split(":")[0]:
                    year_build = content.text.split(":")[1];
                if "Parking" in content.text.split(":")[0]:
                    parking = content.text.split(":")[1];
                if "HOA" in content.text.split(":")[0]:
                    hoa = content.text.split(":")[1];
                if "Price/sqft" in content.text.split(":")[0]:
                    zillow_price_per_sqft = content.text.split(":")[1];
#             print('lot:', lot)
#             print('type:', house_type);
#             print('year-build:', year_build);
#             print('parking:', parking);
#             print('HOA:', hoa);
#             print("Price/sqft:", zillow_price_per_sqft);

            try:
                if (str(lot.split(" ")[1]) == "sqft"):
                    lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                    lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                elif (lot == "No Data"):
                    lot_conversion_to_sqft = 'null'
                else:
                    lot_conversion_to_sqft = 'null'
            except IndexError:
                lot_conversion_to_sqft = 'null'
#             print('lot_conversion_to_sqft:', lot_conversion_to_sqft);
            try:
                state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
#                 print('state:', state);
            except IndexError:
                state = 'null'
            try:
                zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
#                 print('zestimate', zestimate)
                rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[3].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
#                 print(rent_zestimate)
            except:
                zestimate = 'null'
#                 print('zestimate:', zestimate)
                rent_zestimate = 'null'
#             print(zestimate)
            
            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
            house_obj = {
                "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "House_type": house_type,
                "Year_build": year_build,
                "Parking": parking,
                "HOA": hoa,
                "Lot": lot,
                "Lot_conversion_to_sqft": lot_conversion_to_sqft,
                "Zestimate": zestimate,
                "Rent_zestimate": rent_zestimate,
                "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
           }

            #Continue to add data into collection house_dict
            house_dict.append(house_obj)
            time.sleep(2)
            
            
        except AttributeError as e:
            continue

print(house_dict)
# Out:
# House_website: https://www.zillow.com/homedetails/5048-S-Kensington-Ave-Ontario-CA-91762/145563987_zpid/
# House_website: https://www.zillow.com/homedetails/300-N-Orchid-Tree-Ln-Palm-Springs-CA-92262/18019371_zpid/
# House_website: https://www.zillow.com/homedetails/6221-W-Avenue-L12-Lancaster-CA-93536/20310045_zpid/
# House_website: https://www.zillow.com/homedetails/9804-Choiceana-Ave-Hesperia-CA-92345/17445087_zpid/
# House_website: https://www.zillow.com/homedetails/3032-Via-Primero-Palmdale-CA-93550/20267353_zpid/
# House_website: https://www.zillow.com/homedetails/4330-Altivo-Ln-Corona-CA-92883/69282409_zpid/
# House_website: https://www.zillow.com/homedetails/22300-Isatis-Ave-Apple-Valley-CA-92307/17460481_zpid/
# House_website: https://www.zillow.com/homedetails/23500-The-Old-Rd-72-Newhall-CA-91321/2079966429_zpid/
# House_website: https://www.zillow.com/homedetails/7910-Balboa-Rd-Atascadero-CA-93422/15425232_zpid/
# House_website: https://www.zillow.com/homedetails/5558-Avenida-Fiesta-La-Jolla-CA-92037/16857129_zpid/
# House_website: https://www.zillow.com/homedetails/1001-Emerald-Hills-Ct-El-Dorado-Hills-CA-95762/18618692_zpid/
# House_website: https://www.zillow.com/homedetails/1834-Adelaide-Ct-Oxnard-CA-93035/16382280_zpid/
# House_website: https://www.zillow.com/homedetails/69480-Victoria-Dr-Cathedral-City-CA-92234/18120454_zpid/
# [{'Listing_type': 'House for sale', 'Price': '$610,000', 'Full_address': '5048 S Kensington Ave, Ontario, CA 91762', 'Street': '5048 S Kensington Ave', 'City': 'Ontario', 'State': 'CA', 'Zip_code': '91762', 'Bed': '5', 'Bath': '4', 'Square_Feet': '3,416', 'House_type': 'Single Family', 'Year_build': '2016', 'Parking': '2 spaces', 'HOA': '$160/month', 'Lot': '5,009 sqft', 'Lot_conversion_to_sqft': 5009.0, 'Zestimate': '$605,235', 'Rent_zestimate': '$3,024/mo', 'Zillow_price/sqft': '$179', 'House_website': 'https://www.zillow.com/homedetails/5048-S-Kensington-Ave-Ontario-CA-91762/145563987_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$615,000', 'Full_address': '300 N Orchid Tree Ln, Palm Springs, CA 92262', 'Street': '300 N Orchid Tree Ln', 'City': 'PalmSprings', 'State': 'CA', 'Zip_code': '92262', 'Bed': '3', 'Bath': '2', 'Square_Feet': '1,842', 'House_type': 'Single Family', 'Year_build': '1966', 'Parking': '2 spaces', 'HOA': 'null', 'Lot': '0.25 acres', 'Lot_conversion_to_sqft': 10890.0, 'Zestimate': '$598,336', 'Rent_zestimate': '$4,000/mo', 'Zillow_price/sqft': '$334', 'House_website': 'https://www.zillow.com/homedetails/300-N-Orchid-Tree-Ln-Palm-Springs-CA-92262/18019371_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$435,000', 'Full_address': '6221 W Avenue L12, Lancaster, CA 93536', 'Street': '6221 W Avenue L12', 'City': 'Lancaster', 'State': 'CA', 'Zip_code': '93536', 'Bed': '4', 'Bath': '3', 'Square_Feet': '2,430', 'House_type': 'Single Family', 'Year_build': '1989', 'Parking': '3 spaces', 'HOA': 'null', 'Lot': '9,583 sqft', 'Lot_conversion_to_sqft': 9583.0, 'Zestimate': '$433,776', 'Rent_zestimate': '$2,645/mo', 'Zillow_price/sqft': '$179', 'House_website': 'https://www.zillow.com/homedetails/6221-W-Avenue-L12-Lancaster-CA-93536/20310045_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$469,900', 'Full_address': '9804 Choiceana Ave, Hesperia, CA 92345', 'Street': '9804 Choiceana Ave', 'City': 'Hesperia', 'State': 'CA', 'Zip_code': '92345', 'Bed': '5', 'Bath': '5', 'Square_Feet': '5,575', 'House_type': 'Single Family', 'Year_build': '1989', 'Parking': '2 spaces', 'HOA': 'null', 'Lot': '1.21 acres', 'Lot_conversion_to_sqft': 52707.6, 'Zestimate': '$460,481', 'Rent_zestimate': '$2,300/mo', 'Zillow_price/sqft': '$84', 'House_website': 'https://www.zillow.com/homedetails/9804-Choiceana-Ave-Hesperia-CA-92345/17445087_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$95,000,000', 'Full_address': '2571 Wallingford Dr, Beverly Hills, CA 90210', 'Street': '2571 Wallingford Dr', 'City': 'BeverlyHills', 'State': 'CA', 'Zip_code': '90210', 'Bed': '12', 'Bath': '24', 'Square_Feet': '38,000', 'House_type': 'Single Family', 'Year_build': '2000', 'Parking': '80 spaces', 'HOA': '$233/month', 'Lot': '5.2 acres', 'Lot_conversion_to_sqft': 226512.0, 'Zestimate': '$77,674,096', 'Rent_zestimate': '$119,621/mo', 'Zillow_price/sqft': '$2,500', 'House_website': 'https://www.zillow.com/homedetails/2571-Wallingford-Dr-Beverly-Hills-CA-90210/20532066_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$100,000,000', 'Full_address': '10697 Somma Way, Los Angeles, CA 90077', 'Street': '10697 Somma Way', 'City': 'LosAngeles', 'State': 'CA', 'Zip_code': '90077', 'Bed': '8', 'Bath': '21', 'Square_Feet': '41,000', 'House_type': 'Single Family', 'Year_build': '2020', 'Parking': '20 spaces', 'HOA': 'null', 'Lot': '1.35 acres', 'Lot_conversion_to_sqft': 58806.0, 'Zestimate': '$79,901,996', 'Rent_zestimate': '$50,702/mo', 'Zillow_price/sqft': '$2,439', 'House_website': 'https://www.zillow.com/homedetails/10697-Somma-Way-Los-Angeles-CA-90077/2087104502_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$62,000,000', 'Full_address': '1301 Collingwood Pl, Los Angeles, CA 90069', 'Street': '1301 Collingwood Pl', 'City': 'LosAngeles', 'State': 'CA', 'Zip_code': '90069', 'Bed': '5', 'Bath': '8', 'Square_Feet': '15,642', 'House_type': 'Single Family', 'Year_build': '2018', 'Parking': '15 spaces', 'HOA': 'null', 'Lot': '0.67 acres',  ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#          Listing_type         Price  \
# 0      House for sale      $610,000
# 1      House for sale      $615,000
# 2      House for sale      $435,000
# 3      House for sale      $469,900
# 4      House for sale   $95,000,000
# 5      House for sale  $100,000,000
# 6      House for sale   $62,000,000
# 7      House for sale      $199,999
# 8   For sale by owner      $122,500
# 9      House for sale   $65,000,000
# 10     House for sale        $8,500
# 11     House for sale      $525,000
# 27                1688 Carriage Cir, Vista, CA 92081       1688 Carriage Cir
# 28         141 S Carolwood Dr, Los Angeles, CA 90077      141 S Carolwood Dr
# 29           11584 Dilling St, Studio City, CA 91604        11584 Dilling St
# 30           1622 Viewmont Dr, Los Angeles, CA 90069        1622 Viewmont Dr
# 31              3032 Via Primero, Palmdale, CA 93550        3032 Via Primero
# 32                  4330 Altivo Ln, Corona, CA 92883          4330 Altivo Ln
# 33          22300 Isatis Ave, Apple Valley, CA 92307        22300 Isatis Ave
# 34                 23500 The Old Rd #72, Newhall, CA    23500 The Old Rd #72
# 35              7910 Balboa Rd, Atascadero, CA 93422          7910 Balboa Rd
# 36           5558 Avenida Fiesta, La Jolla, CA 92037     5558 Avenida Fiesta
# 37  1001 Emerald Hills Ct, El Dorado Hills, CA 95762   1001 Emerald Hills Ct
# 38                1834 Adelaide Ct, Oxnard, CA 93035        1834 Adelaide Ct
# 39       69480 Victoria Dr, Cathedral City, CA 92234       69480 Victoria Dr
#
#                City State Zip_code Bed Bath Square_Feet     House_type  \
# 0           Ontario    CA    91762   5    4       3,416  Single Family
# 1       PalmSprings    CA    92262   3    2       1,842  Single Family
# 2         Lancaster    CA    93536   4    3       2,430  Single Family
# 3          Hesperia    CA    92345   5    5       5,575  Single Family
# 4      BeverlyHills    CA    90210  12   24      38,000  Single Family
# 5        LosAngeles    CA    90077   8   21      41,000  Single Family
# 6        LosAngeles    CA    90069   5    8      15,642  Single Family
# 7          Palmdale    CA    93550   4    3       2,290  Single Family
# 8       PalmSprings    CA    92262   3    2       1,284  Single Family
# 9        LosAngeles    CA    90077   9   17      28,000  Single Family
# 10         LaQuinta    CA    92253   4    3       2,757  Single Family
# 11           Corona    CA    92882   4    3       1,910  Single Family
# 12          LaJolla    CA    92037   4    4       3,395  Single Family
# 13       Sacramento    CA    95823   4    2       1,552  Single Family
# 14       LosAngeles    CA    90046   4    6       5,700  Single Family
# 15     MorenoValley    CA    92551   4    3       2,134  Single Family
# 16         Redlands    CA    92374   3    1         960  Single Family
# 17          Norwalk    CA    90650   4    2       1,290  Single Family
# 18          LaJolla    CA     null   7    8       7,569  Single Family
# 19          Fontana    CA    92337   5    3       2,213  Single Family
# 20      AppleValley    CA    92307   3    2       1,824  Single Family
# 21        Lancaster    CA    93536   3    3       2,254  Single Family
# 22  HaciendaHeights    CA    91745   3    2       1,230           null
# 23       LosAngeles    CA    90049   9   15      18,850           null
# 24     BeverlyHills    CA    90210  10   11      17,245           null
# 25        Fullerton    CA    92832   4    4       2,500           null
# 26           Venice    CA    90291   5    9       7,102           null
# 27            Vista    CA    92081   4    3       2,150           null
# 28       LosAngeles    CA    90077   9   10      12,201           null
# 29       StudioCity    CA    91604   6    9       8,500           null
# 30       LosAngeles    CA    90069   5    8       9,810           null
# 31         Palmdale    CA    93550   3    2       1,209           null
# 32           Corona    CA    92883   4    3       2,206           null
# 33      AppleValley    CA    92307   3    2       1,592           null
# 34          Newhall    CA     null   3    2       1,040           null
# 35       Atascadero    CA    93422   3    2       1,748           null
# 36          LaJolla    CA    92037   5    6       4,127           null
# 37    ElDoradoHills    CA    95762   3    3       1,628           null
# 38           Oxnard    CA    93035   4    2       1,588           null
# 39    CathedralCity    CA    92234   3    2       1,313           null
#
#    Year_build    Parking         HOA          Lot Lot_conversion_to_sqft  \
# 0        2016   2 spaces  $160/month   5,009 sqft                   5009
# 1        1966   2 spaces        null   0.25 acres                  10890
# 2        1989   3 spaces        null   9,583 sqft                   9583
# 3        1989   2 spaces        null   1.21 acres                52707.6
# 4        2000  80 spaces  $233/month    5.2 acres                 226512
# 5        2020  20 spaces        null   1.35 acres                  58806
# 6        2018  15 spaces        null   0.67 acres                29185.2
# 7        1973    No Data        null   1.14 acres                49658.4
# 8        1958   6 spaces        None   0.25 acres                  10890
# 9        2019  20 spaces        null   1.25 acres                  54450
# 10       2005   6 spaces  $200/month  10,454 sqft                  10454
# 11       1976   5 spaces        None   6,969 sqft                   6969
# 12       2001   4 spaces  $350/month   0.25 acres                  10890
# 13       1982   2 spaces        None   6,050 sqft                   6050
# 14       1950   2 spaces        null  10,127 sqft                  10127
# 15       1990   2 spaces   $50/month   7,405 sqft                   7405
# 16       1955   2 spaces        None   6,799 sqft                   6799
# 17       1950   2 spaces        None   5,022 sqft                   5022
# 18       2020  12 spaces        None  10,018 sqft                  10018
# 19       1989   2 spaces        None   4,499 sqft                   4499
# 20       1996   2 spaces        null   0.34 acres                14810.4
# 21       1986   3 spaces        None   9,147 sqft                   9147
# 22       null       null        null         null                   null
# 23       null       null        null         null                   null
# 24       null       null        null         null                   null
# 25       null       null        null         null                   null
# 26       null       null        null         null                   null
# 27       null       null        null         null                   null
# 28       null       null        null         null                   null
# 29       null       null        null         null                   null
# 30       null       null        null         null                   null
# 31       null       null        null         null                   null
# 32       null       null        null         null                   null
# 33       null       null        null         null                   null
# 34       null       null        null         null                   null
# 35       null       null        null         null                   null
# 36       null       null        null         null                   null
# 37       null       null        null         null                   null
# 38       null       null        null         null                   null
# 39       null       null        null         null                   null
#
#       Zestimate Rent_zestimate Zillow_price/sqft  \
# 0      $605,235      $3,024/mo              $179
# 1      $598,336      $4,000/mo              $334
# 2      $433,776      $2,645/mo              $179
# 3      $460,481      $2,300/mo               $84
# 4   $77,674,096    $119,621/mo            $2,500
# 5   $79,901,996     $50,702/mo            $2,439
# 6   $50,805,553     $66,566/mo            $3,964
# 7      $198,733      $2,400/mo               $87
# 8      $777,588      $3,500/mo               $95
# 9   $53,263,839    $207,270/mo            $2,321
# 10     $727,993      $4,500/mo                $3
# 11     $525,002      $2,600/mo              $275
# 12     $972,588      $7,471/mo              $294
# 13     $301,929      $1,800/mo              $193
# 14   $2,286,065      $6,200/mo              $412
# 15     $379,964      $2,200/mo              $140
# 16     $298,715      $1,750/mo              $318
# 17     $549,905      $2,945/mo              $426
# 18         null           null            $2,642
# 19     $437,633      $2,400/mo              $158
# 20     $194,677      $1,600/mo              $153
# 21     $369,915      $2,400/mo              $173
# 22         null           null              null
# 23         null           null              null
# 24         null           null              null
# 25         null           null              null
# 26         null           null              null
# 27         null           null              null
# 28         null           null              null
# 29         null           null              null
# 30         null           null              null
# 31         null           null              null
# 32         null           null              null
# 33         null           null              null
# 34         null           null              null
# 35         null           null              null
# 36         null           null              null
# 37         null           null              null
# 38         null           null              null
# 39         null           null              null
#
#                                         House_website
# 0   https://www.zillow.com/homedetails/5048-S-Kens...
# 1   https://www.zillow.com/homedetails/300-N-Orchi...
# 2   https://www.zillow.com/homedetails/6221-W-Aven...
# 3   https://www.zillow.com/homedetails/9804-Choice...
# 4   https://www.zillow.com/homedetails/2571-Wallin...
# 5   https://www.zillow.com/homedetails/10697-Somma...
# 6   https://www.zillow.com/homedetails/1301-Collin...
# 7   https://www.zillow.com/homedetails/36326-32nd-...
# 8   https://www.zillow.com/homedetails/259-N-Farre...
# 9   https://www.zillow.com/homedetails/627-Carcass...
# 10  https://www.zillow.com/homedetails/78145-Red-H...
# 11  https://www.zillow.com/homedetails/2128-Appleg...
# 12  https://www.zillow.com/homedetails/2535-Ridgeg...
# 13  https://www.zillow.com/homedetails/59-Milpitas...
# 14  https://www.zillow.com/homedetails/7932-Woodro...
# 15  https://www.zillow.com/homedetails/25825-Via-Q...
# 16  https://www.zillow.com/homedetails/750-E-Pione...
# 17  https://www.zillow.com/homedetails/11308-Foste...
# 18  https://www.zillow.com/homedetails/5220-Chelse...
# 19  https://www.zillow.com/homedetails/11448-Winer...
# 20  https://www.zillow.com/homedetails/16424-Pauha...
# 21  https://www.zillow.com/homedetails/43704-Sugar...
# 22  https://www.zillow.com/homedetails/1140-Eldon-...
# 23  https://www.zillow.com/homedetails/11490-Orum-...
# 24  https://www.zillow.com/homedetails/14175-Mulho...
# 25  https://www.zillow.com/homedetails/401-S-Highl...
# 26  https://www.zillow.com/homedetails/17-23rd-Ave...
# 27  https://www.zillow.com/homedetails/1688-Carria...
# 28  https://www.zillow.com/homedetails/141-S-Carol...
# 29  https://www.zillow.com/homedetails/11584-Dilli...
# 30  https://www.zillow.com/homedetails/1622-Viewmo...
# 31  https://www.zillow.com/homedetails/3032-Via-Pr...
# 32  https://www.zillow.com/homedetails/4330-Altivo...
# 33  https://www.zillow.com/homedetails/22300-Isati...
# 34  https://www.zillow.com/homedetails/23500-The-O...
# 35  https://www.zillow.com/homedetails/7910-Balboa...
# 36  https://www.zillow.com/homedetails/5558-Avenid...
# 37  https://www.zillow.com/homedetails/1001-Emeral...
# 38  https://www.zillow.com/homedetails/1834-Adelai...
# 39  https://www.zillow.com/homedetails/69480-Victo...

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q2-2020_Single_Family_Data_page5-8.csv", index=False, header=True)
