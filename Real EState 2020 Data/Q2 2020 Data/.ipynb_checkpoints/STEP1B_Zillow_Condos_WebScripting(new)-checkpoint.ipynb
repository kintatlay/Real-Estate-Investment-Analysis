# %%
# Tutorial: https://www.youtube.com/watch?v=dRcvJRmqFHQ&lc=UgyUDvoIA0A37EWWoC54AaABAg.9Aem3mXGQzz9Aep5dNrAY6
import requests
from bs4 import BeautifulSoup
import json
import time
import csv
import pandas as pd
import os

class ZillowScraper():
    results = []
    headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'zguid=23|%24d7ce356c-e3c5-4a48-85b3-61d0af33c3a1; zgsession=1|76ac70ba-62bc-4f77-81a1-b46b55a3f268; _ga=GA1.2.656681018.1593695925; _gid=GA1.2.1901059192.1593695925; zjs_user_id=null; zjs_anonymous_id=%22d7ce356c-e3c5-4a48-85b3-61d0af33c3a1%22; _pxvid=930c8230-bc66-11ea-9dd2-0242ac120007; _gcl_au=1.1.2002891296.1593696177; KruxPixel=true; DoubleClickSession=true; _pin_unauth=dWlkPU9EbG1aR0ptTTJVdFkySXpPUzAwWVdZMUxXSTFNVE10TnpFNE1EZGpOamxsWWpZNQ; _fbp=fb.1.1593696180071.236888825; KruxAddition=true; g_state={"i_p":1593716288950,"i_l":1}; JSESSIONID=0C394BB3DC7B91E479B72A328353817A; GASession=true; _pxff_bsco=1; AWSALB=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; AWSALBCORS=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; search=6|1596363321838%7Crect%3D43.45764218649565%252C-109.08936284375%252C30.85123360186431%252C-129.52393315625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D0%26days%3D90%26type%3Dhouse%26lt%3Dfsba%252Cfsbo%252Cfore%252Cnew%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%09%099%09%09%09%09%09%09; _px3=d4336234c4010c751aebc89c46325b0fb974e47215ce19445dfb759a629e81dc:X7e2f9pB1glpxKBrZ31UbYr/SXJFF+UxNWu+hiMsI+DQ7Mqle+9ez9SpkHaEa0n8KjNaAtb3oFQCfBoM9SkdFQ==:1000:AfuabQEQyo2l//8QKend7zOjb5sDW5Is+c6zQcm/upUYyYJc1jNQiyYnwroZOcBIjJBNJ8+vUKEJ3TlBoNaX/O7UbA0YkImLQb+VkAlAZWRj+w8lmqxZjshBeq6rrIg7GVsOSD+a1N8QtabSrjTIOF1SbQdGaZFzwVUu+aT6YiQ=; _uetsid=b093ce5e-93c4-0334-9c39-42ee7af2a929; _uetvid=e59e74ae-427f-984f-1765-cdc49ba1fa47',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    }
        
    def fetch(self, url, params):
        response = requests.get(url, headers=self.headers, params=params)
        print(response.status_code)
        return response
    
    def parse(self, response):
        content = BeautifulSoup(response, 'lxml')
        deck = content.find('ul', {'class': 'photo-cards photo-cards_wow photo-cards_short'})
        for card in deck.contents:
            script = card.find('script', {'type': 'application/ld+json'})
            if script:
                script_json = json.loads(script.contents[0])
                loop_response = requests.get(script_json['url'], headers=self.headers)
                loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
                try:
                    loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
                except IndexError:
                    loop_result2 = 'null'
                lot = 'null';
                house_type = 'null';
                year_build = 'null';
                parking = 'null';
                hoa = 'null';
                lot_conversion_to_sqft = 'null';
                zillow_price_per_sqft = 'null';
                
                if loop_result2:
                    for contents in loop_result2:
                        print(contents.text)
                        if "Lot" in contents.text.split(":")[0]:
                            lot = contents.text.split(":")[1];
                        if "Type" in contents.text.split(":")[0]:
                            house_type = contents.text.split(":")[1];
                        if "Year built" in contents.text.split(":")[0]:
                            year_build = contents.text.split(":")[1];
                        if "Parking" in contents.text.split(":")[0]:
                            parking = contents.text.split(":")[1];
                        if "HOA" in contents.text.split(":")[0]:
                            hoa = contents.text.split(":")[1];
                        if "Price/sqft" in contents.text.split(":")[0]:
                            zillow_price_per_sqft = contents.text.split(":")[1];
                
                    try:
                        zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
                        rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[3].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
                    except AttributeError:
                        zestimate = 'null'
                        rent_zestimate = 'null'
                    try:
                        if (str(lot.split(" ")[1]) == "sqft"):
                            lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                        elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                            lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                        elif (lot == "No Data"):
                            lot_conversion_to_sqft = 'null'
                        else:
                            lot_conversion_to_sqft = 'null'
                    except IndexError:
                        lot_conversion_to_sqft = 'null'
                        
                    self.results.append({
                        'Listing_type': card.find('div', {'class': 'list-card-type'}).text,
                        'Price': card.find('div', {'class': 'list-card-price'}).text,
                        'Full_address': script_json['name'],
                        'Street': script_json['address']['streetAddress'],
                        'City': script_json['address']['addressLocality'],
                        'State': script_json['address']['addressRegion'],
                        'Zip_code': script_json['address']['postalCode'],
                        'Latitude': script_json['geo']['latitude'],
                        'Longitude': script_json['geo']['longitude'],
                        'Square_Feet': script_json['floorSize']['value'],
                        'Lot': lot,
                        'Lot_conversion_to_sqft': lot_conversion_to_sqft,
                        'House_type': house_type,
                        'Year_build': year_build,
                        'Parking': parking,
                        'Hoa': hoa,
                        'Zillow_price_per_sqft': zillow_price_per_sqft,
                        'Zestimate': zestimate,
                        'Rent_zestimate': rent_zestimate,
                        'House_website': script_json['url']
                    })
                    time.sleep(3)
                
    def to_csv(self):
        dirName = 'Output/Zillow/'
        if not os.path.exists(dirName):
            os.mkdir(dirName)
            print("Directory ", dirName, " Folder created ")
        else:
            print("Directory ", dirName, " Folder already exists")
            
        with open('./' + dirName + 'Q2-2020_Condo_Data_page17-20.csv', 'w') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            
            for row in self.results:
                writer.writerow(row)

    def to_dftable(self):
        house_data = pd.DataFrame(self.results)
        print(house_data)

#     Filter Out Coming Soon, Auction, Home Type: Condos, Days On Zillow: 90 Days
    def run(self):
        url = 'https://www.zillow.com/ca/condos/'
        for page in range(17,21):
            params = {
                'searchQueryState':'{"pagination":{"currentPage":%s},"usersSearchTerm":"ca","mapBounds":{"west":-153.847663625,"east":-84.765632375,"south":12.777434491046959,"north":56.013075839104054},"mapZoom":4,"regionSelection":[{"regionId":9,"regionType":2}],"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"},"isSingleFamily":{"value":false}},"isListVisible":true,"isMapVisible":true}' %page
            }
            res = self.fetch(url, params)
            self.parse(res.text)
            time.sleep(2)
        self.to_dftable()
        self.to_csv()
        
if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run();
# Out:
# 200
# Type:Condo
# Year built:1982
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$300/month
# Price/sqft:$490
# Type:Condo
# Year built:1971
# Heating:Forced air
# Cooling:Other
# Parking:Carport, On street
# HOA:$435/month
# Price/sqft:$442
# Type:Condo
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$275/month
# Price/sqft:$216
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$430/month
# Price/sqft:$585
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:None
# Parking:1 space
# HOA:$524/month
# Price/sqft:$343
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$156/month
# Price/sqft:$231
# Type:Condo
# Year built:1964
# Heating:Gas
# Cooling:Central
# Parking:Carport
# HOA:$745/month
# Price/sqft:$333
# Type:Condo
# Year built:1907
# Heating:No Data
# Cooling:No Data
# Parking:Attached Garage
# HOA:$438/month
# Price/sqft:$1,241
# Type:Condo
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$242
# Type:Condo
# Year built:1995
# Heating:No Data
# Cooling:Wall
# Parking:1 space
# HOA:$691/month
# Price/sqft:$920
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$355/month
# Price/sqft:$409
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$395/month
# Price/sqft:$574
# Type:Condo
# Year built:1971
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$86/month
# Price/sqft:$205
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$240/month
# Price/sqft:$186
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$275/month
# Price/sqft:$683
# Type:Condo
# Year built:1993
# Heating:Stove
# Cooling:None
# Parking:2 spaces
# HOA:$172/month
# Price/sqft:$224
# Type:Condo
# Year built:1973
# Heating:No Data
# Cooling:Central
# Parking:1 space
# HOA:No Data
# Price/sqft:$539
# Type:Condo
# Year built:2008
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:$70/month
# Price/sqft:$695
# Type:Condo
# Year built:1974
# Heating:Forced air
# Cooling:Wall
# Parking:1 space
# HOA:$375/month
# Price/sqft:$858
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$608/month
# Price/sqft:$215
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:No Data
# Parking:2 spaces
# HOA:$363/month
# Price/sqft:$332
# Type:Cooperative
# Year built:1965
# Heating:Heat pump
# Cooling:Wall
# Parking:1 space
# HOA:$602/month
# Price/sqft:$223
# Type:Condo
# Year built:1975
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$565/month
# Price/sqft:$1,064
# Type:Condo
# Year built:No Data
# Heating:No Data
# Cooling:No Data
# Parking:None
# HOA:$350/month
# Price/sqft:$804
# Type:Condo
# Year built:1980
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# HOA:$165/month
# Price/sqft:$376
# Type:Condo
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$300/month
# Price/sqft:$175
# Type:Condo
# Year built:1926
# Heating:No Data
# Cooling:No Data
# Parking:1 space
# HOA:No Data
# Price/sqft:$867
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:Other
# Parking:2 spaces
# HOA:$330/month
# Price/sqft:$302
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$363/month
# Price/sqft:$485
# Type:Condo
# Year built:1979
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$785/month
# Price/sqft:$308
# Type:Condo
# Year built:2017
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$164/month
# Price/sqft:$469
# Type:Condo
# Year built:1948
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$386/month
# Price/sqft:$521
# Type:Condo
# Year built:2014
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$139/month
# Price/sqft:$453
# Type:Condo
# Year built:1973
# Heating:Wall
# Cooling:None
# Parking:1 space
# HOA:$222/month
# Price/sqft:$438
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$604/month
# Price/sqft:$187
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$282/month
# Price/sqft:$224
# Type:Condo
# Year built:1982
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$300/month
# Price/sqft:$480
# Type:Condo
# Year built:1963
# Heating:Forced air
# Cooling:None
# Parking:1 space
# HOA:$371/month
# Price/sqft:$499
# Type:Condo
# Year built:1985
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# HOA:$375/month
# Price/sqft:$277
# Type:Condo
# Year built:1970
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$390/month
# Price/sqft:$296
# 200
# Type:Condo
# Year built:1988
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$225/month
# Price/sqft:$352
# Type:Condo
# Year built:1991
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$294/month
# Price/sqft:$487
# Type:Condo
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$300/month
# Price/sqft:$267
# Type:Condo
# Year built:1958
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$610/month
# Price/sqft:$160
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$699/month
# Price/sqft:$519
# Type:Condo
# Year built:1979
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# HOA:$612/month
# Price/sqft:$321
# Type:Condo
# Year built:2000
# Heating:No Data
# Cooling:Central
# Parking:2 spaces
# HOA:$265/month
# Price/sqft:$453
# Type:Condo
# Year built:1979
# Heating:Electric
# Cooling:Central
# Parking:5 spaces
# HOA:$450/month
# Price/sqft:$234
# Type:Condo
# Year built:1986
# Heating:Radiant
# Cooling:None
# Parking:2 spaces
# HOA:$410/month
# Price/sqft:$580
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$280/month
# Price/sqft:$207
# Type:Condo
# Year built:1985
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$416/month
# Price/sqft:$451
# Type:Condo
# Year built:1962
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$2,780/month
# Price/sqft:$827
# Type:Condo
# Year built:1964
# Heating:Forced air
# Cooling:Wall
# Parking:2 spaces
# HOA:$310/month
# Price/sqft:$423
# Type:Condo
# Year built:1967
# Heating:Forced air
# Cooling:Central, Evaporative
# Parking:2 spaces
# HOA:$352/month
# Price/sqft:$395
# Type:Condo
# Year built:1924
# Heating:Radiant
# Cooling:No Data
# Parking:None
# HOA:$614/month
# Price/sqft:$1,151
# Type:Condo
# Year built:1986
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$352/month
# Price/sqft:$424
# Type:Condo
# Year built:2005
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$372/month
# Price/sqft:$243
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Other
# Parking:None
# HOA:$462/month
# Price/sqft:$831
# Type:Condo
# Year built:1970
# Heating:Other
# Cooling:Central
# Parking:No Data
# HOA:$215/month
# Price/sqft:$399
# Type:Condo
# Year built:1982
# Heating:Other
# Cooling:Other
# Parking:2 spaces
# HOA:$300/month
# Price/sqft:$288
# Type:Condo
# Year built:1971
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$725/month
# Price/sqft:$176
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:No Data
# Parking:2 spaces
# HOA:$400/month
# Price/sqft:$286
# Type:Condo
# Year built:1971
# Heating:Forced air
# Cooling:None
# Parking:Off street, Attached Garage
# HOA:$365/month
# Price/sqft:$618
# Type:Condo
# Year built:1972
# Heating:Electric, Gas
# Cooling:No Data
# Parking:2 spaces
# HOA:$450/month
# Price/sqft:$392
# Type:Condo
# Year built:1961
# Heating:Forced air
# Cooling:Other
# Parking:2 spaces
# HOA:$243/month
# Price/sqft:$882
# Type:Condo
# Year built:1976
# Heating:Other
# Cooling:Central
# Parking:No Data
# HOA:$664/month
# Price/sqft:$342
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$310/month
# Price/sqft:$396
# Type:Condo
# Year built:2018
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$139/month
# Price/sqft:$476
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$275/month
# Price/sqft:$478
# Type:Condo
# Year built:1971
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:No Data
# Price/sqft:$416
# Type:Condo
# Year built:1963
# Heating:Radiant
# Cooling:None
# Parking:1 space
# HOA:$400/month
# Price/sqft:$511
# Type:Condo
# Year built:1989
# Heating:Electric
# Cooling:No Data
# Parking:2 spaces
# HOA:$220/month
# Price/sqft:$297
# Type:Condo
# Year built:1993
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$130/month
# Price/sqft:$308
# Type:Condo
# Year built:1973
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$630/month
# Price/sqft:$230
# Type:Condo
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$367/month
# Price/sqft:$396
# Type:Condo
# Year built:1983
# Heating:Forced air
# Cooling:None
# Parking:1 space
# HOA:$465/month
# Price/sqft:$449
# Type:Condo
# Year built:2013
# Heating:No Data
# Cooling:Central
# Parking:1 space
# HOA:$197/month
# Price/sqft:$500
# Type:Condo
# Year built:1911
# Heating:No Data
# Cooling:No Data
# Parking:1 space
# HOA:$351/month
# Price/sqft:$1,185
# Type:Condo
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$573/month
# Price/sqft:$238
# Type:Condo
# Year built:2020
# Heating:No Data
# Cooling:Central
# Parking:2 spaces
# HOA:$215/month
# Price/sqft:$391
# 200
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:Central
# Parking:Carport
# HOA:$253/month
# Price/sqft:$382
# Type:Condo
# Year built:1964
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$381/month
# Price/sqft:$336
# Type:Condo
# Year built:1999
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$1,000/month
# Price/sqft:$244
# Type:Condo
# Year built:2017
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# HOA:None
# Price/sqft:$178
# Type:Condo
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$251/month
# Price/sqft:$242
# Type:Condo
# Year built:1982
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# HOA:$595/month
# Price/sqft:$910
# Type:Condo
# Year built:1983
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$305/month
# Price/sqft:$358
# Type:Condo
# Year built:2012
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# HOA:$776/month
# Price/sqft:$163
# Type:Condo
# Year built:1916
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:$373/month
# Price/sqft:No Data
# Type:Condo
# Year built:1977
# Heating:Forced air
# Cooling:No Data
# Parking:1 space
# HOA:$459/month
# Price/sqft:$434
# Type:Condo
# Year built:1968
# Heating:No Data
# Cooling:Wall
# Parking:No Data
# HOA:No Data
# Price/sqft:$1,067
# Type:Condo
# Year built:1981
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$482/month
# Price/sqft:$436
# Type:Condo
# Year built:1962
# Heating:Forced air
# Cooling:Wall
# Parking:1 space
# HOA:$233/month
# Price/sqft:$671
# Type:Condo
# Year built:1989
# Heating:Electric
# Cooling:No Data
# Parking:2 spaces
# HOA:$355/month
# Price/sqft:$466
# Type:Condo
# Year built:1986
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$679/month
# Price/sqft:$937
# Type:Condo
# Year built:1970
# Heating:No Data
# Cooling:None
# Parking:Carport
# HOA:$268/month
# Price/sqft:$339
# Type:Condo
# Year built:1986
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$348/month
# Price/sqft:$250
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$466/month
# Price/sqft:$733
# Type:Condo
# Year built:1975
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$425/month
# Price/sqft:$145
# Type:Condo
# Year built:1963
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$153/month
# Price/sqft:$416
# Type:Condo
# Year built:1945
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$225
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$420/month
# Price/sqft:$441
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$324/month
# Price/sqft:$219
# Type:Condo
# Year built:1977
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$242/month
# Price/sqft:$496
# Type:Condo
# Year built:1973
# Heating:No Data
# Cooling:No Data
# Parking:1 space
# HOA:$285/month
# Price/sqft:$461
# Type:Condo
# Year built:1988
# Heating:Electric
# Cooling:None
# Parking:1 space
# HOA:$488/month
# Price/sqft:$809
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$358/month
# Price/sqft:$516
# Type:Condo
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$324/month
# Price/sqft:$176
# Type:Condo
# Year built:1986
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:No Data
# Price/sqft:$559
# Type:Condo
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$316/month
# Price/sqft:$321
# Type:Condo
# Year built:1974
# Heating:Wall
# Cooling:None
# Parking:1 space
# HOA:$490/month
# Price/sqft:$672
# Type:Condo
# Year built:1973
# Heating:Electric
# Cooling:No Data
# Parking:1 space
# HOA:$442/month
# Price/sqft:$599
# Type:Condo
# Year built:1977
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$450/month
# Price/sqft:$369
# Type:Condo
# Year built:2008
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$292
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$285/month
# Price/sqft:$454
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central, Other
# Parking:2 spaces
# HOA:$226/month
# Price/sqft:$454
# Type:Condo
# Year built:1993
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$260/month
# Price/sqft:$527
# Type:Condo
# Year built:1959
# Heating:Wall
# Cooling:Other
# Parking:No Data
# HOA:$202/month
# Price/sqft:$425
# Type:Condo
# Year built:1969
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:$350/month
# Price/sqft:No Data
# Type:Condo
# Year built:1985
# Heating:Forced air
# Cooling:Central
# Parking:Carport, Detached Garage
# HOA:$188/month
# Price/sqft:$341
# 200
# Type:Condo
# Year built:1972
# Heating:Wall
# Cooling:No Data
# Parking:No Data
# HOA:No Data
# Price/sqft:$378
# Type:Condo
# Year built:1979
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:$409/month
# Price/sqft:$377
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$510/month
# Price/sqft:$166
# Type:Condo
# Year built:1984
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$536/month
# Price/sqft:$355
# Type:Condo
# Year built:1990
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$299/month
# Price/sqft:$258
# Type:Condo
# Year built:1941
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:$300/month
# Price/sqft:$1,181
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$300/month
# Price/sqft:$208
# Type:Cooperative
# Year built:1966
# Heating:Wall
# Cooling:Wall
# Parking:Carport
# HOA:$772/month
# Price/sqft:$191
# Type:Condo
# Year built:1989
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$402/month
# Price/sqft:$360
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$140/month
# Price/sqft:$229
# Type:Condo
# Year built:2019
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$466/month
# Price/sqft:$305
# Type:Condo
# Year built:1979
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$370/month
# Price/sqft:$626
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$346/month
# Price/sqft:$382
# Type:Condo
# Year built:1964
# Heating:Forced air
# Cooling:Wall
# Parking:Carport
# HOA:$260/month
# Price/sqft:$401
# Type:Condo
# Year built:1971
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# HOA:$451/month
# Price/sqft:$660
# Type:Condo
# Year built:1977
# Heating:Baseboard
# Cooling:None
# Parking:2 spaces
# HOA:$610/month
# Price/sqft:$766
# Type:Condo
# Year built:1986
# Heating:No Data
# Cooling:Central
# Parking:1 space
# HOA:$352/month
# Price/sqft:$334
# Type:Condo
# Year built:1982
# Heating:Baseboard
# Cooling:Other
# Parking:2 spaces
# HOA:$350/month
# Price/sqft:$335
# Type:Condo
# Year built:1966
# Heating:Other, Stove, Wall
# Cooling:No Data
# Parking:1 space
# HOA:No Data
# Price/sqft:$354
# Type:Condo
# Year built:1957
# Heating:Wall
# Cooling:None
# Parking:1 space
# HOA:$320/month
# Price/sqft:$1,004
# Type:Condo
# Year built:2003
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$193/month
# Price/sqft:$339
# Type:Condo
# Year built:1974
# Heating:Baseboard, Wall
# Cooling:Other
# Parking:1 space
# HOA:$712/month
# Price/sqft:$689
# Type:Condo
# Year built:1974
# Heating:Other
# Cooling:No Data
# Parking:2 spaces
# HOA:$153/month
# Price/sqft:$468
# Type:Condo
# Year built:1929
# Heating:Electric
# Cooling:None
# Parking:1 space
# HOA:$1,572/month
# Price/sqft:$587
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$189/month
# Price/sqft:$332
# Type:Condo
# Year built:1990
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$397/month
# Price/sqft:$480
# Type:Condo
# Year built:2008
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$157/month
# Price/sqft:$241
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Other
# Parking:None
# HOA:$387/month
# Price/sqft:$1,465
# Type:Condo
# Year built:1965
# Heating:Wall
# Cooling:None
# Parking:Carport
# HOA:$460/month
# Price/sqft:$831
# Type:Condo
# Year built:1959
# Heating:Forced air, Other
# Cooling:Central
# Parking:1 space
# HOA:$630/month
# Price/sqft:$527
# Type:Condo
# Year built:1973
# Heating:Forced air
# Cooling:No Data
# Parking:1 space
# HOA:$404/month
# Price/sqft:$648
# Type:Condo
# Year built:1984
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$700/month
# Price/sqft:$532
# Type:Condo
# Year built:1986
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$214
# Type:Cooperative
# Year built:1966
# Heating:Wall
# Cooling:Wall
# Parking:1 space
# HOA:$325/month
# Price/sqft:$506
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$325/month
# Price/sqft:$482
# Type:Condo
# Year built:1988
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$721
# Type:Condo
# Year built:2001
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$100/month
# Price/sqft:$237
# Type:Condo
# Year built:2009
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$239/month
# Price/sqft:$304
# Type:Condo
# Year built:1926
# Heating:Forced air
# Cooling:None
# Parking:Detached Garage
# HOA:$105/month
# Price/sqft:$655
# Type:Condo
# Year built:1987
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$358/month
# Price/sqft:$390
#        Listing_type       Price  \
# 0    Condo for sale    $398,000
# 1    Condo for sale    $649,900
# 2    Condo for sale    $225,777
# 3    Condo for sale    $619,000
# 4    Condo for sale    $289,000
# ..              ...         ...
# 155  Condo for sale  $1,998,000
# 156  Condo for sale    $455,000
# 157  Condo for sale    $639,500
# 158  Condo for sale    $885,000
# 159  Condo for sale    $549,990
#
#                                           Full_address  \
# 0           5500 Dobbs St Apt 4, Los Angeles, CA 90032
# 1                      2083 Ascot Dr, Moraga, CA 94556
# 2       2660 Twain Dr Apt 13, San Bernardino, CA 92407
# 3    10926 Bluffside Dr Unit 30, Los Angeles, CA 91604
# 4     4861 Lago Dr Apt 304, Huntington Beach, CA 92649
# ..                                                 ...
# 155     131 Galleon St Apt 2, Marina Del Rey, CA 90292
# 156               42143 Acacia Way, Temecula, CA 92591
# 157               760 E Valencia St, Anaheim, CA 92805
# 158              4516 Montgomery St, Oakland, CA 94611
# 159             3150 Avenida Alcor, Carlsbad, CA 92009
#
#                          Street              City State Zip_code   Latitude  \
# 0           5500 Dobbs St Apt 4       Los Angeles    CA    90032  34.072696
# 1                2083 Ascot Dr             Moraga    CA    94556  37.855179
# 2          2660 Twain Dr Apt 13    San Bernardino    CA    92407  34.186283
# 3    10926 Bluffside Dr Unit 30       Los angeles    CA    91604  34.140865
# 4          4861 Lago Dr Apt 304  Huntington Beach    CA    92649  33.721740
# ..                          ...               ...   ...      ...        ...
# 155        131 Galleon St Apt 2    Marina Del Rey    CA    90292  33.976541
# 156           42143 Acacia Way           Temecula    CA    92591  33.511822
# 157          760 E Valencia St            Anaheim    CA    92805  33.828589
# 158         4516 Montgomery St            Oakland    CA    94611  37.832791
# 159         3150 Avenida Alcor           Carlsbad    CA    92009  33.093818
#
#       Longitude Square_Feet   Lot Lot_conversion_to_sqft House_type  \
# 0   -118.162918         813  null                   null      Condo
# 1   -122.127672       1,472  null                   null      Condo
# 2   -117.348015       1,045  null                   null      Condo
# 3   -118.368151       1,058  null                   null      Condo
# 4   -118.044835         843  null                   null      Condo
# ..          ...         ...   ...                    ...        ...
# 155 -118.462044       2,771  null                   null      Condo
# 156 -117.134762       1,922  null                   null      Condo
# 157 -117.905643       2,107  null                   null      Condo
# 158 -122.246747       1,352  null                   null      Condo
# 159 -117.241068       1,409  null                   null      Condo
#
#     Year_build             Parking         Hoa Zillow_price_per_sqft  \
# 0         1982            2 spaces  $300/month                  $490
# 1         1971  Carport, On street  $435/month                  $442
# 2         1984             1 space  $275/month                  $216
# 3         1981            2 spaces  $430/month                  $585
# 4         1980             1 space  $524/month                  $343
# ..         ...                 ...         ...                   ...
# 155       1988            2 spaces        None                  $721
# 156       2001            2 spaces  $100/month                  $237
# 157       2009            2 spaces  $239/month                  $304
# 158       1926     Detached Garage  $105/month                  $655
# 159       1987            2 spaces  $358/month                  $390
#
#       Zestimate Rent_zestimate  \
# 0      $398,002      $1,950/mo
# 1          null           null
# 2      $224,777      $1,650/mo
# 3      $619,005      $2,800/mo
# 4      $286,536      $1,975/mo
# ..          ...            ...
# 155  $1,943,579      $8,204/mo
# 156    $455,003      $2,295/mo
# 157    $635,600      $3,100/mo
# 158    $965,626      $3,975/mo
# 159    $549,990      $2,625/mo
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/5500-Dobbs-...
# 1    https://www.zillow.com/homedetails/2083-Ascot-...
# 2    https://www.zillow.com/homedetails/2660-Twain-...
# 3    https://www.zillow.com/homedetails/10926-Bluff...
# 4    https://www.zillow.com/homedetails/4861-Lago-D...
# ..                                                 ...
# 155  https://www.zillow.com/homedetails/131-Galleon...
# 156  https://www.zillow.com/homedetails/42143-Acaci...
# 157  https://www.zillow.com/homedetails/760-E-Valen...
# 158  https://www.zillow.com/homedetails/4516-Montgo...
# 159  https://www.zillow.com/homedetails/3150-Avenid...
#
# [160 rows x 20 columns]
# Directory  Output/Zillow/  Folder already exists
