# %%
# Tutorial: https://www.youtube.com/watch?v=dRcvJRmqFHQ&lc=UgyUDvoIA0A37EWWoC54AaABAg.9Aem3mXGQzz9Aep5dNrAY6
import requests
from bs4 import BeautifulSoup
import json
import time
import csv
import pandas as pd
import os

class ZillowScraper():
    results = []
    headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'zguid=23|%24d7ce356c-e3c5-4a48-85b3-61d0af33c3a1; zgsession=1|76ac70ba-62bc-4f77-81a1-b46b55a3f268; _ga=GA1.2.656681018.1593695925; _gid=GA1.2.1901059192.1593695925; zjs_user_id=null; zjs_anonymous_id=%22d7ce356c-e3c5-4a48-85b3-61d0af33c3a1%22; _pxvid=930c8230-bc66-11ea-9dd2-0242ac120007; _gcl_au=1.1.2002891296.1593696177; KruxPixel=true; DoubleClickSession=true; _pin_unauth=dWlkPU9EbG1aR0ptTTJVdFkySXpPUzAwWVdZMUxXSTFNVE10TnpFNE1EZGpOamxsWWpZNQ; _fbp=fb.1.1593696180071.236888825; KruxAddition=true; g_state={"i_p":1593716288950,"i_l":1}; JSESSIONID=0C394BB3DC7B91E479B72A328353817A; GASession=true; _pxff_bsco=1; AWSALB=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; AWSALBCORS=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; search=6|1596363321838%7Crect%3D43.45764218649565%252C-109.08936284375%252C30.85123360186431%252C-129.52393315625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D0%26days%3D90%26type%3Dhouse%26lt%3Dfsba%252Cfsbo%252Cfore%252Cnew%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%09%099%09%09%09%09%09%09; _px3=d4336234c4010c751aebc89c46325b0fb974e47215ce19445dfb759a629e81dc:X7e2f9pB1glpxKBrZ31UbYr/SXJFF+UxNWu+hiMsI+DQ7Mqle+9ez9SpkHaEa0n8KjNaAtb3oFQCfBoM9SkdFQ==:1000:AfuabQEQyo2l//8QKend7zOjb5sDW5Is+c6zQcm/upUYyYJc1jNQiyYnwroZOcBIjJBNJ8+vUKEJ3TlBoNaX/O7UbA0YkImLQb+VkAlAZWRj+w8lmqxZjshBeq6rrIg7GVsOSD+a1N8QtabSrjTIOF1SbQdGaZFzwVUu+aT6YiQ=; _uetsid=b093ce5e-93c4-0334-9c39-42ee7af2a929; _uetvid=e59e74ae-427f-984f-1765-cdc49ba1fa47',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    }
        
    def fetch(self, url, params):
        response = requests.get(url, headers=self.headers, params=params)
        print(response.status_code)
        return response
    
    def parse(self, response):
        content = BeautifulSoup(response, 'lxml')
        deck = content.find('ul', {'class': 'photo-cards photo-cards_wow photo-cards_short'})
        for card in deck.contents:
            script = card.find('script', {'type': 'application/ld+json'})
            if script:
                script_json = json.loads(script.contents[0])
                loop_response = requests.get(script_json['url'], headers=self.headers)
                loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
                try:
                    loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
                except IndexError:
                    loop_result2 = 'null'
                lot = 'null';
                house_type = 'null';
                year_build = 'null';
                parking = 'null';
                hoa = 'null';
                lot_conversion_to_sqft = 'null';
                zillow_price_per_sqft = 'null';
                
                if loop_result2:
                    for contents in loop_result2:
                        try:
                            print(contents.text)
                            if "Lot" in contents.text.split(":")[0]:
                                lot = contents.text.split(":")[1];
                            if "Type" in contents.text.split(":")[0]:
                                house_type = contents.text.split(":")[1];
                            if "Year built" in contents.text.split(":")[0]:
                                year_build = contents.text.split(":")[1];
                            if "Parking" in contents.text.split(":")[0]:
                                parking = contents.text.split(":")[1];
                            if "HOA" in contents.text.split(":")[0]:
                                hoa = contents.text.split(":")[1];
                            if "Price/sqft" in contents.text.split(":")[0]:
                                zillow_price_per_sqft = contents.text.split(":")[1];
                        except AttributeError:
                            continue
                
                    try:
                        zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
                        rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[3].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
                    except:
                        zestimate = 'null'
                        rent_zestimate = 'null'
                    try:
                        if (str(lot.split(" ")[1]) == "sqft"):
                            lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                        elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                            lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                        elif (lot == "No Data"):
                            lot_conversion_to_sqft = 'null'
                        else:
                            lot_conversion_to_sqft = 'null'
                    except IndexError:
                        lot_conversion_to_sqft = 'null'
                        
                    self.results.append({
                        'Listing_type': card.find('div', {'class': 'list-card-type'}).text,
                        'Price': card.find('div', {'class': 'list-card-price'}).text,
                        'Full_address': script_json['name'],
                        'Street': script_json['address']['streetAddress'],
                        'City': script_json['address']['addressLocality'],
                        'State': script_json['address']['addressRegion'],
                        'Zip_code': script_json['address']['postalCode'],
                        'Latitude': script_json['geo']['latitude'],
                        'Longitude': script_json['geo']['longitude'],
                        'Square_Feet': script_json['floorSize']['value'],
                        'Lot': lot,
                        'Lot_conversion_to_sqft': lot_conversion_to_sqft,
                        'House_type': house_type,
                        'Year_build': year_build,
                        'Parking': parking,
                        'Hoa': hoa,
                        'Zillow_price_per_sqft': zillow_price_per_sqft,
                        'Zestimate': zestimate,
                        'Rent_zestimate': rent_zestimate,
                        'House_website': script_json['url']
                    })
                    time.sleep(3)
                
    def to_csv(self):
        dirName = 'Output/Zillow/'
        if not os.path.exists(dirName):
            os.mkdir(dirName)
            print("Directory ", dirName, " Folder created ")
        else:
            print("Directory ", dirName, " Folder already exists")
            
        with open('./' + dirName + 'Q2-2020_Townhouse_Data_page17-20.csv', 'w') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            
            for row in self.results:
                writer.writerow(row)

    def to_dftable(self):
        house_data = pd.DataFrame(self.results)
        print(house_data)

#     Filter Out Coming Soon, Auction, Home Type: Townhomes, Days On Zillow: 90 Days
    def run(self):
        url = 'https://www.zillow.com/ca/townhomes/'
        for page in range(17,21):
            params = {
                'searchQueryState':'{"pagination":{"currentPage":%s},"usersSearchTerm":"ca","mapBounds":{"west":-153.847663625,"east":-84.765632375,"south":12.777434491046995,"north":56.013075839104054},"mapZoom":4,"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"filterState":{"isPreMarketPreForeclosure":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"isSingleFamily":{"value":false},"isManufactured":{"value":false},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isLotLand":{"value":false},"doz":{"value":"90"},"isApartment":{"value":false},"isPreMarketForeclosure":{"value":false}},"isListVisible":true}' %page
            }
            res = self.fetch(url, params)
            self.parse(res.text)
            time.sleep(2)
        self.to_dftable()
        self.to_csv()
        
if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run();
# Out:
# 200
# Type:Townhouse
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$449/month
# Lot:766 sqft
# Price/sqft:$701
# Type:Townhouse
# Year built:1990
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$347/month
# Lot:1,001 sqft
# Price/sqft:$494
# Type:Townhouse
# Year built:1972
# Heating:Forced air, Radiant
# Cooling:None
# Parking:2 spaces
# HOA:$240/month
# Lot:8,132 sqft
# Price/sqft:$728
# Type:Townhouse
# Year built:2020
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$202/month
# Lot:No Data
# Price/sqft:$312
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$432/month
# Lot:1,280 sqft
# Price/sqft:$561
# Type:Townhouse
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$399/month
# Lot:710 sqft
# Price/sqft:$605
# Type:Townhouse
# Year built:2019
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$311/month
# Lot:No Data
# Price/sqft:$301
# Type:Townhouse
# Year built:2003
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$493/month
# Lot:100 sqft
# Price/sqft:$597
# Type:Townhouse
# Year built:2013
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# HOA:$408/month
# Lot:0.78 acres
# Price/sqft:$537
# Type:Townhouse
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$465/month
# Lot:7,814 sqft
# Price/sqft:$399
# Type:Townhouse
# Year built:1966
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$495/month
# Lot:6.12 acres
# Price/sqft:$259
# Type:Townhouse
# Year built:1992
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$370/month
# Lot:1.32 acres
# Price/sqft:$342
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$390/month
# Lot:0.31 acres
# Price/sqft:$534
# Type:Townhouse
# Year built:2010
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$115/month
# Lot:988 sqft
# Price/sqft:$304
# Type:Townhouse
# Year built:2003
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Lot:7,505 sqft
# Price/sqft:$525
# Type:Townhouse
# Year built:2019
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$350/month
# Lot:10,602 sqft
# Price/sqft:$536
# Type:Townhouse
# Year built:1991
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$467/month
# Lot:0.6 acres
# Price/sqft:$466
# Type:Townhouse
# Year built:1979
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$336/month
# Lot:3,484 sqft
# Price/sqft:$326
# 200
# Type:Townhouse
# Year built:2002
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$1,075/month
# Lot:1.38 acres
# Price/sqft:$524
# Type:Townhouse
# Year built:1982
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$375/month
# Lot:6,494 sqft
# Price/sqft:$475
# Type:Townhouse
# Year built:1985
# Heating:Forced air
# Cooling:No Data
# Parking:2 spaces
# HOA:$436/month
# Lot:1.73 acres
# Price/sqft:$548
# Type:Townhouse
# Year built:1988
# Heating:Forced air
# Cooling:No Data
# Parking:3 spaces
# HOA:$279/month
# Lot:1,742 sqft
# Price/sqft:$480
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$340/month
# Lot:2,134 sqft
# Price/sqft:$218
# Type:Townhouse
# Year built:2011
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$422/month
# Lot:888 sqft
# Price/sqft:$794
# Type:Townhouse
# Year built:1980
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# HOA:$472/month
# Lot:No Data
# Price/sqft:$542
# Type:Townhouse
# Year built:1983
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$250/month
# Lot:2,726 sqft
# Price/sqft:$262
# Type:Townhouse
# Year built:1975
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$282/month
# Lot:1,385 sqft
# Price/sqft:$415
# Type:Townhouse
# Year built:1975
# Heating:Forced air, Other
# Cooling:Central
# Parking:2 spaces
# HOA:$495/month
# Lot:1.43 acres
# Price/sqft:$303
# Type:Townhouse
# Year built:2014
# Heating:Forced air, Heat pump
# Cooling:Central
# Parking:2 spaces
# HOA:$315/month
# Lot:0.36 acres
# Price/sqft:$294
# Type:Townhouse
# Year built:1976
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$175/month
# Lot:7,226 sqft
# Price/sqft:$730
# Type:Townhouse
# Year built:1974
# Heating:Heat pump, Stove
# Cooling:Central
# Parking:1 space
# HOA:$240/month
# Lot:2,713 sqft
# Price/sqft:$158
# Type:Townhouse
# Year built:2020
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$343/month
# Lot:No Data
# Price/sqft:$318
# Type:Townhouse
# Year built:2020
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$343/month
# Lot:No Data
# Price/sqft:$326
# Type:Townhouse
# Year built:1993
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$335/month
# Lot:1 acre
# Price/sqft:$719
# Type:Townhouse
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$350/month
# Lot:0.39 acres
# Price/sqft:$798
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$257/month
# Lot:No Data
# Price/sqft:$497
# 200
# Type:Townhouse
# Year built:2018
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$280/month
# Lot:1,093 sqft
# Price/sqft:$669
# Type:Townhouse
# Year built:2020
# Heating:No Data
# Cooling:None
# Parking:2 spaces
# HOA:$200/month
# Lot:7,509 sqft
# Price/sqft:$618
# Type:Townhouse
# Year built:2001
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$505/month
# Lot:7,514 sqft
# Price/sqft:$859
# Type:Townhouse
# Year built:1973
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# HOA:$400/month
# Lot:No Data
# Price/sqft:$523
# Type:Townhouse
# Year built:1982
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$315/month
# Lot:644 sqft
# Price/sqft:$451
# Type:Townhouse
# Year built:1980
# Heating:Radiant
# Cooling:Other
# Parking:2 spaces
# HOA:$344/month
# Lot:4.07 acres
# Price/sqft:$506
# Type:Townhouse
# Year built:1982
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$360/month
# Lot:1.97 acres
# Price/sqft:$330
# Type:Townhouse
# Year built:1988
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$429/month
# Lot:2,191 sqft
# Price/sqft:$392
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:$50/month
# Lot:2,090 sqft
# Price/sqft:$475
# Type:Townhouse
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$330/month
# Lot:No Data
# Price/sqft:$423
# Type:Townhouse
# Year built:2015
# Heating:Forced air
# Cooling:None
# Parking:1 space
# HOA:$179/month
# Lot:1,467 sqft
# Price/sqft:$353
# Type:Townhouse
# Year built:1995
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# HOA:$805/month
# Lot:7,518 sqft
# Price/sqft:$911
# Type:Townhouse
# Year built:1995
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$285/month
# Lot:No Data
# Price/sqft:$432
# Type:Townhouse
# Year built:1982
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$150/month
# Lot:4,308 sqft
# Price/sqft:$772
# Type:Townhouse
# Year built:1971
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Lot:664 sqft
# Price/sqft:$340
# Type:Townhouse
# Year built:2020
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$266/month
# Lot:No Data
# Price/sqft:$359
# Type:Townhouse
# Year built:2014
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$332/month
# Lot:1,219 sqft
# Price/sqft:$868
# Type:Townhouse
# Year built:1979
# Heating:Forced air
# Cooling:No Data
# Parking:2 spaces
# HOA:$400/month
# Lot:1,041 sqft
# Price/sqft:$1,014
# Type:Townhouse
# Year built:2007
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Lot:1,203 sqft
# Price/sqft:$638
# Type:Townhouse
# Year built:1986
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$340/month
# Lot:4,673 sqft
# Price/sqft:$668
# 200
# Type:Townhouse
# Year built:2003
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$225/month
# Lot:No Data
# Price/sqft:$397
# Type:Townhouse
# Year built:1990
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$386/month
# Lot:4.47 acres
# Price/sqft:$333
# Type:Townhouse
# Year built:1974
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# HOA:$420/month
# Lot:1,459 sqft
# Price/sqft:$412
# Type:Townhouse
# Year built:1973
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$245/month
# Lot:3.77 acres
# Price/sqft:$409
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$338/month
# Lot:0.41 acres
# Price/sqft:$537
# Type:Townhouse
# Year built:2005
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# HOA:$495/month
# Lot:1.59 acres
# Price/sqft:$666
#           Listing_type       Price  \
# 0   Townhouse for sale    $680,000
# 1   Townhouse for sale    $517,000
# 2   Townhouse for sale  $1,100,000
# 3     New construction    $435,900
# 4   Townhouse for sale    $920,000
# ..                 ...         ...
# 57  Townhouse for sale    $538,000
# 58  Townhouse for sale    $470,000
# 59  Townhouse for sale    $450,000
# 60  Townhouse for sale    $825,000
# 61  Townhouse for sale  $1,559,000
#
#                                         Full_address  \
# 0              1317 Greenwich Ct, San Jose, CA 95125
# 1                  6 Liana Pl, Aliso Viejo, CA 92656
# 2     1528 Berkeley St Apt 1, Santa Monica, CA 90404
# 3          4019 Mission Inn Ave, Riverside, CA 92501
# 4          5711 Canterbury Dr, Culver City, CA 90230
# ..                                               ...
# 57             14073 Lemoli Ave, Hawthorne, CA 90250
# 58  2960 S Greenville St Unit F, Santa Ana, CA 92704
# 59   10950 Saticoy St Unit 46, Los Angeles, CA 91352
# 60            1181 Cherryview Ln, San Jose, CA 95118
# 61   5350 Playa Vista Dr # 29, Playa Vista, CA 90094
#
#                          Street          City State Zip_code   Latitude  \
# 0            1317 Greenwich Ct       San Jose    CA    95125  37.298368
# 1                   6 Liana Pl    Aliso Viejo    CA    92656  33.575106
# 2        1528 Berkeley St Apt 1  Santa Monica    CA    90404  34.034968
# 3         4019 Mission Inn Ave      Riverside    CA    92501  33.985096
# 4           5711 Canterbury Dr    Culver City    CA    90230  33.987781
# ..                          ...           ...   ...      ...        ...
# 57            14073 Lemoli Ave      Hawthorne    CA    90250  33.903559
# 58  2960 S Greenville St Unit F     Santa Ana    CA    92704  33.707749
# 59     10950 Saticoy St Unit 46   Los angeles    CA    91352  34.208291
# 60          1181 Cherryview Ln       San Jose    CA    95118  37.257199
# 61     5350 Playa Vista Dr # 29   Playa Vista    CA    90094  33.975208
#
#      Longitude Square_Feet         Lot Lot_conversion_to_sqft House_type  \
# 0  -121.922980         970    766 sqft                    766  Townhouse
# 1  -117.721656       1,047  1,001 sqft                   1001  Townhouse
# 2  -118.467590       1,512  8,132 sqft                   8132  Townhouse
# 3  -117.377511       1,396     No Data                   null  Townhouse
# 4  -118.379933       1,639  1,280 sqft                   1280  Townhouse
# ..         ...         ...         ...                    ...        ...
# 57 -118.331429       1,615  4.47 acres                 194713  Townhouse
# 58 -117.905865       1,142  1,459 sqft                   1459  Townhouse
# 59 -118.369537       1,100  3.77 acres                 164221  Townhouse
# 60 -121.879350       1,537  0.41 acres                17859.6  Townhouse
# 61 -118.427836       2,340  1.59 acres                69260.4  Townhouse
#
#    Year_build   Parking         Hoa Zillow_price_per_sqft   Zestimate  \
# 0        1981   1 space  $449/month                  $701    $681,767
# 1        1990  2 spaces  $347/month                  $494    $512,622
# 2        1972  2 spaces  $240/month                  $728  $1,113,300
# 3        2020  2 spaces  $202/month                  $312        null
# 4        1984  2 spaces  $432/month                  $561    $920,544
# ..        ...       ...         ...                   ...         ...
# 57       1990  2 spaces  $386/month                  $333    $538,593
# 58       1974  2 spaces  $420/month                  $412    $470,002
# 59       1973  2 spaces  $245/month                  $409    $450,002
# 60       1984  2 spaces  $338/month                  $537    $836,674
# 61       2005  3 spaces  $495/month                  $666  $1,534,567
#
#    Rent_zestimate                                      House_website
# 0       $2,725/mo  https://www.zillow.com/homedetails/1317-Greenw...
# 1       $2,420/mo  https://www.zillow.com/homedetails/6-Liana-Pl-...
# 2       $4,700/mo  https://www.zillow.com/homedetails/1528-Berkel...
# 3            null  https://www.zillow.com/homedetails/4019-Missio...
# 4       $3,500/mo  https://www.zillow.com/homedetails/5711-Canter...
# ..            ...                                                ...
# 57      $2,950/mo  https://www.zillow.com/homedetails/14073-Lemol...
# 58      $2,500/mo  https://www.zillow.com/homedetails/2960-S-Gree...
# 59      $2,550/mo  https://www.zillow.com/homedetails/10950-Satic...
# 60      $3,400/mo  https://www.zillow.com/homedetails/1181-Cherry...
# 61      $6,000/mo  https://www.zillow.com/homedetails/5350-Playa-...
#
# [62 rows x 20 columns]
# Directory  Output/Zillow/  Folder already exists
