# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(1, 21):
    # Filter Out Coming Soon, Auction, Home Type: Houses, Days On Zillow: 90 Days
    linked = 'https://www.zillow.com/ca/houses/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-130.9521558125,"east":-107.6611401875,"south":28.570940002914515,"north":45.333552921012235},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":5,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
    user_agent = 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'
#     user_agent = 'Mozilla/5.0 (Windows NT 5.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
#     user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
#             # Identify and return housing weblink
            house_website = str(result.a.get('href'))
#             print('House_website:', house_website);
#             Identify and return house data
            listing_type = result.find('div', class_="list-card-footer").text;
#             print('listing_type:', listing_type);
            price = result.find('div', class_="list-card-price").text
#             print('price:', price);
            full_address = result.find('address', class_="list-card-addr").text
#             print('full_address:', full_address);
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
#             print('street:', street);
            city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
#             print('city:', city);
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
#                 print('zip_code:', zip_code);
            except IndexError:
                zip_code = 'null'
                print('zip_code:', zip_code);
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
#             print('bed:', bed);
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
#             print('bath:', bath);
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
#             print('house_square_feet:', house_square_feet);
#             # Loop inside each house website and get more house data
#             loop_response = requests.get(house_website, headers=headers)
#             print(loop_response)
#             loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
#             try:
#                 loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
#             except IndexError:
#                 loop_result2 = 'null'
#             lot = 'null';
#             house_type = 'null';
#             year_build = 'null';
#             parking = 'null';
#             hoa = 'null';
#             lot_conversion_to_sqft = 'null';
#             zillow_price_per_sqft = 'null';
            
#             for content in loop_result2:
#                 if "Lot" in content.text.split(":")[0]:
#                     lot = content.text.split(":")[1];
#                 if "Type" in content.text.split(":")[0]:
#                     house_type = content.text.split(":")[1];
#                 if "Year built" in content.text.split(":")[0]:
#                     year_build = content.text.split(":")[1];
#                 if "Parking" in content.text.split(":")[0]:
#                     parking = content.text.split(":")[1];
#                 if "HOA" in content.text.split(":")[0]:
#                     hoa = content.text.split(":")[1];
#                 if "Price/sqft" in content.text.split(":")[0]:
#                     zillow_price_per_sqft = content.text.split(":")[1];
#             print('lot:', lot)
# #             print('type:', house_type);
# #             print('year-build:', year_build);
# #             print('parking:', parking);
# #             print('HOA:', hoa);
# #             print("Price/sqft:", zillow_price_per_sqft);

#             try:
#                 if (str(lot.split(" ")[1]) == "sqft"):
#                     lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
#                 elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
#                     lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
#                 elif (lot == "No Data"):
#                     lot_conversion_to_sqft = 'null'
#                 else:
#                     lot_conversion_to_sqft = 'null'
#             except IndexError:
#                 lot_conversion_to_sqft = 'null'
# #             print('lot_conversion_to_sqft:', lot_conversion_to_sqft);
#             try:
#                 state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
# #                 print('state:', state);
#             except IndexError:
#                 state = 'null'
#             try:
#                 zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
# #                 print('zestimate', zestimate)
#                 rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[3].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
# #                 print(rent_zestimate)
#             except IndexError:
#                 zestimate = 'null'
# #                 print('zestimate:', zestimate)
#                 rent_zestimate = 'null'
# #             print(zestimate)
            
            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
            house_obj = {
                "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "House_type": "Single Family",
#                 "Year_build": year_build,
#                 "Parking": parking,
#                 "HOA": hoa,
#                 "Lot": lot,
#                 "Lot_conversion_to_sqft": lot_conversion_to_sqft,
#                 "Zestimate": zestimate,
#                 "Rent_zestimate": rent_zestimate,
#                 "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
           }

            #Continue to add data into collection house_dict
            house_dict.append(house_obj)
#             listing_type = "";
#             price = "";
#             full_address = "";
#             street = "";
#             city = "";
#             state = "";
#             zip_code = "";
#             bed = "";
#             bath = "";
#             house_square_feet = "";
#             house_type = "";
#             year_build = "";
#             parking = "";
#             hoa = "";
#             lot = "";
#             lot_conversion_to_sqft = "";
#             zestimate = "";
#             rent_zestimate = "";
#             zillow_price_per_sqft = "";
#             house_website = "";
            
            time.sleep(1)
            
            
        except AttributeError as e:
            continue

print(house_dict)
# Out:
# zip_code: null
# zip_code: null
# zip_code: null
# zip_code: null
# zip_code: null
# zip_code: null
# zip_code: null
# zip_code: null
# [{'Listing_type': 'House for sale', 'Price': '$615,000', 'Full_address': '300 N Orchid Tree Ln, Palm Springs, CA 92262', 'Street': '300 N Orchid Tree Ln', 'City': 'PalmSprings', 'State': '', 'Zip_code': '92262', 'Bed': '3', 'Bath': '2', 'Square_Feet': '1,842', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/300-N-Orchid-Tree-Ln-Palm-Springs-CA-92262/18019371_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$100,000,000', 'Full_address': '10697 Somma Way, Los Angeles, CA 90077', 'Street': '10697 Somma Way', 'City': 'LosAngeles', 'State': '', 'Zip_code': '90077', 'Bed': '8', 'Bath': '21', 'Square_Feet': '41,000', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/10697-Somma-Way-Los-Angeles-CA-90077/2087104502_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$95,000,000', 'Full_address': '2571 Wallingford Dr, Beverly Hills, CA 90210', 'Street': '2571 Wallingford Dr', 'City': 'BeverlyHills', 'State': '', 'Zip_code': '90210', 'Bed': '12', 'Bath': '24', 'Square_Feet': '38,000', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/2571-Wallingford-Dr-Beverly-Hills-CA-90210/20532066_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$115,000,000', 'Full_address': '141 S Carolwood Dr, Los Angeles, CA 90077', 'Street': '141 S Carolwood Dr', 'City': 'LosAngeles', 'State': '', 'Zip_code': '90077', 'Bed': '9', 'Bath': '10', 'Square_Feet': '12,201', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/141-S-Carolwood-Dr-Los-Angeles-CA-90077/68993539_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$16,950,000', 'Full_address': '14175 Mulholland Dr, Beverly Hills, CA 90210', 'Street': '14175 Mulholland Dr', 'City': 'BeverlyHills', 'State': '', 'Zip_code': '90210', 'Bed': '10', 'Bath': '11', 'Square_Feet': '17,245', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/14175-Mulholland-Dr-Beverly-Hills-CA-90210/19987655_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$549,900', 'Full_address': '11308 Foster Rd, Norwalk, CA 90650', 'Street': '11308 Foster Rd', 'City': 'Norwalk', 'State': '', 'Zip_code': '90650', 'Bed': '4', 'Bath': '2', 'Square_Feet': '1,290', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/11308-Foster-Rd-Norwalk-CA-90650/21394256_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$269,900', 'Full_address': '1073 Pinon Ln, Big Bear City, CA 92314', 'Street': '1073 Pinon Ln', 'City': 'BigBearCity', 'State': '', 'Zip_code': '92314', 'Bed': '3', 'Bath': '2', 'Square_Feet': '1,267', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/1073-Pinon-Ln-Big-Bear-City-CA-92314/17394615_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$65,000,000', 'Full_address': '627 Carcassonne Rd, Los Angeles, CA 90077', 'Street': '627 Carcassonne Rd', 'City': 'LosAngeles', 'State': '', 'Zip_code': '90077', 'Bed': '9', 'Bath': '17', 'Square_Feet': '28,000', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/627-Carcassonne-Rd-Los-Angeles-CA-90077/2082373160_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$2,350,000', 'Full_address': '7932 Woodrow Wilson Dr, Los Angeles, CA 90046', 'Street': '7932 Woodrow Wilson Dr', 'City': 'LosAngeles', 'State': '', 'Zip_code': '90046', 'Bed': '4', 'Bath': '6', 'Square_Feet': '5,700', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/7932-Woodrow-Wilson-Dr-Los-Angeles-CA-90046/20802904_zpid/'}, {'Listing_type': 'House for sale', 'Price': '$479,999', 'Full_address': '6755 Saint James Ct, Riverside, CA 92504', 'Street': '6755 Saint James Ct', 'City': 'Riverside', 'State': '', 'Zip_code': '92504', 'Bed': '5', 'Bath': '2', 'Square_Feet': '1,899', 'House_type': 'Single Family', 'House_website': 'https://www.zillow.com/homedetails/6755-Saint-James-Ct-Riverside-CA-92504/17849336_zpid/'}, {'List ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#           Listing_type         Price  \
# 0       House for sale      $615,000
# 1       House for sale  $100,000,000
# 2       House for sale   $95,000,000
# 3       House for sale  $115,000,000
# 4       House for sale   $16,950,000
# ..                 ...           ...
# 595  For sale by owner      $198,000
# 596     House for sale      $283,000
# 597  For sale by owner      $789,900
# 598     House for sale      $460,000
# 599     House for sale      $549,999
#
#                                      Full_address                Street  \
# 0    300 N Orchid Tree Ln, Palm Springs, CA 92262  300 N Orchid Tree Ln
# 1          10697 Somma Way, Los Angeles, CA 90077       10697 Somma Way
# 2    2571 Wallingford Dr, Beverly Hills, CA 90210   2571 Wallingford Dr
# 3       141 S Carolwood Dr, Los Angeles, CA 90077    141 S Carolwood Dr
# 4    14175 Mulholland Dr, Beverly Hills, CA 90210   14175 Mulholland Dr
# ..                                            ...                   ...
# 595               217 W D St, Tehachapi, CA 93561            217 W D St
# 596        3722 W Palo Alto Ave, Fresno, CA 93711  3722 W Palo Alto Ave
# 597     16916 Simonds St, Granada Hills, CA 91344      16916 Simonds St
# 598       20199 Rim Rock Ct, Foresthill, CA 95631     20199 Rim Rock Ct
# 599            2420 Linda Ct, Escondido, CA 92027         2420 Linda Ct
#
#              City State Zip_code Bed Bath Square_Feet     House_type  \
# 0     PalmSprings          92262   3    2       1,842  Single Family
# 1      LosAngeles          90077   8   21      41,000  Single Family
# 2    BeverlyHills          90210  12   24      38,000  Single Family
# 3      LosAngeles          90077   9   10      12,201  Single Family
# 4    BeverlyHills          90210  10   11      17,245  Single Family
# ..            ...   ...      ...  ..  ...         ...            ...
# 595     Tehachapi          93561   2    1         980  Single Family
# 596        Fresno          93711   3    2       1,434  Single Family
# 597  GranadaHills          91344   3    2       2,002  Single Family
# 598    Foresthill          95631   2    2       1,974  Single Family
# 599     Escondido          92027   4    2       1,600  Single Family
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/300-N-Orchi...
# 1    https://www.zillow.com/homedetails/10697-Somma...
# 2    https://www.zillow.com/homedetails/2571-Wallin...
# 3    https://www.zillow.com/homedetails/141-S-Carol...
# 4    https://www.zillow.com/homedetails/14175-Mulho...
# ..                                                 ...
# 595  https://www.zillow.com/homedetails/217-W-D-St-...
# 596  https://www.zillow.com/homedetails/3722-W-Palo...
# 597  https://www.zillow.com/homedetails/16916-Simon...
# 598  https://www.zillow.com/homedetails/20199-Rim-R...
# 599  https://www.zillow.com/homedetails/2420-Linda-...
#
# [600 rows x 12 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q2-2020_Single_Family_Data_page1-20.csv", index=False, header=True)
