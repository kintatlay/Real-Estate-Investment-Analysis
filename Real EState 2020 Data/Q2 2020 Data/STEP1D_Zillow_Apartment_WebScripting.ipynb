# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

# Filter Out Coming Soon, Auction, Home Type: Apartment, Days On Zillow: 90 Days
linked = 'https://www.zillow.com/ca/duplex/?searchQueryState={"pagination":{},"usersSearchTerm":"ca","mapBounds":{"west":-152.089851125,"east":-86.523444875,"south":14.485661126627711,"north":55.01789701556767},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":4,"filterState":{"isPreMarketForeclosure":{"value":false},"isPreMarketPreForeclosure":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"isSingleFamily":{"value":false},"isManufactured":{"value":false},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
headers = {'User-Agent': user_agent}
response = requests.get(linked, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
results = soup.find_all('article', class_='list-card')
# print(results)
    
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return housing weblink
        house_website = str(result.a.get('href'))
        # Identify and return house data
        listing_type = result.find('div', class_="list-card-footer").text;
        price = result.find('div', class_="list-card-price").text
        print(price);
        full_address = result.find('address', class_="list-card-addr").text
        street = result.find('address', class_="list-card-addr").text.split(",")[0]
        city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
        state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
        try:
            zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
        except IndexError:
            zip_code = 'null'
        bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
        bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
        house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
        # Loop inside each house website and get more house data
#         loop_response = requests.get(house_website, headers=headers)
#         loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
        
#         loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
#         loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")
        
#         lot = 'null';
#         house_type = 'null';
#         year_build = 'null';
#         parking = 'null';
#         hoa = 'null';
#         lot_conversion_to_sqft = 'null';
#         zillow_price_per_sqft = 'null';
            
#         for content in loop_result2:
#             if "Lot" in content.text.split(":")[0]:
#                 lot = content.text.split(":")[1];
#             if "Type" in content.text.split(":")[0]:
#                 house_type = content.text.split(":")[1];
#             if "Year built" in content.text.split(":")[0]:
#                 year_build = content.text.split(":")[1];
#             if "Parking" in content.text.split(":")[0]:
#                 parking = content.text.split(":")[1];
#             if "HOA" in content.text.split(":")[0]:
#                 hoa = content.text.split(":")[1];
#             if "Price/sqft" in content.text.split(":")[0]:
#                 zillow_price_per_sqft = content.text.split(":")[1];
                    
#         try:
#             if (str(lot.split(" ")[1]) == "sqft"):
#                 lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
#             elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
#                 lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
#             elif (lot == "No Data"):
#                 lot_conversion_to_sqft = 'null'
#             else:
#                 lot_conversion_to_sqft = 'null'
#         except IndexError:
#             lot_conversion_to_sqft = 'null'
                
#         try:
#             zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[0].text
#             if (zestimate == "Zestimate®"):
#                 zestimate = 'null'
# #                 print('zestimate', zestimate)
#             rent_zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[1].text
#         except:
#             zestimate = 'null'
# #                 print('zestimate', zestimate)
#             rent_zestimate = 'null'
# #             print(zestimate)

            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
        house_obj = {
            "Listing_type": listing_type,
            "Price": price,
            "Full_address": full_address,
            "Street": street,
            "City": city,
            "State": state,
            "Zip_code": zip_code,
            "Bed": bed,
            "Bath": bath,
            "Square_Feet": house_square_feet,
            "House_type": "Apartment",
#             "Year_build": year_build,
#             "Parking": parking,
#             "HOA": hoa,
#             "Lot": lot,
#             "Lot_conversion_to_sqft": lot_conversion_to_sqft,
#             "Zestimate": zestimate,
#             "Rent_zestimate": rent_zestimate,
#             "Zillow_price/sqft": zillow_price_per_sqft,
            "House_website": house_website
            }

        #Continue to add data into collection house_dict
        house_dict.append(house_obj)
        time.sleep(2)
    except AttributeError as e:
        continue

print(house_dict)
# Out:
# $295,000
# $355,000
# $389,900
# $419,000
# $349,000
# $625,000
# $380,000
# $4,495,000
# [{'Listing_type': 'Apartment for sale', 'Price': '$295,000', 'Full_address': '639 James St, West Sacramento, CA 95605', 'Street': '639 James St', 'City': 'WestSacramento', 'State': 'CA', 'Zip_code': '95605', 'Bed': '2', 'Bath': '2', 'Square_Feet': '1,000', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/639-James-St-West-Sacramento-CA-95605/16513848_zpid/'}, {'Listing_type': 'For sale by owner', 'Price': '$355,000', 'Full_address': '3056 Via Alicante UNIT J, La Jolla, CA 92037', 'Street': '3056 Via Alicante UNIT J', 'City': 'LaJolla', 'State': 'CA', 'Zip_code': '92037', 'Bed': '1', 'Bath': '1', 'Square_Feet': '504', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/3056-Via-Alicante-UNIT-J-La-Jolla-CA-92037/16841712_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$389,900', 'Full_address': '3520 Paseo De Los Americanos UNIT 96, Oceanside, CA 92056', 'Street': '3520 Paseo De Los Americanos UNIT 96', 'City': 'Oceanside', 'State': 'CA', 'Zip_code': '92056', 'Bed': '2', 'Bath': '2', 'Square_Feet': '1,093', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/3520-Paseo-De-Los-Americanos-UNIT-96-Oceanside-CA-92056/2079025531_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$419,000', 'Full_address': '3465 16th Ave, Sacramento, CA 95820', 'Street': '3465 16th Ave', 'City': 'Sacramento', 'State': 'CA', 'Zip_code': '95820', 'Bed': '6', 'Bath': '2', 'Square_Feet': '2', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/3465-16th-Ave-Sacramento-CA-95820/25808087_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$349,000', 'Full_address': '938 5th St, Orland, CA 95963', 'Street': '938 5th St', 'City': 'Orland', 'State': 'CA', 'Zip_code': '95963', 'Bed': '4', 'Bath': '4', 'Square_Feet': '1,710', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/938-5th-St-Orland-CA-95963/58754207_zpid/'}, {'Listing_type': 'For sale by owner', 'Price': '$625,000', 'Full_address': '4915 Tyrone Ave, Sherman Oaks, CA 91423', 'Street': '4915 Tyrone Ave', 'City': 'ShermanOaks', 'State': 'CA', 'Zip_code': '91423', 'Bed': '2', 'Bath': '2', 'Square_Feet': '1,323', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/4915-Tyrone-Ave-Sherman-Oaks-CA-91423/2108261540_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$380,000', 'Full_address': '5325 Newcastle Ave UNIT 203, Los Angeles, CA 91316', 'Street': '5325 Newcastle Ave UNIT 203', 'City': 'LosAngeles', 'State': 'CA', 'Zip_code': '91316', 'Bed': '2', 'Bath': '2', 'Square_Feet': '940', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/5325-Newcastle-Ave-UNIT-203-Los-Angeles-CA-91316/19938556_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$4,495,000', 'Full_address': '7350 Hollywood Blvd, Los Angeles, CA 90046', 'Street': '7350 Hollywood Blvd', 'City': 'LosAngeles', 'State': 'CA', 'Zip_code': '90046', 'Bed': 'Studio', 'Bath': '--', 'Square_Feet': '9,648', 'House_type': 'Apartment', 'House_website': 'https://www.zillow.com/homedetails/7350-Hollywood-Blvd-Los-Angeles-CA-90046/2084063250_zpid/'}]

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#          Listing_type       Price  \
# 0  Apartment for sale    $295,000
# 1   For sale by owner    $355,000
# 2  Apartment for sale    $389,900
# 3  Apartment for sale    $419,000
# 4  Apartment for sale    $349,000
# 5   For sale by owner    $625,000
# 6  Apartment for sale    $380,000
# 7  Apartment for sale  $4,495,000
#
#                                         Full_address  \
# 0            639 James St, West Sacramento, CA 95605
# 1       3056 Via Alicante UNIT J, La Jolla, CA 92037
# 2  3520 Paseo De Los Americanos UNIT 96, Oceansid...
# 3                3465 16th Ave, Sacramento, CA 95820
# 4                       938 5th St, Orland, CA 95963
# 5            4915 Tyrone Ave, Sherman Oaks, CA 91423
# 6  5325 Newcastle Ave UNIT 203, Los Angeles, CA 9...
# 7         7350 Hollywood Blvd, Los Angeles, CA 90046
#
#                                  Street            City State Zip_code  \
# 0                          639 James St  WestSacramento    CA    95605
# 1              3056 Via Alicante UNIT J         LaJolla    CA    92037
# 2  3520 Paseo De Los Americanos UNIT 96       Oceanside    CA    92056
# 3                         3465 16th Ave      Sacramento    CA    95820
# 4                            938 5th St          Orland    CA    95963
# 5                       4915 Tyrone Ave     ShermanOaks    CA    91423
# 6           5325 Newcastle Ave UNIT 203      LosAngeles    CA    91316
# 7                   7350 Hollywood Blvd      LosAngeles    CA    90046
#
#       Bed Bath Square_Feet House_type  \
# 0       2    2       1,000  Apartment
# 1       1    1         504  Apartment
# 2       2    2       1,093  Apartment
# 3       6    2           2  Apartment
# 4       4    4       1,710  Apartment
# 5       2    2       1,323  Apartment
# 6       2    2         940  Apartment
# 7  Studio   --       9,648  Apartment
#
#                                        House_website
# 0  https://www.zillow.com/homedetails/639-James-S...
# 1  https://www.zillow.com/homedetails/3056-Via-Al...
# 2  https://www.zillow.com/homedetails/3520-Paseo-...
# 3  https://www.zillow.com/homedetails/3465-16th-A...
# 4  https://www.zillow.com/homedetails/938-5th-St-...
# 5  https://www.zillow.com/homedetails/4915-Tyrone...
# 6  https://www.zillow.com/homedetails/5325-Newcas...
# 7  https://www.zillow.com/homedetails/7350-Hollyw...

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q2-2020_Apartment_page1.csv", index=False, header=True)
