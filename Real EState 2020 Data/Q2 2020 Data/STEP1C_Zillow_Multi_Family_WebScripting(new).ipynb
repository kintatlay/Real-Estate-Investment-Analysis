# %%
# Tutorial: https://www.youtube.com/watch?v=dRcvJRmqFHQ&lc=UgyUDvoIA0A37EWWoC54AaABAg.9Aem3mXGQzz9Aep5dNrAY6
import requests
from bs4 import BeautifulSoup
import json
import time
import csv
import pandas as pd
import os

class ZillowScraper():
    results = []
    headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'zguid=23|%24d7ce356c-e3c5-4a48-85b3-61d0af33c3a1; zgsession=1|76ac70ba-62bc-4f77-81a1-b46b55a3f268; _ga=GA1.2.656681018.1593695925; _gid=GA1.2.1901059192.1593695925; zjs_user_id=null; zjs_anonymous_id=%22d7ce356c-e3c5-4a48-85b3-61d0af33c3a1%22; _pxvid=930c8230-bc66-11ea-9dd2-0242ac120007; _gcl_au=1.1.2002891296.1593696177; KruxPixel=true; DoubleClickSession=true; _pin_unauth=dWlkPU9EbG1aR0ptTTJVdFkySXpPUzAwWVdZMUxXSTFNVE10TnpFNE1EZGpOamxsWWpZNQ; _fbp=fb.1.1593696180071.236888825; KruxAddition=true; g_state={"i_p":1593716288950,"i_l":1}; JSESSIONID=0C394BB3DC7B91E479B72A328353817A; GASession=true; _pxff_bsco=1; AWSALB=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; AWSALBCORS=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; search=6|1596363321838%7Crect%3D43.45764218649565%252C-109.08936284375%252C30.85123360186431%252C-129.52393315625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D0%26days%3D90%26type%3Dhouse%26lt%3Dfsba%252Cfsbo%252Cfore%252Cnew%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%09%099%09%09%09%09%09%09; _px3=d4336234c4010c751aebc89c46325b0fb974e47215ce19445dfb759a629e81dc:X7e2f9pB1glpxKBrZ31UbYr/SXJFF+UxNWu+hiMsI+DQ7Mqle+9ez9SpkHaEa0n8KjNaAtb3oFQCfBoM9SkdFQ==:1000:AfuabQEQyo2l//8QKend7zOjb5sDW5Is+c6zQcm/upUYyYJc1jNQiyYnwroZOcBIjJBNJ8+vUKEJ3TlBoNaX/O7UbA0YkImLQb+VkAlAZWRj+w8lmqxZjshBeq6rrIg7GVsOSD+a1N8QtabSrjTIOF1SbQdGaZFzwVUu+aT6YiQ=; _uetsid=b093ce5e-93c4-0334-9c39-42ee7af2a929; _uetvid=e59e74ae-427f-984f-1765-cdc49ba1fa47',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    }
        
    def fetch(self, url, params):
        response = requests.get(url, headers=self.headers, params=params)
        print(response.status_code)
        return response
    
    def parse(self, response):
        content = BeautifulSoup(response, 'lxml')
        deck = content.find('ul', {'class': 'photo-cards photo-cards_wow photo-cards_short'})
        for card in deck.contents:
            script = card.find('script', {'type': 'application/ld+json'})
            if script:
                script_json = json.loads(script.contents[0])
                loop_response = requests.get(script_json['url'], headers=self.headers)
                loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
                try:
                    loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
                except IndexError:
                    loop_result2 = 'null'
                lot = 'null';
                house_type = 'null';
                year_build = 'null';
                parking = 'null';
                hoa = 'null';
                lot_conversion_to_sqft = 'null';
                zillow_price_per_sqft = 'null';
                
                if loop_result2:
                    for contents in loop_result2:
                        print(contents.text)
                        if "Lot" in contents.text.split(":")[0]:
                            lot = contents.text.split(":")[1];
                        if "Type" in contents.text.split(":")[0]:
                            house_type = contents.text.split(":")[1];
                        if "Year built" in contents.text.split(":")[0]:
                            year_build = contents.text.split(":")[1];
                        if "Parking" in contents.text.split(":")[0]:
                            parking = contents.text.split(":")[1];
                        if "HOA" in contents.text.split(":")[0]:
                            hoa = contents.text.split(":")[1];
                        if "Price/sqft" in contents.text.split(":")[0]:
                            zillow_price_per_sqft = contents.text.split(":")[1];
                
                    try:
                        zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
                        rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[3].find('p', class_="Text-aiai24-0 sc-cMljjf sc-cTjmhe eXGbuO").text
                    except AttributeError:
                        zestimate = 'null'
                        rent_zestimate = 'null'
                    try:
                        if (str(lot.split(" ")[1]) == "sqft"):
                            lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                        elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                            lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                        elif (lot == "No Data"):
                            lot_conversion_to_sqft = 'null'
                        else:
                            lot_conversion_to_sqft = 'null'
                    except IndexError:
                        lot_conversion_to_sqft = 'null'
                        
                    self.results.append({
                        'Listing_type': card.find('div', {'class': 'list-card-type'}).text,
                        'Price': card.find('div', {'class': 'list-card-price'}).text,
                        'Full_address': script_json['name'],
                        'Street': script_json['address']['streetAddress'],
                        'City': script_json['address']['addressLocality'],
                        'State': script_json['address']['addressRegion'],
                        'Zip_code': script_json['address']['postalCode'],
                        'Latitude': script_json['geo']['latitude'],
                        'Longitude': script_json['geo']['longitude'],
                        'Square_Feet': script_json['floorSize']['value'],
                        'Lot': lot,
                        'Lot_conversion_to_sqft': lot_conversion_to_sqft,
                        'House_type': house_type,
                        'Year_build': year_build,
                        'Parking': parking,
                        'Hoa': hoa,
                        'Zillow_price_per_sqft': zillow_price_per_sqft,
                        'Zestimate': zestimate,
                        'Rent_zestimate': rent_zestimate,
                        'House_website': script_json['url']
                    })
                    time.sleep(3)
                
    def to_csv(self):
        dirName = 'Output/Zillow/'
        if not os.path.exists(dirName):
            os.mkdir(dirName)
            print("Directory ", dirName, " Folder created ")
        else:
            print("Directory ", dirName, " Folder already exists")
            
        with open('./' + dirName + 'Q2-2020_Multi_Family_Data_page17-20.csv', 'w') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            
            for row in self.results:
                writer.writerow(row)

    def to_dftable(self):
        house_data = pd.DataFrame(self.results)
        print(house_data)

#     Filter Out Coming Soon, Auction, Home Type: Houses, Days On Zillow: 90 Days
    def run(self):
        url = 'https://www.zillow.com/ca/duplex/'
        for page in range(17,21):
            params = {
                'searchQueryState':'{"pagination":{"currentPage":%s},"usersSearchTerm":"ca","mapBounds":{"west":-130.93471906436687,"east":-107.64370343936687,"south":31.980790552461904,"north":48.0418909706512},"mapZoom":5,"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"},"isSingleFamily":{"value":false},"isCondo":{"value":false}},"isListVisible":true}' %page
            }
            res = self.fetch(url, params)
            self.parse(res.text)
            time.sleep(2)
        self.to_dftable()
        self.to_csv()
        
if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run();
# Out:
# 200
# Type:Multi Family
# Year built:1966
# Heating:Forced air
# Cooling:None
# Parking:3 spaces
# Price/sqft:$1,023
# Type:Multi Family
# Year built:1922
# Heating:Forced air, Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$262
# Type:Multi Family
# Year built:1910
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$457
# Type:Multi Family
# Year built:1940
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$567
# Type:Multi Family
# Year built:1900
# Heating:No Data
# Cooling:No Data
# Parking:Attached Garage
# Price/sqft:$661
# Type:Multi Family
# Year built:1967
# Heating:No Data
# Cooling:Other
# Parking:10 spaces
# Price/sqft:$442
# Type:Multi Family
# Year built:1953
# Heating:Forced air
# Cooling:Central
# Parking:10 spaces
# Price/sqft:$503
# Type:Multi Family
# Year built:1947
# Heating:Wall
# Cooling:Wall
# Parking:6 spaces
# Price/sqft:$615
# Type:Multi Family
# Year built:1950
# Heating:Wall
# Cooling:Evaporative
# Parking:Carport
# Price/sqft:$268
# Type:Multi Family
# Year built:1940
# Heating:Gas
# Cooling:None
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:2019
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# HOA:None
# Price/sqft:$145
# Type:Multi Family
# Year built:1941
# Heating:Gas
# Cooling:No Data
# Parking:No Data
# Price/sqft:$513
# Type:Multi Family
# Year built:1979
# Heating:Forced air
# Cooling:None
# Parking:Attached Garage
# Price/sqft:$641
# Type:Multi Family
# Year built:1961
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$641
# Type:Multi Family
# Year built:1907
# Heating:Forced air
# Cooling:Other
# Parking:6 spaces
# Price/sqft:$317
# Type:Multi Family
# Year built:1921
# Heating:Gas
# Cooling:Other
# Parking:4 spaces
# Price/sqft:$530
# Type:Multi Family
# Year built:1943
# Heating:No Data
# Cooling:None
# Parking:2 spaces
# Price/sqft:$442
# Type:Multi Family
# Year built:1956
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$141
# Type:Multi Family
# Year built:1939
# Heating:Wall
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$330
# Type:Multi Family
# Year built:1952
# Heating:Gas
# Cooling:Other
# Parking:12 spaces
# Price/sqft:$1,212
# Type:Multi Family
# Year built:1966
# Heating:No Data
# Cooling:Wall
# Parking:8 spaces
# Price/sqft:$148
# Type:Multi Family
# Year built:1985
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1922
# Heating:No Data
# Cooling:None
# Parking:3 spaces
# HOA:None
# Price/sqft:$506
# Type:Multi Family
# Year built:1985
# Heating:Forced air
# Cooling:Central
# Parking:84 spaces
# Price/sqft:$470
# Type:Multi Family
# Year built:No Data
# Heating:No Data
# Cooling:No Data
# Parking:Carport
# Price/sqft:$583
# Type:Multi Family
# Year built:1924
# Heating:Wall
# Cooling:None
# Parking:4 spaces
# Price/sqft:$851
# Type:Multi Family
# Year built:1950
# Heating:Electric
# Cooling:Evaporative
# Parking:14 spaces
# Price/sqft:$137
# Type:Multi Family
# Year built:1948
# Heating:Gas
# Cooling:No Data
# Parking:5 spaces
# Price/sqft:$713
# Type:Multi Family
# Year built:1957
# Heating:Other
# Cooling:Evaporative
# Parking:Carport
# Price/sqft:$100
# Type:Multi Family
# Year built:1924
# Heating:Gas
# Cooling:No Data
# Parking:On street
# Price/sqft:$447
# Type:Multi Family
# Year built:1923
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:None
# Price/sqft:$304
# Type:Multi Family
# Year built:2013
# Heating:Other
# Cooling:Central
# Parking:No Data
# Price/sqft:$203
# Type:Multi Family
# Year built:1927
# Heating:No Data
# Cooling:Other
# Parking:Attached Garage
# Price/sqft:$706
# Type:Multi Family
# Year built:1923
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$317
# Type:Multi Family
# Year built:1940
# Heating:Gas
# Cooling:None
# Parking:4 spaces
# Price/sqft:$309
# Type:Multi Family
# Year built:1969
# Heating:Forced air
# Cooling:Wall
# Parking:6 spaces
# Price/sqft:No Data
# Type:Multi Family
# Year built:1928
# Heating:Other
# Cooling:Wall
# Parking:Attached Garage
# Price/sqft:$1,596
# Type:Multi Family
# Year built:1922
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$241
# Type:Multi Family
# Year built:1971
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# HOA:None
# Price/sqft:$568
# Type:Multi Family
# Year built:1949
# Heating:Gas
# Cooling:None
# Parking:1 space
# Price/sqft:$692
# 200
# Type:Multi Family
# Year built:1904
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Price/sqft:$480
# Type:Multi Family
# Year built:1922
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$240
# Type:Multi Family
# Year built:1991
# Heating:Forced air
# Cooling:None
# Parking:7 spaces
# HOA:None
# Price/sqft:$1,040
# Type:Multi Family
# Year built:1916
# Heating:No Data
# Cooling:None
# Parking:No Data
# Price/sqft:$178
# Type:Multi Family
# Year built:1970
# Heating:Gas
# Cooling:No Data
# Parking:Attached Garage
# Price/sqft:$911
# Type:Multi Family
# Year built:1976
# Heating:Forced air
# Cooling:Central
# Parking:Attached Garage
# HOA:None
# Price/sqft:$78
# Type:Multi Family
# Year built:2020
# Heating:Forced air
# Cooling:Central
# Parking:8 spaces
# HOA:$791/month
# Price/sqft:$553
# Type:Multi Family
# Year built:1978
# Heating:Forced air
# Cooling:Wall
# Parking:Attached Garage
# Price/sqft:No Data
# Type:Multi Family
# Year built:1947
# Heating:No Data
# Cooling:No Data
# Parking:16 spaces
# Price/sqft:$180
# Type:Multi Family
# Year built:1927
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$625
# Type:Multi Family
# Year built:1923
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$381
# Type:Multi Family
# Year built:1944
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$998
# Type:Multi Family
# Year built:No Data
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$709
# Type:Multi Family
# Year built:1969
# Heating:Forced air
# Cooling:None
# Parking:Carport
# Price/sqft:$821
# Type:Multi Family
# Year built:1961
# Heating:No Data
# Cooling:Wall
# Parking:3 spaces
# Price/sqft:$577
# Type:Multi Family
# Year built:1954
# Heating:No Data
# Cooling:Evaporative
# Parking:1 space
# Price/sqft:$181
# Type:Multi Family
# Year built:1957
# Heating:No Data
# Cooling:Evaporative, Wall
# Parking:No Data
# Price/sqft:$140
# Type:Multi Family
# Year built:1981
# Heating:Wall
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$101
# Type:Multi Family
# Year built:1915
# Heating:Electric, Gas
# Cooling:Wall
# Parking:3 spaces
# Price/sqft:$445
# Type:Multi Family
# Year built:1977
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:2006
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$265
# Type:Multi Family
# Year built:1979
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$430/month
# Price/sqft:$353
# Type:Multi Family
# Year built:1970
# Heating:No Data
# Cooling:Evaporative, Wall
# Parking:Carport
# Price/sqft:$113
# Type:Multi Family
# Year built:1983
# Heating:Forced air
# Cooling:Central
# Parking:8 spaces
# HOA:None
# Price/sqft:$131
# Type:Multi Family
# Year built:1965
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1948
# Heating:Heat pump
# Cooling:Other
# Parking:5 spaces
# Price/sqft:$561
# Type:Multi Family
# Year built:1956
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$178
# Type:Multi Family
# Year built:1930
# Heating:Wall
# Cooling:No Data
# Parking:1 space
# Price/sqft:$483
# Type:Multi Family
# Year built:1976
# Heating:No Data
# Cooling:Other
# Parking:12 spaces
# Price/sqft:$327
# Type:Multi Family
# Year built:1973
# Heating:No Data
# Cooling:No Data
# Parking:4 spaces
# HOA:None
# Price/sqft:$353
# Type:Multi Family
# Year built:1957
# Heating:Wall
# Cooling:Wall
# Parking:No Data
# Price/sqft:$360
# Type:Multi Family
# Year built:2000
# Heating:Electric, Gas
# Cooling:No Data
# Parking:No Data
# HOA:$208/month
# Price/sqft:$485
# Type:Multi Family
# Year built:1900
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$1,102
# Type:Multi Family
# Year built:1936
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# HOA:None
# Price/sqft:$564
# Type:Multi Family
# Year built:1912
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# Price/sqft:$516
# Type:Multi Family
# Year built:1926
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1948
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# Price/sqft:$701
# Type:Multi Family
# Year built:1924
# Heating:Gas
# Cooling:None
# Parking:4 spaces
# Price/sqft:$329
# 200
# Type:Multi Family
# Year built:1947
# Heating:No Data
# Cooling:No Data
# Parking:16 spaces
# Price/sqft:$180
# Type:Multi Family
# Year built:1927
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$625
# Type:Multi Family
# Year built:1923
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$381
# Type:Multi Family
# Year built:1944
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$998
# Type:Multi Family
# Year built:No Data
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$709
# Type:Multi Family
# Year built:1969
# Heating:Forced air
# Cooling:None
# Parking:Carport
# Price/sqft:$821
# Type:Multi Family
# Year built:1961
# Heating:No Data
# Cooling:Wall
# Parking:3 spaces
# Price/sqft:$577
# Type:Multi Family
# Year built:1954
# Heating:No Data
# Cooling:Evaporative
# Parking:1 space
# Price/sqft:$181
# Type:Multi Family
# Year built:1957
# Heating:No Data
# Cooling:Evaporative, Wall
# Parking:No Data
# Price/sqft:$140
# Type:Multi Family
# Year built:1981
# Heating:Wall
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$101
# Type:Multi Family
# Year built:1915
# Heating:Electric, Gas
# Cooling:Wall
# Parking:3 spaces
# Price/sqft:$445
# Type:Multi Family
# Year built:1977
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:2006
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$265
# Type:Multi Family
# Year built:1979
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$430/month
# Price/sqft:$353
# Type:Multi Family
# Year built:1970
# Heating:No Data
# Cooling:Evaporative, Wall
# Parking:Carport
# Price/sqft:$113
# Type:Multi Family
# Year built:1983
# Heating:Forced air
# Cooling:Central
# Parking:8 spaces
# HOA:None
# Price/sqft:$131
# Type:Multi Family
# Year built:1965
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1948
# Heating:Heat pump
# Cooling:Other
# Parking:5 spaces
# Price/sqft:$561
# Type:Multi Family
# Year built:1956
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$178
# Type:Multi Family
# Year built:1930
# Heating:Wall
# Cooling:No Data
# Parking:1 space
# Price/sqft:$483
# Type:Multi Family
# Year built:1976
# Heating:No Data
# Cooling:Other
# Parking:12 spaces
# Price/sqft:$327
# Type:Multi Family
# Year built:1973
# Heating:No Data
# Cooling:No Data
# Parking:4 spaces
# HOA:None
# Price/sqft:$353
# Type:Multi Family
# Year built:1957
# Heating:Wall
# Cooling:Wall
# Parking:No Data
# Price/sqft:$360
# Type:Multi Family
# Year built:2000
# Heating:Electric, Gas
# Cooling:No Data
# Parking:No Data
# HOA:$208/month
# Price/sqft:$485
# Type:Multi Family
# Year built:1900
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$1,102
# Type:Multi Family
# Year built:1936
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# HOA:None
# Price/sqft:$564
# Type:Multi Family
# Year built:1912
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# Price/sqft:$516
# Type:Multi Family
# Year built:1948
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# Price/sqft:$701
# Type:Multi Family
# Year built:1924
# Heating:Gas
# Cooling:None
# Parking:4 spaces
# Price/sqft:$329
# Type:Multi Family
# Year built:1977
# Heating:No Data
# Cooling:Central, Wall
# Parking:4 spaces
# Price/sqft:$161
# Type:Multi Family
# Year built:1913
# Heating:Gas
# Cooling:No Data
# Parking:Detached Garage
# Price/sqft:$552
# Type:Multi Family
# Year built:1978
# Heating:Forced air
# Cooling:Central, Solar
# Parking:8 spaces
# HOA:None
# Price/sqft:$166
# Type:Multi Family
# Year built:1904
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$583
# Type:Multi Family
# Year built:1953
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1895
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$734
# Type:Multi Family
# Year built:1927
# Heating:Gas
# Cooling:None
# Parking:2 spaces
# HOA:None
# Price/sqft:$1,657
# Type:Multi Family
# Year built:1958
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1955
# Heating:Wall
# Cooling:None
# Parking:8 spaces
# HOA:None
# Price/sqft:$225
# Type:Multi Family
# Year built:1926
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# 200
# Type:Multi Family
# Year built:1988
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$499
# Type:Multi Family
# Year built:1967
# Heating:Forced air
# Cooling:Central
# Parking:6 spaces
# Price/sqft:$124
# Type:Multi Family
# Year built:1900
# Heating:Forced air
# Cooling:Central
# Parking:Detached Garage
# Price/sqft:$831
# Type:Multi Family
# Year built:No Data
# Heating:No Data
# Cooling:Other
# Parking:2 spaces
# HOA:None
# Price/sqft:No Data
# Type:Multi Family
# Year built:1938
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$208/month
# Price/sqft:$670
# Type:Multi Family
# Year built:1968
# Heating:Forced air
# Cooling:Central
# Parking:13 spaces
# Price/sqft:$243
# Type:Multi Family
# Year built:1979
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$430/month
# Price/sqft:$353
# Type:Multi Family
# Year built:1972
# Heating:Forced air
# Cooling:No Data
# Parking:Attached Garage
# Price/sqft:$576
# Type:Multi Family
# Year built:1976
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$418
# Type:Multi Family
# Year built:1948
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# HOA:None
# Price/sqft:$331
# Type:Multi Family
# Year built:1965
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$775
# Type:Multi Family
# Year built:1924
# Heating:Wall
# Cooling:Wall
# Parking:1 space
# Price/sqft:$338
# Type:Multi Family
# Year built:1906
# Heating:Forced air
# Cooling:Central
# Parking:5 spaces
# Price/sqft:$586
# Type:Multi Family
# Year built:1921
# Heating:No Data
# Cooling:No Data
# Parking:4 spaces
# Price/sqft:$519
# Type:Multi Family
# Year built:1923
# Heating:Forced air
# Cooling:Central
# Parking:8 spaces
# HOA:None
# Price/sqft:$494
# Type:Multi Family
# Year built:2004
# Heating:Forced air
# Cooling:Central
# Parking:7 spaces
# Price/sqft:$634
# Type:Multi Family
# Year built:2020
# Heating:Forced air
# Cooling:None
# Parking:10 spaces
# Price/sqft:$820
# Type:Multi Family
# Year built:1928
# Heating:Gas
# Cooling:No Data
# Parking:No Data
# Price/sqft:No Data
# Type:Multi Family
# Year built:1960
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$272
# Type:Multi Family
# Year built:1953
# Heating:No Data
# Cooling:Other
# Parking:14 spaces
# Price/sqft:$625
# Type:Multi Family
# Year built:1931
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$558
# Type:Multi Family
# Year built:2015
# Heating:Forced air
# Cooling:No Data
# Parking:On street
# HOA:None
# Price/sqft:$1,720
# Type:Multi Family
# Year built:1953
# Heating:Wall
# Cooling:None
# Parking:1 space
# HOA:None
# Price/sqft:$1,495
# Type:Multi Family
# Year built:1962
# Heating:Forced air
# Cooling:Other
# Parking:3 spaces
# Price/sqft:$1,028
# Type:Multi Family
# Year built:1971
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$389
# Type:Multi Family
# Year built:1968
# Heating:Forced air
# Cooling:None
# Parking:3 spaces
# Price/sqft:$544
# Type:Multi Family
# Year built:1925
# Heating:Gas
# Cooling:No Data
# Parking:No Data
# Price/sqft:$446
# Type:Multi Family
# Year built:1962
# Heating:Forced air
# Cooling:None
# Parking:Attached Garage
# Price/sqft:$642
# Type:Multi Family
# Year built:1912
# Heating:Other
# Cooling:None
# Parking:5 spaces
# HOA:None
# Price/sqft:$950
# Type:Multi Family
# Year built:No Data
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$620
# Type:Multi Family
# Year built:1927
# Heating:Forced air
# Cooling:Wall
# Parking:4 spaces
# Price/sqft:$524
# Type:Multi Family
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$271
# Type:Multi Family
# Year built:1938
# Heating:No Data
# Cooling:Other
# Parking:4 spaces
# Price/sqft:$417
# Type:Multi Family
# Year built:1930
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$1,857
# Type:Multi Family
# Year built:1911
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$1,078
# Type:Multi Family
# Year built:1949
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$863
# Type:Multi Family
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$175
# Type:Multi Family
# Year built:1964
# Heating:Wall
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$218
# Type:Multi Family
# Year built:1953
# Heating:Other
# Cooling:None
# Parking:1 space
# Price/sqft:$442
# Type:Multi Family
# Year built:1951
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:None
# Price/sqft:$444
#            Listing_type       Price  \
# 0    Apartment for sale  $3,290,000
# 1    Apartment for sale    $675,000
# 2    Apartment for sale  $2,495,000
# 3    Apartment for sale    $789,000
# 4    Apartment for sale  $2,775,000
# ..                  ...         ...
# 154  Apartment for sale  $2,300,000
# 155  Apartment for sale    $699,000
# 156  Apartment for sale    $825,000
# 157  Apartment for sale  $1,050,000
# 158    New construction  $1,199,999
#
#                                       Full_address                   Street  \
# 0                    11 20th Ave, Venice, CA 90291             11 20th Ave
# 1               348 E Opp St, Wilmington, CA 90744            348 E Opp St
# 2               1415 Calistoga Ave, Napa, CA 94559      1415 Calistoga Ave
# 3          1222 N Avenue 49, Los Angeles, CA 90042        1222 N Avenue 49
# 4        635-637 Baker St, San Francisco, CA 94117        635-637 Baker St
# ..                                             ...                      ...
# 154  1445 N El Camino Real, San Clemente, CA 92672   1445 N El Camino Real
# 155             507 Montecito Ave, Hemet, CA 92543       507 Montecito Ave
# 156               1253 73rd Ave, Oakland, CA 94621           1253 73rd Ave
# 157              431 Larkin St, Monterey, CA 93940           431 Larkin St
# 158     17232-17234 Keswick St, Van Nuys, CA 91406  17232-17234 Keswick St
#
#               City State Zip_code   Latitude   Longitude Square_Feet   Lot  \
# 0           Venice    CA    90291  33.985138 -118.471568       3,216  null
# 1       Wilmington    CA    90744  33.782750 -118.258035       2,574  null
# 2             Napa    CA    94559  38.299490 -122.291037       5,456  null
# 3      Los Angeles    CA    90042  34.120668 -118.209194       1,391  null
# 4    San Francisco    CA    94117  37.777033 -122.441954       4,200  null
# ..             ...   ...      ...        ...         ...         ...   ...
# 154   San Clemente    CA    92672  33.432373 -117.625674       2,664  null
# 155          Hemet    CA    92543  33.731435 -116.966956       4,000  null
# 156        Oakland    CA    94621  37.758714 -122.188349       3,792  null
# 157       Monterey    CA    93940  36.600088 -121.898691       2,376  null
# 158       Van Nuys    CA    91406  34.209138 -118.508953       2,702  null
#
#     Lot_conversion_to_sqft    House_type Year_build          Parking   Hoa  \
# 0                     null  Multi Family       1966         3 spaces  null
# 1                     null  Multi Family       1922         2 spaces  null
# 2                     null  Multi Family       1910         2 spaces  null
# 3                     null  Multi Family       1940         2 spaces  null
# 4                     null  Multi Family       1900  Attached Garage  null
# ..                     ...           ...        ...              ...   ...
# 154                   null  Multi Family       1949          No Data  null
# 155                   null  Multi Family       1974         2 spaces  null
# 156                   null  Multi Family       1964         4 spaces  null
# 157                   null  Multi Family       1953          1 space  null
# 158                   null  Multi Family       1951         2 spaces  None
#
#     Zillow_price_per_sqft   Zestimate Rent_zestimate  \
# 0                  $1,023  $3,217,956      $4,150/mo
# 1                    $262    $675,000      $2,600/mo
# 2                    $457  $2,378,443      $7,500/mo
# 3                    $567    $791,941      $2,875/mo
# 4                    $661        null           null
# ..                    ...         ...            ...
# 154                  $863        null           null
# 155                  $175        null           null
# 156                  $218    $860,483      $2,500/mo
# 157                  $442  $1,020,921      $3,000/mo
# 158                  $444        null           null
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/11-20th-Ave...
# 1    https://www.zillow.com/homedetails/348-E-Opp-S...
# 2    https://www.zillow.com/homedetails/1415-Calist...
# 3    https://www.zillow.com/homedetails/1222-N-Aven...
# 4    https://www.zillow.com/homedetails/635-637-Bak...
# ..                                                 ...
# 154  https://www.zillow.com/homedetails/1445-N-El-C...
# 155  https://www.zillow.com/homedetails/507-Monteci...
# 156  https://www.zillow.com/homedetails/1253-73rd-A...
# 157  https://www.zillow.com/homedetails/431-Larkin-...
# 158  https://www.zillow.com/homedetails/17232-17234...
#
# [159 rows x 20 columns]
# Directory  Output/Zillow/  Folder already exists
