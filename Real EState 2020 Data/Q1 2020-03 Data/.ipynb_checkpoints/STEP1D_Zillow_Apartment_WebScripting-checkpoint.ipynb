# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

# Filter Out Coming Soon, Auction, Home Type: Apartment, Days On Zillow: 90 Days
linked = 'https://www.zillow.com/ca/duplex/?searchQueryState={"pagination":{},"usersSearchTerm":"ca","mapBounds":{"west":-152.089851125,"east":-86.523444875,"south":14.485661126627711,"north":55.01789701556767},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":4,"filterState":{"isPreMarketForeclosure":{"value":false},"isPreMarketPreForeclosure":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"isSingleFamily":{"value":false},"isManufactured":{"value":false},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
headers = {'User-Agent': user_agent}
response = requests.get(linked, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
results = soup.find_all('article', class_='list-card')
# print(results)
    
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return housing weblink
        house_website = str(result.a.get('href'))
        # Identify and return house data
        listing_type = result.find('div', class_="list-card-footer").text;
        price = result.find('div', class_="list-card-price").text
        print(price);
        full_address = result.find('address', class_="list-card-addr").text
        street = result.find('address', class_="list-card-addr").text.split(",")[0]
        city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
        state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
        try:
            zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
        except IndexError:
            zip_code = 'null'
        bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
        bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
        house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
        # Loop inside each house website and get more house data
        loop_response = requests.get(house_website, headers=headers)
        loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
        
        loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
        loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")
        
        lot = 'null';
        house_type = 'null';
        year_build = 'null';
        parking = 'null';
        hoa = 'null';
        lot_conversion_to_sqft = 'null';
        zillow_price_per_sqft = 'null';
            
        for content in loop_result2:
            if "Lot" in content.text.split(":")[0]:
                lot = content.text.split(":")[1];
            if "Type" in content.text.split(":")[0]:
                house_type = content.text.split(":")[1];
            if "Year built" in content.text.split(":")[0]:
                year_build = content.text.split(":")[1];
            if "Parking" in content.text.split(":")[0]:
                parking = content.text.split(":")[1];
            if "HOA" in content.text.split(":")[0]:
                hoa = content.text.split(":")[1];
            if "Price/sqft" in content.text.split(":")[0]:
                zillow_price_per_sqft = content.text.split(":")[1];
                    
        try:
            if (str(lot.split(" ")[1]) == "sqft"):
                lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
            elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
            elif (lot == "No Data"):
                lot_conversion_to_sqft = 'null'
            else:
                lot_conversion_to_sqft = 'null'
        except IndexError:
            lot_conversion_to_sqft = 'null'
                
        try:
            zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[0].text
            if (zestimate == "Zestimate®"):
                zestimate = 'null'
#                 print('zestimate', zestimate)
            rent_zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[1].text
        except:
            zestimate = 'null'
#                 print('zestimate', zestimate)
            rent_zestimate = 'null'
#             print(zestimate)

            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
        house_obj = {
            "Listing_type": listing_type,
            "Price": price,
            "Full_address": full_address,
            "Street": street,
            "City": city,
            "State": state,
            "Zip_code": zip_code,
            "Bed": bed,
            "Bath": bath,
            "Square_Feet": house_square_feet,
            "House_type": house_type,
            "Year_build": year_build,
            "Parking": parking,
            "HOA": hoa,
            "Lot": lot,
            "Lot_conversion_to_sqft": lot_conversion_to_sqft,
            "Zestimate": zestimate,
            "Rent_zestimate": rent_zestimate,
            "Zillow_price/sqft": zillow_price_per_sqft,
            "House_website": house_website
            }

        #Continue to add data into collection house_dict
        house_dict.append(house_obj)
        time.sleep(2)
    except AttributeError as e:
        continue

print(house_dict)
# Out:
# $2,700
# $475,000
# $1,350,000
# $515,000
# $270,000
# $1,500,000
# $750,000
# $1,275,000
# $1,495,000
# $825,000
# $6,995,000
# $19,000,000
# $699,000
# $5,100,000
# $547,000
# $4,980,000
# $2,980,000
# $1,100,000
# [{'Listing_type': 'Apartment for sale', 'Price': '$2,700', 'Full_address': '3734 2nd Ave, Glendale, CA 91214', 'Street': '3734 2nd Ave', 'City': 'Glendale', 'State': 'CA', 'Zip_code': '91214', 'Bed': '2', 'Bath': '1', 'Square_Feet': '915', 'House_type': 'Apartment', 'Year_build': '1955', 'Parking': '1 space', 'HOA': 'null', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'Zestimate': 'null', 'Rent_zestimate': 'null', 'Zillow_price/sqft': '$3', 'House_website': 'https://www.zillow.com/homedetails/3734-2nd-Ave-Glendale-CA-91214/20815335_zpid/'}, {'Listing_type': 'Apartment for sale', 'Price': '$475,000', 'Full_address': '4713-4715 Large Oak Ct, Sacramento, CA 95841', 'Street': '4713-4715 Large Oak Ct', 'City': 'Sacramento', 'State': 'CA', 'Zip_code': '95841', 'Bed': '4', 'Bath': '3', 'Square_Feet': '2,030', 'House_type': 'Apartment', 'Year_build': '1974', 'Parking': 'Attached Garage', 'HOA': 'null', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'Zestimate': 'null', 'Rent_zestimate': 'null', 'Zillow_price/sqft': '$234', 'House_
# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#    Bath     Bed           City  \
# 0     1       2       Glendale
# 1     3       4     Sacramento
# 2     2       2         Albany
# 3     2       2  ImperialBeach
# 4     2       3     Sacramento
# 5    --       3   EastPaloAlto
# 6     7      13         Fresno
# 7     2       2   SanFrancisco
# 8     3       3   SanFrancisco
# 9     2       1     LosAngeles
# 10    4       5       YubaCity
# 11   --  Studio     LosAngeles
# 12    2       1     LosAngeles
# 13   --      10     SimiValley
# 14    3       3   SpringValley
# 15   20      28     SanGabriel
# 16    9      11     SanGabriel
# 17    6       6     LosAngeles
#
#                                          Full_address         HOA House_type  \
# 0                    3734 2nd Ave, Glendale, CA 91214        null  Apartment
# 1        4713-4715 Large Oak Ct, Sacramento, CA 95841        null  Apartment
# 2                     814 Curtis St, Albany, CA 94706        None  Apartment
# 3   1111 Seacoast Dr UNIT 20, Imperial Beach, CA 9...  $436/month  Apartment
# 4                1536 South Ave, Sacramento, CA 95838        None  Apartment
# 5       2371 University Ave, East Palo Alto, CA 94303        null  Apartment
# 6              4168 N Millbrook Ave, Fresno, CA 93726        null  Apartment
# 7               187 19th Ave, San Francisco, CA 94121        null  Apartment
# 8               185 19th Ave, San Francisco, CA 94121        null  Apartment
# 9   7250 Franklin Ave UNIT 1101, Los Angeles, CA 9...   $64/month  Apartment
# 10                605 Queens Ave, Yuba City, CA 95991        null       null
# 11           571 S Coronado St, Los Angeles, CA 90057        null  Apartment
# 12  10751 Wilshire Blvd APT 1205, Los Angeles, CA ...  $730/month  Apartment
# 13             4453 Apricot Rd, Simi Valley, CA 93063        null  Apartment
# 14        1670 Whitestone Rd, Spring Valley, CA 91977  $190/month  Apartment
# 15             5715 N Vista St, San Gabriel, CA 91775        null  Apartment
# 16              302 E Broadway, San Gabriel, CA 91776        null  Apartment
# 17               324 W 50th St, Los Angeles, CA 90037        null  Apartment
#
#                                         House_website        Listing_type  \
# 0   https://www.zillow.com/homedetails/3734-2nd-Av...  Apartment for sale
# 1   https://www.zillow.com/homedetails/4713-4715-L...  Apartment for sale
# 2   https://www.zillow.com/homedetails/814-Curtis-...   For sale by owner
# 3   https://www.zillow.com/homedetails/1111-Seacoa...   For sale by owner
# 4   https://www.zillow.com/homedetails/1536-South-...  Apartment for sale
# 5   https://www.zillow.com/homedetails/2371-Univer...   For sale by owner
# 6   https://www.zillow.com/homedetails/4168-N-Mill...   For sale by owner
# 7   https://www.zillow.com/homedetails/187-19th-Av...  Apartment for sale
# 8   https://www.zillow.com/homedetails/185-19th-Av...  Apartment for sale
# 9   https://www.zillow.com/homedetails/7250-Frankl...  Apartment for sale
# 10  https://www.zillow.com/homedetails/605-Queens-...  Apartment for sale
# 11  https://www.zillow.com/homedetails/571-S-Coron...  Apartment for sale
# 12  https://www.zillow.com/homedetails/10751-Wilsh...   For sale by owner
# 13  https://www.zillow.com/homedetails/4453-Aprico...  Apartment for sale
# 14  https://www.zillow.com/homedetails/1670-Whites...  Apartment for sale
# 15  https://www.zillow.com/homedetails/5715-N-Vist...  Apartment for sale
# 16  https://www.zillow.com/homedetails/302-E-Broad...  Apartment for sale
# 17  https://www.zillow.com/homedetails/324-W-50th-...  Apartment for sale
#
#      Lot Lot_conversion_to_sqft          Parking        Price Rent_zestimate  \
# 0   null                   null          1 space       $2,700           null
# 1   null                   null  Attached Garage     $475,000           null
# 2   null                   null         2 spaces   $1,350,000           null
# 3   null                   null          1 space     $515,000           null
# 4   null                   null         2 spaces     $270,000           null
# 5   null                   null         4 spaces   $1,500,000           null
# 6   null                   null          No Data     $750,000           null
# 7   null                   null          1 space   $1,275,000           null
# 8   null                   null         4 spaces   $1,495,000           null
# 9   null                   null         2 spaces     $825,000           null
# 10  null                   null             null   $6,995,000           null
# 11  null                   null          No Data  $19,000,000           null
# 12  null                   null         2 spaces     $699,000           null
# 13  null                   null        25 spaces   $5,100,000           null
# 14  null                   null         2 spaces     $547,000      $2,850/mo
# 15  null                   null        40 spaces   $4,980,000           null
# 16  null                   null         2 spaces   $2,980,000           null
# 17  null                   null             None   $1,100,000           null
#
#    Square_Feet State                        Street Year_build Zestimate  \
# 0          915    CA                  3734 2nd Ave       1955      null
# 1        2,030    CA        4713-4715 Large Oak Ct       1974      null
# 2          750    CA                 814 Curtis St       1950      null
# 3          908    CA      1111 Seacoast Dr UNIT 20       1973      null
# 4        1,796    CA                1536 South Ave       1945      null
# 5        3,900    CA           2371 University Ave       1952      null
# 6        5,762    CA          4168 N Millbrook Ave       1971      null
# 7        1,555    CA                  187 19th Ave       1924      null
# 8        1,840    CA                  185 19th Ave       1924      null
# 9          966    CA   7250 Franklin Ave UNIT 1101       1964      null
# 10       2,600    CA                605 Queens Ave       null      null
# 11      62,826    CA             571 S Coronado St       1923      null
# 12         954    CA  10751 Wilshire Blvd APT 1205       1972      null
# 13      11,924    CA               4453 Apricot Rd       2017      null
# 14       1,689    CA            1670 Whitestone Rd       1990  $549,135
# 15      11,808    CA               5715 N Vista St       1961      null
# 16       5,626    CA                302 E Broadway       1954      null
# 17       4,556    CA                 324 W 50th St       1922      null
#
#    Zillow_price/sqft Zip_code
# 0                 $3    91214
# 1               $234    95841
# 2             $1,800    94706
# 3               $567    91932
# 4               $150    95838
# 5               $385    94303
# 6               $130    93726
# 7               $820    94121
# 8               $812    94121
# 9               $854    90046
# 10              null    95991
# 11              $302    90057
# 12              $733    90024
# 13              $428    93063
# 14              $324    91977
# 15              $422    91775
# 16              $530    91776
# 17              $241    90037

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q1-2020_Apartment_page1.csv", index=False, header=True)
