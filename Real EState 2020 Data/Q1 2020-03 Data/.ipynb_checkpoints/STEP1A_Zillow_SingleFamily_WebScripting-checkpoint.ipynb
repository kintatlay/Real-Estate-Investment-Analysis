# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(1, 2):
    # Filter Out Coming Soon, Auction, Home Type: Houses, Days On Zillow: 90 Days
    linked = 'https://www.zillow.com/ca/houses/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-130.9521558125,"east":-107.6611401875,"south":28.570940002914515,"north":45.333552921012235},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":5,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
#     user_agent = 'Mozilla/5.0 (Windows NT 5.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
            # Identify and return housing weblink
            house_website = str(result.a.get('href'))
#             print('House_website:', house_website);
#             Identify and return house data
            listing_type = result.find('div', class_="list-card-footer").text;
#             print('listing_type:', listing_type);
            price = result.find('div', class_="list-card-price").text
            print('price:', price);
            full_address = result.find('address', class_="list-card-addr").text
#             print('full_address:', full_address);
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
#             print('street:', street);
            city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
#             print('city:', city);
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
#                 print('zip_code:', zip_code);
            except IndexError:
                zip_code = 'null'
#                 print('zip_code:', zip_code);
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
#             print('bed:', bed);
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
#             print('bath:', bath);
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
#             print('house_square_feet:', house_square_feet);
            # Loop inside each house website and get more house data
            loop_response = requests.get(house_website, headers=headers)
            loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
#             print(loop_soup)
            loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
            loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")
#             house_type = loop_result1.select('li')[0].text.split(":")[1]
#             print('house_type:', house_type);
#             year_build = loop_result1.select('li')[1].text.split(":")[1]
#             print('year_build:', year_build);
#             lot = loop_result1.select('li')[5].text.split(":")[1]
#             test = loop_result2
#             print('lot:', lot);
#             for content in test:
#                 if "lot" in content:
#                     print("yes")
#                     lot = content.text.split(":")[1]
#             lot = 'null';
#             house_type = 'null';
#             year_build = 'null';
#             parking = 'null';
#             hoa = 'null';
#             try:
            for content in loop_result2:
                if "Lot" in content.text.split(":")[0]:
                    lot = content.text.split(":")[1];
                if "Type" in content.text.split(":")[0]:
                    house_type = content.text.split(":")[1];
                if "Year built" in content.text.split(":")[0]:
                    year_bulid = content.text.split(":")[1];
                if "Parking" in content.text.split(":")[0]:
                    parking = content.text.split(":")[1];
                if "HOA" in content.text.split(":")[0]:
                    hoa = content.text.split(":")[1];
                print('test:', content.text);
#             except NameError:
#                 lot = 'null';
#                 house_type = 'null';
#                 year_build = 'null';
#                 parking = 'null';
#                 hoa = 'null';
            print('lot', lot)
            print('type', house_type);
            print('year-build', year_build);
            print('parking', parking);
            print('HOA', hoa);



#             try:
#                 if (str(lot.split(" ")[1]) == "sqft"):
#                     lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""))
# #                     print('lot_conversion_to_sqft:', lot_conversion_to_sqft);
#                 elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
#                     lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', "")) * 43560
#                 elif (lot == "No Data"):
#                     lot_conversion_to_sqft = 'null'
#                 else:
#                     lot_conversion_to_sqft = 'null'
#                 print('lot_conversion_to_sqft:', lot_conversion_to_sqft);
#             except IndexError:
#                 lot_conversion_to_sqft = 'null'
#             try:
#                 state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
# #                 print('state:', state);
#                 zillow_price_per_sqft = loop_result1.select('li')[6].text.split(":")[1]
# #                 print('zillow_price_per_sqft:', zillow_price_per_sqft);
#             except IndexError:
#                 state = 'null'
#                 zillow_price_per_sqft = 'null'
#             try:
#                 zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[0].text
#                 if (zestimate == "Zestimate®"):
#                     zestimate = 'null'
# #                 print('zestimate', zestimate)
#                 rent_zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[1].text
#             except:
#                 zestimate = 'null'
# #                 print('zestimate', zestimate)
#                 rent_zestimate = 'null'
# #             print(zestimate)
            
#             # Store data to house object if all elements are available
# #             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
#             house_obj = {
#                 "Listing_type": listing_type,
#                 "Price": price,
#                 "Full_address": full_address,
#                 "Street": street,
#                 "City": city,
#                 "State": state,
#                 "Zip_code": zip_code,
#                 "Bed": bed,
#                 "Bath": bath,
#                 "Square_Feet": house_square_feet,
#                 "House_type": house_type,
#                 "Year_build": year_build,
#                 "Parking": parking,
#                 "HOA": hoa,
#                 "Lot": lot,
#                 "Lot_conversion_to_sqft": lot_conversion_to_sqft,
#                 "Zestimate": zestimate,
#                 "Rent_zestimate": rent_zestimate,
#                 "Zillow_price/sqft": zillow_price_per_sqft,
#                 "House_website": house_website
#            }

#             #Continue to add data into collection house_dict
#             house_dict.append(house_obj)
#             time.sleep(1)
            
            
        except AttributeError as e:
            continue

# print(house_dict)
# Out:
# price: $365,000
# test: Type:Single Family
# test: Year built:2009
# test: Heating:Forced air
# test: Cooling:Central
# test: Parking:4 spaces
# test: Lot:7,413 sqft
# test: Price/sqft:$100
# lot 7,413 sqft
# type Single Family
# year-build null
# parking 4 spaces
# HOA None
# price: $325,900
# test: Type:Single Family
# test: Year built:1984
# test: Heating:Forced air
# test: Cooling:Central
# test: Parking:3 spaces
# test: Lot:0.37 acres
# test: Price/sqft:$192
# lot 0.37 acres
# type Single Family
# year-build null
# parking 3 spaces
# HOA None
# price: $389,000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-162-fa960ff447a2> in <module>()
#      42 #             print('house_square_feet:', house_square_feet);
#      43             # Loop inside each house website and get more house data
# ---> 44             loop_response = requests.get(house_website, headers=headers)
#      45             loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
#      46 #             print(loop_soup)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#    Bath Bed              City                                   Full_address  \
# 0     5   5          Adelanto         11062 Mckinley Ave, Adelanto, CA 92301
# 1     2   3             Hemet             27304 Pacifica Ct, Hemet, CA 92544
# 2     3   4     CathedralCity      68325 Verano Rd, Cathedral City, CA 92234
# 3     2   3  DesertHotSprings  9900 Hoylake Rd, Desert Hot Springs, CA 92240
# 4     3   4          Adelanto         11084 Remington Ct, Adelanto, CA 92301
# 5     5   4        Winchester       31964 Silk Vine Dr, Winchester, CA 92596
# 6     3   4        ChinoHills  16168 Singing Hills Dr, Chino Hills, CA 91709
# 7     3   5        Sacramento       7748 Finnhorse Way, Sacramento, CA 95828
# 8     2   4       Victorville       12933 Ivy Hill Ct, Victorville, CA 92392
# 9     3   3         Riverside            5154 Olivia Ln, Riverside, CA 92505
# 10    3   5           Menifee              30047 Wales Ct, Menifee, CA 92584
# 11    3   3             Hemet                41802 Lomas St, Hemet, CA 92544
# 12    2   3         Oceanside            769 Mosaic Cir, Oceanside, CA 92057
# 13    2   3       Victorville         14193 Auburn Ct, Victorville, CA 92394
# 14    3   3      SantaClarita   26606 Isabella Pkwy, Santa Clarita, CA 91351
# 15    2   4        Sacramento         3538 Huntsman Dr, Sacramento, CA 95826
# 16    3   3             Chino           8250 Garden Gate St, Chino, CA 91708
# 17    3   3            Saugus               20312 Julia Ln, Saugus, CA 91350
# 18    3   3         Riverside        3008 Streamwell St, Riverside, CA 92501
# 19    3   4            Folsom             1328 Freswick Dr, Folsom, CA 95630
# 20    2   3           Lincoln          1302 Barrington Ln, Lincoln, CA 95648
# 21    2   3          ElkGrove     8711 Aviary Woods Way, Elk Grove, CA 95624
# 22    3   4        PalmDesert       45775 Portola Ave, Palm Desert, CA 92260
# 23    3   2     CathedralCity        35407 Rush Ln, Cathedral City, CA 92234
# 24    4   5          Temecula        32758 Stonefield Ln, Temecula, CA 92592
# 25   23  20      BeverlyHills    67 Beverly Park Ct, Beverly Hills, CA 90210
# 26    3   3         CostaMesa         2135 Palmilla Ct, Costa Mesa, CA 92627
# 27    2   2           Yucaipa             35011 Beech Ave, Yucaipa, CA 92399
# 28    4   5           Ontario       5048 S Kensington Ave, Ontario, CA 91762
# 29   15   9        LosAngeles           11490 Orum Rd, Los Angeles, CA 90049
# 13      $1,400/mo       1,366    CA          14193 Auburn Ct       1995
# 14      $2,750/mo       1,660    CA      26606 Isabella Pkwy       1998
# 15      $1,900/mo       1,487    CA         3538 Huntsman Dr       1973
# 16      $2,200/mo       1,619    CA      8250 Garden Gate St       2006
# 17      $3,200/mo       2,701    CA           20312 Julia Ln       2011
# 18      $2,200/mo       1,855    CA       3008 Streamwell St       2003
# 19      $2,716/mo       2,277    CA         1328 Freswick Dr       2001
# 20      $2,200/mo       1,916    CA       1302 Barrington Ln       2005
# 21      $1,750/mo       1,330    CA    8711 Aviary Woods Way       1999
# 22      $2,800/mo       2,110    CA        45775 Portola Ave       1958
# 23      $2,575/mo       1,775    CA            35407 Rush Ln       2017
# 24      $3,000/mo       3,898    CA      32758 Stonefield Ln       2004
# 25           null      28,660    CA       67 Beverly Park Ct       1998
# 26      $3,200/mo       1,653    CA         2135 Palmilla Ct       2015
# 27      $1,550/mo       1,028    CA          35011 Beech Ave       1962
# 28      $2,886/mo       3,416    CA    5048 S Kensington Ave       2016
# 29           null      18,850    CA            11490 Orum Rd       2018
# 30    $250,000/mo      12,201    CA       141 S Carolwood Dr       1936
# 31     $53,519/mo      17,245    CA      14175 Mulholland Dr       1992
# 32      $1,350/mo       1,110    CA            11870 Star St       2005
# 33    $184,560/mo      28,000    CA       627 Carcassonne Rd       2019
# 34      $4,375/mo       9,495    CA           950 Lombard St    No Data
# 35      $5,133/mo       2,377    CA        3378 Ledgewood Dr       1958
# 36           null      10,646    CA  27930 Pacific Coast Hwy       1997
# 37      $2,100/mo       1,984    CA        43363 Windrose Ln       1993
# 38           null      17,297    CA          1940 Bel Air Rd       2013
# 39           null         360    CA         14000 Calle Real       2015
#
#       Zestimate Zillow_price/sqft Zip_code
# 0      $365,000              $100    92301
# 1      $325,900              $192    92544
# 2      $389,000              $201    92234
# 3      $265,965        8,276 sqft    92240
# 4      $282,900        7,252 sqft    92301
# 5      $498,997        8,276 sqft    92596
# 6      $588,901              $325    91709
# 7      $530,611              $175    95828
# 8          null              $166    92392
# 9      $405,902        5,662 sqft    92505
# 10     $423,901        8,276 sqft    92584
# 11     $307,901              $145    92544
# 12     $523,028       12.52 acres    92057
# 13     $240,900              $176    92394
# 14     $562,909        5.21 acres    91351
# 15     $347,086              $228    95826
# 16     $440,037        3,963 sqft    91708
# 17     $604,013        7,997 sqft    91350
# 18     $393,669        3,049 sqft    92501
# 19     $647,807        7,819 sqft    95630
# 20     $410,040        6,194 sqft    95648
# 21     $394,448              $289    95624
# 22     $476,477              $227    92260
# 23     $535,763        3,484 sqft    92234
# 24     $587,222        7,405 sqft    92592
# 25         null        9.87 acres    90210
# 26     $767,904        2,644 sqft    92627
# 27     $298,862              $291    92399
# 28     $620,736        5,009 sqft    91762
# 29         null            $2,971    90049
# 30  $99,610,005            $9,425    90077
# 31  $15,629,344              $983    90210
# 32     $176,684              $162    92301
# 33  $56,301,260            $2,321    90077
# 34  $37,925,852            $4,265    94133
# 35   $1,650,462        8,672 sqft    90068
# 36         null           $10,802    90265
# 37     $424,902              $214    93536
# 38         null            $1,445    90077
# 39         null          $305,556    93117
