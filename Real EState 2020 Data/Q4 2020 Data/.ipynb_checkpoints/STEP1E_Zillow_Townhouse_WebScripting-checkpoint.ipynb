# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(17, 21):
    linked = 'https://www.zillow.com/ca/townhomes/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-153.847663625,"east":-84.765632375,"south":12.777434491046995,"north":56.013075839104054},"mapZoom":4,"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"filterState":{"isPreMarketPreForeclosure":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"isSingleFamily":{"value":false},"isManufactured":{"value":false},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isLotLand":{"value":false},"doz":{"value":"90"},"isApartment":{"value":false},"isPreMarketForeclosure":{"value":false}},"isListVisible":true}'
    user_agent = 'Mozilla/5.0'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
            # Identify and return housing weblink
            house_website = str(result.a.get('href'))
            print(house_website)
            # Identify and return house data
            listing_type = result.find('div', class_="list-card-footer").text;
            price = result.find('div', class_="list-card-price").text
#             print(price)
            full_address = result.find('address', class_="list-card-addr").text
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
            try:
                city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
            except IndexError:
                city = 'null'
            try:
                state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
            except IndexError:
                state = 'null'
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
            except IndexError:
                zip_code = 'null'
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
            # Loop inside each house website and get more house data
            loop_response = requests.get(house_website, headers=headers)
            loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
            loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
            loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")

            lot = 'null';
            house_type = 'null';
            year_build = 'null';
            parking = 'null';
            hoa = 'null';
            lot_conversion_to_sqft = 'null';
            zillow_price_per_sqft = 'null';
            
            for content in loop_result2:
                if "Lot" in content.text.split(":")[0]:
                    lot = content.text.split(":")[1];
                if "Type" in content.text.split(":")[0]:
                    house_type = content.text.split(":")[1];
                if "Year built" in content.text.split(":")[0]:
                    year_build = content.text.split(":")[1];
                if "Parking" in content.text.split(":")[0]:
                    parking = content.text.split(":")[1];
                if "HOA" in content.text.split(":")[0]:
                    hoa = content.text.split(":")[1];
                if "Price/sqft" in content.text.split(":")[0]:
                    zillow_price_per_sqft = content.text.split(":")[1];
                    
            try:
                if (str(lot.split(" ")[1]) == "sqft"):
                    lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre") or (str(lot.split(" ")[1]) == "Acres") or (str(lot.split(" ")[1]) == "Acre")):
                    lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                elif (lot == "No Data"):
                    lot_conversion_to_sqft = 'null'
                else:
                    lot_conversion_to_sqft = 'null'
            except IndexError:
                lot_conversion_to_sqft = 'null'
                
            try:
                zestimate = loop_soup.findAll('span', class_="Text-c11n-8-18-0__aiai24-0 einFCw")[1].text
            except:
                zestimate = 'null'
#             try:
#                 rent_zestimate = loop_soup.findAll('p', class_="Text-aiai24-0 sc-eHgmQL sc-kasBVs iZUTqI")[1].text
#             except:
#                 rent_zestimate = 'null'
            if (zestimate[0] != '$'):
                zestimate = 'null';
            print('zestimate', zestimate)

            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
            house_obj = {
                "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "Lot": lot,
                "Lot_conversion_to_sqft": lot_conversion_to_sqft,
                "House_type": house_type,
                "Year_build": year_build,
                "Parking": parking,
                "HOA": hoa,
                "Zestimate": zestimate,
#                 "Rent_zestimate": rent_zestimate,
                "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
            }

            #Continue to add data into collection house_dict
            house_dict.append(house_obj)
            time.sleep(3)
            
        except AttributeError as e:
            continue

print(house_dict)
# Out:
# https://www.zillow.com/homedetails/3800-Stocker-St-APT-32-View-Park-CA-90008/20566918_zpid/
# zestimate $619,385
# https://www.zillow.com/homedetails/20427-Paseo-Azul-Northridge-CA-91326/95585946_zpid/
# zestimate $642,407
# https://www.zillow.com/community/violet-at-canvas/2080511505_zpid/
# zestimate null
# https://www.zillow.com/homedetails/2243-Stonewood-Ct-San-Pedro-CA-90732/21301984_zpid/
# zestimate $580,005
# https://www.zillow.com/homedetails/764-Via-Colinas-Westlake-Village-CA-91362/16488489_zpid/
# zestimate $639,921
# https://www.zillow.com/community/uptown-in-livermore/2077104727_zpid/
# zestimate null
# https://www.zillow.com/homedetails/12-Portside-Irvine-CA-92614/25752585_zpid/
# zestimate $889,001
# https://www.zillow.com/homedetails/10509-Caminito-Basswood-San-Diego-CA-92131/16866939_zpid/
# zestimate $629,999
# https://www.zillow.com/community/solstice-at-day-creek-square/2085199166_zpid/
# zestimate null
# https://www.zillow.com/homedetails/6476-Summit-Village-Ln-UNIT-2-Simi-Valley-CA-93063/131677527_zpid/
# zestimate $560,565
# https://www.zillow.com/homedetails/628-E-Walnut-St-Pasadena-CA-91101/54668658_zpid/
# zestimate $755,522
# https://www.zillow.com/homedetails/20003-Villa-Torino-Yorba-Linda-CA-92886/89154180_zpid/
# zestimate $734,757
# https://www.zillow.com/homedetails/22347-Mission-Cir-Chatsworth-CA-91311/20163690_zpid/
# zestimate $605,759
# https://www.zillow.com/homedetails/125-E-Sierra-Madre-Blvd-UNIT-E-Sierra-Madre-CA-91024/20884770_zpid/
# zestimate $698,994
# https://www.zillow.com/community/del-sur-avante/2080124181_zpid/
# zestimate null
# https://www.zillow.com/homedetails/519-S-Orange-Ave-APT-D-Monterey-Park-CA-91755/20664137_zpid/
# zestimate $598,714
# https://www.zillow.com/homedetails/15031-Sherman-Way-UNIT-D-Van-Nuys-CA-91405/19961715_zpid/
# zestimate $458,113
# https://www.zillow.com/homedetails/8338-Woodley-Pl-UNIT-44-Los-Angeles-CA-91343/20144002_zpid/
# zestimate $455,410
# https://www.zillow.com/homedetails/807-Estancia-Ter-17-San-Lorenzo-CA-94580/2076886960_zpid/
# zestimate $769,607
# https://www.zillow.com/community/collection-at-st-cloud/2085176135_zpid/
# zestimate null
# https://www.zillow.com/homedetails/1220-N-Orange-Grove-Ave-APT-12-West-Hollywood-CA-90046/95632851_zpid/
# zestimate $1,390,011
# https://www.zillow.com/community/indigo-walk/2078037990_zpid/
# zestimate null
# https://www.zillow.com/homedetails/74172-Catalina-Way-Palm-Desert-CA-92260/18080167_zpid/
# zestimate $265,354
# https://www.zillow.com/homedetails/309-Barbara-Ln-Daly-City-CA-94015/15609788_zpid/
# zestimate $1,027,050
# https://www.zillow.com/homedetails/5650-Roundtree-Pl-Westlake-Village-CA-91362/16488997_zpid/
# zestimate $776,553
# https://www.zillow.com/homedetails/37687-Weatherly-Rd-Newark-CA-94560/2076764313_zpid/
# zestimate null
# https://www.zillow.com/homedetails/1016-Pier-Ave-UNIT-4-Santa-Monica-CA-90405/20481586_zpid/
# zestimate $1,199,011
# https://www.zillow.com/homedetails/11237-Barnwall-St-APT-F-Norwalk-CA-90650/21405412_zpid/
# zestimate $487,868
# https://www.zillow.com/homedetails/1092-Trevino-Ter-San-Jose-CA-95120/19766368_zpid/
# zestimate $1,012,980
# https://www.zillow.com/homedetails/12888-Four-Palms-Ln-24-Sylmar-CA-91342/2077566360_zpid/
# zestimate $525,006
# https://www.zillow.com/homedetails/2674-Cleat-Ln-Sacramento-CA-95818/240357809_zpid/
# zestimate $471,495
# https://www.zillow.com/homedetails/2000-N-Village-Dr-APT-235-Truckee-CA-96161/17707262_zpid/
# zestimate $200,000
# https://www.zillow.com/homedetails/5528-Azure-Way-Long-Beach-CA-90803/21215235_zpid/
# zestimate $1,650,013
# https://www.zillow.com/homedetails/1850-Village-South-Rd-4-313-Olympic-Valley-CA-96146/2076873529_zpid/
# zestimate $701,621
# https://www.zillow.com/homedetails/23326-Caminito-Juanico-302-Laguna-Hills-CA-92653/25707000_zpid/
# zestimate $487,175
# https://www.zillow.com/homedetails/11770-Pacific-Coast-Hwy-APT-T-Malibu-CA-90265/16493878_zpid/
# zestimate $1,611,707
# https://www.zillow.com/community/latitude-at-rancho-tesoro/2081178110_zpid/
# zestimate null
# https://www.zillow.com/community/alay/2084680071_zpid/
# zestimate null
# https://www.zillow.com/homedetails/18631-Collins-St-APT-4-Tarzana-CA-91356/19934070_zpid/
# zestimate $465,273
# https://www.zillow.com/homedetails/2651-W-Lincoln-Ave-UNIT-25-Anaheim-CA-92801/250188897_zpid/
# zestimate $615,809
# https://www.zillow.com/homedetails/108-Via-Katrina-Thousand-Oaks-CA-91320/64632889_zpid/
# zestimate $643,225
# https://www.zillow.com/community/solara-at-skyline/2082357013_zpid/
# zestimate null
# https://www.zillow.com/homedetails/292-Palmer-St-APT-C2-Costa-Mesa-CA-92627/2077402942_zpid/
# zestimate $799,007
# https://www.zillow.com/homedetails/312-N-Francisca-Ave-UNIT-2-Redondo-Beach-CA-90277/21318020_zpid/
# zestimate $1,249,003
# https://www.zillow.com/community/prism/2079362539_zpid/
# zestimate null
# https://www.zillow.com/homedetails/18843-Hatteras-St-UNIT-2-Los-Angeles-CA-91356/19933558_zpid/
# zestimate $560,336
# https://www.zillow.com/homedetails/11417-Culver-Blvd-APT-2-Los-Angeles-CA-90066/51582291_zpid/
# zestimate $943,721
# https://www.zillow.com/homedetails/7022-Turin-Pl-Eastvale-CA-92880/325833853_zpid/
# zestimate null
# https://www.zillow.com/homedetails/1555-N-Chaparral-Rd-204-Palm-Springs-CA-92262/18023854_zpid/
# zestimate $287,664
# https://www.zillow.com/homedetails/16067-Sierra-Pass-Way-Hacienda-Heights-CA-91745/21469429_zpid/
# zestimate $480,579
# https://www.zillow.com/community/palazzo-at-day-creek-square/2077163953_zpid/
# zestimate null
# https://www.zillow.com/homedetails/6011-Dawn-Crk-UNIT-8-Playa-Vista-CA-90094/68993399_zpid/
# zestimate $1,499,010
# https://www.zillow.com/homedetails/700-W-East-St-UNIT-516-San-Diego-CA-92101/70598019_zpid/
# zestimate $749,005
# https://www.zillow.com/homedetails/1327-Holly-Ave-Imperial-Beach-CA-91932/2097174736_zpid/
# zestimate $595,112
# https://www.zillow.com/homedetails/1747-Bradbury-Dr-Montebello-CA-90640/20674808_zpid/
# zestimate $324,155
# https://www.zillow.com/homedetails/332-Village-Creek-Rd-Aptos-CA-95003/16136182_zpid/
# zestimate $893,240
# https://www.zillow.com/homedetails/3106-Hugo-St-San-Diego-CA-92106/61901109_zpid/
# zestimate $730,003
# https://www.zillow.com/homedetails/6929-Hazeltine-Ave-UNIT-A-Los-Angeles-CA-91405/19959341_zpid/
# zestimate $525,316
# https://www.zillow.com/homedetails/1214-Westmont-Dr-San-Pedro-CA-90732/21301566_zpid/
# zestimate $589,005
# https://www.zillow.com/homedetails/923-N-Stoneman-Ave-A-Alhambra-CA-91801/51583265_zpid/
# zestimate $740,731
# https://www.zillow.com/homedetails/664-3rd-St-Hermosa-Beach-CA-90254/2077261675_zpid/
# zestimate $1,827,488
# https://www.zillow.com/homedetails/124-Bridle-Point-Cir-Copperopolis-CA-95228/79792668_zpid/
# zestimate $241,208
# https://www.zillow.com/homedetails/13200-Pacific-Promenade-APT-152-Playa-Vista-CA-90094/63090795_zpid/
# zestimate $1,099,003
# https://www.zillow.com/community/sage-at-ninth/2076854865_zpid/
# zestimate null
# https://www.zillow.com/homedetails/4530-Ramsdell-Ave-APT-10-La-Crescenta-CA-91214/20899622_zpid/
# zestimate $562,727
# https://www.zillow.com/homedetails/1646-Orinda-Ct-Thousand-Oaks-CA-91362/16431804_zpid/
# zestimate $499,901
# https://www.zillow.com/community/landings-waypoint/2082500932_zpid/
# zestimate null
# https://www.zillow.com/homedetails/2520-Ruhland-Ave-APT-D-Redondo-Beach-CA-90278/20404618_zpid/
# zestimate $754,989
# https://www.zillow.com/homedetails/5-Starview-Dr-Oakland-CA-94618/24820411_zpid/
# zestimate $1,316,174
# https://www.zillow.com/community/alay/2084680068_zpid/
# zestimate null
# https://www.zillow.com/homedetails/13815-Victory-Blvd-UNIT-4-Los-Angeles-CA-91401/89148282_zpid/
# zestimate $590,554
# https://www.zillow.com/homedetails/1803-16th-St-D-Santa-Monica-CA-90404/2092036726_zpid/
# zestimate $1,352,408
# https://www.zillow.com/homedetails/708-Palisades-Dr-Pacific-Palisades-CA-90272/20543746_zpid/
# zestimate $1,777,302
# https://www.zillow.com/homedetails/10235-Madrid-Way-UNIT-149-Spring-Valley-CA-91977/62655657_zpid/
# zestimate $295,420
# https://www.zillow.com/homedetails/500-Harbor-Woods-Pl-Newport-Beach-CA-92660/25704567_zpid/
# zestimate $1,000,242
# https://www.zillow.com/community/rancho-milagro-at-pacific-highlands-ranch/2077495122_zpid/
# zestimate null
# https://www.zillow.com/community/landings-waypoint/2082500938_zpid/
# zestimate null
# https://www.zillow.com/homedetails/328-Ford-Rd-Costa-Mesa-CA-92627/2077001235_zpid/
# zestimate null
# https://www.zillow.com/community/rancho-milagro-at-pacific-highlands-ranch/2077486549_zpid/
# zestimate null
# https://www.zillow.com/homedetails/621-W-Foothill-Blvd-UNIT-49-Glendora-CA-91741/244502106_zpid/
# zestimate $620,005
# https://www.zillow.com/homedetails/219-Altura-Vis-Los-Gatos-CA-95032/19666516_zpid/
# zestimate $1,489,647
# https://www.zillow.com/homedetails/1742-Glendon-Ave-APT-C-Los-Angeles-CA-90024/20505148_zpid/
# zestimate $1,195,008
# https://www.zillow.com/homedetails/3001-S-Sycamore-St-APT-F-Santa-Ana-CA-92707/25684362_zpid/
# zestimate $469,278
# https://www.zillow.com/homedetails/2628-Kansas-Ave-APT-13-Santa-Monica-CA-90404/20473532_zpid/
# zestimate $759,400
# https://www.zillow.com/homedetails/13880-Sayre-St-UNIT-9-Los-Angeles-CA-91342/20072980_zpid/
# zestimate $392,668
# https://www.zillow.com/community/cerro-at-rancho-soleo/2080511488_zpid/
# zestimate null
# https://www.zillow.com/homedetails/1908-Plant-Ave-A-Redondo-Beach-CA-90278/20403336_zpid/
# zestimate $1,216,191
# https://www.zillow.com/homedetails/2416-Grant-Ave-A-Redondo-Beach-CA-90278/123168069_zpid/
# zestimate $980,349
# https://www.zillow.com/homedetails/1271-Granville-Ave-APT-302-Los-Angeles-CA-90025/20466630_zpid/
# zestimate $1,087,502
# https://www.zillow.com/homedetails/23860-Toscana-Dr-Valencia-CA-91354/80275533_zpid/
# zestimate $569,005
# https://www.zillow.com/homedetails/440-Navaro-Pl-UNIT-108-San-Jose-CA-95134/19489444_zpid/
# zestimate $1,275,057
# https://www.zillow.com/community/alay/2084680067_zpid/
# zestimate null
# https://www.zillow.com/homedetails/2809-Via-Alta-Pl-San-Diego-CA-92108/251201612_zpid/
# zestimate $1,250,001
# https://www.zillow.com/homedetails/4111-Gloster-Way-Sacramento-CA-95834/157720844_zpid/
# zestimate $445,007
# https://www.zillow.com/community/oakland-wattling-lane/2078810980_zpid/
# zestimate null
# https://www.zillow.com/homedetails/984-Palo-Verde-Ave-Long-Beach-CA-90815/21212624_zpid/
# zestimate $749,006
# https://www.zillow.com/homedetails/838-16th-St-APT-5-Santa-Monica-CA-90403/67420572_zpid/
# zestimate $1,750,013
# https://www.zillow.com/homedetails/2688-Santa-Anita-Ave-El-Monte-CA-91733/325800258_zpid/
# zestimate $630,003
# https://www.zillow.com/homedetails/621-California-Ave-APT-3-Santa-Monica-CA-90403/20484887_zpid/
# zestimate $1,099,010
# https://www.zillow.com/homedetails/723-S-Broadway-B-Redondo-Beach-CA-90277/21321723_zpid/
# zestimate $1,758,803
# https://www.zillow.com/homedetails/5230-Zelzah-Ave-APT-14-Los-Angeles-CA-91316/19939939_zpid/
# zestimate $699,006
# https://www.zillow.com/homedetails/1803-16th-St-UNIT-E-Santa-Monica-CA-90404/302796309_zpid/
# zestimate $1,241,830
# https://www.zillow.com/community/cava-at-rancho-soleo/2080511506_zpid/
# zestimate null
# https://www.zillow.com/homedetails/117-Paperbark-Ter-Sunnyvale-CA-94086/243211971_zpid/
# zestimate $1,550,969
# https://www.zillow.com/community/wilshire-at-boulevard/2081344556_zpid/
# zestimate null
# https://www.zillow.com/homedetails/7304-SW-Franklin-Blvd-3-Sacramento-CA-95823/2076866919_zpid/
# zestimate $164,430
# https://www.zillow.com/community/lantana-beach/2081046659_zpid/
# zestimate null
# https://www.zillow.com/homedetails/618-Harwood-Ln-Thousand-Oaks-CA-91360/16427280_zpid/
# zestimate $667,004
# https://www.zillow.com/homedetails/5437-Don-Edmondo-Ct-San-Jose-CA-95123/19707838_zpid/
# zestimate $565,004
# https://www.zillow.com/homedetails/924-Alhambra-Blvd-Sacramento-CA-95816/124738727_zpid/
# zestimate $779,769
# https://www.zillow.com/community/revo-at-novel-park/2077282640_zpid/
# zestimate null
# https://www.zillow.com/community/mission-crossing/2079933474_zpid/
# zestimate null
# https://www.zillow.com/homedetails/2862-6th-Ave-UNIT-102-San-Diego-CA-92103/2080085256_zpid/
# zestimate $1,847,633
# https://www.zillow.com/homedetails/6828-Las-Olas-Way-Malibu-CA-90265/20556868_zpid/
# zestimate $2,304,341
# https://www.zillow.com/homedetails/965-Branham-Ln-San-Jose-CA-95136/19703650_zpid/
# zestimate $764,118
# https://www.zillow.com/homedetails/28139-Bobwhite-Cir-UNIT-89-Santa-Clarita-CA-91350/20316915_zpid/
# zestimate $508,415
# https://www.zillow.com/homedetails/1539-W-158th-St-UNIT-3-Gardena-CA-90247/20980348_zpid/
# zestimate $564,365
# https://www.zillow.com/community/rancho-milagro-at-pacific-highlands-ranch/2077495120_zpid/
# zestimate null
# https://www.zillow.com/homedetails/114-Corsica-Dr-Newport-Beach-CA-92660/25676089_zpid/
# zestimate $594,573
# https://www.zillow.com/homedetails/3915-Bentley-Ave-Culver-City-CA-90232/68964082_zpid/
# zestimate $1,265,084
# https://www.zillow.com/community/bridgeway-towns/2077139124_zpid/
# zestimate null
# https://www.zillow.com/homedetails/1438-Thomas-Ave-San-Diego-CA-92109/16920569_zpid/
# zestimate $799,005
# https://www.zillow.com/homedetails/2622-Glamis-Ct-Arcadia-CA-91007/2076861480_zpid/
# zestimate null
# https://www.zillow.com/homedetails/2130-Federal-Ave-Los-Angeles-CA-90025/20464752_zpid/
# zestimate $1,349,006
# https://www.zillow.com/homedetails/6181-Arroyo-Rd-UNIT-5-Palm-Springs-CA-92264/18135637_zpid/
# zestimate $275,308
# https://www.zillow.com/homedetails/4748-La-Villa-Mari-UNIT-H-Marina-Del-Rey-CA-90292/2077179428_zpid/
# zestimate $1,199,004
# https://www.zillow.com/homedetails/4968-Waring-Rd-A-San-Diego-CA-92120/16986849_zpid/
# zestimate $558,855
# https://www.zillow.com/homedetails/39-Sea-Colony-Dr-Santa-Monica-CA-90405/20483657_zpid/
# zestimate $1,999,009
# https://www.zillow.com/homedetails/1169-Minnesota-Ave-UNIT-6-San-Jose-CA-95125/19682857_zpid/
# zestimate $1,054,952
# https://www.zillow.com/homedetails/3958-Bentley-Ave-APT-3-Culver-City-CA-90232/20436292_zpid/
# zestimate $1,024,941
# https://www.zillow.com/homedetails/139-Pacchetti-Way-Mountain-View-CA-94040/19510790_zpid/
# zestimate $1,426,865
# https://www.zillow.com/homedetails/857-San-Pablo-Way-Duarte-CA-91010/21624224_zpid/
# zestimate $616,269
# https://www.zillow.com/homedetails/27862-Inverness-42-Mission-Viejo-CA-92692/25735929_zpid/
# zestimate $620,003
# https://www.zillow.com/community/sohay-line/2077320021_zpid/
# zestimate null
# https://www.zillow.com/community/bridgeway-towns/2077139128_zpid/
# zestimate null
# https://www.zillow.com/homedetails/23741-Highland-Valley-Rd-Diamond-Bar-CA-91765/21665973_zpid/
# zestimate $423,225
# https://www.zillow.com/homedetails/2753-Waverly-Dr-APT-702-Los-Angeles-CA-90039/145645531_zpid/
# zestimate $834,900
# https://www.zillow.com/homedetails/902-N-Hummingbird-Ln-San-Mateo-CA-94402/2076856078_zpid/
# zestimate $1,139,526
# https://www.zillow.com/homedetails/4132-Sitio-Cielo-Oceanside-CA-92057/2076777981_zpid/
# zestimate $609,994
# https://www.zillow.com/community/landings-waypoint/2082500935_zpid/
# zestimate null
# https://www.zillow.com/community/prado-palermo/2082868516_zpid/
# zestimate null
# https://www.zillow.com/homedetails/10164-Samoa-Ave-APT-12-Los-Angeles-CA-91042/20098718_zpid/
# zestimate $511,558
# https://www.zillow.com/homedetails/105-Willow-Lake-Dr-Palm-Desert-CA-92260/18074501_zpid/
# zestimate $340,473
# https://www.zillow.com/community/langston-at-mountain-house/2080665210_zpid/
# zestimate null
# https://www.zillow.com/homedetails/318-Novel-Irvine-CA-92618/2076794663_zpid/
# zestimate null
# https://www.zillow.com/homedetails/206-W-Cypress-Ave-APT-E-Monrovia-CA-91016/21579407_zpid/
# zestimate $527,999
# https://www.zillow.com/homedetails/269-S-Barrington-Ave-E5-Los-Angeles-CA-90049/60115505_zpid/
# zestimate $1,108,166
# https://www.zillow.com/homedetails/1317-Greenwich-Ct-San-Jose-CA-95125/19591871_zpid/
# zestimate $668,301
# https://www.zillow.com/homedetails/7570-Gibraltar-St-UNIT-104-Carlsbad-CA-92009/250195691_zpid/
# zestimate $901,916
# https://www.zillow.com/homedetails/12826-Zurich-Pl-3-Truckee-CA-96161/82887408_zpid/
# zestimate $705,797
# https://www.zillow.com/community/river-village-concord/2076858746_zpid/
# zestimate null
# https://www.zillow.com/homedetails/19452-Mountainview-Ln-Huntington-Beach-CA-92648/25111827_zpid/
# zestimate $879,000
# https://www.zillow.com/homedetails/5677-Kai-Ct-Orcutt-CA-93455/248138190_zpid/
# zestimate $570,998
# https://www.zillow.com/homedetails/12016-Washington-Pl-APT-107-Los-Angeles-CA-90066/20446719_zpid/
# zestimate $819,007
# https://www.zillow.com/homedetails/1831-Rainbow-Terrace-Ln-Montebello-CA-90640/20674774_zpid/
# zestimate $463,795
# https://www.zillow.com/community/solmar/2080883567_zpid/
# zestimate null
# https://www.zillow.com/homedetails/8-Arabian-Way-Scotts-Valley-CA-95066/16120371_zpid/
# zestimate $729,006
# https://www.zillow.com/community/suwerte/2087663802_zpid/
# zestimate null
# https://www.zillow.com/homedetails/1360-Josselyn-Canyon-Rd-APT-33-Monterey-CA-93940/19358798_zpid/
# zestimate $639,003
# https://www.zillow.com/homedetails/1758-Pedrozzi-Cir-14-Livermore-CA-94551/2076826263_zpid/
# zestimate $878,628
# [{'Listing_type': 'Townhouse for sale', 'Price': '$610,000', 'Full_address': '3800 Stocker St APT 32, View Park, CA 90008', 'Street': '3800 Stocker St APT 32', 'City': 'ViewPark', 'State': 'CA', 'Zip_code': '90008', 'Bed': '2', 'Bath': '3', 'Square_Feet': '1,300', 'Lot': '2.52 Acres', 'Lot_conversion_to_sqft': 109771.2, 'House_type': 'Townhouse', 'Year_build': '1984', 'Parking': 'Carport, Covered', 'HOA': '$456/mo', 'Zestimate': '$619,385', 'Zillow_price/sqft': '$469', 'House_website': 'https://www.zillow.com/homedetails/3800-Stocker-St-APT-32-View-Park-CA-90008/20566918_zpid/'}, {'Listing_type': 'Townhouse for sale', 'Price': '$639,000', 'Full_address': '20427 Paseo Azul, Northridge, CA 91326', 'Street': '20427 Paseo Azul', 'City': 'Northridge', 'State': 'CA', 'Zip_code': '91326', 'Bed': '2', 'Bath': '3', 'Square_Feet': '1,381', 'Lot': '0.73 Acres', 'Lot_conversion_to_sqft': 31798.8, 'House_type': 'Townhouse', 'Year_build': '2009', 'Parking': 'Garage - Attached, Covered', 'HOA': '$382/mo', 'Zestimate': '$642,407', 'Zillow_price/sqft': '$463', 'House_website': 'https://www.zillow.com/homedetails/20427-Paseo-Azul-Northridge-CA-91326/95585946_zpid/'}, {'Listing_type': 'New construction', 'Price': '$676,710+', 'Full_address': 'Residence 3 Plan, Violet at Canvas', 'Street': 'Residence 3 Plan', 'City': 'VioletatCanvas', 'State': 'null', 'Zip_code': 'null', 'Bed': '4', 'Bath': '4', 'Square_Feet': '2,179', 'Lot': 'No Data', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Townhouse', 'Year_build': '2021', 'Parking': 'Covered', 'HOA': 'null', 'Zestimate': 'null', 'Zillow_price/sqft': '$311', 'House_website': 'https://www.zillow.com/community/violet-at-canvas/2080511505_zpid/'}, {'Listing_type': 'Contingent', 'Price': '$580,000', 'Full_address': '2243 Stonewood Ct, San Pedro, CA 90732', 'Street': '2243 Stonewood Ct', 'City': 'SanPedro', 'State': 'CA', 'Zip_code': '90732', 'Bed': '2', 'Bath': '3', 'Square_Feet': '1,429', 'Lot': '10.70 Acres', 'Lot_conversion_to_sqft': 466092.0, 'House_type': 'Townhouse', 'Year_build': '1979', 'Parking': 'Garage - Attached, Covered', 'HOA': '$463/mo', 'Zestimate': '$580,005', 'Zillow_price/sqft': '$406', 'House_website': 'https://www.zillow.com/homedetails/2243-Stonewood-Ct-San-Pedro-CA-90732/21301984_zpid/'}, {'Listing_type': 'Townhouse for sale', 'Price': '$639,918', 'Full_address': '764 Via Colinas, Westlake Village, CA 91362', 'Street': '764 Via Colinas', 'City': 'WestlakeVillage', 'State': 'CA', 'Zip_code': '91362', 'Bed': '3', 'Bath': '3', 'Square_Feet': '1,435', 'Lot': '1,433 sqft', 'Lot_conversion_to_sqft': 1433.0, 'House_type': 'Townhouse', 'Year_build': '1988', 'Parking': 'Garage, Garage - Attached, Covered', 'HOA': '$307/mo', 'Zestimate': '$639,921', 'Zillow_price/sqft': '$446', 'House_website': 'https://www.zillow.com/homedetails/764-Via-Colinas-Westlake-Village-CA-91362/16488489_zpid/'}, {'Listing_type': 'New construction', 'Price': '$845,000+', 'Full_address': 'Plan 3 Plan, Uptown in Livermore', 'Street': 'Plan 3 Plan', 'City': 'UptowninLivermore', 'State': 'null', 'Zip_code': 'null', 'Bed': '4', 'Bath': '4', 'Square_Feet': '2,150', 'Lot': 'No Data', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Townhouse', 'Year_build': '2020', 'Parking': 'Covered', 'HOA': 'null', 'Zestimate': 'null', 'Zillow_price/sqft': '$393', 'House_website': 'https://www.zillow.com/community/uptown-in-livermore/2077104727_zpid/'}, {'Listing_type': 'Contingent', 'Price': '$889,000', 'Full_address': '12 Portside, Irvine, CA 92614', 'Street': '12 Portside', 'City': 'Irvine', 'State': 'CA', 'Zip_code': '92614', 'Bed': '2', 'Bath': '2', 'Square_Feet': '1,100', 'Lot': '3,528 sqft', 'Lot_conversion_to_sqft': 3528.0, 'House_type': 'Townhouse', 'Year_build': '1984', 'Parking': 'Garage, Garage - Attached, On-street, Covered', 'HOA': '$180/mo', 'Zestimate': '$889,001', 'Zillow_price/sqft': '$808', 'House_website': 'https://www.zillow.com/homedetails/12-Portside-Irvine-CA-92614/25752585_zpid/'}, {'Listing_type': 'Townhouse for ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#            Listing_type      Price  \
# 0    Townhouse for sale   $610,000
# 1    Townhouse for sale   $639,000
# 2      New construction  $676,710+
# 3            Contingent   $580,000
# 4    Townhouse for sale   $639,918
# ..                  ...        ...
# 155    New construction  $432,435+
# 156  Townhouse for sale   $729,000
# 157    New construction  $499,900+
# 158          Contingent   $639,000
# 159  Townhouse for sale   $848,975
#
#                                           Full_address  \
# 0          3800 Stocker St APT 32, View Park, CA 90008
# 1               20427 Paseo Azul, Northridge, CA 91326
# 2                   Residence 3 Plan, Violet at Canvas
# 3               2243 Stonewood Ct, San Pedro, CA 90732
# 4          764 Via Colinas, Westlake Village, CA 91362
# ..                                                 ...
# 155                                Plan 2 Plan, Solmar
# 156             8 Arabian Way, Scotts Valley, CA 95066
# 157                               Plan 5 Plan, Suwerte
# 158  1360 Josselyn Canyon Rd APT 33, Monterey, CA 9...
# 159         1758 Pedrozzi Cir #14, Livermore, CA 94551
#
#                              Street             City State Zip_code Bed Bath  \
# 0            3800 Stocker St APT 32         ViewPark    CA    90008   2    3
# 1                  20427 Paseo Azul       Northridge    CA    91326   2    3
# 2                  Residence 3 Plan   VioletatCanvas  null     null   4    4
# 3                 2243 Stonewood Ct         SanPedro    CA    90732   2    3
# 4                   764 Via Colinas  WestlakeVillage    CA    91362   3    3
# ..                              ...              ...   ...      ...  ..  ...
# 155                     Plan 2 Plan           Solmar  null     null   2    3
# 156                   8 Arabian Way     ScottsValley    CA    95066   3    2
# 157                     Plan 5 Plan          Suwerte  null     null   3    4
# 158  1360 Josselyn Canyon Rd APT 33         Monterey    CA    93940   2    3
# 159           1758 Pedrozzi Cir #14        Livermore    CA    94551   4    4
#
#     Square_Feet          Lot Lot_conversion_to_sqft House_type Year_build  \
# 0         1,300   2.52 Acres                 109771  Townhouse       1984
# 1         1,381   0.73 Acres                31798.8  Townhouse       2009
# 2         2,179      No Data                   null  Townhouse       2021
# 3         1,429  10.70 Acres                 466092  Townhouse       1979
# 4         1,435   1,433 sqft                   1433  Townhouse       1988
# ..          ...          ...                    ...        ...        ...
# 155       1,310      No Data                   null  Townhouse       2021
# 156       1,393   1,568 sqft                   1568  Townhouse       1985
# 157       2,025      No Data                   null  Townhouse       2021
# 158       1,778   1,454 sqft                   1454  Townhouse       1975
# 159       1,929   2,500 sqft                   2500  Townhouse       2020
#
#                                 Parking      HOA Zestimate Zillow_price/sqft  \
# 0                      Carport, Covered  $456/mo  $619,385              $469
# 1            Garage - Attached, Covered  $382/mo  $642,407              $463
# 2                               Covered     null      null              $311
# 3            Garage - Attached, Covered  $463/mo  $580,005              $406
# 4    Garage, Garage - Attached, Covered  $307/mo  $639,921              $446
# ..                                  ...      ...       ...               ...
# 155                             Covered  $305/mo      null              $330
# 156           Garage, Garage - Attached  $391/mo  $729,006              $523
# 157                             Covered  $266/mo      null              $247
# 158                             Carport  $537/mo  $639,003              $359
# 159                   Garage - Attached  $370/mo  $878,628              $440
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/3800-Stocke...
# 1    https://www.zillow.com/homedetails/20427-Paseo...
# 2    https://www.zillow.com/community/violet-at-can...
# 3    https://www.zillow.com/homedetails/2243-Stonew...
# 4    https://www.zillow.com/homedetails/764-Via-Col...
# ..                                                 ...
# 155  https://www.zillow.com/community/solmar/208088...
# 156  https://www.zillow.com/homedetails/8-Arabian-W...
# 157  https://www.zillow.com/community/suwerte/20876...
# 158  https://www.zillow.com/homedetails/1360-Jossel...
# 159  https://www.zillow.com/homedetails/1758-Pedroz...
#
# [160 rows x 19 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q4-2020_Townhouse_Data_page17-20.csv", index=False, header=True)
