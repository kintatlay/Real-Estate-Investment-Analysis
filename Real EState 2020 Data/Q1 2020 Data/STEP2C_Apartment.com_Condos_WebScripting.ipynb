# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
# Testing 2
for page in range(1,2):
    link = 'https://www.apartments.com/condos/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='premiumPlus placard')

    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        pprint(new_results)
# Out:
# <div class="mainWrapper">
# <div class="profileHeaderWrapper profileHeaderProsumerWrapper js-profileHeaderStickyWrapper" id="profileHeaderWrapper">
# <header class="hasBackToResults mainHeader" id="mainHeader">
# <nav class="mainHeaderNavigation" id="mainHeaderNavigation">
# <div class="backToResultsSection">
# <a class="backToResults" href="https://www.apartments.com/condos/los-angeles-ca/" id="backToResults">
# <i class="leftArrowIcon"></i>
# <span class="mapText">Map</span>
# </a>
# </div>
# <div class="menuSection">
# <button class="dropdownToggle primary homeBtn" id="headerMenuLink" type="button">
# <i class="hamburgerBittenIcon"></i><span>Menu</span>
# </button>
# <div class="menuNavWrapper" id="menuNavWrapper">
# <div id="menuNavContainer">
# <div class="menuOpenWrapper">
# <span class="menuHeader" id="menuHeader"><i class="hamburgerBittenIcon"></i><span class="menuText">Menu</span></span>
# <ul class="menuNavigation" id="menuNavigation">
# <li>
# <a class="expandable" data-requirelogin="false" href="#">Renter Tools<i class="profileCarouselArrowRightIcon"></i></a>
# <ul class="submenu tools">
# <li><a href="https://www.apartments.com/my-account/#FavoriteListings">Favorites</a></li>
# <li><a href="https://www.apartments.com/my-account/#SavedSearches">Saved Searches</a></li>
# </ul>
# </li>
# <li id="menuNavLnkUserNotificationSettings">
# <a href="https://www.apartments.com/customers/" rel="nofollow">Customer Tools</a>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/">Apartments For Rent<i class="profileCarouselArrowRightIcon"></i><i class="viewMoreIcon"></i></a>
# <ul class="submenu properties">
# <li><a href="https://www.apartments.com/barrington-ca/">Barrington Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/beverly-hills-ca/">Beverly Hills Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/culver-city-ca/">Culver City Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/hollywood-ca/">Hollywood Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/long-beach-ca/">Long Beach Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/los-angeles-ca/">Los Angeles Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/north-hollywood-ca/">North Hollywood Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/santa-monica-ca/">Santa Monica Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/van-nuys-ca/">Van Nuys Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/hollywood-ca/">Hollywood Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/irvine-ca/">Irvine Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/los-angeles-ca/">Los Angeles Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/newport-beach-ca/">Newport Beach Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/playa-del-rey-ca/">Playa Del Rey Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/redondo-beach-ca/">Redondo Beach Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/santa-monica-ca/">Santa Monica Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/torrance-ca/">Torrance Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/venice-ca/">Venice Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/west-hollywood-ca/">West Hollywood Townhomes For Rent</a></li>
# </ul>
# </li>
# <li>
# <a data-requirelogin="false" href="https://helpcenter.apartments.com" id="menuNavHelpCenter" target="_blank">Help Center</a>
# </li>
# <li>
# <a data-requirelogin="false" href="https://www.apartments.com/mobile/" id="menuNavLnkMobileApps" target="_blank">Mobile Apps</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="headerSwitchLanguageWrapper">
# <a class="headerSwitchLanguage" data-culture="es-US" data-url="https://www.apartments.com/es/5247-hermitage-ave-los-angeles-ca-unidad-5247/8b8ky61/" href="https://www.apartments.com/es/5247-hermitage-ave-los-angeles-ca-unidad-5247/8b8ky61/" title="Español"><i class="worldIcon"></i>Español</a>
# </div>
# <div class="logoSpacer"></div>
# <div class="logo">
# <a href="https://www.apartments.com/">
# <img alt="Apartments.com Logo" src="/a/4d9af0/content/images/apartments-for-rent-logo.png"/>
# </a>
# </div>
# <div class="loginPrevNextWrapper">
# <div class="loginSection" id="headerLoginSection">
# <a class="js-headerSignUp headerSignUp" href="javascript:void(0);" title="Sign Up">Sign Up</a>
# <span>/</span>
# <a class="js-headerSignin headerSignIn" href="javascript:void(0);" title="Sign In">Sign In</a>
# </div>
# </div>
# </nav>
# </header>
# <header class="propertyHeader prosumer " id="propertyHeader">
# <div class="propertyInformationColumn">
# <div class="propertyLocation">
# <div class="propertyNameRow">
# <h1 class="propertyName">
#                         5247 Hermitage Ave Unit 5247
#                     </h1>
# </div>
# <div class="propertyAddressRow">
# <div class="propertyAddress">
# <h2>
# <span>Los Angeles</span>,
#                             <span>CA</span>
# <span>91607</span>
# </h2>
# <div class="neighborhoodAddress">
# <span class="neighborhood">–</span>
# <a class="neighborhood" href="https://www.apartments.com/condos/los-angeles-ca/">Los Angeles</a>
# </div>
# </div>
# </div>
# </div>
# <div class="favoriteBox">
# <a class="heartOutlineIcon neutral js-propertyHeaderFavorite" href="javascript:void(0);" icon-position="right"></a>
# </div>
# </div>
# <div class="leadColumn">
# <div class="leadColumnContainer">
# <div class="leadGen">
# <a class="primary js-checkAvailability" href="javascript:void(0)" rel="nofollow" role="button" title="Contact Property">
# <i class="emailIcon"></i>
# <span class="contact">Contact</span>
# </a>
# <span class="phoneNumber">
# <i class="phoneIcon"></i>
# <span>323-477-2393</span>
# </span>
# </div>
# </div>
# </div>
# </header>
# <div class="rentRollupsWrapper screen">
# <div class="rentRollups" id="rentRollups">
# <div class="rentRollupContainer">
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
#                         $1,650
#                     </span>
# <div class="leadFavScamContainer">
# <div class="prosumerLeadPhone">
# <i class="phoneIcon"></i>
# <span>323-477-2393</span>
# </div>
# <div class="prosumerLeadEmail">
# <a class="checkAvailability js-checkAvailabilityModified" href="javascript:void(0)" rel="nofollow" role="button" title="Contact Property">
# <i class="emailIcon"></i>
# </a>
# </div>
# <div class="prosumerFavoriteBox">
# <a class="heartOutlineIcon neutral js-propertyHeaderFavorite" href="javascript:void(0);" icon-position="right"></a>
# </div>
# <div class="prosumerFlag">
# <a class="prosumerflagButton js-openFlagModal" href="javascript:void(0);"><i class="flagIcon"></i></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <main data-listingid="8b8ky61">
# <section class="profileApp" id="profileApp">
# <div class="profileAppWrapper prosumer" id="profileWrapper">
# <div class="profileProsumer clearfix" id="profileProsumer">
# <aside class="contactLead" id="contactLead">
# <div class="lead-form-container">
# <div class="inlineDlfWrapper" id="inlineDlfWrapper">
# <div class="contactLeadWrapper " id="contactLeadForm">
# <input id="DlfConfiguration" type="hidden" value='{"DynamicLeadFormId":0,"DynamicLeadFormType":0,"ListingId":0,"HasContactVia":false,"HasMaxRent":false,"HasBedsBaths":false,"HasReasonForMoving":false,"IsPhoneRequired":false,"IsContactViaRequired":false,"IsMaxRentRequired":false,"IsBedsRequired":false,"IsReasonForMovingRequired":false,"HasOnlineScheduling":false,"OnlineSchedulingProviderType":0}'/>
# <header class="property-title-header">
# <h3>
# <i class="phoneTransparentIcon"></i>
# <span class="contactPhone" id="ctn">323-477-2393</span>
# </h3>
# </header>
# <div class="contactForm" id="contactForm">
# <div class="cell-xs-6 first-input">
# <label class="input-label">First Name *</label>
# <input class="contactFormFirstName input-override" id="contactFormFirstName" type="text"/>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Last Name *</label>
# <input class="contactFormLastName input-override" id="contactFormLastName" type="text"/>
# </div>
# <div class="cell-xs-12">
# <label class="input-label">Email Address *</label>
# <input class="contactFormEmail input-override" id="contactFormEmail" type="email"/>
# </div>
# <div class="cell-xs-6 first-input calendar-input-wrapper">
# <div class="calendar-input moveIn-calendar-input" id="MoveInDateContainer">
# <label class="input-label">Move-in Date *</label>
# <i class="calendarOutlineIcon"></i>
# <input class="contactFormMoveInDate input-override" id="MoveInDate" placeholder="Move-in Date *" type="text" value="05/01/2020">
# </input></div>
# </div>
# <div class="cell-xs-6 last-input phone-input-wrapper">
# <label class="input-label">Phone</label>
# <input class="contactFormPhoneNumber input-override" id="phone" placeholder="" type="tel" value=""/>
# </div>
# <div class="cell-xs-12 preference-wrapper" id="preference-wrapper">
# <h4>I would like to...</h4>
# <div class="checkbox-section">
# <input class="primaryCheckbox schedule-tour" id="schedule-tour-inline" type="checkbox"/>
# <label for="schedule-tour-inline" title="Schedule a Tour">
# <span>Schedule a Tour</span>
# </label>
# <input class="primaryCheckbox fill-out-application" id="fill-out-application-inline" type="checkbox"/>
# <label for="fill-out-application-inline" title="Request Application">
# <span>Request Application</span>
# </label>
# <input class="primaryCheckbox confirm-availability" id="confirm-availability-inline" type="checkbox"/>
# <label for="confirm-availability-inline" title="Confirm Availability">
# <span>Confirm Availability</span>
# </label>
# <input class="primaryCheckbox custom-message" id="custom-message-inline" type="checkbox"/>
# <label for="custom-message-inline" title="Custom Message">
# <span>Custom Message</span>
# </label>
# <div class="cell-xs-12 contactFormMessageWrapper">
# <label class="input-label full-label">Message</label>
# <textarea class="contactFormMessage input-override" id="contactFormMessage" maxlength="400" placeholder=""></textarea>
# <span class="counter-wrapper">
# <span id="contactFormMessageCounter"></span>
# </span>
# </div>
# </div>
# </div>
# <div class="cell-xs-12 submitError">
# <input id="submitGeneralError" type="hidden">
# </input></div>
# <a class="primary contactFormAction" href="javascript:void(0);" id="contactFormAction">
# <span class="default-send-title">Send Message</span>
# </a>
# <div class="email-listing-checkbox">
# <input checked="" class="optin primaryCheckbox emailListings" id="emailListingsInline" type="checkbox">
# <label class="emailListingsLabel" for="emailListingsInline">
# <span class="emailListing">Email me listings and apartment related info.</span>
# </label>
# </input></div>
# </div>
# </div>
# </div>
# <div id="submitSpinnerModalWrapper">
# <div class="submitRequestSpinner fade modalContainer" data-backdrop="static" id="submitRequestSpinner">
# <div class="spinner"></div>
# <p>Submitting Request</p>
# </div>
# </div>
# <div id="successModalWrapper">
# <div class="fade out successModal modalContainer" data-backdrop="static" id="successModal">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3 id="successModalHeader">Thank You</h3>
# <p class="message" id="successModalMsg">Thank you! Your email has been sent.</p>
# </div>
# </div>
# </div>
# </aside>
# <div class="profileContent">
# <span class="lastUpdated">
# <i class="rotateRightIcon" title="Last Updated"></i>
# <span>1 Day Ago</span>
# </span>
# <div class="mapNavBreadcrumb" id="mapNavBreadcrumb">
# <div class="crumbs" id="breadcrumbs-container">
# <span class="crumb">
# <a data-type="condos" href="https://www.apartments.com/condos/" title="Condos">Condos</a>
# </span>
# <span class="crumb">
# <a data-type="state" href="https://www.apartments.com/condos/ca/" title="California">California</a>
# </span>
# <span class="crumb">
# <a data-type="city" href="https://www.apartments.com/condos/los-angeles-ca/" title="Los Angeles">Los Angeles</a>
# </span>
# <span>5247 Hermitage Ave Unit 5247</span>
# </div>
# </div>
# <div id="profileMediaViewer">
# <div class="profileMediaViewerWrapper fade modal" id="profileMediaViewerWrapper">
# <div class="header">
# <div class="propertyName">
# <span>
#                 5247 Hermitage Ave |
#             </span>
# </div>
# <span class="propertyPhoneNumber">
#             323-477-2393
#         </span>
# <a class="checkAvailability js-checkavailability" href="javascript:void(0);" rel="nofollow" role="button">
# <span>
# <i class="emailIcon"></i>
#                 Contact Property
#             </span>
# </a>
# <div class="headerUtilities" id="headerUtilities">
# <span class="viewToggle active" id="gridToggle">
# <a data-modeid="0" href="javascript:void(0);">
# <i class="gridIcon" data-modeid="0"></i>
#                     Gallery
#                 </a>
# </span>
# <span class="viewToggle" id="singleViewToggle">
# <a data-modeid="1" href="javascript:void(0);">
# <i class="singleViewIcon" data-modeid="1"></i>
#                     Single View
#                 </a>
# </span>
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# </div>
# </div>
# <div class="viewerContent" id="viewerContent">
# <div class="singleGalleryWrapper active" id="singleGalleryWrapper">
# <div class="singleGalleryContent" id="singleGalleryContent" style="visibility: hidden"></div>
# </div>
# <div class="gridGalleryWrapper" id="gridGalleryWrapper">
# <div class="gridGalleryContent" data-bind="with: mediaViewer" id="gridGalleryContent">
# <div class="nano nano-fixed">
# <ul class="nano-content">
# <!-- ko foreach: attachments -->
# <li>
# <div class="gridImageWrapper aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <!-- ko if: $data.MediaType === 3 || $data.MediaType === 4 -->
# <button class="videoPlayIconLarge" data-bind="attr: {'data-attachmentid': Id}" type="button"></button>
# <!-- /ko -->
# <div class="aspectRatioImage" data-bind="style: {backgroundImage: 'url(' + Uri + ')'}, attr: {'data-attachmentid': Id, 'data-tabid': $index}">
# <img class="gridImage" data-bind="attr: {src: Uri}">
# </img></div>
# <span class="description" data-bind="text: Caption"></span>
# </div>
# </div>
# </li>
# <!-- /ko -->
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="carouselSection carousel " id="carouselSection">
# <div class="navigationControl">
# <button class="leftNav js-leftNav"><i class="profileCarouselArrowLeftIcon"></i></button>
# <button class="rightNav js-rightNav"><i class="profileCarouselArrowRightIcon"></i></button>
# </div>
# <ul class="carouselContent js-carouselContent">
# <li class="item active" data-image-idx="0">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="1" data-attachmenttypeid="3" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/mtpG4cCsyDNfRMlrPB8t6keUifW5HbvlB5T0KFIgxMA/111/5247-hermitage-ave-unit-5247-los-angeles-ca-primary-photo.jpg');">
# <img alt="Primary Photo - 5247 Hermitage Ave" src="https://images1.apartments.com/i2/mtpG4cCsyDNfRMlrPB8t6keUifW5HbvlB5T0KFIgxMA/111/5247-hermitage-ave-unit-5247-los-angeles-ca-primary-photo.jpg"/>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="item " data-image-idx="1">
# <div class="itemInner">
# <div class="aspectRatioImageWrapper">
# <div class="aspectRatioElement">
# <div class="aspectRatioImage " data-attachmentid="2" data-attachmenttypeid="4" data-mediatypeid="1" style="background-image: url('https://images1.apartments.com/i2/pBYyqhFpRnZei_iLpyi186W9O60idPlBHqca6aul03o/117/5247-hermitage-ave-unit-5247-los-angeles-ca-building-photo.jpg');">
# <img alt="Building Photo - 5247 Hermitage Ave" src="https://images1.apartments.com/i2/pBYyqhFpRnZei_iLpyi186W9O60idPlBHqca6aul03o/117/5247-hermitage-ave-unit-5247-los-angeles-ca-building-photo.jpg"/>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
#

# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="availabilitySection js-viewAnalyticsSection" data-analytics-name="unit_mix_grid" id="availabilitySection">
# <div class="js-expandableContainer expandableContainer">
# <table class="availabilityTable basic oneRental">
# <tbody>
# <tr class="oneRental">
# <th scope="col">Beds</th>
# <th scope="col">Baths</th>
# <th scope="col">Rent</th>
# <th class="depositHeading " scope="col">Deposit</th>
# <th scope="col">Unit #</th>
# <th scope="col">Sq Ft</th>
# <th class="leaseLengthHeading" scope="col">Lease Length</th>
# <th scope="col"></th>
# <th scope="col">Available</th>
# <th scope="col"></th>
# </tr>
# <tr class="rentalGridRow bold first" data-baths="1" data-beds="1" data-maxrent="1650" data-model="" data-rentalkey="dl4lejl" data-rentaltype="2" data-unit="5247">
# <td class="beds">
# <span class="longText">
# 				1 Bedroom
# 			</span>
# <span class="mediumText">
# 				1 Bed
# 			</span>
# <span class="shortText">
# 				1 BR
# 			</span>
# </td>
# <td class="baths">
# <span class="longText">
# 				1 Bathroom
# 			</span>
# <span class="mediumText">
# 				1 Bath
# 			</span>
# <span class="shortText">
# 				1 BA
# 			</span>
# </td>
# <td class="rent">
# 			$1,650
# 		</td>
# <td class="deposit ">$1,650 </td>
# <td class="unit ">5247</td>
# <td class="sqft">800 Sq Ft</td>
# <td class="leaseLength">12 Month Lease</td>
# <td class="name collapsed"></td>
# <td class="available">
# 			Available Now
# 		</td>
# <td class="applyNow">
# <a class="js-applyNow profile" href="javascript:void(0);" rel="nofollow" role="button">Apply Now</a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="disclaimer">Prices and availability subject to change without notice.</div>
# </section>
# <section class="descriptionSection js-viewAnalyticsSection" data-analytics-name="about" id="descriptionSection">
# <h3>About 5247 Hermitage Ave Los Angeles, CA 91607</h3>
# <p>This is a great one bedroom in a fully renovated triplex!! Free laundry on site with one parking space included. There is a gym in the garage. Upstairs unit with hardwood floors and tile in the kitchen. New fixtures throughout and faucets in the unit as well. New counter tops and an Oven/stove is included and fridge is optional. Brand new ceiling fans in the unit. Owner pays for water and laundry. Right down the street from the orange line and the NOHO west mall is less than 3 miles away. Contact for showing pets considered with additional deposit. $150 OFF SECOND MONTH'S RENT IF LEASED BY APRIL 1st!</p>
# </section>
# <section class="amenitiesSection anchorBuffer" id="amenitiesSection">
# <div class="js-viewAnalyticsSection js-viewAnalyticsSection" data-analytics-name="amenities">
# <h3>Condo Amenities</h3>
# <section class="specGroup js-specGroup">
# <div class="specList parking js-spec">
# <span class="amenityCircle"><i class="parkingIcon"></i></span><h3>Parking</h3>
# <div class="parkingDetails">
# <div class="parkingTypeFeeContainer">
# <h4>
#                             Surface Lot
#                         </h4>
# </div>
# <p>
# </p>
# </div>
# </div>
# <div class="specList js-spec">
# <span class="amenityCircle"><i class="leaseIcon"></i></span><h3>Lease Length</h3>
# <ul>
# <li class="leaseLength">12 Months</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="servicesIcon"></i></span><h3>Services</h3>
# <ul>
# <li><span class="bullet">•</span>Laundry Facilities</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="parksIcon"></i></span><h3>Outdoor Space</h3>
# <ul>
# <li><span class="bullet">•</span>Gated</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="propertyIcon"></i></span><h3>Features</h3>
# <ul>
# <li><span class="bullet">•</span>Ceiling Fans</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="kitchenIcon"></i></span><h3>Kitchen</h3>
# <ul>
# <li><span class="bullet">•</span>Kitchen</li>
# <li><span class="bullet">•</span>Oven</li>
# </ul>
# </div>
# <div class="specList js-spec" data-shuffle-priority="4">
# <span class="amenityCircle"><i class="sofaIcon"></i></span><h3>Living Space</h3>
# <ul>
# <li><span class="bullet">•</span>Hardwood Floors</li>
# </ul>
# </div>
# </section>
# </div>
# </section>
# <section class="contactSection js-viewAnalyticsSection negativeMargin" data-analytics-name="contact" id="contactSection">
# <h3>Contact</h3>
# <div class="contactContainer prosumer">
# <div class="contactInfo">
# <div class="agentContainer">
# <span class="contactCircle"><i class="userIcon"></i></span>
# <div class="agentFullName">
# 								Darryn Henderson
# 						</div>
# </div>
# <div class="phoneLeadFormContainer">
# <div class="phoneNumber">
# <span class="phoneIcon"></span> 323-477-2393
#                 </div>
# <div class="phoneNumberMobile">
# <a href="tel:3234772393">
# <span class="phoneIcon"></span> 323-477-2393
#                     </a>
# </div>
# <a class="checkAvailability" href="javascript:void(0);" id="contactFormAction"><i class="emailIcon"></i> Contact Property</a> </div>
# </div>
# </div>
# </section>
# <section class="schoolsSection" id="schoolsSection">
# <div class="schoolsModule" id="schoolsModule">
# <h3>Schools</h3>
# <div class="schoolsNav">
# <ul class="tabHeader">
# <li class="active" data-tab-id="public">
# <a href="javascript:void(0);" id="publicTabText">Public Schools</a>
# </li>
# <li class="" data-tab-id="private">
# <a href="javascript:void(0);" id="privateTabText">Private Schools</a>
# </li>
# </ul>
# <div class="schoolsLegendOutboundContainer">
# <ul>
# <li><i class="attendanceZoneIcon"></i>Attendance Zone</li>
# <li><i class="nearbySchoolsIcon"></i>Nearby</li>
# <li><i class="propertyIdentifiedIcon"></i>Property Identified</li>
# </ul>
# </div>
# </div>
# <div class="schoolsPublicContainer cell-xs-12 tabContent active" data-tab-content-id="public">
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Public Elementary School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/burbank-boulevard-elementary-school/ctdzxtg/" title="Burbank Boulevard Elementary School">Burbank Boulevard Elementary School</a></p>
# <div class="details">
# <p class="grades">Grades K-5</p>
# <p class="numberOfStudents">379 Students</p>
# <p class="schoolPhone">(818) 763-6497</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating ">
# <i class="rating5gsIcon"></i>
# <span class="outOfTen">out of 10</span>
# </div>
# <div class="nearbySchools">
# <i class="attendanceZoneIcon"></i>
# <span>Attendance Zone</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# <div class="expandableContainer " id="elementarySchools public">
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Charter Elementary, Middle &amp; High School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/vaughn-next-century-learning-center/envqd7n/" title="Vaughn Next Century Learning Center">Vaughn Next Century Learning Center</a></p>
# <div class="details">
# <p class="grades">Grades PK-12</p>
# <p class="numberOfStudents">2,831 Students</p>
# <p class="schoolPhone">(818) 896-7461</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating ">
# <i class="rating6gsIcon"></i>
# <span class="outOfTen">out of 10</span>
# </div>
# <div class="nearbySchools">
# <i class="nearbySchoolsIcon"></i>
# <span>Nearby</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Public Middle School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/walter-reed-middle-school/z4j16cx/" title="Walter Reed Middle School">Walter Reed Middle School</a></p>
# <div class="details">
# <p class="grades">Grades 6-8</p>
# <p class="numberOfStudents">1,610 Students</p>
# <p class="schoolPhone">(818) 487-7600</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating ">
# <i class="rating6gsIcon"></i>
# <span class="outOfTen">out of 10</span>
# </div>
# <div class="nearbySchools">
# <i class="attendanceZoneIcon"></i>
# <span>Attendance Zone</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Public High School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/north-hollywood-senior-high-school/4jdnrek/" title="North Hollywood Senior High School">North Hollywood Senior High School</a></p>
# <div class="details">
# <p class="grades">Grades 9-12</p>
# <p class="numberOfStudents">2,610 Students</p>
# <p class="schoolPhone">(818) 753-6200</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating ">
# <i class="rating7gsIcon"></i>
# <span class="outOfTen">out of 10</span>
# </div>
# <div class="nearbySchools">
# <i class="attendanceZoneIcon"></i>
# <span>Attendance Zone</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="schoolsPrivateContainer cell-xs-12 tabContent " data-tab-content-id="private">
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Private Elementary &amp; Middle School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/country-school-the/8nb5qq0/" title="Country School, The">Country School, The</a></p>
# <div class="details">
# <p class="grades">Grades K-8</p>
# <p class="numberOfStudents">180 Students</p>
# <p class="schoolPhone">(818) 769-2473</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating private">
# <i class="ratingNRgsIcon"></i>
# </div>
# <div class="nearbySchools">
# <i class="nearbySchoolsIcon"></i>
# <span>Nearby</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# <div class="expandableContainer " id="elementarySchools private">
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Private Elementary School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/beth-hillel-day-school/0wggc90/" title="Beth Hillel Day School">Beth Hillel Day School</a></p>
# <div class="details">
# <p class="grades">Grades PK-6</p>
# <p class="numberOfStudents">60 Students</p>
# <p class="schoolPhone">(818) 763-8308</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating private">
# <i class="ratingNRgsIcon"></i>
# </div>
# <div class="nearbySchools">
# <i class="nearbySchoolsIcon"></i>
# <span>Nearby</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cell-sm-6 cell-xs-12 paddingReset">
# <div class="schoolCard">
# <div class="descriptionContainer">
# <p class="schoolType">Private High School</p>
# <p class="schoolName"><a href="https://www.apartments.com/schools/ca/ner-aryeh-dba-usa-outreach/cpm6yye/" title="Ner Aryeh Dba Usa Outreach">Ner Aryeh Dba Usa Outreach</a></p>
# <div class="details">
# <p class="grades">Grades 9-12</p>
# <p class="numberOfStudents">27 Students</p>
# <p class="schoolPhone">(818) 509-5909</p>
# </div>
# </div>
# <div class="iconContainer">
# <div class="schoolRating private">
# <i class="ratingNRgsIcon"></i>
# </div>
# <div class="nearbySchools">
# <i class="nearbySchoolsIcon"></i>
# <span>Nearby</span>
# </div>
# <div class="propertyIdentified">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="outboundLinksContainer cell-xs-12 ">
# <a class="outboundLink" href="http://www.greatschools.org" rel="nofollow" target="_blank">School data provided by GreatSchools</a>
# <span class="rating">
# <a class="questionMarkCircleIcon" data-html="html" data-placement="top" tabindex="-1" title='&lt;h4&gt;&lt;a href="http://www.greatschools.org/" target="_blank"&gt;School data provided by GreatSchools&lt;/a&gt;&lt;/h4&gt;&lt;p&gt;The GreatSchools Rating helps parents compare schools within a state based on a variety of school quality indicators and provides a helpful picture of how effectively each school serves all of its students. Ratings are on a scale of 1 (below average) to 10 (above average) and can include test scores, college readiness, academic progress, advanced courses, equity, discipline and attendance data. We also advise parents to visit schools, consider other information on school performance and programs, and consider family needs as part of the school selection process.&lt;/p&gt;'></a>
# </span>
# <div class="collapsed ratingsMethodology" id="ratingsMethodology">
#                 The GreatSchools Rating helps parents compare schools within a state based on a variety of school quality indicators and provides a helpful picture of how effectively each school serves all of its students. Ratings are on a scale of 1 (below average) to 10 (above average) and can include test scores, college readiness, academic progress, advanced courses, equity, discipline and attendance data. We also advise parents to visit schools, consider other information on school performance and programs, and consider family needs as part of the school selection process.
#             </div>
# </div>
# </div>
# </section>
# <section class="ratings js-viewAnalyticsSection" data-analytics-name="walkscore" id="walkScoreSection">
# <h3> Walkability Near 5247 Hermitage Ave Los Angeles, CA 91607</h3>
# <div class="ratingsInfo ratingsInfo-box">
# <div class="ratingCol walkScore" data-score="82">
# <div class="ratingsBox">
# <span class="scoreType">Walk Score<sup>®</sup></span>
# <div class="ratingsScore">
# <div class="walkIcon"></div>
# <div>
# <span class="score">82</span>
# <span class="scoreDescription">Very Walkable</span>
# </div>
# </div>
# </div>
# </div>
# <div class="ratingCol transitScore" data-score="50">
# <div class="ratingsBox">
# <span class="scoreType">Transit Score<sup>®</sup></span>
# <div class="ratingsScore">
# <div class="commuteBusIcon"></div>
# <div>
# <span class="score">50</span>
# <span class="scoreDescription">Good Transit</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="nearbyAmenitiesSection js-viewAnalyticsSection " data-analytics-name="nearby_amenities" id="nearbyAmenitiesSection">
# <h3>Nearby Transit &amp; Points of Interest </h3>
# <h3 class="subHeading">Time and Distance from 5247 Hermitage Ave Los Angeles, CA 91607</h3>
# <section class="pointsOfInterestSection js-viewAnalyticsSection tabContent active" data-analytics-name="points_of_interest" id="pointsofInterestSection">
# <div class="spec">
# <div class="transportationDetail ">
# <table>
# <thead class="longLabel">
# <tr>
# <th><span class="poiSchoolIcon"></span> Colleges</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <thead class="shortLabel">
# <tr>
# <th><span class="poiSchoolIcon"></span> Colleges</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/off-campus-housing/ca/valley-glen/valley-college/">Valley College</a>
# </div>
# </td>
# <td>6 min</td>
# <td>1.9 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/off-campus-housing/ca/burbank/new-york-film-academy/">New York Film Academy</a>
# </div>
# </td>
# <td>8 min</td>
# <td>4.4 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">Woodbury University</div>
# </td>
# <td>14 min</td>
# <td>6.3 mi</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="transportationDetail showPrint">
# <table>
# <thead class="longLabel">
# <tr>
# <th><span class="poiTransitIcon"></span> Transit / Subway</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <thead class="shortLabel">
# <tr>
# <th><span class="poiTransitIcon"></span> Transit / Subway</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/transit/ca/valley-village/laurel-canyon-station/ehykvsn/">Laurel Canyon Station</a>
# </div>
# </td>
# <td>2 min</td>
# <td>0.4 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/transit/ca/north-hollywood/north-hollywood-station/lsnn4hg/">North Hollywood Station</a>
# </div>
# </td>
# <td>4 min</td>
# <td>1.8 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/transit/ca/van-nuys/valley-college-station/wy7sn3j/">Valley College Station</a>
# </div>
# </td>
# <td>4 min</td>
# <td>1.8 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/transit/ca/van-nuys/woodman-station/6jr320v/">Woodman Station</a>
# </div>
# </td>
# <td>6 min</td>
# <td>2.9 mi</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="transportationDetail ">
# <table>
# <thead class="longLabel">
# <tr>
# <th><span class="poiTransitIcon"></span> Commuter Rail</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <thead class="shortLabel">
# <tr>
# <th><span class="poiTransitIcon"></span> Commuter Rail</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/transit/ca/burbank/burbank-bob-hope-airport/rf0bxf3/">Burbank-Bob Hope Airport</a>
# </div>
# </td>
# <td>10 min</td>
# <td>4.9 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/transit/ca/van-nuys/van-nuys/b4brglb/">Van Nuys</a>
# </div>
# </td>
# <td>12 min</td>
# <td>6.4 mi</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="transportationDetail ">
# <table>
# <thead class="longLabel">
# <tr>
# <th><span class="poiShoppingCenterIcon"></span> Shopping Centers</th>
# <th>Walk</th>
# <th>Distance</th>
# </tr>
# </thead>
# <thead class="shortLabel">
# <tr>
# <th><span class="poiShoppingCenterIcon"></span> Shopping Centers</th>
# <th>Walk</th>
# <th>Distance</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/malls/ca/valley-village/valley-village/63sezkv/">Valley Village</a>
# </div>
# </td>
# <td>6 min</td>
# <td>0.3 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">Strip Center at 5406-5412 Whitsett Ave</div>
# </td>
# <td>9 min</td>
# <td>0.5 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">Strip Center at 12032-1204 Burbank Blvd</div>
# </td>
# <td>14 min</td>
# <td>0.7 mi</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="transportationDetail ">
# <table>
# <thead class="longLabel">
# <tr>
# <th><span class="poiParkIcon"></span> Parks and Recreation</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <thead class="shortLabel">
# <tr>
# <th><span class="poiParkIcon"></span> Parks and Recreation</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="transportationName airport">Franklin Canyon Park</div>
# </td>
# <td>14 min</td>
# <td>5.1 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">Sooky Goldman Nature Center</div>
# </td>
# <td>15 min</td>
# <td>5.2 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">The Japanese Garden</div>
# </td>
# <td>10 min</td>
# <td>5.6 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">Sepulveda Basin Wildlife Reserve</div>
# </td>
# <td>12 min</td>
# <td>6.0 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName airport">Runyon Canyon</div>
# </td>
# <td>14 min</td>
# <td>7.4 mi</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="transportationDetail ">
# <table>
# <thead class="longLabel">
# <tr>
# <th><span class="poiMilitaryBaseIcon"></span> Military Bases</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <thead class="shortLabel">
# <tr>
# <th><span class="poiMilitaryBaseIcon"></span> Military Bases</th>
# <th>Drive</th>
# <th>Distance</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/military/ca/el-segundo/los-angeles-air-force-base/">Los Angeles Air Force Base</a>
# </div>
# </td>
# <td>32 min</td>
# <td>24.6 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# <a href="https://www.apartments.com/military/ca/manhattan-beach/national-guard-armory-south-bay-cities/">National Guard Armory South Bay Cities</a>
# </div>
# </td>
# <td>36 min</td>
# <td>27.7 mi</td>
# </tr>
# <tr>
# <td>
# <div class="transportationName">
# ...
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Last Name *</label>
# <input class="contactFormLastName input-override" id="contactFormLastName" type="text"/>
# </div>
# <div class="cell-xs-12">
# <label class="input-label">Email Address *</label>
# <input class="contactFormEmail input-override" id="contactFormEmail" type="email"/>
# </div>
# <div class="cell-xs-6 first-input calendar-input-wrapper">
# <div class="calendar-input moveIn-calendar-input" id="MoveInDateContainer">
# <label class="input-label">Move-in Date *</label>
# <i class="calendarOutlineIcon"></i>
# <input class="contactFormMoveInDate input-override" id="MoveInDate" placeholder="Move-in Date *" type="text" value="05/01/2020">
# </input></div>
# </div>
# <div class="cell-xs-6 last-input">
# <label class="input-label">Phone</label>
# <input class="contactFormPhoneNumber input-override" id="phone" placeholder="" type="tel" value=""/>
# </div>
# <div class="cell-xs-12 preference-wrapper" id="preference-wrapper">
# <h4>I would like to...</h4>
# <div class="checkbox-section">
# <input class="primaryCheckbox schedule-tour" id="schedule-tour" type="checkbox"/>
# <label for="schedule-tour" title="Schedule a Tour">
# <span>Schedule a Tour</span>
# </label>
# <input class="primaryCheckbox fill-out-application" id="fill-out-application" type="checkbox"/>
# <label for="fill-out-application" title="Request Application">
# <span>Request Application</span>
# </label>
# <input class="primaryCheckbox confirm-availability" id="confirm-availability" type="checkbox"/>
# <label for="confirm-availability" title="Confirm Availability">
# <span>Confirm Availability</span>
# </label>
# <input class="primaryCheckbox custom-message" id="custom-message" type="checkbox"/>
# <label for="custom-message" title="Custom Message">
# <span>Custom Message</span>
# </label>
# <div class="cell-xs-12 contactFormMessageWrapper">
# <label class="input-label full-label">Message</label>
# <textarea class="contactFormMessage input-override" id="contactFormMessage" maxlength="400" placeholder=""></textarea>
# <span class="counter-wrapper">
# <span id="contactFormMessageCounter"></span>
# </span>
# </div>
# </div>
# </div>
# <div class="cell-xs-12 submitError">
# <input id="submitGeneralError" type="hidden">
# </input></div>
# <a class="primary contactFormAction" href="javascript:void(0);" id="contactFormAction">
# <span class="default-send-title">Send Message</span>
# </a>
# <div class="email-listing-checkbox">
# <input checked="" class="optin primaryCheckbox emailListings" id="emailListingsPopup" type="checkbox">
# <label class="emailListingsLabel" for="emailListingsPopup">
# <span class="emailListing">Email me listings and apartment related info.</span>
# </label>
# </input></div>
# </div>
# </div>
# </div>
# <div id="submitSpinnerModalWrapper">
# <div class="submitRequestSpinner fade modalContainer" data-backdrop="static" id="submitRequestSpinner">
# <div class="spinner"></div>
# <p>Submitting Request</p>
# </div>
# </div>
# <div id="successModalWrapper">
# <div class="fade out successModal modalContainer" data-backdrop="static" id="successModal">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3 id="successModalHeader">Thank You</h3>
# <p class="message" id="successModalMsg">Thank you! Your email has been sent.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade errorModal" data-backdrop="static" id="profileErrorModal">
# <div class="modalContainer">
# <div class="modalContent">
# <div class="modalHeader">
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# <h2>Error</h2>
# </div>
# <div class="modalBody">
# <h3 class="errorTitle"></h3>
# <p class="errorDescription"></p>
# </div>
# </div>
# </div>
# </div>
# <div class="profileFooterWrapper" id="profileFooterWrapper">
# <div class="profileLinks js-viewAnalyticsSection" data-analytics-name="popular_searches" id="profileQuickLinks">
# <div class="quickLinks">
# <div class="propertyBlurbSection">
# <h2 class="propertyBlurbHeader">7857 W Manchester Ave Area Info</h2>
# <p class="propertyBlurbContent">7857 W Manchester Ave is a condo located in <a href="https://www.apartments.com/los-angeles-county-ca/">Los Angeles County</a>, the <a href="https://www.apartments.com/playa-del-rey-ca-90293/">90293</a> ZIP Code, and the <a href="https://www.apartments.com/school-districts/ca/los-angeles-unified-school-district/bqtnf28/">Los Angeles Unified School District</a> attendance zone.</p>
# </div>
# <div class="quickLinksContent">
# <h4 class="quickLinksTitle">Popular Searches</h4>
# <div>
# <div class="nearbyAreas clearfix hideOnCollapse">
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Cities">Cities</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/culver-city-ca/" title="Culver City   ">Culver City Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/palms-ca/" title="Palms   ">Palms Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/rancho-park-ca/" title="Rancho Park   ">Rancho Park Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/century-city-ca/" title="Century City   ">Century City Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/mar-vista-ca/" title="Mar Vista   ">Mar Vista Condos</a></li>
# </ul>
# </div>
# <div class="quickLinksCol">
# <h5 class="quickLinksHeading" title="Neighborhoods">Neighborhoods</h5>
# <ul>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/washington-culver-culver-city-ca/" title="Washington Culver   ">Washington Culver Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/park-east-culver-city-ca/" title="Park East   ">Park East Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/downtown-culver-city-culver-city-ca/" title="Downtown Culver City   ">Downtown Culver City Condos</a></li>
# <li class="hideOnCollapse"><a href="https://www.apartments.com/westdale-los-angeles-ca/" title="Westdale   ">Westdale Condos</a></li>
# </p>
# </a>
# <div class="social">
# <span class="socialIcons">
# <a class="facebookIcon" href="https://facebook.com/apartments.com" target="_blank"></a>
# <a class="twitterIcon" href="https://twitter.com/apartmentscom" target="_blank"></a>
# <a class="linkedinIcon" href="https://linkedin.com/company/apartments-com" target="_blank"></a>
# <a class="pinterestIcon" href="http://pinterest.com/apartmentscom" target="_blank"></a>
# <a class="youtubeIcon" href="https://www.youtube.com/user/apartmentscom/custom" target="_blank"></a>
# <a class="blogIcon" href="https://www.apartments.com/blog/" target="_blank"></a>
# </span>
# </div>
# <p class="ehoProfileLabel screen">
# <a href="https://www.apartments.com/advertise/disclaimers/equal-opportunity-in-housing-statement/" target="_blank" title="Equal Housing Opportunity">
# <i class="ehoIcon"></i>
# <span>Equal Housing Opportunity</span>
# </a>
# </p>
# </footer>
# </div>
# <section id="profileLocalGuide"></section>
# <section id="profileApplyNow">
# <section class="ConduitFrameContainer is-modal" id="ApplyNowFrameContainer"></section>
# <section class="ConduitFrameContainer is-modal" id="EcomRenterCheckoutFrameContainer"></section>
# <section class="ConduitFrameContainer is-modal" id="RequestToApplyFrameContainer"></section>
# <section class="app-transition-spinner">
# <div class="content">
# <i class="aptsLogoMarkIcon loading-spinner"></i>
# <p i18n="">Loading...</p>
# </div>
# </section>
# </section>
# </section>
# <div class="videoPlayerWrapper fade modal" id="modalVirtualTourContainer">
# <div class="videoPlayerWrapper" id="virtualTourVideoPlayerWrapper">
# <div class="viewerContent" id="virtualTourViewerContent">
# <div class="videoPlayer active" id="virtualTourVideoPlayer">
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# <div class="videoPlayerContent" id="virtualTourPlayerContent"></div>
# </div>
# </div>
# </div>
# </div>
# <section class="tourOptionsModal" id="tourOptionsModal">
# <div class="tourOptionsModalWrapper tourOptions modal fade" id="tourOptionsModalWrapper">
# <div class="modalContent">
# <div class="modalHeader">
# <button aria-label="close" class="close closeIcon" type="button"></button>
# </div>
# <div class="modalBody">
# <p>
#                     Tools to help you see this property remotely:
#                 </p>
# <div class="tourOptionContainer liveTourContainer">
# <i class="iphoneIcon"></i>
# <span class="tourText">LIVE Online Tour</span>
# <p class="liveTourBlurb">Many properties are now offering LIVE tours via FaceTime and other streaming apps. Contact now:</p>
# <div class="btnContainer">
# <button class="primary sendMessageBtn js-tourOptionsEmail">
# <i class="emailTransparentIcon"></i>
# <span>Send Message</span>
# </button>
# <a class="primary phone phoneBtn js-tourOptionsPhone" href="tel:+1-628-230-6550">
# <i class="phoneTransparentIcon"></i>
# <span>628-230-6550</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="modal fade applyNowConfirmation" data-backdrop="static" id="applyNowConfirmation">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>Online applications are here!</h3>
# <p>Great News! The manager for this property is accepting applications through Apartments.com, a brand new feature that allows you to apply quickly and securely. You'll see more listings with "apply now" buttons as this feature becomes more widely available. <a href="https://renterhelp.apartments.com/article/136-how-to-apply-to-rentals-on-apartments-com" target="_blank">Learn more about applications</a></p>
# <button class="primary" id="continueToAppButton" type="button">Continue</button>
# </div>
# </div>
# </div>
# </main>
# </div>

# %%
rent_obj = []
all_property = []

for page in range(26,29):
    link = 'https://www.apartments.com/condos/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='prosumer placard')

    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        
        full_address = result.find('div', class_ = "location").text
        city = new_results.find('div', class_ = "propertyAddress").select('span')[0].text
        state = new_results.find('div', class_ = "propertyAddress").select('span')[1].text
        zip_code = new_results.find('div', class_ = "propertyAddress").select('span')[2].text
        street = new_results.find('h1', class_ = "propertyName").text.replace('\r\n                    ', "").strip()
        bedroom_container = new_results.find('div', class_="rentRollupContainer")
        house_details = new_results.find('table', class_="availabilityTable")
        bath_number = house_details.find('td', class_="baths").find('span', class_="shortText").text.replace('\r\n                    ', "").strip()
        house_square_feet = house_details.find('td', class_="sqft").text
        square_feet = house_square_feet.split(" ")[0];
        lease_length = house_details.find('td', class_="leaseLength").text
        availability_check = house_details.find('td', class_="available").text.replace('\r\n                    ', "").strip()
        all_the_rents = bedroom_container.findAll('span', class_="rentRollup")

        bedroom_info = []
        for rent_block in all_the_rents:
            bedroom_type = rent_block.find('span', class_="shortText").text
            try:
                price = re.search('\$.* ', rent_block.text)
                price = price.group(0)[:-3]

            except:
                if "Call for Rent" in rent_block.text:
                    price = ""
                else:
                    price = re.search('\$.*', rent_block.text).group()[:-1]
            bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
        rent_obj = {
                "City_Rent": city,
                "Type": "Condos",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                "Full_Address": full_address,
                "Rent_link": find_tag,
                "Bath_Info": bath_number,
                "Square_Feet_Data": house_square_feet,
                "Square_Feet": square_feet,
                "Lease_length": lease_length,
                "Availability_check": availability_check
            }
        for room_type in bedroom_info:
            rent_obj[room_type["bedroom_type"]] = room_type["price"];
        
        all_property.append(rent_obj)
        time.sleep(1)
print(all_property)
# Out:
# [{'City_Rent': '27535 Lakeview Dr', 'Type': 'Condos', 'State_Rent': 'Helendale', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$1,100'}], 'Full_Address': 'Helendale, CA 92342', 'Rent_link': 'https://www.apartments.com/27535-lakeview-dr-helendale-ca-unit-16/perfv7v/', 'Bath_Info': '2 BAs', 'Square_Feet_Data': '', 'Square_Feet': '', 'Lease_length': '', 'Availability_check': 'Available Now', '2 Beds': '$1,100'}, {'City_Rent': '1201 Glen Cove Pkwy', 'Type': 'Condos', 'State_Rent': 'Vallejo', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type':
': '14385 Nautical Ln', 'Type': 'Condos', 'State_Rent': 'Helendale', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$2,000'}], 'Full_Address': 'Helendale, CA 92342', 'Rent_link': 'https://www.apartments.com/14385-nautical-ln-helendale-ca-unit-15/p7mtb0v/', 'Bath_Info': '3 BAs', 'Square_Feet_Data': '', 'Square_Feet': '', 'Lease_length': '', 'Availability_check': 'Available Now', '3 Beds': '$2,000'}, {'City_Rent': 'Ridgecrest', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '93555', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$810'}], 'Full_Address': 'Ridgecrest, CA 93555', 'Rent_link': 'https://www.apartments.com/401-oasis-dr-ridgecrest-ca-unit-3/syql305/', 'Bath_Info': '1 BA', 'Square_Feet_Data': '975 Sq Ft', 'Square_Feet': '975', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now ...

# %%
rent_obj = []
all_property = []

for page in range(16,26):
    link = 'https://www.apartments.com/condos/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='prosumer placard')

    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        
        full_address = result.find('div', class_ = "location").text
        city = new_results.find('div', class_ = "propertyAddress").select('span')[0].text
        state = new_results.find('div', class_ = "propertyAddress").select('span')[1].text
        zip_code = new_results.find('div', class_ = "propertyAddress").select('span')[2].text
        street = new_results.find('h1', class_ = "propertyName").text.replace('\r\n                    ', "").strip()
        bedroom_container = new_results.find('div', class_="rentRollupContainer")
        house_details = new_results.find('table', class_="availabilityTable")
        bath_number = house_details.find('td', class_="baths").find('span', class_="shortText").text.replace('\r\n                    ', "").strip()
        house_square_feet = house_details.find('td', class_="sqft").text
        square_feet = house_square_feet.split(" ")[0];
        try:
            lease_length = house_details.find('td', class_="leaseLength").text
        except:
            lease_length = 'null'
        availability_check = house_details.find('td', class_="available").text.replace('\r\n                    ', "").strip()
        all_the_rents = bedroom_container.findAll('span', class_="rentRollup")

        bedroom_info = []
        for rent_block in all_the_rents:
            bedroom_type = rent_block.find('span', class_="shortText").text
            try:
                price = re.search('\$.* ', rent_block.text)
                price = price.group(0)[:-3]

            except:
                if "Call for Rent" in rent_block.text:
                    price = ""
                else:
                    price = re.search('\$.*', rent_block.text).group()[:-1]
            bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
        rent_obj = {
                "City_Rent": city,
                "Type": "Condos",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                "Full_Address": full_address,
                "Rent_link": find_tag,
                "Bath_Info": bath_number,
                "Square_Feet_Data": house_square_feet,
                "Square_Feet": square_feet,
                "Lease_length": lease_length,
                "Availability_check": availability_check
            }
        for room_type in bedroom_info:
            rent_obj[room_type["bedroom_type"]] = room_type["price"];
        
        all_property.append(rent_obj)
        time.sleep(1)
print(all_property)
# Out:
# [{'City_Rent': 'Stockton', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '95207', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$1,995'}], 'Full_Address': 'Stockton, CA 95207', 'Rent_link': 'https://www.apartments.com/2193-piccardo-cir-stockton-ca-unit-2193/5tgew0m/', 'Bath_Info': '2 BAs', 'Square_Feet_Data': '1,650 Sq Ft', 'Square_Feet': '1,650', 'Lease_length': '12 Month Lease', 'Availability_check': 'Apr 6', '3 Beds': '$1,995'}, {'City_Rent': 'Sacramento', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '95814', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,200'}], 'Full_Address': 'Sacramento, CA 95814', 'Rent_link': 'https://www.apartments.com/200-p-st-sacramento-ca-unit-b-22/4v7488j/', 'Bath_Info': '2 BAs', 'Square_Feet_Data': '1,440 Sq Ft', 'Square_Feet': '1,440', 'Lease_length': '12 Month Lease', 'Availability_check': 'May 1', '2 Beds': '$2,200'}, {'City_Rent': 'South Gate', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '90280', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,595'}], 'Full_Address': 'South Gate, CA 90280', 'Rent_link': 'https://www.apartments.com/2742-firestone-blvd-south-gate-ca-unit-home/fcx7w8v/', 'Bath_Info': '2 BAs', 'Square_Feet_Data': '1,099 Sq Ft', 'Square_Feet': '1,099', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '2 Beds': '$2,595'}, {'City_Rent': 'Malibu', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '90265', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$6,195'}], 'Full_Address': 'Malibu, CA 90265', 'Rent_link': 'https://www.apartments.com/20747-pacific-coast-hwy-malibu-ca-unit-9/18bhpe6/', 'Bath_Info': '1 BA', 'Square_Feet_Data': '975 Sq Ft', 'Square_Feet': '975', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '2 Beds': '$6,195'}, {'City_Rent': 'San Marcos', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '92069', 'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,710'}], 'Full_Address': 'San Marcos, CA 92069', 'Rent_link': 'https://www.apartments.com/201-woodland-pkwy-san-marcos-ca-unit-245/519hm1q/', 'Bath_Info': '1 BA', 'Square_Feet_Data': '651 Sq Ft', 'Square_Feet': '651', 'Lease_length': '24 Month Lease', 'Availability_check': 'Apr 6', '1 Bed': '$1,710'}, {'City_Rent': 'Newport Beach', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '92663', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$4,750'}], 'Full_Address': '4819 River Ave, Newport Beach, CA 92663', 'Rent_link': 'https://www.apartments.com/4819-river-ave-newport-beach-ca-unit-lower/ye2e17r/', 'Bath_Info': '2½ BAs', 'Square_Feet_Data': '1 Sq Ft', 'Square_Feet': '1', 'Lease_length': '12 Month Lease', 'Availability_check': 'May 15', '3 Beds': '$4,750'}, {'City_Rent': 'Oakland', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '94605', 'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,800'}], 'Full_Address': 'Oakland, CA 94605', 'Rent_link': 'https://www.apartments.com/8409-iris-st-oakland-ca-unit-upper/k75pzmc/', 'Bath_Info': '1 BA', 'Square_Feet_Data': '360 Sq Ft', 'Square_Feet': '360', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '1 Bed': '$1,800'}, {'City_Rent': 'Hercules', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '94547', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,600'}], 'Full_Address': 'Hercules, CA 94547', 'Rent_link': 'https://www.apartments.com/802-devonwood-hercules-ca-unit-802/xy897ln/', 'Bath_Info': '2 BAs', 'Square_Feet_Data': '1,011 Sq Ft', 'Square_Feet': '1,011', 'Lease_length': '12 Month Lease', 'Availability_check': 'May 1', '2 Beds': '$2,600'}, {'City_Rent': 'Newport Beach', 'Type': 'Condos', 'State_Rent': 'CA', 'Zip_code': '92663', 'Bedroom_Info': [{'bedroom_type': '4 Beds', 'price': '$5,695'}], 'Full_Address': '4821 River Ave, Newport Beach, CA 92663', 'Rent_link': 'https://www.apartments.com/4821-river-ave-newport-beach-ca-unit-upper/ed74rmp/', 'Bath_Info': '2½ BAs', 'Square_Feet_Data': '2,200 Sq Ft', 'Square_Feet': '2,200', 'Lease_le ...

# %%
rent_data = pd.DataFrame(all_property)
rent_data
# Out:
#      1 Bed  2 Beds  3 Beds  4 Beds Availability_check Bath_Info  \
# 0      NaN  $1,100     NaN     NaN      Available Now     2 BAs
# 1      NaN  $2,300     NaN     NaN      Available Now     2 BAs
# 2      NaN     NaN  $6,200     NaN      Available Now     2 BAs
# 3      NaN  $2,900     NaN     NaN      Available Now     2 BAs
# 4      NaN  $3,275     NaN     NaN      Available Now     3 BAs
# 5      NaN  $2,200     NaN     NaN      Available Now     2 BAs
# 6   $2,995     NaN     NaN     NaN      Available Now      1 BA
# 7      NaN     NaN  $2,000     NaN      Available Now     3 BAs
# 8      NaN     NaN    $810     NaN      Available Now      1 BA
# 9      NaN     NaN     NaN  $1,045      Available Now     2 BAs
# 10    $710     NaN     NaN     NaN      Available Now      1 BA
# 11     NaN    $710     NaN     NaN      Available Now      1 BA
# 12     NaN  $2,750     NaN     NaN      Available Now     2 BAs
# 13     NaN  $1,750     NaN     NaN      Available Now    2½ BAs
# 14     NaN  $2,500     NaN     NaN      Available Now     2 BAs
# 15     NaN  $2,695     NaN     NaN      Available Now     2 BAs
# 16     NaN  $3,200     NaN     NaN      Available Now     2 BAs
# 17     NaN  $1,150     NaN     NaN      Available Now      1 BA
# 18     NaN  $1,650     NaN     NaN      Available Now      1 BA
# 19  $1,750     NaN     NaN     NaN      Available Now      1 BA
# 20  $3,600     NaN     NaN     NaN      Available Now      1 BA
# 21     NaN  $3,400     NaN     NaN      Available Now     2 BAs
# 22     NaN  $7,995     NaN     NaN      Available Now     3 BAs
# 23     NaN     NaN     NaN  $9,995      Available Now     3 BAs
# 24  $2,495     NaN     NaN     NaN      Available Now      1 BA
# 25  $1,800     NaN     NaN     NaN      Available Now      1 BA
# 26     NaN     NaN  $2,850     NaN      Available Now     2 BAs
# 27     NaN  $3,250     NaN     NaN      Available Now    2½ BAs
# 28  $2,000     NaN     NaN     NaN      Available Now     2 BAs
# 29  $3,150     NaN     NaN     NaN      Available Now      1 BA
# ..     ...     ...     ...     ...                ...       ...
# 45     NaN     NaN  $1,000     NaN      Available Now     2 BAs
# 46  $2,800     NaN     NaN     NaN      Available Now      1 BA
# 47  $1,595     NaN     NaN     NaN      Available Now      1 BA
# 48     NaN     NaN  $3,500     NaN      Available Now     2 BAs
# 49     NaN  $2,580     NaN     NaN      Available Now      1 BA
# 50     NaN  $2,800     NaN     NaN      Available Now    2½ BAs
# 51     NaN  $1,750     NaN     NaN      Available Now      1 BA
# 52     NaN  $2,300     NaN     NaN      Available Now    1½ BAs
# 53     NaN     NaN  $3,850     NaN             Apr 15     2 BAs
# 54     NaN  $4,000     NaN     NaN      Available Now     2 BAs
# 55     NaN  $5,000     NaN     NaN      Available Now     2 BAs
# 56  $2,575     NaN     NaN     NaN             Apr 13      1 BA
# 57     NaN  $1,800     NaN     NaN      Available Now    2½ BAs
# 58  $1,895     NaN     NaN     NaN      Available Now      1 BA
# 59  $4,975     NaN     NaN     NaN      Available Now    1½ BAs
# 60     NaN  $2,695     NaN     NaN      Available Now     2 BAs
# 61     NaN  $2,895     NaN     NaN      Available Now     2 BAs
# 62     NaN  $1,295     NaN     NaN      Available Now      1 BA
# 63     NaN  $2,795     NaN     NaN      Available Now      1 BA
# 64     NaN  $4,500     NaN     NaN      Available Now     2 BAs
# 65     NaN  $3,850     NaN     NaN      Available Now     2 BAs
# 66     NaN  $1,195     NaN     NaN      Available Now     2 BAs
# 67     NaN     NaN  $6,500     NaN      Available Now     3 BAs
# 68     NaN  $4,500     NaN     NaN      Available Now      1 BA
# 69     NaN  $3,295     NaN     NaN      Available Now     2 BAs
# 70  $2,895     NaN     NaN     NaN      Available Now      1 BA
# 71     NaN     NaN     NaN     NaN             Apr 16      1 BA
# 72     NaN  $3,300     NaN     NaN              Jul 1     2 BAs
# 73     NaN  $2,900     NaN     NaN             Apr 15    2½ BAs
# 74  $2,400     NaN     NaN     NaN      Available Now      1 BA
#
#                                        Bedroom_Info            City_Rent  \
# 0   [{'bedroom_type': '2 Beds', 'price': '$1,100'}]    27535 Lakeview Dr
# 1   [{'bedroom_type': '2 Beds', 'price': '$2,300'}]  1201 Glen Cove Pkwy
# 2   [{'bedroom_type': '3 Beds', 'price': '$6,200'}]       2865 Park Blvd
# 3   [{'bedroom_type': '2 Beds', 'price': '$2,900'}]          2586 Oak Rd
# 4   [{'bedroom_type': '2 Beds', 'price': '$3,275'}]  223 Avenida Lobeiro
# 5   [{'bedroom_type': '2 Beds', 'price': '$2,200'}]     1023 S Citron St
# 6    [{'bedroom_type': '1 Bed', 'price': '$2,995'}]             200 CA-1
# 7   [{'bedroom_type': '3 Beds', 'price': '$2,000'}]    14385 Nautical Ln
# 8     [{'bedroom_type': '3 Beds', 'price': '$810'}]           Ridgecrest
# 9   [{'bedroom_type': '4 Beds', 'price': '$1,045'}]           Ridgecrest
# 10     [{'bedroom_type': '1 Bed', 'price': '$710'}]           Ridgecrest
# 11    [{'bedroom_type': '2 Beds', 'price': '$710'}]           Ridgecrest
# 12  [{'bedroom_type': '2 Beds', 'price': '$2,750'}]            San Diego
# 13  [{'bedroom_type': '2 Beds', 'price': '$1,750'}]            La Quinta
# 14  [{'bedroom_type': '2 Beds', 'price': '$2,500'}]         Rohnert Park
# 15  [{'bedroom_type': '2 Beds', 'price': '$2,695'}]             San Jose
# 16  [{'bedroom_type': '2 Beds', 'price': '$3,200'}]         Solana Beach
# 17  [{'bedroom_type': '2 Beds', 'price': '$1,150'}]   Desert Hot Springs
# 18  [{'bedroom_type': '2 Beds', 'price': '$1,650'}]     South Lake Tahoe
# 19   [{'bedroom_type': '1 Bed', 'price': '$1,750'}]              Concord
# 20   [{'bedroom_type': '1 Bed', 'price': '$3,600'}]             Berkeley
# 21  [{'bedroom_type': '2 Beds', 'price': '$3,400'}]          Los Angeles
# 22  [{'bedroom_type': '2 Beds', 'price': '$7,995'}]               Malibu
# 23  [{'bedroom_type': '4 Beds', 'price': '$9,995'}]                Aptos
# 24   [{'bedroom_type': '1 Bed', 'price': '$2,495'}]              Oakland
# 25   [{'bedroom_type': '1 Bed', 'price': '$1,800'}]         Palm Springs
# 26  [{'bedroom_type': '3 Beds', 'price': '$2,850'}]         Palm Springs
# 27  [{'bedroom_type': '2 Beds', 'price': '$3,250'}]        Rancho Mirage
# 28   [{'bedroom_type': '1 Bed', 'price': '$2,000'}]         Palm Springs
# 29   [{'bedroom_type': '1 Bed', 'price': '$3,150'}]              Oakland
# ..                                              ...                  ...
# 45  [{'bedroom_type': '3 Beds', 'price': '$1,000'}]               Blythe
# 46   [{'bedroom_type': '1 Bed', 'price': '$2,800'}]        San Francisco
# 47   [{'bedroom_type': '1 Bed', 'price': '$1,595'}]                 Ojai
# 48  [{'bedroom_type': '3 Beds', 'price': '$3,500'}]          Pismo Beach
# 49  [{'bedroom_type': '2 Beds', 'price': '$2,580'}]         Walnut Creek
# 50  [{'bedroom_type': '2 Beds', 'price': '$2,800'}]               Dublin
# 51  [{'bedroom_type': '2 Beds', 'price': '$1,750'}]     South Lake Tahoe
# 52  [{'bedroom_type': '2 Beds', 'price': '$2,300'}]            Pittsburg
# 53  [{'bedroom_type': '3 Beds', 'price': '$3,850'}]          Los Angeles
# 54  [{'bedroom_type': '2 Beds', 'price': '$4,000'}]              Alameda
# 55  [{'bedroom_type': '2 Beds', 'price': '$5,000'}]          Palm Desert
# 56   [{'bedroom_type': '1 Bed', 'price': '$2,575'}]              Oakland
# 57  [{'bedroom_type': '2 Beds', 'price': '$1,800'}]            La Quinta
# 58   [{'bedroom_type': '1 Bed', 'price': '$1,895'}]         Walnut Creek
# 59   [{'bedroom_type': '1 Bed', 'price': '$4,975'}]         Laguna Beach
# 60  [{'bedroom_type': '2 Beds', 'price': '$2,695'}]             Carlsbad
# 61  [{'bedroom_type': '2 Beds', 'price': '$2,895'}]             Carlsbad
# 62  [{'bedroom_type': '2 Beds', 'price': '$1,295'}]              Modesto
# 63  [{'bedroom_type': '2 Beds', 'price': '$2,795'}]           Santa Cruz
# 64  [{'bedroom_type': '2 Beds', 'price': '$4,500'}]              Tiburon
# 65  [{'bedroom_type': '2 Beds', 'price': '$3,850'}]         Walnut Creek
# 66  [{'bedroom_type': '2 Beds', 'price': '$1,195'}]               Fresno
# 67  [{'bedroom_type': '3 Beds', 'price': '$6,500'}]               Malibu
# 68  [{'bedroom_type': '2 Beds', 'price': '$4,500'}]        San Francisco
# 69  [{'bedroom_type': '2 Beds', 'price': '$3,295'}]         Solana Beach
# 70   [{'bedroom_type': '1 Bed', 'price': '$2,895'}]        San Francisco
# 71  [{'bedroom_type': 'Studio', 'price': '$1,250'}]              Vallejo
# 72  [{'bedroom_type': '2 Beds', 'price': '$3,300'}]      San Luis Obispo
# 73  [{'bedroom_type': '2 Beds', 'price': '$2,900'}]              Anaheim
# 74   [{'bedroom_type': '1 Bed', 'price': '$2,400'}]           Emeryville
#
#                                  Full_Address    Lease_length  \
# 0                         Helendale, CA 92342
# 1                           Vallejo, CA 94591  12 Month Lease
# 2                         Palo Alto, CA 94306
# 3                      Walnut Creek, CA 94597
# 4                      San Clemente, CA 92672
# 5                           Anaheim, CA 92805
# 6                        El Segundo, CA 90245
# 7                         Helendale, CA 92342
# 8                        Ridgecrest, CA 93555  12 Month Lease
# 9                        Ridgecrest, CA 93555  12 Month Lease
# 10                       Ridgecrest, CA 93555  12 Month Lease
# 11                       Ridgecrest, CA 93555  12 Month Lease
# 12          3857 Pell Pl, San Diego, CA 92130  12 Month Lease
# 13       45245 Seeley Dr, La Quinta, CA 92253   6 Month Lease
# 14                     Rohnert Park, CA 94928  12 Month Lease
# 15                         San Jose, CA 95118  12 Month Lease
# 16                     Solana Beach, CA 92075  12 Month Lease
# 17               Desert Hot Springs, CA 92241  12 Month Lease
# 18                 South Lake Tahoe, CA 96150   3 Month Lease
# 19                          Concord, CA 94521  12 Month Lease
# 20                         Berkeley, CA 94708  12 Month Lease
# 21    8180 Manitoba St, Los Angeles, CA 90293  12 Month Lease
# 22                           Malibu, CA 90265  12 Month Lease
# 23                            Aptos, CA 95003   1 Month Lease
# 24                          Oakland, CA 94607  12 Month Lease
# 25                     Palm Springs, CA 92262
# 26                     Palm Springs, CA 92262  12 Month Lease
# 27                    Rancho Mirage, CA 92270   7 Month Lease
# 10        850 Sq Ft            CA     NaN  Condos    93555
# 11        850 Sq Ft            CA     NaN  Condos    93555
# 12      1,246 Sq Ft            CA     NaN  Condos    92130
# 13      1,250 Sq Ft            CA     NaN  Condos    92253
# 14      1,034 Sq Ft            CA     NaN  Condos    94928
# 15      1,020 Sq Ft            CA     NaN  Condos    95118
# 16      1,426 Sq Ft            CA     NaN  Condos    92075
# 17          1 Sq Ft            CA     NaN  Condos    92241
# 18        896 Sq Ft            CA     NaN  Condos    96150
# 19        650 Sq Ft            CA     NaN  Condos    94521
# 20      1,470 Sq Ft            CA     NaN  Condos    94708
# 21      1,380 Sq Ft            CA     NaN  Condos    90293
# 22      1,385 Sq Ft            CA     NaN  Condos    90265
# 23      1,563 Sq Ft            CA     NaN  Condos    95003
# 24        822 Sq Ft            CA     NaN  Condos    94607
# 25        580 Sq Ft            CA     NaN  Condos    92262
# 26      1,750 Sq Ft            CA     NaN  Condos    92262
# 27      1,624 Sq Ft            CA     NaN  Condos    92270
# 28      1,000 Sq Ft            CA     NaN  Condos    92264
# 29        728 Sq Ft            CA     NaN  Condos    94612
# ..              ...           ...     ...     ...      ...
# 45      1,344 Sq Ft            CA     NaN  Condos    92225
# 46        500 Sq Ft            CA     NaN  Condos    94103
# 47        550 Sq Ft            CA     NaN  Condos    93023
# 48      1,500 Sq Ft            CA     NaN  Condos    93449
# 49        978 Sq Ft            CA     NaN  Condos    94597
# 50      1,298 Sq Ft            CA     NaN  Condos    94568
# 51        841 Sq Ft            CA     NaN  Condos    96150
# 52      1,122 Sq Ft            CA     NaN  Condos    94565
# 53      1,600 Sq Ft            CA     NaN  Condos    90035
# 54          1 Sq Ft            CA     NaN  Condos    94502
# 55      1,932 Sq Ft            CA     NaN  Condos    92260
# 56        850 Sq Ft            CA     NaN  Condos    94611
# 57      1,250 Sq Ft            CA     NaN  Condos    92253
# 58        780 Sq Ft            CA     NaN  Condos    94596
# 59      2,000 Sq Ft            CA     NaN  Condos    92651
# 60      1,084 Sq Ft            CA     NaN  Condos    92011
# 61      1,145 Sq Ft            CA     NaN  Condos    92011
# 62        750 Sq Ft            CA     NaN  Condos    95350
# 63        700 Sq Ft            CA     NaN  Condos    95060
# 64      1,500 Sq Ft            CA     NaN  Condos    94920
# 65      1,165 Sq Ft            CA     NaN  Condos    94596
# 66      1,248 Sq Ft            CA     NaN  Condos    93727
# 67      1,854 Sq Ft            CA     NaN  Condos    90265
# 68        750 Sq Ft            CA     NaN  Condos    94131
# 69      1,256 Sq Ft            CA     NaN  Condos    92075
# 70        611 Sq Ft            CA     NaN  Condos    94124
# 71        500 Sq Ft            CA  $1,250  Condos    94589
# 72      1,100 Sq Ft            CA     NaN  Condos    93405
# 73      1,554 Sq Ft            CA     NaN  Condos    92805
# 74        768 Sq Ft            CA     NaN  Condos    94608
#
# [75 rows x 17 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
rent_data.to_csv("Output/Apartment.com/Q1-2020_Apartment.com_Condos_Data_page26-28.csv", index=False, header=True)
