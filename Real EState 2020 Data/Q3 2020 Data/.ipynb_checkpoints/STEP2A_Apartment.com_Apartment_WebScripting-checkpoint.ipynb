# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
rent_obj = []
all_property = []

for page in range(21,29):
    link = 'https://www.apartments.com/apartments/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='diamond placard')
    
    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        
        full_address = result.find('div', class_ = "location").text
        street = new_results.find('div', class_ = "propertyAddress").select('span')[0].text
        city = new_results.find('div', class_ = "propertyAddress").select('span')[1].text
        state = new_results.find('div', class_ = "propertyAddress").select('span')[2].text
        zip_code = new_results.find('div', class_ = "propertyAddress").select('span')[3].text
        property_name = new_results.find('h1', class_ = "propertyName").text.replace('\r\n                    ', "").strip()
        bedroom_container = new_results.find('div', class_="rentRollupContainer")
        all_the_rents = bedroom_container.findAll('span', class_="rentRollup")
        
        bedroom_info = []
        for rent_block in all_the_rents:
            bedroom_type = rent_block.find('span', class_="shortText").text
            pprint(rent_block)
            try:
                price = re.search('\$.* ', rent_block.text)
                price = price.group(0)[:-3]

            except:
                if "Call for Rent" in rent_block.text:
                    price = ""
                else:
                    price = re.search('\$.*', rent_block.text).group()[:-1]
            bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
        rent_obj = {
                "Property_Name_Rent": property_name,
                "City_Rent": city,
                "Type": "Apartment",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                "Full_Address": full_address,
                "Rent_link": find_tag
            }
        for room_type in bedroom_info:
            rent_obj[room_type["bedroom_type"]] = room_type["price"];
        
        all_property.append(rent_obj)
        time.sleep(1)

pprint(all_property);
# Out:
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,363 – 3,770
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,988 – 5,142
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,996 – 3,329
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,200 – 4,800
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,015 – 5,313
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,535 – 1,815
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,915 – 2,230
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,125 – 2,705
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,788 – 2,274
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,988 – 2,505
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,914 – 3,357
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,899 – 2,019
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,324 – 2,510
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,726
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,066
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,775 – 1,840
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,155 – 2,495
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,993 – 6,875
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,236 – 7,557
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,127 – 9,140
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,898
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,419
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,623
# 											</span>
# <span class="rentRollup">
# <span class="longText">4 Bedrooms</span>
# <span class="shortText">4 Beds</span>
#
# 													$2,812 – 2,882
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,075 – 3,110
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,335 – 3,245
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,300
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,725 – 3,295
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,075 – 3,375
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,950 – 4,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,930 – 3,220
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,510 – 3,765
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">
# 													1 Bedroom
# 															–
# 2 Bedrooms											</span>
# <span class="shortText">
# 													1 Bed
# 															–
# 2 Beds											</span>
#
# 											Call for Rent
# 									</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,715 – 1,870
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,970 – 2,370
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,499 – 5,343
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,550 – 6,228
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,698 – 2,075
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,894 – 2,380
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,645 – 2,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,325
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,744 – 2,652
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,875 – 2,643
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,678 – 4,674
# 											</span>
# <span class="rentRollup">
# <span class="longText">
# 													2 Bedrooms
# 															–
# 3 Bedrooms											</span>
# <span class="shortText">
# 													2 Beds
# 															–
# 3 Beds											</span>
#
# 											Call for Rent
# 									</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,899 – 2,061
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,995 – 2,305
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,655 – 2,744
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													Call for Rent
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$4,200 – 4,400
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$4,600 – 5,500
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,632 – 2,011
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$3,940 – 4,418
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$4,698 – 5,613
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$5,674 – 7,223
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,985
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,185 – 2,295
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,605 – 1,760
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,955 – 2,005
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,705 – 1,842
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,980 – 2,053
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,436 – 2,502
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,200 – 2,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,550 – 2,925
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,725 – 1,975
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,950 – 2,400
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,350 – 3,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,350 – 3,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,795 – 1,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,895 – 2,355
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,900
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,200 – 2,300
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,550 – 2,700
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,245 – 1,295
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,375 – 1,445
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,625
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,137 – 2,395
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,595 – 2,980
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,485
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,590 – 1,775
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,830 – 2,220
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,500 – 1,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,245 – 2,645
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,095 – 3,395
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,845
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,695
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,545
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,695
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,905 – 2,045
# 											</span>
# <span class="rentRollup perBed">
# <span class="shortText">
# Studio													</span>
#
# 													$1,885 – 2,112
#
#
# 															<span>/ Unit</span>
# </span>
# <span class="rentRollup perBed">
# <span class="shortText">
# 6 Beds													</span>
#
# 													$1,450 – 1,625
#
#
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup perBed">
# <span class="shortText">Studio</span>
# 															$1,009 – 1,575
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup perBed">
# <span class="shortText">4+ Beds</span>
# 															$851 – 1,510
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup perBed">
# <span class="shortText">Studio</span>
# 															$1,700 – 2,100
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup perBed">
# <span class="shortText">4+ Beds</span>
# 															$1,075 – 1,800
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,675
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,380
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,610
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,860 – 1,980
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,895
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,295 – 2,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,695 – 2,795
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,395 – 3,595
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$4,095 – 4,495
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,027
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,205 – 1,223
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,441
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,383 – 2,599
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,734 – 3,199
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,434
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,886 – 2,709
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,373 – 3,302
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,800 – 1,850
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,250 – 2,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,400 – 1,500
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,550 – 1,650
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$2,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,291 – 3,300
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,084 – 3,899
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,585 – 2,785
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,185 – 3,385
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,210
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,340
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,615
# 											</span>
# <span class="rentRollup">
# <span class="longText">
# 													1 Bedroom
# 															–
# 3 Bedrooms											</span>
# <span class="shortText">
# 													1 Bed
# 															–
# 3 Beds											</span>
#
# 											Call for Rent
# 									</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,975 – 2,700
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,125 – 2,795
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,845 – 3,345
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,695 – 1,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,995 – 2,395
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,295 – 2,405
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,595 – 3,000
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,819 – 2,104
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,156 – 2,711
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,900 – 2,000
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,200 – 2,300
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,471
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,671 – 1,811
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,006 – 2,326
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,775 – 2,425
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,058 – 2,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,285 – 1,595
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,462 – 1,815
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,327 – 1,452
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,572 – 1,747
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,000 – 3,060
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,500
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,850
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,595
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,875 – 1,975
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,025 – 2,120
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,310
# 											</span>
# <span class="rentRollup">
# <span class="longText">
# 													Studio
# 															–
# 2 Bedrooms											</span>
# <span class="shortText">
# 													Studio
# 															–
# 2 Beds											</span>
#
# 											Call for Rent
# 									</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,335
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,460 – 1,560
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$2,375 – 3,390
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,595 – 4,295
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,775 – 5,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,580 – 1,775
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,900 – 1,975
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,850
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,925 – 2,200
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,399 – 2,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,583 – 3,175
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,395 – 1,585
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,595 – 1,685
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,610 – 1,735
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,855 – 2,030
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,165 – 2,320
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$3,400 – 4,150
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$5,000 – 6,200
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$14,995 – 40,000
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,080 – 1,090
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,160 – 1,290
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,460 – 1,510
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,590 – 1,775
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,750 – 2,900
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,625 – 1,725
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,725 – 1,900
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,050 – 2,200
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,725 – 1,750
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,400 – 4,875
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,575 – 6,950
# 											</span>
# <span class="rentRollup">
# <span class="longText">4 Bedrooms</span>
# <span class="shortText">4 Beds</span>
#
# 													$4,812 – 7,125
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,025 – 2,473
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,495 – 3,149
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,020
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,205 – 1,330
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,940 – 2,210
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,305 – 2,605
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,275 – 1,425
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,395 – 1,625
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,795 – 1,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,035 – 1,360
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,180 – 1,585
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,510
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,660
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,930
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,475 – 2,725
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,400 – 3,450
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,795 – 2,435
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,205 – 2,870
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,599 – 2,845
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$3,195 – 3,545
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,850
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,245 – 3,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,800 – 4,150
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,654
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,045 – 2,245
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,245 – 3,285
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,500 – 1,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,650 – 1,900
# 											</span>
# <span class="rentRollup">
# <span class="longText">
# 													1 Bedroom
# 															–
# 4 Bedrooms											</span>
# <span class="shortText">
# 													1 Bed
# 															–
# 4 Beds											</span>
#
# 											Call for Rent
# 									</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,625 – 1,880
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,780 – 2,005
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,280 – 2,415
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,295 – 2,985
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,930 – 3,585
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,001 – 2,150
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,252 – 2,550
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,550 – 3,000
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,060 – 2,235
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,860 – 2,910
# 											</span>
# <span class="rentRollup">
# <span class="longText">4 Bedrooms</span>
# <span class="shortText">4 Beds</span>
#
# 													$3,235 – 3,335
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,195 – 1,345
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,395 – 1,545
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,095 – 2,295
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,895 – 1,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,250 – 2,415
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,525 – 2,690
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,998 – 2,200
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,350 – 2,495
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,733 – 1,808
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,071 – 2,181
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,730
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,915 – 2,455
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,515 – 3,490
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$3,465 – 3,865
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,470 – 1,675
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,695 – 1,755
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,270 – 2,360
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,325 – 2,725
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,365 – 1,490
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,425
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,668 – 1,778
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,988 – 2,248
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,305 – 1,495
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,095 – 2,195
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,395 – 2,650
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,895 – 3,250
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,670 – 1,990
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,930 – 2,300
# 											</span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,425 – 1,550
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,525 – 1,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,780 – 1,900
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,075 – 2,285
# 											</span>
# <span class="rentRollup perBed">
# <span class="shortText">2 Beds</span>
# 															$925
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup perBed">
# <span class="shortText">4 Beds</span>
# 															$699
# 															<span>/ Person</span><i class="bedIcon"></i>
# </span>
# <span class="rentRollup">
# <span class="longText">Studio</span>
# <span class="shortText">Studio</span>
#
# 													$1,505 – 1,699
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,625 – 1,899
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,930 – 2,200
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,360 – 2,560
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,395 – 1,475
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,557 – 1,835
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,025 – 2,175
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,190 – 2,515
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,100 – 2,150
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,500 – 2,550
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,800 – 2,850
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,275 – 2,675
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,725 – 3,190
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$4,795 – 6,495
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$6,995 – 7,195
# 											</span>
# <span class="rentRollup">
# <span class="longText">4+ Bedrooms</span>
# <span class="shortText">4+ Beds</span>
#
# 													$17,445
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,465 – 2,209
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,727 – 2,364
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,085 – 2,435
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,350 – 2,525
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,550 – 1,675
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,925
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,650 – 1,750
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,999 – 2,099
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$2,230 – 2,330
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,500 – 1,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,650 – 1,925
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$3,350 – 4,200
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$4,305 – 5,530
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$4,707 – 6,995
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,350
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,410 – 1,600
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,566 – 1,700
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,485 – 1,650
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,675 – 1,990
# 											</span>
# <span class="rentRollup">
# <span class="longText">3 Bedrooms</span>
# <span class="shortText">3 Beds</span>
#
# 													$1,925 – 2,400
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$1,545
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$1,845 – 1,945
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,215 – 2,340
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# <span class="shortText">1 Bed</span>
#
# 													$2,025 – 2,190
# 											</span>
# <span class="rentRollup">
# <span class="longText">2 Bedrooms</span>
# <span class="shortText">2 Beds</span>
#
# 													$2,495 – 2,595
# 											</span>
# <span class="rentRollup">
# <span class="longText">1 Bedroom</span>
# ...
#   'Rent_link': 'https://www.apartments.com/the-courtyards-tierra-palms-norwalk-ca/5fg7evp/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '90650'},
#  {'1 Bed': '$1,750',
#   '2 Beds': '$1,840',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,750'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,840'}],
#   'City_Rent': 'Vacaville',
#   'Full_Address': '555 Elmira Rd, Vacaville, CA 95687',
#   'Property_Name_Rent': 'The Parc',
#   'Rent_link': 'https://www.apartments.com/the-parc-vacaville-ca/143xlc7/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95687'},
#  {'2 Beds': '$2,495',
#   'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,495'}],
#   'City_Rent': 'Carlsbad',
#   'Full_Address': '6555 Sea Gate Rd, Carlsbad, CA 92011',
#   'Property_Name_Rent': 'Seagate Condominium Rentals',
#   'Rent_link': 'https://www.apartments.com/seagate-condominium-rentals-carlsbad-ca/y63geft/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92011'},
#  {'1 Bed': '$1,240',
#   '2 Beds': '$1,380',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,240'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,380'}],
#   'City_Rent': 'Sacramento',
#   'Full_Address': '3435 Routier Rd, Sacramento, CA 95827',
#   'Property_Name_Rent': 'Quail Pointe Apartments',
#   'Rent_link': 'https://www.apartments.com/quail-pointe-apartments-sacramento-ca/zqy1x5z/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95827'},
#  {'1 Bed': '$1,435',
#   '2 Beds': '$1,545',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,435'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,545'}],
#   'City_Rent': 'Woodland',
#   'Full_Address': '575 Matmor Rd, Woodland, CA 95776',
#   'Property_Name_Rent': 'The Fairmont Apartments',
#   'Rent_link': 'https://www.apartments.com/the-fairmont-apartments-woodland-ca/6bmk67s/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95776'},
#  {'1 Bed': '$1,415',
#   '2 Beds': '$1,530',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,415'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,530'}],
#   'City_Rent': 'Sacramento',
#   'Full_Address': '9750 Old Placerville Rd, Sacramento, CA 95827',
#   'Property_Name_Rent': 'Living the Best Life at Arbor Pointe',
#   'Rent_link': 'https://www.apartments.com/living-the-best-life-at-arbor-pointe-sacramento-ca/s7vjv06/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95827'},
#  {'1 Bed': '$1,820',
#   '2 Beds': '$2,170',
#   '3 Beds': '$2,370',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,820'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,170'},
#                    {'bedroom_type': '3 Beds', 'price': '$2,370'}],
#   'City_Rent': 'San Diego',
#   'Full_Address': '10878 Poblado Rd, San Diego, CA 92127',
#   'Property_Name_Rent': 'La Terraza Apartments',
#   'Rent_link': 'https://www.apartments.com/la-terraza-apartments-san-diego-ca/517s4bp/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92127'},
#  {'1 Bed': '$1,665',
#   '2 Beds': '$1,950',
#   '3 Beds': '$2,330',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,665'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,950'},
#                    {'bedroom_type': '3 Beds', 'price': '$2,330'}],
#   'City_Rent': 'Anaheim',
#   'Full_Address': '201 S Magnolia Ave, Anaheim, CA 92804',
#   'Property_Name_Rent': 'Villa Serrano',
#   'Rent_link': 'https://www.apartments.com/villa-serrano-anaheim-ca/ckfkr5g/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92804'},
#  {'2 Beds': '$1,475',
#   '3 Beds': '$1,600',
#   'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$1,475'},
#                    {'bedroom_type': '3 Beds', 'price': '$1,600'}],
#   'City_Rent': 'Bakersfield',
#   'Full_Address': '5201 Gasol Ct, Bakersfield, CA 93313',
#   'Property_Name_Rent': 'Boardwalk Luxury Apartments',
#   'Rent_link': 'https://www.apartments.com/boardwalk-luxury-apartments-bakersfield-ca/t7q000c/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '93313'},
#  {'1 Bed': '$1,850',
#   '2 Beds': '$2,155',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,850'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,155'}],
#   'City_Rent': 'Martinez',
#   'Full_Address': '620 Center Ave, Martinez, CA 94553',
#   'Property_Name_Rent': 'MUIRWOOD GARDENS',
#   'Rent_link': 'https://www.apartments.com/muirwood-gardens-martinez-ca/6nvj5hr/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '94553'},
#  {'1 Bed': '$1,460',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,460'}],
#   'City_Rent': 'Escondido',
#   'Full_Address': '715 N Broadway, Escondido, CA 92025',
#   'Property_Name_Rent': '55 + Casa Escondida',
#   'Rent_link': 'https://www.apartments.com/55-casa-escondida-escondido-ca/sy1kck5/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92025'},
#  {'2 Beds': '$1,715',
#   '3 Beds': '$2,053',
#   'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$1,715'},
#                    {'bedroom_type': '3 Beds', 'price': '$2,053'}],
#   'City_Rent': 'Loma Linda',
#   'Full_Address': '25590 Prospect Ave, Loma Linda, CA 92354',
#   'Property_Name_Rent': 'Oasis Townhome Apartments',
#   'Rent_link': 'https://www.apartments.com/oasis-townhome-apartments-loma-linda-ca/xfnsepq/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92354'},
#  {'1 Bed': '$1,820',
#   '2 Beds': '$2,006',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,820'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,006'}],
#   'City_Rent': 'Richmond',
#   'Full_Address': '3400 Richmond Pky, Richmond, CA 94806',
#   'Property_Name_Rent': 'BELLA VISTA AT HILLTOP',
#   'Rent_link': 'https://www.apartments.com/bella-vista-at-hilltop-richmond-ca/m449jlj/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '94806'},
#  {'Bedroom_Info': [{'bedroom_type': 'Studio', 'price': '$975'}],
#   'City_Rent': 'Stockton',
#   'Full_Address': '1540 Mosaic Way, Stockton, CA 95207',
#   'Property_Name_Rent': 'Venetian Park Apartments',
#   'Rent_link': 'https://www.apartments.com/venetian-park-apartments-stockton-ca/trr0nvb/',
#   'State_Rent': 'CA',
#   'Studio': '$975',
#   'Type': 'Apartment',
#   'Zip_code': '95207'},
#  {'1 Bed': '$1,270',
#   '2 Beds': '$1,570',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,270'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,570'}],
#   'City_Rent': 'Modesto',
#   'Full_Address': '3400 Coffee Rd, Modesto, CA 95355',
#   'Property_Name_Rent': 'Willow Grove',
#   'Rent_link': 'https://www.apartments.com/willow-grove-modesto-ca/jep21l4/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95355'},
#  {'1 Bed': '$1,085',
#   '2 Beds': '$1,390',
#   '3 Beds': '$1,585',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,085'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,390'},
#                    {'bedroom_type': '3 Beds', 'price': '$1,585'}],
#   'City_Rent': 'Modesto',
#   'Full_Address': '2100 Coffee Rd, Modesto, CA 95355',
#   'Property_Name_Rent': 'Greenbriar Villa Apartments',
#   'Rent_link': 'https://www.apartments.com/greenbriar-villa-apartments-modesto-ca/vsndthe/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95355'},
#  {'1 Bed': '$1,010',
#   '2 Beds': '$1,295',
#   'Bedroom_Info': [{'bedroom_type': 'Studio', 'price': '$930'},
#                    {'bedroom_type': '1 Bed', 'price': '$1,010'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,295'}],
#   'City_Rent': 'Jurupa Valley',
#   'Full_Address': '10250 W Country Club Dr, Jurupa Valley, CA 91752',
#   'Property_Name_Rent': 'Country Village Senior Apartments 55+',
#   'Rent_link': 'https://www.apartments.com/country-village-senior-apartments-55-jurupa-valley-ca/bgest5c/',
#   'State_Rent': 'CA',
#   'Studio': '$930',
#   'Type': 'Apartment',
#   'Zip_code': '91752'},
#  {'1 Bed': '$2,170',
#   '2 Beds': '$4,318',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$2,170'},
#                    {'bedroom_type': '2 Beds', 'price': '$4,318'}],
#   'City_Rent': 'Petaluma',
#   'Full_Address': '1113 Baywood Dr, Petaluma, CA 94954',
#   'Property_Name_Rent': 'Altura',
#   'Rent_link': 'https://www.apartments.com/altura-petaluma-ca/7nd9c9w/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '94954'},
#  {'1 Bed': '$1,445',
#   '2 Beds': '$1,745',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,445'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,745'}],
#   'City_Rent': 'Paramount',
#   'Full_Address': '8635 Somerset Blvd, Paramount, CA 90723',
#   'Property_Name_Rent': 'Somerset Village',
#   'Rent_link': 'https://www.apartments.com/somerset-village-paramount-ca/lsj5ldg/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '90723'},
#  {'1 Bed': '$1,875',
#   '2 Beds': '$2,205',
#   '3 Beds': '$2,695',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,875'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,205'},
#                    {'bedroom_type': '3 Beds', 'price': '$2,695'}],
#   'City_Rent': 'Tracy',
#   'Full_Address': '3600 W Grant Line Rd, Tracy, CA 95304',
#   'Property_Name_Rent': 'Gateway Station Apartments',
#   'Rent_link': 'https://www.apartments.com/gateway-station-apartments-tracy-ca/hc3n831/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95304'},
#  {'2 Beds': '$1,640',
#   'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$1,640'}],
#   'City_Rent': 'Temecula',
#   'Full_Address': '29911 Mira Loma Dr, Temecula, CA 92592',
#   'Property_Name_Rent': 'Mira Loma Apartments',
#   'Rent_link': 'https://www.apartments.com/mira-loma-apartments-temecula-ca/wpg0t7l/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92592'},
#  {'2 Beds': '$960',
#   '3 Beds': '$1,250',
#   'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$960'},
#                    {'bedroom_type': '3 Beds', 'price': '$1,250'}],
#   'City_Rent': 'Victorville',
#   'Full_Address': '13520 3rd Ave, Victorville, CA 92395',
#   'Property_Name_Rent': 'Andalusia Luxury Apartments - WAITLIST',
#   'Rent_link': 'https://www.apartments.com/andalusia-luxury-apartments-waitlist-victorville-ca/nbgqe9n/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '92395'},
#  {'\r\n4 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t': '$999',
#   '\r\nStudio\t\t\t\t\t\t\t\t\t\t\t\t\t': '$1,284',
#   'Bedroom_Info': [{'bedroom_type': '\r\nStudio\t\t\t\t\t\t\t\t\t\t\t\t\t',
#                     'price': '$1,284'},
#                    {'bedroom_type': '\r\n4 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t',
#                     'price': '$999'}],
#   'City_Rent': 'San Luis Obispo',
#   'Full_Address': '1 Mustang Dr, San Luis Obispo, CA 93405',
#   'Property_Name_Rent': 'Mustang Village',
#   'Rent_link': 'https://www.apartments.com/mustang-village-san-luis-obispo-ca/w3myfmh/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '93405'},
#  {'1 Bed': '$2,800',
#   '2 Beds': '$2,800',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$2,800'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,800'}],
#   'City_Rent': 'San Jose',
#   'Full_Address': '1785 Almaden Rd, San Jose, CA 95125',
#   'Property_Name_Rent': 'Scotia Apartments',
#   'Rent_link': 'https://www.apartments.com/scotia-apartments-san-jose-ca/b44x7bb/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95125'},
#  {'1 Bed': '$1,825',
#   '2 Beds': '$2,050',
#   '3 Beds': '$2,775',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,825'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,050'},
#                    {'bedroom_type': '3 Beds', 'price': '$2,775'}],
#   'City_Rent': 'Tracy',
#   'Full_Address': '2725 Pavillion Pkwy, Tracy, CA 95304',
#   'Property_Name_Rent': 'Aspire Apartments',
#   'Rent_link': 'https://www.apartments.com/aspire-apartments-tracy-ca/l940xjf/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95304'},
#  {'2 Beds': '$2,075',
#   'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,075'}],
#   'City_Rent': 'Antioch',
#   'Full_Address': '3001 Kodiak St, Antioch, CA 94531',
#   'Property_Name_Rent': 'Hillcrest View',
#   'Rent_link': 'https://www.apartments.com/hillcrest-view-antioch-ca/kdzmhh8/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '94531'},
#  {'1 Bed': '$1,140',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,140'}],
#   'City_Rent': 'Sacramento',
#   'Full_Address': '5351 47th Ave, Sacramento, CA 95824',
#   'Property_Name_Rent': 'Greenridge Apartments',
#   'Rent_link': 'https://www.apartments.com/greenridge-apartments-sacramento-ca/y078b3r/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95824'},
#  {'1 Bed': '$1,585',
#   '2 Beds': '$1,780',
#   '3 Beds': '$1,925',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,585'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,780'},
#                    {'bedroom_type': '3 Beds', 'price': '$1,925'}],
#   'City_Rent': 'Elk Grove',
#   'Full_Address': '3300 Renwick Ave, Elk Grove, CA 95758',
#   'Property_Name_Rent': 'Castellino At Laguna West',
#   'Rent_link': 'https://www.apartments.com/castellino-at-laguna-west-elk-grove-ca/p2nms7r/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95758'},
#  {'\r\n2 \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n4 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t': '$800',
#   '\r\nStudio\t\t\t\t\t\t\t\t\t\t\t\t\t': '$1,560',
#   'Bedroom_Info': [{'bedroom_type': '\r\nStudio\t\t\t\t\t\t\t\t\t\t\t\t\t',
#                     'price': '$1,560'},
#                    {'bedroom_type': '\r\n'
#                                     '2 \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n'
#                                     '4 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t',
#                     'price': '$800'}],
#   'City_Rent': 'Sacramento',
#   'Full_Address': '2920 Ramona Ave, Sacramento, CA 95826',
#   'Property_Name_Rent': 'The Crossings Student Living',
#   'Rent_link': 'https://www.apartments.com/the-crossings-student-living-sacramento-ca/djcnp7l/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95826'},
#  {'1 Bed': '$1,983',
#   '2 Beds': '$2,279',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,983'},
#                    {'bedroom_type': '2 Beds', 'price': '$2,279'}],
#   'City_Rent': 'Ventura',
#   'Full_Address': '930 Pacific Strand Ct, Ventura, CA 93003',
#   'Property_Name_Rent': 'Via Ventura',
#   'Rent_link': 'https://www.apartments.com/via-ventura-ventura-ca/33m4jcg/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '93003'},
#  {'1 Bed': '$1,515',
#   '2 Beds': '$1,895',
#   '3 Beds': '$2,065',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,515'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,895'},
#                    {'bedroom_type': '3 Beds', 'price': '$2,065'}],
#   'City_Rent': 'Ripon',
#   'Full_Address': '1641 N Ripon Rd, Ripon, CA 95366',
#   'Property_Name_Rent': 'Luxe Ripon',
#   'Rent_link': 'https://www.apartments.com/luxe-ripon-ripon-ca/bhl4wj9/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95366'},
#  {'1 Bed': '$1,560',
#   '2 Beds': '$1,960',
#   'Bedroom_Info': [{'bedroom_type': 'Studio', 'price': '$1,255'},
#                    {'bedroom_type': '1 Bed', 'price': '$1,560'},
#                    {'bedroom_type': '2 Beds', 'price': '$1,960'}],
#   'City_Rent': 'Anaheim',
#   'Full_Address': '1000 E La Palma Ave, Anaheim, CA 92805',
#   'Property_Name_Rent': 'Parkside La Palma Apartments',
#   'Rent_link': 'https://www.apartments.com/parkside-la-palma-apartments-anaheim-ca/032qdp3/',
#   'State_Rent': 'CA',
#   'Studio': '$1,255',
#   'Type': 'Apartment',
#   'Zip_code': '92805'},
#  {'1 Bed': '$1,575',
#   '2 Beds': '',
#   '3 Beds': '',
#   'Bedroom_Info': [{'bedroom_type': '1 Bed', 'price': '$1,575'},
#                    {'bedroom_type': '2 Beds', 'price': ''},
#                    {'bedroom_type': '3 Beds', 'price': ''}],
#   'City_Rent': 'Modesto',
#   'Full_Address': '2929 Floyd Ave, Modesto, CA 95355',
#   'Property_Name_Rent': 'The Villas at Villaggio Apartments',
#   'Rent_link': 'https://www.apartments.com/the-villas-at-villaggio-apartments-modesto-ca/grdfp8w/',
#   'State_Rent': 'CA',
#   'Type': 'Apartment',
#   'Zip_code': '95355'}]

# %%
rent_data = pd.DataFrame(all_property)
rent_data
# Out:
#                      Property_Name_Rent       City_Rent       Type State_Rent  \
# 0                             580 Anton      Costa Mesa  Apartment         CA
# 1                         Bell Pasadena        Pasadena  Apartment         CA
# 2                      Candlewood North      Northridge  Apartment         CA
# 3           CASA GRANDE APARTMENT HOMES         Cypress  Apartment         CA
# 4                          Warner Villa  Woodland Hills  Apartment         CA
# ..                                  ...             ...        ...        ...
# 170        The Crossings Student Living      Sacramento  Apartment         CA
# 171                         Via Ventura         Ventura  Apartment         CA
# 172                          Luxe Ripon           Ripon  Apartment         CA
# 173        Parkside La Palma Apartments         Anaheim  Apartment         CA
# 174  The Villas at Villaggio Apartments         Modesto  Apartment         CA
#
#     Zip_code                                       Bedroom_Info  \
# 0      92626  [{'bedroom_type': 'Studio', 'price': ''}, {'be...
# 1      91107  [{'bedroom_type': 'Studio', 'price': '$1,996'}...
# 2      91324  [{'bedroom_type': 'Studio', 'price': '$1,535'}...
# 3      90630  [{'bedroom_type': '1 Bed', 'price': '$1,788'},...
# 4      91367  [{'bedroom_type': '1 Bed', 'price': '$1,899'},...
# ..       ...                                                ...
# 170    95826  [{'bedroom_type': '
# Studio													', 'pr...
# 171    93003  [{'bedroom_type': '1 Bed', 'price': '$1,983'},...
# 172    95366  [{'bedroom_type': '1 Bed', 'price': '$1,515'},...
# 173    92805  [{'bedroom_type': 'Studio', 'price': '$1,255'}...
# 174    95355  [{'bedroom_type': '1 Bed', 'price': '$1,575'},...
#
#                                           Full_Address  \
# 0                 580 Anton Blvd, Costa Mesa, CA 92626
# 1             3330 E Foothill Blvd, Pasadena, CA 91107
# 2               9830 Reseda Blvd, Northridge, CA 91324
# 3              4455 Casa Grande Cir, Cypress, CA 90630
# 4    5807 Topanga Canyon Blvd, Woodland Hills, CA 9...
# ..                                                 ...
# 170              2920 Ramona Ave, Sacramento, CA 95826
# 171           930 Pacific Strand Ct, Ventura, CA 93003
# 172                   1641 N Ripon Rd, Ripon, CA 95366
# 173             1000 E La Palma Ave, Anaheim, CA 92805
# 174                  2929 Floyd Ave, Modesto, CA 95355
#
#                                              Rent_link  Studio   1 Bed  ...  \
# 0    https://www.apartments.com/580-anton-costa-mes...          $2,363  ...
# 1    https://www.apartments.com/bell-pasadena-pasad...  $1,996  $2,200  ...
# 2    https://www.apartments.com/candlewood-north-no...  $1,535  $1,915  ...
# 3    https://www.apartments.com/casa-grande-apartme...     NaN  $1,788  ...
# 4    https://www.apartments.com/warner-villa-woodla...     NaN  $1,899  ...
# ..                                                 ...     ...     ...  ...
# 170  https://www.apartments.com/the-crossings-stude...     NaN     NaN  ...
# 171  https://www.apartments.com/via-ventura-ventura...     NaN  $1,983  ...
# 172  https://www.apartments.com/luxe-ripon-ripon-ca...     NaN  $1,515  ...
# 173  https://www.apartments.com/parkside-la-palma-a...  $1,255  $1,560  ...
# 174  https://www.apartments.com/the-villas-at-villa...     NaN  $1,575  ...
#
#     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t1 Bed\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n2 Beds\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
#     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t2 Beds\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n3 Beds\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
#     \r\nStudio\t\t\t\t\t\t\t\t\t\t\t\t\t \r\n6 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ..                                   ...                                  ...
# 170                               $1,560                                  NaN
# 171                                  NaN                                  NaN
# 172                                  NaN                                  NaN
# 173                                  NaN                                  NaN
# 174                                  NaN                                  NaN
#
#     4+ Beds  \
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 170     NaN
# 171     NaN
# 172     NaN
# 173     NaN
# 174     NaN
#
#     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t1 Bed\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n3 Beds\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
#     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\tStudio\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n2 Beds\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
#     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t1 Bed\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n4 Beds\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
#     \r\n4 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 170                                  NaN
# 171                                  NaN
# 172                                  NaN
# 173                                  NaN
# 174                                  NaN
#
#     \r\n2 \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t–\r\n4 Beds\t\t\t\t\t\t\t\t\t\t\t\t\t
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 170                                               $800
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
#
# [175 rows x 23 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
rent_data.to_csv("Output/Apartment.com/Q3-2020_Apartment.com_Apartment_Data_page21-28.csv", index=False, header=True)
