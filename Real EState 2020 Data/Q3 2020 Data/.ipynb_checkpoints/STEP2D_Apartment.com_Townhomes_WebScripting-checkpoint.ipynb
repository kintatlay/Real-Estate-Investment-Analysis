# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
rent_obj = []
all_property = []

for page in range(13,29):
    link = 'https://www.apartments.com/Townhomes/ca/' + str(page) + '/'
    user_agent = 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
    headers = {'User-Agent': user_agent}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
#     page 1-1
#     results = soup.find_all('article', class_='diamond placard')
#     page 1-1
#     results = soup.find_all('article', class_='platinum placard')
#     page 1-2
#     results = soup.find_all('article', class_='gold placard')
#     page 2-4
#     results = soup.find_all('article', class_='premiumPlus placard')
#     page 4-4
#     results = soup.find_all('article', class_='silver placard')
#     page 4-12
#     results = soup.find_all('article', class_='premium placard')
#     page 9-28
    results = soup.find_all('article', class_='prosumer placard')

    # Loop through returned results and get the hyperlink of the properties of the page
    for result in results:
        find_tag = result.find('a')['href']
        new_response = requests.get(find_tag, headers=headers)
        new_soup = BeautifulSoup(new_response.text, 'html.parser')
        new_results = new_soup.find('div', class_="mainWrapper")
        
        full_address = result.find('div', class_ = "location").text
        try:
            city = new_results.find('div', class_ = "propertyAddress").select('span')[0].text
        except:
            city = 'null'
        try:
            state = new_results.find('div', class_ = "propertyAddress").select('span')[1].text
        except:
            state = 'null'
        zip_code = new_results.find('div', class_ = "propertyAddress").select('span')[2].text
        street = new_results.find('h1', class_ = "propertyName").text.replace('\r\n                    ', "").strip()
        bedroom_container = new_results.find('div', class_="rentRollupContainer")
        house_details = new_results.find('table', class_="availabilityTable")
        try:
            bath_number = house_details.find('td', class_="baths").find('span', class_="shortText").text.replace('\r\n                    ', "").strip()
        except:
            bath_number = 'null'
        house_square_feet = house_details.find('td', class_="sqft").text
        square_feet = house_square_feet.split(" ")[0];
        lease_length = house_details.find('td', class_="leaseLength").text
        availability_check = house_details.find('td', class_="available").text.replace('\r\n                    ', "").strip()
        all_the_rents = bedroom_container.findAll('span', class_="rentRollup")

        bedroom_info = []
        for rent_block in all_the_rents:
            bedroom_type = rent_block.find('span', class_="shortText").text
            try:
                price = re.search('\$.* ', rent_block.text)
                price = price.group(0)[:-3]

            except:
                if "Call for Rent" in rent_block.text:
                    price = ""
                else:
                    price = re.search('\$.*', rent_block.text).group()[:-1]
            bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
        rent_obj = {
                "City_Rent": city,
                "Type": "Townhomes",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                "Full_Address": full_address,
                "Rent_link": find_tag,
                "Bath_Info": bath_number,
                "Square_Feet_Data": house_square_feet,
                "Square_Feet": square_feet,
                "Lease_length": lease_length,
                "Availability_check": availability_check
            }
        for room_type in bedroom_info:
            rent_obj[room_type["bedroom_type"]] = room_type["price"];
        
        all_property.append(rent_obj)
        time.sleep(1)
print(all_property)
# Out:
# [{'City_Rent': '6341 Andromeda Ct', 'Type': 'Townhomes', 'State_Rent': 'Eastvale', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,400'}], 'Full_Address': 'Eastvale, CA 91752', 'Rent_link': 'https://www.apartments.com/6341-andromeda-ct-eastvale-ca/rrvprr3/', 'Bath_Info': '2½ BAs', 'Square_Feet_Data': '1,384 Sq Ft', 'Square_Feet': '1,384', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '2 Beds': '$2,400'}, {'City_Rent': '1036 W Fernleaf Ave', 'Type': 'Townhomes', 'State_Rent': 'Pomona', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$2,700'}], 'Full_Address': 'Pomona, CA 91766', 'Rent_link': 'https://www.apartments.com/1036-w-fernleaf-ave-pomona-ca/20n27gc/', 'Bath_Info': '3 BAs', 'Square_Feet_Data': '1,605 Sq Ft', 'Square_Feet': '1,605', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '3 Beds': '$2,700'}, {'City_Rent': '29740 Denny Dr', 'Type': 'Townhomes', 'State_Rent': 'Lake Elsinore', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$1,800'}], 'Full_Address': 'Lake Elsinore, CA 92530', 'Rent_link': 'https://www.apartments.com/29740-denny-dr-lake-elsinore-ca/83x3210/', 'Bath_Info': '2½ BAs', 'Square_Feet_Data': '1,300 Sq Ft', 'Square_Feet': '1,300', 'Lease_length': '', 'Availability_check': 'Available Now', '3 Beds': '$1,800'}, {'City_Rent': '4140 Workman Mill Rd', 'Type': 'Townhomes', 'State_Rent': 'Whittier', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,295'}], 'Full_Address': 'Whittier, CA 90601', 'Rent_link': 'https://www.apartments.com/4140-workman-mill-rd-whittier-ca/mjrg4mh/', 'Bath_Info': '1 BA', 'Square_Feet_Data': '1,066 Sq Ft', 'Square_Feet': '1,066', 'Lease_length': '1 Month Lease', 'Availability_check': 'Available Now', '2 Beds': '$2,295'}, {'City_Rent': '427 Poinsettia Ave', 'Type': 'Townhomes', 'State_Rent': 'Newport Beach', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$5,995'}], 'Full_Address': 'Newport Beach, CA 92625', 'Rent_link': 'https://www.apartments.com/427-poinsettia-ave-newport-beach-ca/cmhlf0g/', 'Bath_Info': '1½ BAs', 'Square_Feet_Data': '1,935 Sq Ft', 'Square_Feet': '1,935', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '3 Beds': '$5,995'}, {'City_Rent': '3000 N Woods St', 'Type': 'Townhomes', 'State_Rent': 'Orange', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '4 Beds', 'price': '$2,850'}], 'Full_Address': 'Orange, CA 92865', 'Rent_link': 'https://www.apartments.com/3000-n-woods-st-orange-ca/kqzb5fc/', 'Bath_Info': '2½ BAs', 'Square_Feet_Data': '1,550 Sq Ft', 'Square_Feet': '1,550', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '4 Beds': '$2,850'}, {'City_Rent': '1093 E Grand Ave', 'Type': 'Townhomes', 'State_Rent': 'Pomona', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$2,500'}], 'Full_Address': 'Pomona, CA 91766', 'Rent_link': 'https://www.apartments.com/1093-e-grand-ave-pomona-ca/jxdywx7/', 'Bath_Info': '2½ BAs', 'Square_Feet_Data': '2,031 Sq Ft', 'Square_Feet': '2,031', 'Lease_length': '12 Month Lease', 'Availability_check': 'Available Now', '3 Beds': '$2,500'}, {'City_Rent': '76458 Violet Cir', 'Type': 'Townhomes', 'State_Rent': 'Palm Desert', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '2 Beds', 'price': '$2,695'}], 'Full_Address': 'Palm Desert, CA 92211', 'Rent_link': 'https://www.apartments.com/76458-violet-cir-palm-desert-ca/gv63s7x/', 'Bath_Info': '2 BAs', 'Square_Feet_Data': '1,579 Sq Ft', 'Square_Feet': '1,579', 'Lease_length': '', 'Availability_check': 'Available Now', '2 Beds': '$2,695'}, {'City_Rent': '712 Calle Divino', 'Type': 'Townhomes', 'State_Rent': 'San Clemente', 'Zip_code': 'CA', 'Bedroom_Info': [{'bedroom_type': '3 Beds', 'price': '$4,500'}], 'Full_Address': 'San Clemente, CA 92673', 'Rent_link': 'https://www.apartments.com/712-calle-divino-san-clemente-ca/9x9wtv7/', 'Bath_Info': '2½ BAs', 'Square ...

# %%
rent_data = pd.DataFrame(all_property)
rent_data
# Out:
#                 City_Rent       Type     State_Rent Zip_code  \
# 0       6341 Andromeda Ct  Townhomes       Eastvale       CA
# 1     1036 W Fernleaf Ave  Townhomes         Pomona       CA
# 2          29740 Denny Dr  Townhomes  Lake Elsinore       CA
# 3    4140 Workman Mill Rd  Townhomes       Whittier       CA
# 4      427 Poinsettia Ave  Townhomes  Newport Beach       CA
# ..                    ...        ...            ...      ...
# 320             San Mateo  Townhomes             CA    94401
# 321               Ventura  Townhomes             CA    93001
# 322           Aliso Viejo  Townhomes             CA    92656
# 323         Thousand Oaks  Townhomes             CA    91320
# 324           Los Angeles  Townhomes             CA    90019
#
#                                         Bedroom_Info             Full_Address  \
# 0    [{'bedroom_type': '2 Beds', 'price': '$2,400'}]       Eastvale, CA 91752
# 1    [{'bedroom_type': '3 Beds', 'price': '$2,700'}]         Pomona, CA 91766
# 2    [{'bedroom_type': '3 Beds', 'price': '$1,800'}]  Lake Elsinore, CA 92530
# 3    [{'bedroom_type': '2 Beds', 'price': '$2,295'}]       Whittier, CA 90601
# 4    [{'bedroom_type': '3 Beds', 'price': '$5,995'}]  Newport Beach, CA 92625
# ..                                               ...                      ...
# 320   [{'bedroom_type': '3 Beds', 'price': '$4,10'}]      San Mateo, CA 94401
# 321   [{'bedroom_type': '4 Beds', 'price': '$3,10'}]        Ventura, CA 93001
# 322   [{'bedroom_type': '2 Beds', 'price': '$2,90'}]    Aliso Viejo, CA 92656
# 323   [{'bedroom_type': '2 Beds', 'price': '$2,02'}]  Thousand Oaks, CA 91320
# 324   [{'bedroom_type': '3 Beds', 'price': '$5,50'}]    Los Angeles, CA 90019
#
#                                              Rent_link Bath_Info  \
# 0    https://www.apartments.com/6341-andromeda-ct-e...    2½ BAs
# 1    https://www.apartments.com/1036-w-fernleaf-ave...     3 BAs
# 2    https://www.apartments.com/29740-denny-dr-lake...    2½ BAs
# 3    https://www.apartments.com/4140-workman-mill-r...      1 BA
# 4    https://www.apartments.com/427-poinsettia-ave-...    1½ BAs
# ..                                                 ...       ...
# 320  https://www.apartments.com/358-e-bellevue-ave-...    2½ BAs
# 321  https://www.apartments.com/274-el-medio-st-ven...     2 BAs
# 322  https://www.apartments.com/14-hillgate-pl-alis...    2½ BAs
# 323  https://www.apartments.com/210-deerpath-ln-tho...    1½ BAs
# 324  https://www.apartments.com/1018-s-stanley-ave-...     2 BAs
#
#     Square_Feet_Data Square_Feet    Lease_length Availability_check  2 Beds  \
# 0        1,384 Sq Ft       1,384  12 Month Lease      Available Now  $2,400
# 1        1,605 Sq Ft       1,605  12 Month Lease      Available Now     NaN
# 2        1,300 Sq Ft       1,300                      Available Now     NaN
# 3        1,066 Sq Ft       1,066   1 Month Lease      Available Now  $2,295
# 4        1,935 Sq Ft       1,935  12 Month Lease      Available Now     NaN
# ..               ...         ...             ...                ...     ...
# 320      1,500 Sq Ft       1,500                      Available Now     NaN
# 321      2,000 Sq Ft       2,000  12 Month Lease      Available Now     NaN
# 322      1,300 Sq Ft       1,300                      Available Now   $2,90
# 323      1,100 Sq Ft       1,100  12 Month Lease      Available Now   $2,02
# 324      2,121 Sq Ft       2,121  12 Month Lease      Available Now     NaN
#
#      3 Beds 4 Beds 4+ Beds 1 Bed Studio
# 0       NaN    NaN     NaN   NaN    NaN
# 1    $2,700    NaN     NaN   NaN    NaN
# 2    $1,800    NaN     NaN   NaN    NaN
# 3       NaN    NaN     NaN   NaN    NaN
# 4    $5,995    NaN     NaN   NaN    NaN
# ..      ...    ...     ...   ...    ...
# 320   $4,10    NaN     NaN   NaN    NaN
# 321     NaN  $3,10     NaN   NaN    NaN
# 322     NaN    NaN     NaN   NaN    NaN
# 323     NaN    NaN     NaN   NaN    NaN
# 324   $5,50    NaN     NaN   NaN    NaN
#
# [325 rows x 18 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
rent_data.to_csv("Output/Apartment.com/Q3-2020_Apartment.com_Townhomes_Data_page13-28.csv", index=False, header=True)
