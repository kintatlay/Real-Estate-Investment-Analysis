# %%
# Tutorial: https://www.youtube.com/watch?v=dRcvJRmqFHQ&lc=UgyUDvoIA0A37EWWoC54AaABAg.9Aem3mXGQzz9Aep5dNrAY6
import requests
from bs4 import BeautifulSoup
import json
import time
import csv
import pandas as pd
import os

class ZillowScraper():
    results = []
    headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'zguid=23|%24d7ce356c-e3c5-4a48-85b3-61d0af33c3a1; zgsession=1|76ac70ba-62bc-4f77-81a1-b46b55a3f268; _ga=GA1.2.656681018.1593695925; _gid=GA1.2.1901059192.1593695925; zjs_user_id=null; zjs_anonymous_id=%22d7ce356c-e3c5-4a48-85b3-61d0af33c3a1%22; _pxvid=930c8230-bc66-11ea-9dd2-0242ac120007; _gcl_au=1.1.2002891296.1593696177; KruxPixel=true; DoubleClickSession=true; _pin_unauth=dWlkPU9EbG1aR0ptTTJVdFkySXpPUzAwWVdZMUxXSTFNVE10TnpFNE1EZGpOamxsWWpZNQ; _fbp=fb.1.1593696180071.236888825; KruxAddition=true; g_state={"i_p":1593716288950,"i_l":1}; JSESSIONID=0C394BB3DC7B91E479B72A328353817A; GASession=true; _pxff_bsco=1; AWSALB=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; AWSALBCORS=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; search=6|1596363321838%7Crect%3D43.45764218649565%252C-109.08936284375%252C30.85123360186431%252C-129.52393315625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D0%26days%3D90%26type%3Dhouse%26lt%3Dfsba%252Cfsbo%252Cfore%252Cnew%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%09%099%09%09%09%09%09%09; _px3=d4336234c4010c751aebc89c46325b0fb974e47215ce19445dfb759a629e81dc:X7e2f9pB1glpxKBrZ31UbYr/SXJFF+UxNWu+hiMsI+DQ7Mqle+9ez9SpkHaEa0n8KjNaAtb3oFQCfBoM9SkdFQ==:1000:AfuabQEQyo2l//8QKend7zOjb5sDW5Is+c6zQcm/upUYyYJc1jNQiyYnwroZOcBIjJBNJ8+vUKEJ3TlBoNaX/O7UbA0YkImLQb+VkAlAZWRj+w8lmqxZjshBeq6rrIg7GVsOSD+a1N8QtabSrjTIOF1SbQdGaZFzwVUu+aT6YiQ=; _uetsid=b093ce5e-93c4-0334-9c39-42ee7af2a929; _uetvid=e59e74ae-427f-984f-1765-cdc49ba1fa47',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    }
        
    def fetch(self, url, params):
        response = requests.get(url, headers=self.headers, params=params)
        print(response.status_code)
        return response
    
    def parse(self, response):
        content = BeautifulSoup(response, 'lxml')
        deck = content.find('ul', {'class': 'photo-cards photo-cards_wow photo-cards_short'})
        for card in deck.contents:
            script = card.find('script', {'type': 'application/ld+json'})
            if script:
                script_json = json.loads(script.contents[0])
                loop_response = requests.get(script_json['url'], headers=self.headers)
                loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
                try:
                    loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
                except IndexError:
                    loop_result2 = 'null'
                lot = 'null';
                house_type = 'null';
                year_build = 'null';
                parking = 'null';
                hoa = 'null';
                lot_conversion_to_sqft = 'null';
                zillow_price_per_sqft = 'null';
                
                if loop_result2:
                    for contents in loop_result2:
                        print(contents.text)
                        if "Lot" in contents.text.split(":")[0]:
                            lot = contents.text.split(":")[1];
                        if "Type" in contents.text.split(":")[0]:
                            house_type = contents.text.split(":")[1];
                        if "Year built" in contents.text.split(":")[0]:
                            year_build = contents.text.split(":")[1];
                        if "Parking" in contents.text.split(":")[0]:
                            parking = contents.text.split(":")[1];
                        if "HOA" in contents.text.split(":")[0]:
                            hoa = contents.text.split(":")[1];
                        if "Price/sqft" in contents.text.split(":")[0]:
                            zillow_price_per_sqft = contents.text.split(":")[1];
                
                    try:
                        zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-fzoxKX sc-oTpqt loFLRQ").text
                        rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[4].find('p', class_="Text-aiai24-0 sc-fzoxKX sc-oTpqt loFLRQ").text
                    except AttributeError:
                        zestimate = 'null'
                        rent_zestimate = 'null'
                    try:
                        if (str(lot.split(" ")[1]) == "sqft"):
                            lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                        elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                            lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                        elif (lot == "No Data"):
                            lot_conversion_to_sqft = 'null'
                        else:
                            lot_conversion_to_sqft = 'null'
                    except IndexError:
                        lot_conversion_to_sqft = 'null'
                        
                    self.results.append({
                        'Listing_type': card.find('div', {'class': 'list-card-type'}).text,
                        'Price': card.find('div', {'class': 'list-card-price'}).text,
                        'Full_address': script_json['name'],
                        'Street': script_json['address']['streetAddress'],
                        'City': script_json['address']['addressLocality'],
                        'State': script_json['address']['addressRegion'],
                        'Zip_code': script_json['address']['postalCode'],
                        'Latitude': script_json['geo']['latitude'],
                        'Longitude': script_json['geo']['longitude'],
                        'Square_Feet': script_json['floorSize']['value'],
                        'Lot': lot,
                        'Lot_conversion_to_sqft': lot_conversion_to_sqft,
                        'House_type': house_type,
                        'Year_build': year_build,
                        'Parking': parking,
                        'Hoa': hoa,
                        'Zillow_price_per_sqft': zillow_price_per_sqft,
                        'Zestimate': zestimate,
                        'Rent_zestimate': rent_zestimate,
                        'House_website': script_json['url']
                    })
                    time.sleep(3)
                
    def to_csv(self):
        dirName = 'Output/Zillow/'
        if not os.path.exists(dirName):
            os.mkdir(dirName)
            print("Directory ", dirName, " Folder created ")
        else:
            print("Directory ", dirName, " Folder already exists")
            
        with open('./' + dirName + 'Q3-2020_Condo_Data_page17-20.csv', 'w') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            
            for row in self.results:
                writer.writerow(row)

    def to_dftable(self):
        house_data = pd.DataFrame(self.results)
        print(house_data)

#     Filter Out Coming Soon, Auction, Home Type: Condos, Days On Zillow: 90 Days
    def run(self):
        url = 'https://www.zillow.com/ca/condos/'
        for page in range(17,21):
            params = {
                'searchQueryState':'{"pagination":{"currentPage":%s},"usersSearchTerm":"ca","mapBounds":{"west":-153.847663625,"east":-84.765632375,"south":12.777434491046959,"north":56.013075839104054},"mapZoom":4,"regionSelection":[{"regionId":9,"regionType":2}],"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"},"isSingleFamily":{"value":false}},"isListVisible":true,"isMapVisible":true}' %page
            }
            res = self.fetch(url, params)
            self.parse(res.text)
            time.sleep(2)
        self.to_dftable()
        self.to_csv()
        
if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run();
# Out:
# 200
# Type:Condo
# Year built:1978
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# HOA:$400/mo
# Price/sqft:$581
# Type:Condo
# Year built:1974
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$285/mo
# Price/sqft:$365
# Type:Condo
# Year built:1976
# Heating:Forced air, Electric
# Cooling:Central
# Parking:1 space
# HOA:$425/mo
# Price/sqft:$296
# Type:Condo
# Year built:2005
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# HOA:$180/mo
# Price/sqft:$319
# Type:Condo
# Year built:1980
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$336/mo
# Price/sqft:$456
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$659/mo
# Price/sqft:$1,448
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$330/mo
# Price/sqft:$341
# Type:Condo
# Year built:1971
# Heating:No Data
# Cooling:No Data
# Parking:4 spaces
# HOA:$330/mo
# Price/sqft:$338
# Type:Condo
# Year built:2005
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$324/mo
# Price/sqft:$174
# Type:Condo
# Year built:1971
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# HOA:$202/mo
# Price/sqft:$247
# Type:Condo
# Year built:1965
# Heating:Forced air, Gas
# Cooling:Central
# Parking:1 space
# HOA:$325/mo
# Price/sqft:$431
# Type:Condo
# Year built:1972
# Heating:None, Forced air
# Cooling:Other
# Parking:No Data
# HOA:$320/mo
# Price/sqft:$550
# Type:Condo
# Year built:1927
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$4,426/mo
# Price/sqft:$2,910
# Type:Condo
# Year built:2008
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$420/mo
# Price/sqft:$631
# Type:Condo
# Year built:1995
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$222/mo
# Price/sqft:$819
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$415/mo
# Price/sqft:$608
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$350/mo
# Price/sqft:$138
# Type:Condo
# Year built:1985
# Heating:No Data
# Cooling:Central
# Parking:2 spaces
# HOA:$310/mo
# Price/sqft:$264
# Type:Condo
# Year built:2008
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$3,014/mo
# Price/sqft:$911
# Type:Condo
# Year built:1982
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$418/mo
# Price/sqft:$299
# Type:Condo
# Year built:2007
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$375/mo
# Price/sqft:$286
# Type:Condo
# Year built:1996
# Heating:Forced air
# Cooling:None
# Parking:No Data
# HOA:$559/mo
# Price/sqft:$1,099
# Type:Condo
# Year built:1929
# Heating:Baseboard
# Cooling:No Data
# Parking:No Data
# HOA:$441/mo
# Price/sqft:$1,123
# Type:Condo
# Year built:1964
# Heating:Forced air, Electric
# Cooling:Wall
# Parking:2 spaces
# HOA:$700/mo
# Price/sqft:$374
# Type:Condo
# Year built:1978
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$430/mo
# Price/sqft:$268
# Type:Condo
# Year built:1969
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$300/mo
# Price/sqft:$130
# Type:Condo
# Year built:1922
# Heating:No Data
# Cooling:Wall
# Parking:1 space
# HOA:$250/mo
# Price/sqft:$786
# Type:Condo
# Year built:1984
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$367/mo
# Price/sqft:$233
# Type:Condo
# Year built:1931
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$635/mo
# Price/sqft:$1,059
# Type:Condo
# Year built:1959
# Heating:Forced air, Gas
# Cooling:Central
# Parking:1 space
# HOA:$900/mo
# Price/sqft:$644
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$223/mo
# Price/sqft:$461
# Type:Condo
# Year built:1977
# Heating:Forced air, Electric, Gas
# Cooling:Wall
# Parking:No Data
# HOA:$320/mo
# Price/sqft:$477
# Type:Condo
# Year built:1973
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$428/mo
# Price/sqft:$491
# Type:Condo
# Year built:1966
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:1 space
# HOA:$616/mo
# Price/sqft:$384
# Type:Condo
# Year built:2005
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$444/mo
# Price/sqft:$644
# Type:Condo
# Year built:1975
# Heating:Forced air, Electric
# Cooling:None
# Parking:2 spaces
# HOA:$270/mo
# Price/sqft:$372
# 200
# Type:Condo
# Year built:1990
# Heating:Forced air, Gas
# Cooling:Central
# Parking:3 spaces
# HOA:$425/mo
# Price/sqft:$145
# Type:Condo
# Year built:2000
# Heating:No Data
# Cooling:Central
# Parking:2 spaces
# HOA:$265/mo
# Price/sqft:$500
# Type:Condo
# Year built:1981
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$317/mo
# Price/sqft:$302
# Type:Condo
# Year built:2003
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$221/mo
# Price/sqft:$366
# Type:Condo
# Year built:1974
# Heating:Baseboard, Electric
# Cooling:Wall
# Parking:1 space
# HOA:$480/mo
# Price/sqft:$451
# Type:Condo
# Year built:1982
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$299/mo
# Price/sqft:$458
# Type:Condo
# Year built:2005
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$260/mo
# Price/sqft:$359
# Type:Condo
# Year built:1923
# Heating:Wall
# Cooling:No Data
# Parking:1 space
# HOA:$263/mo
# Price/sqft:$674
# Type:Condo
# Year built:1989
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# HOA:$369/mo
# Type:Condo
# Year built:1965
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$350/mo
# Price/sqft:$213
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$400/mo
# Price/sqft:$698
# Type:Condo
# Year built:1995
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$553/mo
# Price/sqft:$562
# Type:Condo
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$235/mo
# Price/sqft:$252
# Type:Condo
# Year built:1981
# Heating:None
# Cooling:No Data
# Parking:1 space
# HOA:$368/mo
# Price/sqft:$293
# Type:Condo
# Year built:1969
# Heating:Heat pump, Radiant, Electric
# Cooling:No Data
# Parking:1 space
# HOA:$614/mo
# Price/sqft:$218
# Type:Condo
# Year built:1980
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# HOA:$387/mo
# Price/sqft:$318
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$260/mo
# Price/sqft:$662
# Type:Condo
# Year built:2007
# Heating:Forced air, Electric, Gas
# Cooling:None
# Parking:2 spaces
# HOA:$234/mo
# Price/sqft:$326
# Type:Condo
# Year built:1985
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:1 space
# HOA:$280/mo
# Price/sqft:$530
# Type:Condo
# Year built:2015
# Heating:Forced air, Gas
# Cooling:None
# Parking:No Data
# HOA:$472/mo
# Price/sqft:$700
# Type:Condo
# Year built:1991
# Heating:Forced air
# Cooling:Wall
# Parking:3 spaces
# HOA:$165/mo
# Price/sqft:$439
# Type:Condo
# Year built:1906
# Heating:None, Other
# Cooling:No Data
# Parking:1 space
# Price/sqft:$931
# Type:Condo
# Year built:1981
# Heating:Baseboard, Gas
# Cooling:None
# Parking:2 spaces
# HOA:$408/mo
# Price/sqft:$674
# Type:Condo
# Year built:1971
# Heating:Forced air, Electric
# Cooling:No Data
# Parking:2 spaces
# HOA:$435/mo
# Price/sqft:$362
# Type:Condo
# Year built:1987
# Heating:Wall, Gas
# Cooling:Wall
# Parking:1 space
# HOA:$438/mo
# Price/sqft:$523
# Type:Condo
# Year built:1979
# Heating:Other, Other
# Cooling:No Data
# Parking:No Data
# HOA:$675/mo
# Price/sqft:$541
# Type:Condo
# Year built:1912
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$540/mo
# Price/sqft:$1,020
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$596/mo
# Price/sqft:$1,388
# Type:Condo
# Year built:1914
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$175/mo
# Price/sqft:$352
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$310/mo
# Price/sqft:$265
# Type:Condo
# Year built:1988
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$360/mo
# Price/sqft:$449
# Type:Condo
# Year built:1983
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$378
# Type:Condo
# Year built:2011
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$309/mo
# Price/sqft:$783
# Type:Condo
# Year built:2004
# Heating:No Data
# Cooling:None
# Parking:2 spaces
# Price/sqft:$353
# Type:Condo
# Year built:2005
# Heating:Radiant, Other
# Cooling:None
# Parking:1 space
# HOA:$742/mo
# Price/sqft:$422
# Type:Condo
# Year built:1973
# Heating:Wall, Gas
# Cooling:None
# Parking:2 spaces
# HOA:$355/mo
# Price/sqft:$472
# 200
# Type:Condo
# Year built:1979
# Heating:None
# Cooling:No Data
# Parking:No Data
# HOA:$296/mo
# Price/sqft:$328
# Type:Condo
# Year built:1990
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$325/mo
# Price/sqft:$516
# Type:Condo
# Year built:1994
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$440/mo
# Price/sqft:$381
# Type:Condo
# Year built:2006
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$250/mo
# Price/sqft:$959
# Type:Condo
# Year built:1977
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$524/mo
# Price/sqft:$260
# Type:Condo
# Year built:1970
# Heating:Other, Electric
# Cooling:None
# Parking:1 space
# HOA:$479/mo
# Price/sqft:$888
# Type:Condo
# Year built:1982
# Heating:Forced air, Gas
# Cooling:None
# Parking:2 spaces
# HOA:$730/mo
# Price/sqft:$564
# Type:Condo
# Year built:2012
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# HOA:$320/mo
# Price/sqft:$353
# Type:Condo
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$205/mo
# Price/sqft:$336
# Type:Condo
# Year built:1973
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$325/mo
# Price/sqft:$310
# Type:Condo
# Year built:1990
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$377/mo
# Price/sqft:$176
# Type:Condo
# Year built:2001
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$700/mo
# Price/sqft:$769
# Type:Condo
# Year built:1922
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# HOA:$4,471/mo
# Price/sqft:$2,824
# Type:Condo
# Year built:1962
# Heating:Forced air, Electric
# Cooling:Wall
# Parking:No Data
# HOA:$180/mo
# Price/sqft:$437
# Type:Condo
# Year built:2008
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$280/mo
# Price/sqft:$270
# Type:Condo
# Year built:2000
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$300/mo
# Price/sqft:$407
# Type:Condo
# Year built:2007
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$254/mo
# Price/sqft:$382
# Type:Condo
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$360/mo
# Price/sqft:$265
# Type:Condo
# Year built:1990
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$342/mo
# Price/sqft:$451
# Type:Condo
# Year built:1958
# Heating:Wall, Gas
# Cooling:None
# Parking:1 space
# HOA:$314/mo
# Price/sqft:$885
# Type:Condo
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$695/mo
# Price/sqft:$681
# Type:Condo
# Year built:1994
# Heating:Electric
# Cooling:Central
# Parking:1 space
# HOA:$440/mo
# Price/sqft:$389
# Type:Condo
# Year built:1979
# Heating:Wall, Electric, Gas
# Cooling:Wall
# Parking:No Data
# HOA:$240/mo
# Price/sqft:$638
# Type:Condo
# Year built:1976
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# HOA:$320/mo
# Price/sqft:$413
# Type:Condo
# Year built:1908
# Heating:No Data
# Cooling:Wall
# Parking:No Data
# HOA:$150/mo
# Price/sqft:$1,404
# Type:Condo
# Year built:1964
# Heating:Forced air, Gas
# Cooling:Central
# Parking:1 space
# HOA:$200/mo
# Price/sqft:$358
# Type:Condo
# Year built:2007
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# HOA:$532/mo
# Price/sqft:$707
# Type:Condo
# Year built:1895
# Heating:Forced air, Gas
# Cooling:Central
# Parking:1 space
# HOA:$242/mo
# Price/sqft:$1,061
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$360/mo
# Price/sqft:$313
# Type:Condo
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$602/mo
# Price/sqft:$1,264
# Type:Condo
# Year built:1968
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$395/mo
# Price/sqft:$345
# Type:Condo
# Year built:1963
# Heating:Radiant, Electric
# Cooling:None
# Parking:1 space
# HOA:$400/mo
# Price/sqft:$443
# 200
# Type:Condo
# Year built:1967
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$381
# Type:Condo
# Year built:1973
# Heating:Heat pump, Radiant, Electric
# Cooling:Other
# Parking:1 space
# HOA:$650/mo
# Price/sqft:$263
# Type:Condo
# Year built:1986
# Heating:Forced air, Heat pump, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$220/mo
# Price/sqft:$175
# Type:Condo
# Year built:2006
# Heating:Forced air, Electric
# Cooling:Central
# Parking:3 spaces
# Price/sqft:$157
# Type:Condo
# Year built:1983
# Heating:Gas
# Cooling:None
# Parking:No Data
# HOA:$125/mo
# Price/sqft:$410
# Type:Condo
# Year built:1987
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$264/mo
# Price/sqft:$589
# Type:Condo
# Year built:1970
# Heating:Forced air
# Cooling:None
# Parking:1 space
# HOA:$375/mo
# Price/sqft:$506
# Type:Condo
# Year built:2004
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$242/mo
# Price/sqft:$349
# Type:Condo
# Year built:1978
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$405/mo
# Price/sqft:$377
# Type:Condo
# Year built:2017
# Heating:Other, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$454/mo
# Price/sqft:$357
# Type:Condo
# Year built:1966
# Heating:No Data
# Cooling:Wall
# Parking:No Data
# Price/sqft:$396
# Type:Condo
# Year built:1986
# Heating:Forced air, Electric
# Cooling:Central
# Parking:1 space
# HOA:$2,519/mo
# Price/sqft:$286
# Type:Condo
# Year built:1927
# Heating:Forced air
# Cooling:Central
# Parking:No Data
# HOA:$3,186/mo
# Price/sqft:$2,043
# Type:Condo
# Year built:1981
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# HOA:$410/mo
# Price/sqft:$400
# Type:Condo
# Year built:1994
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$282/mo
# Price/sqft:$436
# Type:Condo
# Year built:1983
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$284/mo
# Price/sqft:$255
# Type:Condo
# Year built:1972
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$914/mo
# Price/sqft:$631
# Type:Condo
# Year built:1987
# Heating:Forced air, Electric
# Cooling:Central
# Parking:1 space
# HOA:$227/mo
# Price/sqft:$447
# Type:Condo
# Year built:1983
# Heating:No Data
# Cooling:None
# Parking:2 spaces
# HOA:$250/mo
# Price/sqft:$342
# Type:Condo
# Year built:1975
# Heating:Forced air, Gas
# Cooling:No Data
# Parking:3 spaces
# HOA:$335/mo
# Price/sqft:$332
# Type:Condo
# Year built:2014
# Heating:Forced air, Electric, Solar
# Cooling:Central
# Parking:2 spaces
# HOA:$211/mo
# Price/sqft:$298
# Type:Condo
# Year built:1983
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:1 space
# HOA:$223/mo
# Price/sqft:$399
# Type:Condo
# Year built:1981
# Heating:Forced air, Electric, Gas
# Cooling:None
# Parking:No Data
# HOA:$495/mo
# Price/sqft:$250
# Type:Condo
# Year built:1985
# Heating:Forced air, Gas
# Cooling:Central
# Parking:1 space
# HOA:$665/mo
# Price/sqft:$209
# Type:Condo
# Year built:1981
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# HOA:$319/mo
# Price/sqft:$305
# Type:Condo
# Year built:1986
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# HOA:$293/mo
# Price/sqft:$539
# Type:Condo
# Year built:2005
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Price/sqft:$429
# Type:Condo
# Year built:1972
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$280/mo
# Price/sqft:$400
# Type:Condo
# Year built:2005
# Heating:Forced air, Gas
# Cooling:Central
# Parking:1 space
# HOA:$280/mo
# Price/sqft:$234
# Type:Condo
# Year built:1999
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$200/mo
# Price/sqft:$380
# Type:Condo
# Year built:1981
# Heating:No Data
# Cooling:Wall
# Parking:1 space
# HOA:$297/mo
# Price/sqft:$312
# Type:Condo
# Year built:1972
# Heating:None
# Cooling:No Data
# Parking:No Data
# HOA:$170/mo
# Price/sqft:$185
# Type:Condo
# Year built:2016
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# HOA:$203/mo
# Price/sqft:$509
# Type:Condo
# Year built:1973
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# HOA:$350/mo
# Price/sqft:$85
# Type:Condo
# Year built:2020
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# HOA:$268/mo
# Price/sqft:$261
#           Listing_type     Price  \
# 0       Condo for sale  $565,000
# 1       Condo for sale  $316,000
# 2       Condo for sale  $265,000
# 3    For sale by owner  $460,000
# 4       Condo for sale  $539,000
# ..                 ...       ...
# 134     Condo for sale  $299,000
# 135     Condo for sale  $195,000
# 136     Condo for sale  $598,000
# 137     Condo for sale   $47,999
# 138   New construction  $431,229
#
#                                           Full_address  \
# 0    2323 Huntington St Apt 1004, Huntington Beach,...
# 1                 3414 Thunder Dr, Oceanside, CA 92056
# 2            1414 Pajaro Ave Apt 41, Manteca, CA 95336
# 3             19558 Laroda Ln, Santa Clarita, CA 91350
# 4           2530 Coventry Cir #88, Fullerton, CA 92833
# ..                                                 ...
# 134      2094 E Grand Ave Unit 39, Escondido, CA 92027
# 135               718 Simpson Pl, Santa Rosa, CA 95401
# 136      17011 Independence Way, Yorba Linda, CA 92886
# 137  9639 Spyglass Ave Unit 48, Desert Hot Springs,...
# 138      16502 Casa Grande Ave #343, Fontana, CA 92336
#
#                           Street                City State Zip_code  \
# 0    2323 Huntington St APT 1004    Huntington Beach    CA    92648
# 1                3414 Thunder Dr           Oceanside    CA    92056
# 2         1414 Pajaro Ave APT 41             Manteca    CA    95336
# 3                19558 Laroda Ln       Santa Clarita    CA    91350
# 4          2530 Coventry Cir #88           Fullerton    CA    92833
# ..                           ...                 ...   ...      ...
# 134     2094 E Grand Ave UNIT 39           Escondido    CA    92027
# 135               718 Simpson Pl          Santa Rosa    CA    95401
# 136       17011 Independence Way         Yorba Linda    CA    92886
# 137    9639 Spyglass Ave UNIT 48  Desert Hot Springs    CA    92240
# 138   16502 Casa Grande Ave #343             Fontana    CA    92336
#
#       Latitude   Longitude Square_Feet   Lot Lot_conversion_to_sqft  \
# 0    33.678206 -117.996098         973  null                   null
# 1    33.183251 -117.287613         866  null                   null
# 2    37.818127 -121.227298         896  null                   null
# 3    34.445936 -118.478446       1,440  null                   null
# 4    33.898566 -117.969802       1,181  null                   null
# ..         ...         ...         ...   ...                    ...
# 134  33.135728 -117.047937         959  null                   null
# 135  38.441880 -122.737285       1,052  null                   null
# 136  33.889280 -117.837334       1,176  null                   null
# 137  33.978387 -116.541702         565  null                   null
# 138  34.157803 -117.451986       1,652  null                   null
#
#     House_type Year_build   Parking      Hoa Zillow_price_per_sqft Zestimate  \
# 0        Condo       1978  2 spaces  $400/mo                  $581  $568,885
# 1        Condo       1974  2 spaces  $285/mo                  $365  $317,990
# 2        Condo       1976   1 space  $425/mo                  $296  $266,622
# 3        Condo       2005  2 spaces  $180/mo                  $319  $446,514
# 4        Condo       1980  2 spaces  $336/mo                  $456  $545,959
# ..         ...        ...       ...      ...                   ...       ...
# 134      Condo       1981   1 space  $297/mo                  $312  $289,865
# 135      Condo       1972   No Data  $170/mo                  $185  $198,725
# 136      Condo       2016  2 spaces  $203/mo                  $509  $602,196
# 137      Condo       1973  2 spaces  $350/mo                   $85   $45,182
# 138      Condo       2020  2 spaces  $268/mo                  $261      null
#
#     Rent_zestimate                                      House_website
# 0        $2,400/mo  https://www.zillow.com/homedetails/2323-Huntin...
# 1        $1,850/mo  https://www.zillow.com/homedetails/3414-Thunde...
# 2        $1,550/mo  https://www.zillow.com/homedetails/1414-Pajaro...
# 3        $2,600/mo  https://www.zillow.com/homedetails/19558-Larod...
# 4        $2,600/mo  https://www.zillow.com/homedetails/2530-Covent...
# ..             ...                                                ...
# 134      $1,700/mo  https://www.zillow.com/homedetails/2094-E-Gran...
# 135      $2,300/mo  https://www.zillow.com/homedetails/718-Simpson...
# 136      $2,600/mo  https://www.zillow.com/homedetails/17011-Indep...
# 137      $1,100/mo  https://www.zillow.com/homedetails/9639-Spygla...
# 138           null  https://www.zillow.com/homedetails/16502-Casa-...
#
# [139 rows x 20 columns]
# Directory  Output/Zillow/  Folder already exists
