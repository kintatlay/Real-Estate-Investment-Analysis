# %%
# Tutorial: https://www.youtube.com/watch?v=dRcvJRmqFHQ&lc=UgyUDvoIA0A37EWWoC54AaABAg.9Aem3mXGQzz9Aep5dNrAY6
import requests
from bs4 import BeautifulSoup
import json
import time
import csv
import pandas as pd
import os

class ZillowScraper():
    results = []
    headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'zguid=23|%24d7ce356c-e3c5-4a48-85b3-61d0af33c3a1; zgsession=1|76ac70ba-62bc-4f77-81a1-b46b55a3f268; _ga=GA1.2.656681018.1593695925; _gid=GA1.2.1901059192.1593695925; zjs_user_id=null; zjs_anonymous_id=%22d7ce356c-e3c5-4a48-85b3-61d0af33c3a1%22; _pxvid=930c8230-bc66-11ea-9dd2-0242ac120007; _gcl_au=1.1.2002891296.1593696177; KruxPixel=true; DoubleClickSession=true; _pin_unauth=dWlkPU9EbG1aR0ptTTJVdFkySXpPUzAwWVdZMUxXSTFNVE10TnpFNE1EZGpOamxsWWpZNQ; _fbp=fb.1.1593696180071.236888825; KruxAddition=true; g_state={"i_p":1593716288950,"i_l":1}; JSESSIONID=0C394BB3DC7B91E479B72A328353817A; GASession=true; _pxff_bsco=1; AWSALB=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; AWSALBCORS=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; search=6|1596363321838%7Crect%3D43.45764218649565%252C-109.08936284375%252C30.85123360186431%252C-129.52393315625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D0%26days%3D90%26type%3Dhouse%26lt%3Dfsba%252Cfsbo%252Cfore%252Cnew%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%09%099%09%09%09%09%09%09; _px3=d4336234c4010c751aebc89c46325b0fb974e47215ce19445dfb759a629e81dc:X7e2f9pB1glpxKBrZ31UbYr/SXJFF+UxNWu+hiMsI+DQ7Mqle+9ez9SpkHaEa0n8KjNaAtb3oFQCfBoM9SkdFQ==:1000:AfuabQEQyo2l//8QKend7zOjb5sDW5Is+c6zQcm/upUYyYJc1jNQiyYnwroZOcBIjJBNJ8+vUKEJ3TlBoNaX/O7UbA0YkImLQb+VkAlAZWRj+w8lmqxZjshBeq6rrIg7GVsOSD+a1N8QtabSrjTIOF1SbQdGaZFzwVUu+aT6YiQ=; _uetsid=b093ce5e-93c4-0334-9c39-42ee7af2a929; _uetvid=e59e74ae-427f-984f-1765-cdc49ba1fa47',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    }
        
    def fetch(self, url, params):
        response = requests.get(url, headers=self.headers, params=params)
        print(response.status_code)
        return response
    
    def parse(self, response):
        content = BeautifulSoup(response, 'lxml')
        deck = content.find('ul', {'class': 'photo-cards photo-cards_wow photo-cards_short'})
        for card in deck.contents:
            script = card.find('script', {'type': 'application/ld+json'})
            if script:
                script_json = json.loads(script.contents[0])
                loop_response = requests.get(script_json['url'], headers=self.headers)
                loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
                try:
                    loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
                except IndexError:
                    loop_result2 = 'null'
                lot = 'null';
                house_type = 'null';
                year_build = 'null';
                parking = 'null';
                hoa = 'null';
                lot_conversion_to_sqft = 'null';
                zillow_price_per_sqft = 'null';
                
                if loop_result2:
                    for contents in loop_result2:
                        print(contents.text)
                        if "Lot" in contents.text.split(":")[0]:
                            lot = contents.text.split(":")[1];
                        if "Type" in contents.text.split(":")[0]:
                            house_type = contents.text.split(":")[1];
                        if "Year built" in contents.text.split(":")[0]:
                            year_build = contents.text.split(":")[1];
                        if "Parking" in contents.text.split(":")[0]:
                            parking = contents.text.split(":")[1];
                        if "HOA" in contents.text.split(":")[0]:
                            hoa = contents.text.split(":")[1];
                        if "Price/sqft" in contents.text.split(":")[0]:
                            zillow_price_per_sqft = contents.text.split(":")[1];
                
                    try:
                        zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-fzoxKX sc-oTpqt loFLRQ").text
                        rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[4].find('p', class_="Text-aiai24-0 sc-fzoxKX sc-oTpqt loFLRQ").text
                    except AttributeError:
                        zestimate = 'null'
                        rent_zestimate = 'null'
                    try:
                        if (str(lot.split(" ")[1]) == "sqft"):
                            lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                        elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre")):
                            lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                        elif (lot == "No Data"):
                            lot_conversion_to_sqft = 'null'
                        else:
                            lot_conversion_to_sqft = 'null'
                    except IndexError:
                        lot_conversion_to_sqft = 'null'
                        
                    self.results.append({
                        'Listing_type': card.find('div', {'class': 'list-card-type'}).text,
                        'Price': card.find('div', {'class': 'list-card-price'}).text,
                        'Full_address': script_json['name'],
                        'Street': script_json['address']['streetAddress'],
                        'City': script_json['address']['addressLocality'],
                        'State': script_json['address']['addressRegion'],
                        'Zip_code': script_json['address']['postalCode'],
                        'Latitude': script_json['geo']['latitude'],
                        'Longitude': script_json['geo']['longitude'],
                        'Square_Feet': script_json['floorSize']['value'],
                        'Lot': lot,
                        'Lot_conversion_to_sqft': lot_conversion_to_sqft,
                        'House_type': house_type,
                        'Year_build': year_build,
                        'Parking': parking,
                        'Hoa': hoa,
                        'Zillow_price_per_sqft': zillow_price_per_sqft,
                        'Zestimate': zestimate,
                        'Rent_zestimate': rent_zestimate,
                        'House_website': script_json['url']
                    })
                    time.sleep(3)
                
    def to_csv(self):
        dirName = 'Output/Zillow/'
        if not os.path.exists(dirName):
            os.mkdir(dirName)
            print("Directory ", dirName, " Folder created ")
        else:
            print("Directory ", dirName, " Folder already exists")
            
        with open('./' + dirName + 'Q3-2020_Apartment_page17-20.csv', 'w') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            
            for row in self.results:
                writer.writerow(row)

    def to_dftable(self):
        house_data = pd.DataFrame(self.results)
        print(house_data)

#     Filter Out Coming Soon, Auction, Home Type: Apartment, Days On Zillow: 90 Days
    def run(self):
        url = 'https://www.zillow.com/ca/duplex/'
        for page in range(17,21):
            params = {
                'searchQueryState':'{"pagination":{},"usersSearchTerm":"ca","mapBounds":{"west":-152.089851125,"east":-86.523444875,"south":14.485661126627711,"north":55.01789701556767},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":4,"filterState":{"isPreMarketForeclosure":{"value":false},"isPreMarketPreForeclosure":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"isSingleFamily":{"value":false},"isManufactured":{"value":false},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
            }
            res = self.fetch(url, params)
            self.parse(res.text)
            time.sleep(2)
        self.to_dftable()
        self.to_csv()
        
if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run();
# Out:
# 200
# Type:Multiple Occupancy
# Year built:1903
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$330
# Type:Multiple Occupancy
# Year built:1951
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$170
# Type:Multiple Occupancy
# Year built:1980
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$222
# Type:Multiple Occupancy
# Year built:1988
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$261
# Type:Multiple Occupancy
# Year built:1935
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$512
# Type:Multiple Occupancy
# Year built:1976
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$423
# Type:Multiple Occupancy
# Year built:1911
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$361
# Type:Multiple Occupancy
# Year built:1959
# Heating:Wall, Gas
# Cooling:Evaporative
# Parking:No Data
# Price/sqft:$111
# Type:Multiple Occupancy
# Year built:1952
# Heating:Electric, Gas
# Cooling:Evaporative
# Parking:3 spaces
# Price/sqft:$178
# Type:Multiple Occupancy
# Year built:1900
# Heating:Wall, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$342
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall, Electric, Gas
# Cooling:None
# Parking:8 spaces
# Price/sqft:$127
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:7 spaces
# Price/sqft:$649
# Type:Multiple Occupancy
# Year built:1958
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Type:Multiple Occupancy
# Year built:1987
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$504
# Type:Multiple Occupancy
# Year built:1959
# Heating:No Data
# Cooling:None
# Parking:4 spaces
# Price/sqft:$306
# Type:Multiple Occupancy
# Year built:1985
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$281
# Type:Multiple Occupancy
# Year built:1953
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$599
# Type:Multiple Occupancy
# Year built:1895
# Heating:Wall
# Cooling:None
# Parking:3 spaces
# Price/sqft:$268
# Type:Multiple Occupancy
# Year built:1914
# Heating:No Data
# Cooling:None
# Parking:6 spaces
# Price/sqft:$384
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$591
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$339
# Type:Multiple Occupancy
# Year built:1913
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$888
# Type:Multiple Occupancy
# Year built:1951
# Heating:None, Wall
# Cooling:Wall
# Parking:1 space
# Price/sqft:$2,072
# Type:Multiple Occupancy
# Year built:1924
# Heating:Gas
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$414
# Type:Multiple Occupancy
# Year built:1992
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$574
# Type:Multiple Occupancy
# Year built:1925
# Heating:Baseboard, Wall, Gas
# Cooling:Evaporative, Wall
# Parking:2 spaces
# Price/sqft:$81
# Type:Multiple Occupancy
# Year built:1948
# Heating:Wall
# Cooling:No Data
# Parking:5 spaces
# Price/sqft:$110
# Type:Multiple Occupancy
# Year built:1991
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1949
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$452
# Type:Multiple Occupancy
# Year built:1950
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# Price/sqft:$428
# Type:Multiple Occupancy
# Year built:1986
# Heating:Wall
# Cooling:No Data
# Parking:No Data
# Price/sqft:$99
# 200
# Type:Multiple Occupancy
# Year built:1903
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$330
# Type:Multiple Occupancy
# Year built:1951
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$170
# Type:Multiple Occupancy
# Year built:1980
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$222
# Type:Multiple Occupancy
# Year built:1988
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$261
# Type:Multiple Occupancy
# Year built:1935
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$512
# Type:Multiple Occupancy
# Year built:1976
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$423
# Type:Multiple Occupancy
# Year built:1911
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$361
# Type:Multiple Occupancy
# Year built:1959
# Heating:Wall, Gas
# Cooling:Evaporative
# Parking:No Data
# Price/sqft:$111
# Type:Multiple Occupancy
# Year built:1952
# Heating:Electric, Gas
# Cooling:Evaporative
# Parking:3 spaces
# Price/sqft:$178
# Type:Multiple Occupancy
# Year built:1900
# Heating:Wall, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$342
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall, Electric, Gas
# Cooling:None
# Parking:8 spaces
# Price/sqft:$127
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:7 spaces
# Price/sqft:$649
# Type:Multiple Occupancy
# Year built:1958
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Type:Multiple Occupancy
# Year built:1987
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$504
# Type:Multiple Occupancy
# Year built:1959
# Heating:No Data
# Cooling:None
# Parking:4 spaces
# Price/sqft:$306
# Type:Multiple Occupancy
# Year built:1985
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$281
# Type:Multiple Occupancy
# Year built:1953
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$599
# Type:Multiple Occupancy
# Year built:1895
# Heating:Wall
# Cooling:None
# Parking:3 spaces
# Price/sqft:$268
# Type:Multiple Occupancy
# Year built:1914
# Heating:No Data
# Cooling:None
# Parking:6 spaces
# Price/sqft:$384
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$591
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$339
# Type:Multiple Occupancy
# Year built:1913
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$888
# Type:Multiple Occupancy
# Year built:1951
# Heating:None, Wall
# Cooling:Wall
# Parking:1 space
# Price/sqft:$2,072
# Type:Multiple Occupancy
# Year built:1924
# Heating:Gas
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$414
# Type:Multiple Occupancy
# Year built:1992
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$574
# Type:Multiple Occupancy
# Year built:1925
# Heating:Baseboard, Wall, Gas
# Cooling:Evaporative, Wall
# Parking:2 spaces
# Price/sqft:$81
# Type:Multiple Occupancy
# Year built:1948
# Heating:Wall
# Cooling:No Data
# Parking:5 spaces
# Price/sqft:$110
# Type:Multiple Occupancy
# Year built:1991
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1949
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$452
# Type:Multiple Occupancy
# Year built:1950
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# Price/sqft:$428
# Type:Multiple Occupancy
# Year built:1986
# Heating:Wall
# Cooling:No Data
# Parking:No Data
# Price/sqft:$99
# 200
# Type:Multiple Occupancy
# Year built:1903
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$330
# Type:Multiple Occupancy
# Year built:1951
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$170
# Type:Multiple Occupancy
# Year built:1980
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$222
# Type:Multiple Occupancy
# Year built:1988
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$261
# Type:Multiple Occupancy
# Year built:1935
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$512
# Type:Multiple Occupancy
# Year built:1976
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$423
# Type:Multiple Occupancy
# Year built:1911
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$361
# Type:Multiple Occupancy
# Year built:1959
# Heating:Wall, Gas
# Cooling:Evaporative
# Parking:No Data
# Price/sqft:$111
# Type:Multiple Occupancy
# Year built:1952
# Heating:Electric, Gas
# Cooling:Evaporative
# Parking:3 spaces
# Price/sqft:$178
# Type:Multiple Occupancy
# Year built:1900
# Heating:Wall, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$342
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall, Electric, Gas
# Cooling:None
# Parking:8 spaces
# Price/sqft:$127
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:7 spaces
# Price/sqft:$649
# Type:Multiple Occupancy
# Year built:1958
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Type:Multiple Occupancy
# Year built:1987
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$504
# Type:Multiple Occupancy
# Year built:1959
# Heating:No Data
# Cooling:None
# Parking:4 spaces
# Price/sqft:$306
# Type:Multiple Occupancy
# Year built:1985
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$281
# Type:Multiple Occupancy
# Year built:1953
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$599
# Type:Multiple Occupancy
# Year built:1895
# Heating:Wall
# Cooling:None
# Parking:3 spaces
# Price/sqft:$268
# Type:Multiple Occupancy
# Year built:1914
# Heating:No Data
# Cooling:None
# Parking:6 spaces
# Price/sqft:$384
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$591
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$339
# Type:Multiple Occupancy
# Year built:1913
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$888
# Type:Multiple Occupancy
# Year built:1951
# Heating:None, Wall
# Cooling:Wall
# Parking:1 space
# Price/sqft:$2,072
# Type:Multiple Occupancy
# Year built:1924
# Heating:Gas
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$414
# Type:Multiple Occupancy
# Year built:1992
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$574
# Type:Multiple Occupancy
# Year built:1925
# Heating:Baseboard, Wall, Gas
# Cooling:Evaporative, Wall
# Parking:2 spaces
# Price/sqft:$81
# Type:Multiple Occupancy
# Year built:1948
# Heating:Wall
# Cooling:No Data
# Parking:5 spaces
# Price/sqft:$110
# Type:Multiple Occupancy
# Year built:1991
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1949
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$452
# Type:Multiple Occupancy
# Year built:1950
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# Price/sqft:$428
# Type:Multiple Occupancy
# Year built:1986
# Heating:Wall
# Cooling:No Data
# Parking:No Data
# Price/sqft:$99
# 200
# Type:Multiple Occupancy
# Year built:1903
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$330
# Type:Multiple Occupancy
# Year built:1951
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$170
# Type:Multiple Occupancy
# Year built:1988
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$261
# Type:Multiple Occupancy
# Year built:1935
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$512
# Type:Multiple Occupancy
# Year built:1976
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$423
# Type:Multiple Occupancy
# Year built:1911
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$361
# Type:Multiple Occupancy
# Year built:1959
# Heating:Wall, Gas
# Cooling:Evaporative
# Parking:No Data
# Price/sqft:$111
# Type:Multiple Occupancy
# Year built:1952
# Heating:Electric, Gas
# Cooling:Evaporative
# Parking:3 spaces
# Price/sqft:$178
# Type:Multiple Occupancy
# Year built:1900
# Heating:Wall, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$342
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall, Electric, Gas
# Cooling:None
# Parking:8 spaces
# Price/sqft:$127
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:7 spaces
# Price/sqft:$649
# Type:Multiple Occupancy
# Year built:1958
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Type:Multiple Occupancy
# Year built:1987
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$504
# Type:Multiple Occupancy
# Year built:1959
# Heating:No Data
# Cooling:None
# Parking:4 spaces
# Price/sqft:$306
# Type:Multiple Occupancy
# Year built:1985
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$281
# Type:Multiple Occupancy
# Year built:1953
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Type:Multiple Occupancy
# Year built:1924
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Price/sqft:$599
# Type:Multiple Occupancy
# Year built:1895
# Heating:Wall
# Cooling:None
# Parking:3 spaces
# Price/sqft:$268
# Type:Multiple Occupancy
# Year built:1914
# Heating:No Data
# Cooling:None
# Parking:6 spaces
# Price/sqft:$384
# Type:Multiple Occupancy
# Year built:1930
# Heating:Forced air, Gas
# Cooling:Wall
# Parking:No Data
# Price/sqft:$591
# Type:Multiple Occupancy
# Year built:1946
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Price/sqft:$339
# Type:Multiple Occupancy
# Year built:1913
# Heating:Wall
# Cooling:No Data
# Parking:2 spaces
# Price/sqft:$888
# Type:Multiple Occupancy
# Year built:1951
# Heating:None, Wall
# Cooling:Wall
# Parking:1 space
# Price/sqft:$2,072
# Type:Multiple Occupancy
# Year built:1924
# Heating:Gas
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$414
# Type:Multiple Occupancy
# Year built:1992
# Heating:No Data
# Cooling:No Data
# Parking:3 spaces
# Price/sqft:$574
# Type:Multiple Occupancy
# Year built:1925
# Heating:Baseboard, Wall, Gas
# Cooling:Evaporative, Wall
# Parking:2 spaces
# Price/sqft:$81
# Type:Multiple Occupancy
# Year built:1948
# Heating:Wall
# Cooling:No Data
# Parking:5 spaces
# Price/sqft:$110
# Type:Multiple Occupancy
# Year built:1991
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$392
# Type:Multiple Occupancy
# Year built:1949
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Price/sqft:$452
# Type:Multiple Occupancy
# Year built:1950
# Heating:Wall
# Cooling:Wall
# Parking:2 spaces
# Price/sqft:$428
# Type:Multiple Occupancy
# Year built:1986
# Heating:Wall
# Cooling:No Data
# Parking:No Data
# Price/sqft:$99
#                    Listing_type       Price  \
# 0    Multi-family home for sale    $559,990
# 1    Multi-family home for sale    $269,900
# 2    Multi-family home for sale    $385,000
# 3    Multi-family home for sale    $429,000
# 4    Multi-family home for sale    $519,000
# ..                          ...         ...
# 126  Multi-family home for sale    $559,000
# 127  Multi-family home for sale    $639,000
# 128  Multi-family home for sale  $1,169,000
# 129  Multi-family home for sale    $635,000
# 130  Multi-family home for sale    $299,900
#
#                                           Full_address  \
# 0                 403 E 43rd St, Los Angeles, CA 90011
# 1                   704 N Garden St, Visalia, CA 93291
# 2                 627 S Teakwood Ave, Rialto, CA 92376
# 3                24084 Falconer Dr, Murrieta, CA 92562
# 4               675 Leonard Ave, Los Angeles, CA 90022
# ..                                                 ...
# 126               918 E 76th St, Los Angeles, CA 90001
# 127  16256 Avenida Venusto Unit A, San Diego, CA 92128
# 128                3908 E 5th St, Long Beach, CA 90814
# 129             6023 Allston St, Los Angeles, CA 90022
# 130                3454 Oak Creek Rd, Mojave, CA 93501
#
#                            Street         City State Zip_code   Latitude  \
# 0                   403 E 43rd St  Los Angeles    CA    90011  34.005935
# 1                 704 N Garden St      Visalia    CA    93291  36.337271
# 2              627 S Teakwood Ave       Rialto    CA    92376  34.110889
# 3               24084 Falconer Dr     Murrieta    CA    92562  33.590358
# 4                 675 Leonard Ave  Los Angeles    CA    90022  34.019822
# ..                            ...          ...   ...      ...        ...
# 126                 918 E 76th St  Los Angeles    CA    90001  33.970932
# 127  16256 Avenida Venusto UNIT A    San Diego    CA    92128  33.009822
# 128                 3908 E 5th St   Long Beach    CA    90814  33.772341
# 129               6023 Allston St  Los Angeles    CA    90022  34.016429
# 130             3454 Oak Creek Rd       Mojave    CA    93501  35.053510
#
#       Longitude Square_Feet   Lot Lot_conversion_to_sqft          House_type  \
# 0   -118.268326       1,697  null                   null  Multiple Occupancy
# 1   -119.289813       1,590  null                   null  Multiple Occupancy
# 2   -117.389328       1,735  null                   null  Multiple Occupancy
# 3   -117.201181       1,646  null                   null  Multiple Occupancy
# 4   -118.142653       1,013  null                   null  Multiple Occupancy
# ..          ...         ...   ...                    ...                 ...
# 126 -118.257895       5,103  null                   null  Multiple Occupancy
# 127 -117.075797       1,632  null                   null  Multiple Occupancy
# 128 -118.146896       2,587  null                   null  Multiple Occupancy
# 129 -118.143266       1,484  null                   null  Multiple Occupancy
# 130 -118.194400       3,044  null                   null  Multiple Occupancy
#
#     Year_build   Parking   Hoa Zillow_price_per_sqft Zestimate Rent_zestimate  \
# 0         1903  2 spaces  null                  $330  $559,991      $2,700/mo
# 1         1951  2 spaces  null                  $170  $175,129      $1,250/mo
# 2         1980  4 spaces  null                  $222  $385,003      $2,050/mo
# 3         1988  2 spaces  null                  $261  $420,953      $2,400/mo
# 4         1935  2 spaces  null                  $512  $527,752      $2,085/mo
# ..         ...       ...   ...                   ...       ...            ...
# 126       1948  5 spaces  null                  $110  $501,662      $2,595/mo
# 127       1991  4 spaces  null                  $392  $659,734      $2,900/mo
# 128       1949  4 spaces  null                  $452  $974,378      $2,488/mo
# 129       1950  2 spaces  null                  $428  $519,396      $2,225/mo
# 130       1986   No Data  null                   $99  $244,743        $970/mo
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/403-E-43rd-...
# 1    https://www.zillow.com/homedetails/704-N-Garde...
# 2    https://www.zillow.com/homedetails/627-S-Teakw...
# 3    https://www.zillow.com/homedetails/24084-Falco...
# 4    https://www.zillow.com/homedetails/675-Leonard...
# ..                                                 ...
# 126  https://www.zillow.com/homedetails/918-E-76th-...
# 127  https://www.zillow.com/homedetails/16256-Aveni...
# 128  https://www.zillow.com/homedetails/3908-E-5th-...
# 129  https://www.zillow.com/homedetails/6023-Allsto...
# 130  https://www.zillow.com/homedetails/3454-Oak-Cr...
#
# [131 rows x 20 columns]
# Directory  Output/Zillow/  Folder already exists
