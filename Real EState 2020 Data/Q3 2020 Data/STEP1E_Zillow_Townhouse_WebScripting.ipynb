# %%
# Tutorial: https://www.youtube.com/watch?v=dRcvJRmqFHQ&lc=UgyUDvoIA0A37EWWoC54AaABAg.9Aem3mXGQzz9Aep5dNrAY6
import requests
from bs4 import BeautifulSoup
import json
import time
import csv
import pandas as pd
import os

class ZillowScraper():
    results = []
    headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'zguid=23|%24d7ce356c-e3c5-4a48-85b3-61d0af33c3a1; zgsession=1|76ac70ba-62bc-4f77-81a1-b46b55a3f268; _ga=GA1.2.656681018.1593695925; _gid=GA1.2.1901059192.1593695925; zjs_user_id=null; zjs_anonymous_id=%22d7ce356c-e3c5-4a48-85b3-61d0af33c3a1%22; _pxvid=930c8230-bc66-11ea-9dd2-0242ac120007; _gcl_au=1.1.2002891296.1593696177; KruxPixel=true; DoubleClickSession=true; _pin_unauth=dWlkPU9EbG1aR0ptTTJVdFkySXpPUzAwWVdZMUxXSTFNVE10TnpFNE1EZGpOamxsWWpZNQ; _fbp=fb.1.1593696180071.236888825; KruxAddition=true; g_state={"i_p":1593716288950,"i_l":1}; JSESSIONID=0C394BB3DC7B91E479B72A328353817A; GASession=true; _pxff_bsco=1; AWSALB=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; AWSALBCORS=ICqV1IKa+cj8ecut5WcXnUJCq3pP//RbqBzZ49F9UxNm0bLvluUKA3yHj1v2AbnyZ74OnEhFTZXZYd39kdbddeIij3ZzH2d20INkvIhGwFyGR+evOyhe+uUmhlil; search=6|1596363321838%7Crect%3D43.45764218649565%252C-109.08936284375%252C30.85123360186431%252C-129.52393315625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D0%26days%3D90%26type%3Dhouse%26lt%3Dfsba%252Cfsbo%252Cfore%252Cnew%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%09%099%09%09%09%09%09%09; _px3=d4336234c4010c751aebc89c46325b0fb974e47215ce19445dfb759a629e81dc:X7e2f9pB1glpxKBrZ31UbYr/SXJFF+UxNWu+hiMsI+DQ7Mqle+9ez9SpkHaEa0n8KjNaAtb3oFQCfBoM9SkdFQ==:1000:AfuabQEQyo2l//8QKend7zOjb5sDW5Is+c6zQcm/upUYyYJc1jNQiyYnwroZOcBIjJBNJ8+vUKEJ3TlBoNaX/O7UbA0YkImLQb+VkAlAZWRj+w8lmqxZjshBeq6rrIg7GVsOSD+a1N8QtabSrjTIOF1SbQdGaZFzwVUu+aT6YiQ=; _uetsid=b093ce5e-93c4-0334-9c39-42ee7af2a929; _uetvid=e59e74ae-427f-984f-1765-cdc49ba1fa47',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    }
        
    def fetch(self, url, params):
        response = requests.get(url, headers=self.headers, params=params)
        print(response.status_code)
        return response
    
    def parse(self, response):
        content = BeautifulSoup(response, 'lxml')
        deck = content.find('ul', {'class': 'photo-cards photo-cards_wow photo-cards_short'})
        for card in deck.contents:
            script = card.find('script', {'type': 'application/ld+json'})
            if script:
                script_json = json.loads(script.contents[0])
                try:
                    latitude = script_json['geo']['latitude']
                    longitude = script_json['geo']['longitude']
                except KeyError:
                    latitude = 'null'
                    longitude = 'null'
                except AttributeError:
                    latitude = 'null'
                    longitude = 'null'
                loop_response = requests.get(script_json['url'], headers=self.headers)
                loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
                try:
                    loop_result2 = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[1].findAll('li', class_="ds-home-fact-list-item")
                except IndexError:
                    loop_result2 = 'null'
                lot = 'null';
                house_type = 'null';
                year_build = 'null';
                parking = 'null';
                hoa = 'null';
                lot_conversion_to_sqft = 'null';
                zillow_price_per_sqft = 'null';
                
                if loop_result2:
                    for contents in loop_result2:
                        try:
                            print(contents.text)
                            if "Lot" in contents.text.split(":")[0]:
                                lot = contents.text.split(":")[1];
                            if "Type" in contents.text.split(":")[0]:
                                house_type = contents.text.split(":")[1];
                            if "Year built" in contents.text.split(":")[0]:
                                year_build = contents.text.split(":")[1];
                            if "Parking" in contents.text.split(":")[0]:
                                parking = contents.text.split(":")[1];
                            if "HOA" in contents.text.split(":")[0]:
                                hoa = contents.text.split(":")[1];
                            if "Price/sqft" in contents.text.split(":")[0]:
                                zillow_price_per_sqft = contents.text.split(":")[1];
                        except AttributeError:
                            continue
                
                    try:
                        zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[2].find('p', class_="Text-aiai24-0 sc-fzoxKX sc-oTpqt loFLRQ").text
                        rent_zestimate = loop_soup.findAll('div', class_="ds-expandable-card-section-default-padding")[4].find('p', class_="Text-aiai24-0 sc-fzoxKX sc-oTpqt loFLRQ").text
                    except:
                        zestimate = 'null'
                        rent_zestimate = 'null'
                    try:
                        if (str(lot.split(" ")[1]) == "sqft"):
                            lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                        elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre") or (str(lot.split(" ")[1]) == "Acres") or (str(lot.split(" ")[1]) == "Acre")):
                            lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                        elif (lot == "No Data"):
                            lot_conversion_to_sqft = 'null'
                        else:
                            lot_conversion_to_sqft = 'null'
                    except IndexError:
                        lot_conversion_to_sqft = 'null'
                        
                    self.results.append({
                        'Listing_type': card.find('div', {'class': 'list-card-type'}).text,
                        'Price': card.find('div', {'class': 'list-card-price'}).text,
                        'Full_address': script_json['name'],
                        'Street': script_json['address']['streetAddress'],
                        'City': script_json['address']['addressLocality'],
                        'State': script_json['address']['addressRegion'],
                        'Zip_code': script_json['address']['postalCode'],
                        'Latitude': latitude,
                        'Longitude': longitude,
                        'Square_Feet': script_json['floorSize']['value'],
                        'Lot': lot,
                        'Lot_conversion_to_sqft': lot_conversion_to_sqft,
                        'House_type': house_type,
                        'Year_build': year_build,
                        'Parking': parking,
                        'Hoa': hoa,
                        'Zillow_price_per_sqft': zillow_price_per_sqft,
                        'Zestimate': zestimate,
                        'Rent_zestimate': rent_zestimate,
                        'House_website': script_json['url']
                    })
                    time.sleep(3)
                
    def to_csv(self):
        dirName = 'Output/Zillow/'
        if not os.path.exists(dirName):
            os.mkdir(dirName)
            print("Directory ", dirName, " Folder created ")
        else:
            print("Directory ", dirName, " Folder already exists")
            
        with open('./' + dirName + 'Q3-2020_Townhouse_Data_page17-20.csv', 'w') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            
            for row in self.results:
                writer.writerow(row)

    def to_dftable(self):
        house_data = pd.DataFrame(self.results)
        print(house_data)

#     Filter Out Coming Soon, Auction, Home Type: Townhomes, Days On Zillow: 90 Days
    def run(self):
        url = 'https://www.zillow.com/ca/townhomes/'
        for page in range(17,21):
            params = {
                'searchQueryState':'{"pagination":{"currentPage":%s},"usersSearchTerm":"ca","mapBounds":{"west":-153.847663625,"east":-84.765632375,"south":12.777434491046995,"north":56.013075839104054},"mapZoom":4,"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"filterState":{"isPreMarketPreForeclosure":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"isSingleFamily":{"value":false},"isManufactured":{"value":false},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isLotLand":{"value":false},"doz":{"value":"90"},"isApartment":{"value":false},"isPreMarketForeclosure":{"value":false}},"isListVisible":true}' %page
            }
            res = self.fetch(url, params)
            self.parse(res.text)
            time.sleep(2)
        self.to_dftable()
        self.to_csv()
        
if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run();
# Out:
# 200
# Type:Townhouse
# Year built:1980
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,751 sqft
# Price/sqft:$321
# Type:Townhouse
# Year built:2012
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:1,406 sqft
# Price/sqft:$300
# Type:Townhouse
# Year built:1944
# Heating:Wall, Electric
# Cooling:None
# Parking:1 space
# Lot:9.98 Acres
# Price/sqft:$495
# Type:Townhouse
# Year built:1992
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:2.56 Acres
# Price/sqft:$458
# Type:Townhouse
# Year built:1967
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:2,178 sqft
# Price/sqft:$249
# Type:Townhouse
# Year built:1986
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Lot:10,341 sqft
# Price/sqft:$574
# Type:Townhouse
# Year built:1977
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,542 sqft
# Price/sqft:$373
# Type:Townhouse
# Year built:1993
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Lot:1,241 sqft
# Price/sqft:$491
# Type:Townhouse
# Year built:1972
# Heating:Wall, Electric
# Cooling:None
# Parking:2 spaces
# Lot:2,596 sqft
# Price/sqft:$396
# Type:Townhouse
# Year built:1986
# Heating:Forced air, Gas
# Cooling:No Data
# Parking:4 spaces
# Lot:4.64 Acres
# Price/sqft:$649
# Type:Townhouse
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:2,121 sqft
# Price/sqft:$331
# Type:Townhouse
# Year built:1980
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# Lot:7,318 sqft
# Price/sqft:$524
# Type:Townhouse
# Year built:1973
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,254 sqft
# Price/sqft:$602
# Type:Townhouse
# Year built:1973
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:3.14 Acres
# Price/sqft:$667
# Type:Townhouse
# Year built:1982
# Heating:Gas
# Cooling:No Data
# Parking:4 spaces
# Lot:7,792 sqft
# Price/sqft:$451
# Type:Townhouse
# Year built:1976
# Heating:Forced air, Electric, Gas
# Cooling:Other
# Parking:2 spaces
# Lot:0.38 Acres
# Price/sqft:$377
# Type:Townhouse
# Year built:1984
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:7,501 sqft
# Price/sqft:$801
# Type:Townhouse
# Year built:2019
# Heating:Wall, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:6,037 sqft
# Price/sqft:$794
# Type:Townhouse
# Year built:1980
# Heating:Forced air, Gas
# Cooling:None
# Parking:2 spaces
# Lot:4.54 Acres
# Price/sqft:$506
# Type:Townhouse
# Year built:1988
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,319 sqft
# Price/sqft:$437
# Type:Townhouse
# Year built:1977
# Heating:Forced air, Electric, Gas
# Cooling:None
# Parking:6 spaces
# Lot:5,488 sqft
# Price/sqft:$588
# Type:Townhouse
# Year built:1971
# Heating:Forced air
# Cooling:Wall
# Parking:1 space
# Lot:453 sqft
# Price/sqft:$655
# Type:Townhouse
# Year built:1983
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:2.64 Acres
# Price/sqft:$328
# Type:Townhouse
# Year built:1974
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:3 spaces
# Lot:1,600 sqft
# Price/sqft:$424
# Type:Townhouse
# Year built:1975
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:5 Acres
# Price/sqft:$406
# Type:Townhouse
# Year built:1972
# Heating:Forced air, Gas
# Cooling:None
# Parking:No Data
# Lot:7,474 sqft
# Price/sqft:$508
# Type:Townhouse
# Year built:1976
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Lot:3,920 sqft
# Price/sqft:$364
# Type:Townhouse
# Year built:2020
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$509
# Type:Townhouse
# Year built:2019
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,916 sqft
# Price/sqft:$417
# Type:Townhouse
# Year built:1972
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# Lot:1,006 sqft
# Price/sqft:$497
# Type:Townhouse
# Year built:1980
# Heating:Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1.36 Acres
# Price/sqft:$397
# Type:Townhouse
# Year built:1984
# Heating:No Data
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$500
# Type:Townhouse
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# Lot:3,920 sqft
# Price/sqft:$423
# Type:Townhouse
# Year built:1990
# Heating:Forced air, Electric
# Cooling:Central
# Parking:1 space
# Lot:566 sqft
# Price/sqft:$227
# 200
# Type:Townhouse
# Year built:1980
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:3.31 Acres
# Price/sqft:$431
# Type:Townhouse
# Year built:1973
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# Lot:6.87 Acres
# Price/sqft:$345
# Type:Townhouse
# Year built:1984
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,576 sqft
# Price/sqft:$184
# Type:Townhouse
# Year built:1990
# Heating:Forced air, Gas
# Cooling:Wall
# Parking:No Data
# Lot:2,387 sqft
# Price/sqft:$848
# Type:Townhouse
# Year built:2017
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$909
# Type:Townhouse
# Year built:1991
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:6,207 sqft
# Price/sqft:$1,011
# Type:Townhouse
# Year built:1989
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,772 sqft
# Price/sqft:$375
# Type:Townhouse
# Year built:1982
# Heating:Forced air, Electric
# Cooling:None
# Parking:2 spaces
# Lot:1,724 sqft
# Price/sqft:$466
# Type:Townhouse
# Year built:1987
# Heating:Forced air, Electric, Gas
# Cooling:None
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$571
# Type:Townhouse
# Year built:1964
# Heating:Other, Gas
# Cooling:No Data
# Parking:No Data
# Lot:531 sqft
# Price/sqft:$835
# Type:Townhouse
# Year built:1973
# Heating:Forced air
# Cooling:No Data
# Parking:2 spaces
# Lot:2 Acres
# Price/sqft:$477
# Type:Townhouse
# Year built:1974
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:0.38 Acres
# Price/sqft:$804
# Type:Townhouse
# Year built:1970
# Heating:Forced air, Gas
# Cooling:None
# Parking:No Data
# Lot:2,051 sqft
# Price/sqft:$491
# Type:Townhouse
# Year built:1990
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Lot:560 sqft
# Price/sqft:$637
# Type:Townhouse
# Year built:1974
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Lot:2,047 sqft
# Price/sqft:$415
# Type:Townhouse
# Year built:1974
# Heating:Forced air, Electric
# Cooling:No Data
# Parking:2 spaces
# Lot:7.68 Acres
# Price/sqft:$511
# Type:Townhouse
# Year built:2015
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:0.32 Acres
# Price/sqft:$934
# Type:Townhouse
# Year built:2018
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$429
# Type:Townhouse
# Year built:1964
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# Lot:6.40 Acres
# Price/sqft:$324
# Type:Townhouse
# Year built:1993
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,306 sqft
# Price/sqft:$269
# Type:Townhouse
# Year built:2014
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,276 sqft
# Price/sqft:$695
# Type:Townhouse
# Year built:2011
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$361
# Type:Townhouse
# Year built:1980
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:4.85 Acres
# Price/sqft:$459
# Type:Townhouse
# Year built:1973
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Lot:315 sqft
# Price/sqft:$741
# Type:Townhouse
# Year built:2001
# Heating:None, Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1.49 Acres
# Price/sqft:$588
# Type:Townhouse
# Year built:1980
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:9.26 Acres
# Price/sqft:$563
# Type:Townhouse
# Year built:1989
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:0.51 Acres
# Price/sqft:$590
# Type:Townhouse
# Year built:2005
# Heating:No Data
# Cooling:No Data
# Parking:2 spaces
# Lot:1,041 sqft
# Price/sqft:$384
# Type:Townhouse
# Year built:1986
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:6,011 sqft
# Price/sqft:$598
# Type:Townhouse
# Year built:2015
# Heating:Forced air, Other
# Cooling:Central
# Parking:2 spaces
# Lot:644 sqft
# Price/sqft:$565
# Type:Townhouse
# Year built:1969
# Heating:Forced air, Electric, Gas
# Cooling:Wall
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$338
# 200
# Type:Townhouse
# Year built:1991
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:7,139 sqft
# Price/sqft:$768
# Type:Townhouse
# Year built:2002
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,502 sqft
# Price/sqft:$464
# Type:Townhouse
# Year built:1999
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:4.31 Acres
# Price/sqft:$573
# Type:Townhouse
# Year built:2015
# Heating:Forced air
# Cooling:Central
# Parking:4 spaces
# Lot:7,535 sqft
# Price/sqft:$862
# Type:Townhouse
# Year built:1980
# Heating:None, Forced air
# Cooling:Central
# Parking:1 space
# Lot:435 sqft
# Price/sqft:$253
# Type:Townhouse
# Year built:1983
# Heating:Other
# Cooling:No Data
# Parking:2 spaces
# Lot:7,265 sqft
# Price/sqft:$421
# Type:Townhouse
# Year built:1971
# Heating:Forced air, Gas
# Cooling:None
# Parking:No Data
# Lot:2,500 sqft
# Price/sqft:$792
# Type:Townhouse
# Year built:1995
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Lot:3,049 sqft
# Price/sqft:$478
# Type:Townhouse
# Year built:1979
# Heating:Forced air, Gas
# Cooling:None
# Parking:2 spaces
# Lot:0.88 Acres
# Price/sqft:$370
# Type:Townhouse
# Year built:1979
# Heating:Forced air, Gas
# Cooling:None
# Parking:No Data
# Lot:7.83 Acres
# Price/sqft:$729
# Type:Townhouse
# Year built:2016
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:905 sqft
# Price/sqft:$400
# Type:Townhouse
# Year built:2019
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$374
# Type:Townhouse
# Year built:1992
# Heating:No Data
# Cooling:Central
# Parking:2 spaces
# Lot:3,467 sqft
# Price/sqft:$368
# Type:Townhouse
# Year built:2008
# Heating:Forced air, Gas
# Cooling:No Data
# Parking:2 spaces
# Lot:2,400 sqft
# Price/sqft:$945
# Type:Townhouse
# Year built:1986
# Heating:Forced air
# Cooling:None
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$453
# Type:Townhouse
# Year built:2001
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,001 sqft
# Price/sqft:$410
# Type:Townhouse
# Year built:1966
# Heating:Baseboard
# Cooling:None
# Parking:No Data
# Lot:981 sqft
# Price/sqft:$1,611
# Type:Townhouse
# Year built:1972
# Heating:Electric
# Cooling:No Data
# Parking:3 spaces
# Lot:6.92 Acres
# Price/sqft:$462
# Type:Townhouse
# Year built:2006
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:0.88 Acres
# Price/sqft:$295
# Type:Townhouse
# Year built:1986
# Heating:Forced air, Electric
# Cooling:Central
# Parking:4 spaces
# Lot:2,500 sqft
# Price/sqft:$553
# Type:Townhouse
# Year built:1965
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,319 sqft
# Price/sqft:$353
# Type:Townhouse
# Year built:1971
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,894 sqft
# Price/sqft:$391
# Type:Townhouse
# Year built:1986
# Heating:Wall, Electric, Gas
# Cooling:None
# Parking:2 spaces
# Lot:3,606 sqft
# Price/sqft:$518
# Type:Townhouse
# Year built:2020
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$608
# Type:Townhouse
# Year built:2004
# Heating:Forced air, Electric
# Cooling:Central
# Parking:1 space
# Lot:No Data
# Price/sqft:$329
# Type:Townhouse
# Year built:1980
# Heating:Forced air
# Cooling:Central
# Parking:1 space
# Lot:1,400 sqft
# Price/sqft:$507
# Type:Townhouse
# Year built:2018
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$272
# Type:Townhouse
# Year built:1990
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Lot:2,700 sqft
# Price/sqft:$454
# Type:Townhouse
# Year built:1984
# Heating:Forced air, Electric
# Cooling:Central
# Parking:2 spaces
# Lot:2,178 sqft
# Price/sqft:$232
# Type:Townhouse
# Year built:2008
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:3 spaces
# Lot:6,970 sqft
# Price/sqft:$799
# 200
# Type:Townhouse
# Year built:1961
# Heating:Wall
# Cooling:None
# Parking:2 spaces
# Lot:2.86 Acres
# Price/sqft:$874
# Type:Townhouse
# Year built:1999
# Heating:Other
# Cooling:Central
# Parking:2 spaces
# Lot:0.39 Acres
# Price/sqft:$481
# Type:Townhouse
# Year built:1972
# Heating:Forced air, Gas
# Cooling:None
# Parking:2 spaces
# Lot:1,337 sqft
# Price/sqft:$629
# Type:Townhouse
# Year built:2015
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:No Data
# Price/sqft:$480
# Type:Townhouse
# Year built:2006
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:2.11 Acres
# Price/sqft:$591
# Type:Townhouse
# Year built:2007
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:5,619 sqft
# Price/sqft:$510
# Type:Townhouse
# Year built:1986
# Heating:Stove, Gas
# Cooling:None
# Parking:4 spaces
# Lot:7,501 sqft
# Price/sqft:$894
# Type:Townhouse
# Year built:1976
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:2,609 sqft
# Price/sqft:$385
# Type:Townhouse
# Year built:2004
# Heating:Forced air, Gas
# Cooling:None
# Parking:2 spaces
# Lot:3,606 sqft
# Price/sqft:$525
# Type:Townhouse
# Year built:2007
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:7.23 Acres
# Price/sqft:$410
# Type:Townhouse
# Year built:1984
# Heating:Forced air, Gas
# Cooling:None
# Parking:2 spaces
# Lot:1,224 sqft
# Price/sqft:$279
# Type:Townhouse
# Year built:1998
# Heating:Forced air
# Cooling:No Data
# Parking:No Data
# Lot:2,613 sqft
# Type:Townhouse
# Year built:1990
# Heating:Forced air, Electric, Gas
# Cooling:None
# Parking:2 spaces
# Lot:0.39 Acres
# Price/sqft:$584
# Type:Townhouse
# Year built:1972
# Heating:Forced air, Gas
# Cooling:No Data
# Parking:2 spaces
# Lot:435 sqft
# Price/sqft:$563
# Type:Townhouse
# Year built:1976
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,729 sqft
# Price/sqft:$672
# Type:Townhouse
# Year built:1988
# Heating:Other
# Cooling:Central
# Parking:1 space
# Lot:0.25 Acres
# Price/sqft:$180
# Type:Townhouse
# Year built:2014
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:7,832 sqft
# Price/sqft:$369
# Type:Townhouse
# Year built:No Data
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,999 sqft
# Price/sqft:$566
# Type:Townhouse
# Year built:1979
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:8,267 sqft
# Price/sqft:$711
# Type:Townhouse
# Year built:1992
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:8,097 sqft
# Price/sqft:$397
# Type:Townhouse
# Year built:2005
# Heating:Forced air, Gas
# Cooling:Central
# Parking:4 spaces
# Lot:2,178 sqft
# Price/sqft:$392
# Type:Townhouse
# Year built:1977
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,846 sqft
# Price/sqft:$449
# Type:Townhouse
# Year built:1988
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:0.98 Acres
# Price/sqft:$374
# Type:Townhouse
# Year built:1992
# Heating:Forced air
# Cooling:Central
# Parking:3 spaces
# Lot:2,077 sqft
# Price/sqft:$419
# Type:Townhouse
# Year built:2005
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:0.40 Acres
# Price/sqft:$383
# Type:Townhouse
# Year built:1973
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:1,306 sqft
# Price/sqft:$245
# Type:Townhouse
# Year built:1988
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:4 spaces
# Lot:1,481 sqft
# Price/sqft:$521
# Type:Townhouse
# Year built:2018
# Heating:Electric, Solar
# Cooling:Central
# Parking:2 spaces
# Lot:1 Acres
# Price/sqft:$359
# Type:Townhouse
# Year built:1990
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Lot:390 sqft
# Price/sqft:$532
# Type:Townhouse
# Year built:No Data
# Heating:No Data
# Cooling:No Data
# Parking:No Data
# Lot:No Data
# Price/sqft:$644
# Type:Townhouse
# Year built:2009
# Heating:Forced air, Electric, Gas
# Cooling:Central
# Parking:4 spaces
# Lot:0.60 Acres
# Price/sqft:$306
# Type:Townhouse
# Year built:1984
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:3,358 sqft
# Price/sqft:$408
# Type:Townhouse
# Year built:1988
# Heating:Forced air
# Cooling:Other
# Parking:2 spaces
# Lot:7.34 Acres
# Price/sqft:$731
# Type:Townhouse
# Year built:2008
# Heating:Other
# Cooling:No Data
# Parking:2 spaces
# Lot:6,904 sqft
# Price/sqft:$751
# Type:Townhouse
# Year built:1988
# Heating:Forced air, Gas
# Cooling:Central
# Parking:2 spaces
# Lot:3,998 sqft
# Price/sqft:$469
# Type:Townhouse
# Year built:1985
# Heating:Forced air
# Cooling:Central
# Parking:2 spaces
# Lot:1,450 sqft
# Price/sqft:$290
#            Listing_type       Price  \
# 0    Townhouse for sale    $425,000
# 1    Townhouse for sale    $639,999
# 2    Townhouse for sale    $275,000
# 3    Townhouse for sale    $550,000
# 4    Townhouse for sale    $495,000
# ..                  ...         ...
# 126  Townhouse for sale    $975,000
# 127  Townhouse for sale    $745,000
# 128  Townhouse for sale  $1,625,000
# 129  Townhouse for sale    $999,000
# 130  Townhouse for sale    $420,998
#
#                                           Full_address  \
# 0        2791 Mcbride Ln Apt 136, Santa Rosa, CA 95403
# 1           1179 Swallowtail Way #70, Nipomo, CA 93444
# 2               447 1/2 E 234th Walk, Carson, CA 90745
# 3     12636 Springbrook Dr Unit C, San Diego, CA 92128
# 4                441 Hartnell Pl, Sacramento, CA 95825
# ..                                                 ...
# 126        1479 Quail View Cir, Walnut Creek, CA 94597
# 127   28711 Pacific Coast Hwy Apt 20, Malibu, CA 90265
# 128              10125 Sagebrush Ct, Truckee, CA 96161
# 129  3626 Paseo Vista Famosa, Rancho Santa Fe, CA 9...
# 130               11936 Ottawa Pl #87, Chino, CA 91710
#
#                              Street             City State Zip_code Latitude  \
# 0           2791 Mcbride Ln APT 136       Santa Rosa    CA    95403  38.4648
# 1          1179 Swallowtail Way #70           Nipomo    CA    93444  35.0282
# 2              447 1/2 E 234th Walk           Carson    CA    90745   33.813
# 3       12636 Springbrook Dr UNIT C        San Diego    CA    92128  32.9467
# 4                   441 Hartnell Pl       Sacramento    CA    95825  38.5678
# ..                              ...              ...   ...      ...      ...
# 126             1479 Quail View Cir     Walnut Creek    CA    94597  37.9163
# 127  28711 Pacific Coast Hwy APT 20           Malibu    CA    90265  34.0215
# 128              10125 Sagebrush Ct          Truckee    CA    96161  39.3089
# 129         3626 Paseo Vista Famosa  Rancho Santa Fe    CA    92091  32.9914
# 130             11936 Ottawa Pl #87            Chino    CA    91710  34.0365
#
#     Longitude Square_Feet         Lot Lot_conversion_to_sqft House_type  \
# 0    -122.731       1,324  1,751 sqft                   1751  Townhouse
# 1    -120.555       2,130  1,406 sqft                   1406  Townhouse
# 2    -118.266         556  9.98 Acres                 434729  Townhouse
# 3    -117.088       1,200  2.56 Acres                 111514  Townhouse
# 4    -121.415       1,986  2,178 sqft                   2178  Townhouse
# ..        ...         ...         ...                    ...        ...
# 126  -122.088       2,387  3,358 sqft                   3358  Townhouse
# 127  -118.798       1,019  7.34 Acres                 319730  Townhouse
# 128  -120.164       2,163  6,904 sqft                   6904  Townhouse
# 129  -117.215       2,129  3,998 sqft                   3998  Townhouse
# 130  -117.686       1,450  1,450 sqft                   1450  Townhouse
#
#     Year_build   Parking   Hoa Zillow_price_per_sqft   Zestimate  \
# 0         1980  2 spaces  null                  $321    $429,372
# 1         2012  2 spaces  null                  $300        null
# 2         1944   1 space  null                  $495        null
# 3         1992  2 spaces  null                  $458    $555,725
# 4         1967  2 spaces  null                  $249    $492,926
# ..         ...       ...   ...                   ...         ...
# 126       1984  2 spaces  null                  $408    $975,008
# 127       1988  2 spaces  null                  $731    $747,299
# 128       2008  2 spaces  null                  $751  $1,625,001
# 129       1988  2 spaces  null                  $469    $999,008
# 130       1985  2 spaces  null                  $290    $421,001
#
#     Rent_zestimate                                      House_website
# 0        $2,600/mo  https://www.zillow.com/homedetails/2791-Mcbrid...
# 1             null  https://www.zillow.com/homedetails/1179-Swallo...
# 2             null  https://www.zillow.com/homedetails/447-1-2-E-2...
# 3        $2,500/mo  https://www.zillow.com/homedetails/12636-Sprin...
# 4        $2,300/mo  https://www.zillow.com/homedetails/441-Hartnel...
# ..             ...                                                ...
# 126      $3,800/mo  https://www.zillow.com/homedetails/1479-Quail-...
# 127      $2,850/mo  https://www.zillow.com/homedetails/28711-Pacif...
# 128      $4,500/mo  https://www.zillow.com/homedetails/10125-Sageb...
# 129      $3,800/mo  https://www.zillow.com/homedetails/3626-Paseo-...
# 130      $2,195/mo  https://www.zillow.com/homedetails/11936-Ottaw...
#
# [131 rows x 20 columns]
# Directory  Output/Zillow/  Folder already exists
