# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
#Testing
scrape_link = 'https://www.apartments.com/apartments/ca/'

response = requests.get(scrape_link)
soup = BeautifulSoup(response.text, 'html.parser')
result = soup.find_all('div', class_="placardContainer")
result
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-a9a5eb1f3bc3> in <module>
#       2 scrape_link = 'https://www.apartments.com/apartments/ca/'
#       3
# ----> 4 response = requests.get(scrape_link)
#       5 soup = BeautifulSoup(response.text, 'html.parser')
#       6 result = soup.find_all('div', class_="placardContainer")
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     493
#     494         except (ProtocolError, socket.error) as err:
# --> 495             raise ConnectionError(err, request=request)
#     496
#     497         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))

# %%
#Set up list to hold response info
link_dict = []
all_property = []

# %%
scrape_link = 'https://www.apartments.com/apartments/ca/{}'
# Loop through x pages of the website with filter of Single House
for scrape_links in [scrape_link.format(page) for page in range(20,25)]:
    res = requests.get(scrape_links)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('article', class_="placard")
    
    # Loop through returned results
    for result in new_results:
        find_tag = result.find('a')['href']
        link_dict.append(find_tag)

for property_link in link_dict:
    res = requests.get(property_link)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('div', class_="mainWrapper")
    
    
    for result in new_results:
        try:
            # Identify and return property name of Rental Place
            property_name = result.find('h1', class_="propertyName")
            # Identify and return address information of Rental Place
            clean_property_name = property_name.text.strip().replace("\n", "")
            street_data = result.find('div', class_="propertyAddress")
            street = street_data.text.strip().replace("\n", "").replace("\r", "")
            street_address = street.split(",")
            city = " ".join(street_address[1].split())
            state = " ".join(street_address[2].split())[:2]
            zip_code = " ".join(street_address[2].split())[2:7]
            # Identify and return number of bedroom and price of Rental Place
            bedroom_container = result.find('div', class_="rentRollupContainer")
            all_the_rents = bedroom_container.findAll('span', class_="rentRollup")
            
            bedroom_info = []
            for rent_block in all_the_rents:
                
                bedroom_type = rent_block.find('span', class_="longText").text
                try:
                    price = re.search('\$.* ', rent_block.text)
                    price = price.group(0)[:-2]
                except:
                    price = ""
                
                bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
            
            rent_obj = {
                "Property_Name_Rent": clean_property_name,
                "City_Rent": city,
                "Type": "Apartment",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                
            }
            
            for item in bedroom_info:
                rent_obj[item["bedroom_type"]] = item["price"]
                

        
            all_property.append(rent_obj)
        except AttributeError as e:
            print(e)

# print(all_property)

# %%
house_data = pd.DataFrame(all_property)
house_data
# Out:
#     \r\n                        1 Bedroom\r\n                            –\r\n2 Bedrooms                      \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#     \r\n                        1 Bedroom\r\n                            –\r\n3 Bedrooms                      \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#     \r\n                        Studio\r\n                      \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#     \r\n                        Studio\r\n                            –\r\n3 Bedrooms                      \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#     1 Bedroom 2 Bedrooms 3 Bedrooms 4 Bedrooms  \
# 0     $2,356     $2,890         NaN        NaN
# 1     $1,849     $2,379     $3,424         NaN
# 2     $3,300                               NaN
# 3     $3,215     $3,800     $5,355         NaN
# 4     $2,180     $3,070                    NaN
# 5     $1,400     $1,805                    NaN
# 6     $2,655     $2,860     $4,080         NaN
# 7     $2,639     $3,765         NaN        NaN
# 8                $1,425                    NaN
# 9     $2,165     $2,745         NaN        NaN
# 10    $2,015     $2,700     $3,670         NaN
# 11    $1,425     $1,570         NaN        NaN
# 12    $2,725     $3,647     $5,583         NaN
# 13    $1,382     $1,502         NaN        NaN
# 14    $3,760     $4,625         NaN        NaN
# 15    $1,592     $2,319         NaN        NaN
# 16    $3,259     $3,519     $5,959         NaN
# 17    $1,897     $2,696         NaN        NaN
# 18    $1,985     $2,520     $2,826     $3,154
# 19    $2,718     $3,541                    NaN
# 20    $2,240     $2,905     $3,360         NaN
# 21    $3,410     $4,153         NaN        NaN
# 22    $1,925     $1,997         NaN        NaN
# 23    $2,735     $3,330                    NaN
# 24    $2,525     $3,318         NaN        NaN
# 25    $1,584     $2,058         NaN        NaN
# 26    $2,060     $2,795         NaN        NaN
# 27    $2,284     $2,874         NaN        NaN
# 28        NaN    $2,030     $2,415         NaN
# 29    $1,938     $2,511     $3,339         NaN
# ..        ...        ...        ...        ...
# 95    $2,570     $3,360     $6,024         NaN
# 96    $1,796     $2,557         NaN        NaN
# 97    $1,310     $1,380         NaN        NaN
# 98    $2,695     $3,429                    NaN
# 99    $1,670     $2,040         NaN        NaN
# 100   $2,832     $3,246     $4,288         NaN
# 101   $2,390     $2,945     $3,924         NaN
# 102   $2,430     $3,220         NaN        NaN
# 103   $2,625     $3,400         NaN        NaN
# 104   $2,500     $3,430         NaN        NaN
# 105                             NaN        NaN
# 106   $1,740     $2,045         NaN        NaN
# 107   $2,320     $2,480         NaN        NaN
# 108   $2,255     $2,630     $3,684         NaN
# 109   $2,950     $3,485                    NaN
# 110   $2,370     $2,925     $3,460         NaN
# 111   $1,482     $1,675     $2,235         NaN
# 112   $4,000     $7,875         NaN        NaN
# 113   $2,267     $2,945         NaN        NaN
# 114   $2,657     $3,828     $5,143         NaN
# 115   $2,285     $3,590                    NaN
# 116   $2,206     $3,190         NaN        NaN
# 117   $2,029     $2,573         NaN        NaN
# 118   $2,864     $3,389                    NaN
# 119   $2,857     $3,509                    NaN
# 120       NaN    $2,399     $2,899         NaN
# 121       NaN        NaN        NaN        NaN
# 122   $2,122     $2,586     $3,500         NaN
# 123   $2,453     $2,820     $3,078         NaN
# 124       NaN    $2,655     $3,690         NaN
#
#                                           Bedroom_Info         City_Rent  \
# 0    [{'bedroom_type': 'Studio', 'price': '$2,030 '...       Los Angeles
# 1    [{'bedroom_type': 'Studio', 'price': '$1,669 '...        Costa Mesa
# 2    [{'bedroom_type': 'Studio', 'price': ''}, {'be...          Berkeley
# 3    [{'bedroom_type': 'Studio', 'price': ''}, {'be...    West Hollywood
# 4    [{'bedroom_type': '1 Bedroom', 'price': '$2,18...    Woodland Hills
# 5    [{'bedroom_type': 'Studio', 'price': ''}, {'be...           La Mesa
# 6    [{'bedroom_type': '1 Bedroom', 'price': '$2,65...           Fremont
# 7    [{'bedroom_type': 'Studio', 'price': '$2,405 '...     Mountain View
# 8    [{'bedroom_type': '1 Bedroom', 'price': ''}, {...           Ontario
# 9    [{'bedroom_type': 'Studio', 'price': '$1,950 '...            Irvine
# 10   [{'bedroom_type': 'Studio', 'price': ''}, {'be...  Huntington Beach
# 11   [{'bedroom_type': '1 Bedroom', 'price': '$1,42...             Vista
# 12   [{'bedroom_type': '1 Bedroom', 'price': '$2,72...      Santa Monica
# 13   [{'bedroom_type': 'Studio', 'price': '$1,375 '...          Redlands
# 14   [{'bedroom_type': '1 Bedroom', 'price': '$3,76...       Playa Vista
# 15   [{'bedroom_type': 'Studio', 'price': '$1,542 '...           Anaheim
# 16   [{'bedroom_type': 'Studio', 'price': '$3,430 '...      Redwood City
# 17   [{'bedroom_type': 'Studio', 'price': ''}, {'be...       Aliso Viejo
# 18   [{'bedroom_type': '1 Bedroom', 'price': '$1,98...  Rancho Cucamonga
# 19   [{'bedroom_type': '1 Bedroom', 'price': '$2,71...          San Jose
# 20   [{'bedroom_type': 'Studio', 'price': '$1,905 '...         San Diego
# 21   [{'bedroom_type': '1 Bedroom', 'price': '$3,41...         Sunnyvale
# 22   [{'bedroom_type': '1 Bedroom', 'price': '$1,92...         Santa Ana
# 23   [{'bedroom_type': 'Studio', 'price': '$2,590 '...          San Jose
# 24   [{'bedroom_type': 'Studio', 'price': '$2,000 '...       Los Angeles
# 25   [{'bedroom_type': '1 Bedroom', 'price': '$1,58...            Corona
# 26   [{'bedroom_type': 'Studio', 'price': '$1,825 '...         San Diego
# 27   [{'bedroom_type': 'Studio', 'price': '$2,309 '...          Cerritos
# 28   [{'bedroom_type': '2 Bedrooms', 'price': '$2,0...           Ontario
# 29   [{'bedroom_type': 'Studio', 'price': '$1,849 '...         San Diego
# ..                                                 ...               ...
# 95   [{'bedroom_type': '1 Bedroom', 'price': '$2,57...       Los Angeles
# 96   [{'bedroom_type': 'Studio', 'price': '$1,741 '...            Irvine
# 97   [{'bedroom_type': '1 Bedroom', 'price': '$1,31...         Fair Oaks
# 98   [{'bedroom_type': 'Studio', 'price': '$2,130 '...       Los Angeles
# 99   [{'bedroom_type': '1 Bedroom', 'price': '$1,67...         Santa Ana
# 100  [{'bedroom_type': '1 Bedroom', 'price': '$2,83...          San Jose
# 101  [{'bedroom_type': 'Studio', 'price': ''}, {'be...            Dublin
# 102  [{'bedroom_type': 'Studio', 'price': '$2,075 '...         San Diego
# 103  [{'bedroom_type': '1 Bedroom', 'price': '$2,62...          Milpitas
# 104  [{'bedroom_type': '1 Bedroom', 'price': '$2,50...       Los Angeles
# 105  [{'bedroom_type': '1 Bedroom', 'price': ''}, {...       Santa Clara
# 106  [{'bedroom_type': '1 Bedroom', 'price': '$1,74...        Costa Mesa
# 107  [{'bedroom_type': '1 Bedroom', 'price': '$2,32...         Sunnyvale
# 108  [{'bedroom_type': '1 Bedroom', 'price': '$2,25...         San Diego
# 109  [{'bedroom_type': '1 Bedroom', 'price': '$2,95...         Sunnyvale
# 110  [{'bedroom_type': '1 Bedroom', 'price': '$2,37...        Pleasanton
# 111  [{'bedroom_type': 'Studio', 'price': '$1,399 '...  Rancho Cucamonga
# 112  [{'bedroom_type': 'Studio', 'price': '$3,200 '...      Santa Monica
# 113  [{'bedroom_type': 'Studio', 'price': '$2,361 '...          Pasadena
# 114  [{'bedroom_type': '1 Bedroom', 'price': '$2,65...    Marina Del Rey
# 115  [{'bedroom_type': 'Studio', 'price': '$1,750 '...       Los Angeles
# 116  [{'bedroom_type': 'Studio', 'price': '$2,101 '...          Glendale
# 117  [{'bedroom_type': '1 Bedroom', 'price': '$2,02...         San Diego
# 118  [{'bedroom_type': '1 Bedroom', 'price': '$2,86...         San Diego
# 119  [{'bedroom_type': '1 Bedroom', 'price': '$2,85...       Los Angeles
# 120  [{'bedroom_type': '2 Bedrooms', 'price': '$2,3...    Woodland Hills
# 121  [{'bedroom_type': '
#                         S...          Berkeley
# 122  [{'bedroom_type': 'Studio', 'price': '$1,995 '...           Anaheim
# 123  [{'bedroom_type': '1 Bedroom', 'price': '$2,45...           Fremont
# 124  [{'bedroom_type': '2 Bedrooms', 'price': '$2,6...            Irvine
#
#                                Property_Name_Rent State_Rent   Studio  \
# 0                                 Sakura Crossing         CA  $2,030
# 1                      27 Seventy Five Mesa Verde         CA  $1,669
# 2                                          Parker         CA
# 3                           Avalon West Hollywood         CA
# 4                                           Motif         CA      NaN
# 5           The Hills At Spring Street Apartments         CA
# 6                                  Avalon Fremont         CA      NaN
# 7                   eaves Mt. View at Middlefield         CA  $2,405
# 8                                 Mission Village         CA      NaN
# 9                      Park Place Apartment Homes         CA  $1,950
# 10                                           Luce         CA
# 11                      Sycamore Ridge Apartments         CA      NaN
# 12                                AO Santa Monica         CA      NaN
# 13                       Redlands Lawn and Tennis         CA  $1,375
# 14              Villas at Playa Vista - Montecito         CA      NaN
# 15                            The Mix at CTR City         CA  $1,542
# 16                         Indigo Apartment Homes         CA  $3,430
# 17                                         Vantis         CA
# 18          The Enclave at Homecoming Terra Vista         CA      NaN
# 19                          Avalon on the Alameda         CA      NaN
# 20                                  Pacific Ridge         CA  $1,905
# 21                                     Loft House         CA      NaN
# 22   The Californian Apartments-South Coast Metro         CA      NaN
# 23               Crescent Village Apartment Homes         CA  $2,590
# 24                                  Next on Sixth         CA  $2,000
# 25                                          One11         CA      NaN
# 26                                          IDEA1         CA  $1,825
# 27                               Sage at Cerritos         CA  $2,309
# 28                              Paseos at Ontario         CA      NaN
# 29                          Hanover Mission Gorge         CA  $1,849
# ..                                            ...        ...      ...
# 95                                   Palazzo East         CA      NaN
# 96                                    Sofi Irvine         CA  $1,741
# 97                          Eclipse 96 Apartments         CA      NaN
# 98                                       The 5550         CA  $2,130
# 99                                Artists Village         CA      NaN
# 100                                      Vista 99         CA      NaN
# 101                         Avalon Dublin Station         CA
# 102                                    Alexan ALX         CA  $2,075
# 103                                   Capitol 650         CA      NaN
# 104             Villas at Park La Brea Apartments         CA      NaN
# 105                       Spring Creek Apartments         CA      NaN
# 106                  Pinecreek Village Apartments         CA      NaN
# 107                                The Highlander         CA      NaN
# 108                                      Valentia         CA      NaN
# 109                         Avalon Silicon Valley         CA      NaN
# 110                                 Park Hacienda         CA      NaN
# 111                        Terra Vista Apartments         CA  $1,399
# 112                          Chelsea Santa Monica         CA  $3,200
# 113                        Avalon Del Mar Station         CA  $2,361
# 114                                Tierra del Rey         CA      NaN
# 115                                          Stoa         CA  $1,750
# 116               Brio Apartment Homes and Villas         CA  $2,101
# 117                               Olympus Corsair         CA      NaN
# 118                                        Strata         CA      NaN
# 119                                        Accent         CA      NaN
# 120                       Summit at Warner Center         CA      NaN
# 121                              Varsity Berkeley         CA      NaN
# 122                   Jefferson Platinum Triangle         CA  $1,995
# 123                                   The Rexford         CA      NaN
# 124                                       Carlyle         CA      NaN
#
#           Type Zip_code
# 0    Apartment    90012
# 1    Apartment    92626
# 2    Apartment    94704
# 3    Apartment    90046
# 4    Apartment    91367
# 5    Apartment    91941
# 6    Apartment    94538
# 7    Apartment    94043
# 8    Apartment    91762
# 9    Apartment    92612
# 10   Apartment    92647
# 11   Apartment    92081
# 12   Apartment    90404
# 13   Apartment    92373
# 14   Apartment    90094
# 15   Apartment    92805
# 16   Apartment    94063
# 17   Apartment    92656
# 18   Apartment    91730
# 19   Apartment    95126
# 20   Apartment    92110
# 21   Apartment    94086
# 22   Apartment    92707
# 23   Apartment    95134
# 24   Apartment    90005
# 25   Apartment    92880
# 26   Apartment    92101
# 27   Apartment    90703
# 28   Apartment    91764
# 29   Apartment    92120
# ..         ...      ...
# 95   Apartment    90036
# 96   Apartment    92614
# 97   Apartment    95628
# 98   Apartment    90028
# 99   Apartment    92701
# 100  Apartment    95134
# 101  Apartment    94568
# 102  Apartment    92101
# 103  Apartment    95035
# 104  Apartment    90036
# 105  Apartment    95051
# 106  Apartment    92626
# 107  Apartment    94086
# 108  Apartment    92122
# 109  Apartment    94085
# 110  Apartment    94588
# 111  Apartment    91730
# 112  Apartment    90401
# 113  Apartment    91105
# 114  Apartment    90292
# 115  Apartment    90012
# 116  Apartment    91204
# 117  Apartment    92123
# 118  Apartment    92101
# 119  Apartment    90066
# 120  Apartment    91367
# 121  Apartment    94704
# 122  Apartment    92805
# 123  Apartment    94536
# 124  Apartment    92612
#
# [125 rows x 15 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Q2-2018_Apartment_Apartment_Data26.csv", index=False, header=True)
