# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Testing
linked = 'https://www.century21.com/real-estate/california/LSCA/'

response = requests.get(linked)
soup = BeautifulSoup(response.text, 'html.parser')
result = soup.find_all('div', class_='infinite-item')
result
# Out:
# [<div class="infinite-item property-card clearfix property-card-C2180910323" data-brand-cd="C21" data-id="C2180910323" data-latitude="38.02535" data-link="/property/22216-parrotts-ferry-13-sonora-ca-95370-C2180910323" data-listing-id="" data-longitude="-120.40381" data-mls="20181467" data-source-id="56dafcea-766d-461e-97bc-6ee9e5eb9983" data-zip="95370">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/0r6e05264hncmdte4j3a11qnf4i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">12</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/22216-parrotts-ferry-13-sonora-ca-95370-C2180910323">
#
#
#                 $15,990,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>550</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="22216 Parrotts Ferry #13">
#                 22216 Parrotts Ferry #13
#              </div>
#  <div class="property-city">
#              Sonora CA 95370
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Wildwood Properties, Inc.
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911172" data-brand-cd="C21" data-id="C2180911172" data-latitude="34.05225" data-link="/property/2222-avenue-of-the-stars-1201e-los-angeles-ca-90067-C2180911172" data-listing-id="" data-longitude="-118.40849" data-mls="SR18185481" data-source-id="1ce7de9f-1e19-450c-ada1-733e0b83043f" data-zip="90067">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/81w4s1yg233vmejryeetvt85y3i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">35</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/2222-avenue-of-the-stars-1201e-los-angeles-ca-90067-C2180911172">
#
#
#                 $1,949,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,639</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="2222 Avenue of the Stars 1201E">
#                 2222 Avenue of the Stars 1201E
#              </div>
#  <div class="property-city">
#              Los Angeles CA 90067
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Peak
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911239" data-brand-cd="C21" data-id="C2180911239" data-latitude="38.44093" data-link="/property/5167-hall-rd-santa-rosa-ca-95401-C2180911239" data-listing-id="" data-longitude="-122.80131" data-mls="18051792" data-source-id="c67b5759-1065-4365-a58f-d9c97a3d511b" data-zip="95401">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/4dhx2p4madc3476ngnp6ace7k7i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">36</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/5167-hall-rd-santa-rosa-ca-95401-C2180911239">
#
#
#                 $1,500,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>3,671</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="5167 Hall Rd">
#                 5167 Hall Rd
#              </div>
#  <div class="property-city">
#              Santa Rosa CA 95401
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911676" data-brand-cd="C21" data-id="C2180911676" data-latitude="34.288917" data-link="/property/2959-reservoir-dr-simi-valley-ca-93065-C2180911676" data-listing-id="" data-longitude="-118.739461" data-mls="218009657" data-source-id="fb7ae3e3-e2b7-41f2-8122-60c46ed8d2bd" data-zip="93065">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://dev.virtualearth.net/REST/v1/Imagery/Map/Aerial/34.288917,-118.739461/18?key=Aifo-Q0bU-2xqFafu5AzBNi5fz59f5ufmjxeulcOJc1DddNIqLLW5Sozv3EQ8dhn&amp;mapSize=800,600);">
#  <div class="property-image-flag open-house">Open House</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/2959-reservoir-dr-simi-valley-ca-93065-C2180911676">
#
#
#                 $1,023,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>3,964</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="2959 Reservoir Dr">
#                 2959 Reservoir Dr
#              </div>
#  <div class="property-city">
#              Simi Valley CA 93065
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Troop Real Estate
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910373" data-brand-cd="C21" data-id="C2180910373" data-latitude="38.247959" data-link="/property/1038-allen-street-petaluma-ca-94954-C2180910373" data-listing-id="" data-longitude="-122.594025" data-mls="21819956" data-source-id="94bab554-f566-4c94-86da-cab254545e23" data-zip="94954">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/qxhkqbgkp7xwmxyjna4hkwwnd5i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">41</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1038-allen-street-petaluma-ca-94954-C2180910373">
#
#
#                 $979,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>5</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>2,858</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1038 Allen Street">
#                 1038 Allen Street
#              </div>
#  <div class="property-city">
#              Petaluma CA 94954
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Bundesen
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911519" data-brand-cd="C21" data-id="C2180911519" data-latitude="34.0706" data-link="/property/236-n-park-view-st-echo-park-ca-90026-C2180911519" data-listing-id="" data-longitude="-118.27201" data-mls="GD18183350" data-source-id="9cedd36e-46f7-4fa0-89ec-9bebf0df7625" data-zip="90026">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/eaqb2qxzz4vg46242qadas8a41i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">16</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/236-n-park-view-st-echo-park-ca-90026-C2180911519">
#
#
#                 $850,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="236 N Park View St">
#                 236 N Park View St
#              </div>
#  <div class="property-city">
#              Echo Park CA 90026
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Arroyo Seco
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911032" data-brand-cd="C21" data-id="C2180911032" data-latitude="37.65842" data-link="/property/25123-belmont-ave-hayward-ca-94542-C2180911032" data-listing-id="" data-longitude="-122.0718" data-mls="40832572" data-source-id="34292814-fcc4-459f-b8c0-252fc84058c7" data-zip="94542">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/e84vskrsb8g144p2fm86hhrc96i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">35</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/25123-belmont-ave-hayward-ca-94542-C2180911032">
#
#
#                 $777,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,287</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="25123 Belmont Ave">
#                 25123 Belmont Ave
#              </div>
#  <div class="property-city">
#              Hayward CA 94542
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911267" data-brand-cd="C21" data-id="C2180911267" data-latitude="38.28624" data-link="/property/1873-seville-dr-napa-ca-94559-C2180911267" data-listing-id="" data-longitude="-122.26038" data-mls="21819703" data-source-id="89d4bf57-b14a-4b19-95fd-e8bfbe00441d" data-zip="94559">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/63bqec99rc8242pyzxm2yy7051i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">36</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1873-seville-dr-napa-ca-94559-C2180911267">
#
#
#                 $750,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,115</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1873 Seville Dr">
#                 1873 Seville Dr
#              </div>
#  <div class="property-city">
#              Napa CA 94559
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911621" data-brand-cd="C21" data-id="C2180911621" data-latitude="32.74288" data-link="/property/3536-kite-st-san-diego-ca-92103-C2180911621" data-listing-id="" data-longitude="-117.1752" data-mls="N/A" data-source-id="8387be04-0dd7-43a1-868c-ee9f259ac6e3" data-zip="92103">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://dev.virtualearth.net/REST/v1/Imagery/Map/Aerial/32.74288,-117.1752/18?key=Aifo-Q0bU-2xqFafu5AzBNi5fz59f5ufmjxeulcOJc1DddNIqLLW5Sozv3EQ8dhn&amp;mapSize=800,600);">
#  <div class="property-image-flag sale-pending">Sale Pending</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3536-kite-st-san-diego-ca-92103-C2180911621">
#
#
#                 $700,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  </div>
#  <div class="col-wrap-last">
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3536 Kite St">
#                 3536 Kite St
#              </div>
#  <div class="property-city">
#              San Diego CA 92103
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Award
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911683" data-brand-cd="C21" data-id="C2180911683" data-latitude="34.27213" data-link="/property/5320-queens-st-ventura-ca-93003-C2180911683" data-listing-id="" data-longitude="-119.22216" data-mls="218009655" data-source-id="76ecf2f7-1c79-4603-b435-fc15a0fdd740" data-zip="93003">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://dev.virtualearth.net/REST/v1/Imagery/Map/Aerial/34.27213,-119.22216/18?key=Aifo-Q0bU-2xqFafu5AzBNi5fz59f5ufmjxeulcOJc1DddNIqLLW5Sozv3EQ8dhn&amp;mapSize=800,600);">
#  <div class="property-image-flag open-house">Open Houses</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/5320-queens-st-ventura-ca-93003-C2180911683">
#
#
#                 $659,500
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,478</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="5320 Queens St">
#                 5320 Queens St
#              </div>
#  <div class="property-city">
#              Ventura CA 93003
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Troop Real Estate
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911642" data-brand-cd="C21" data-id="C2180911642" data-latitude="37.30981" data-link="/property/2625-e-north-bear-creek-dr-merced-ca-95340-C2180911642" data-listing-id="" data-longitude="-120.43886" data-mls="18052579" data-source-id="d3e31cd9-895a-4143-bb31-1b4cf9dcd314" data-zip="95340">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/yjx4yhc3r3d64ky4y4jjcnpvd4i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">36</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/2625-e-north-bear-creek-dr-merced-ca-95340-C2180911642">
#
#
#                 $649,900
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>3,385</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="2625 E North Bear Creek Dr">
#                 2625 E North Bear Creek Dr
#              </div>
#  <div class="property-city">
#              Merced CA 95340
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911513" data-brand-cd="C21" data-id="C2180911513" data-latitude="37.30981" data-link="/property/2625-e-north-bear-creek-drive-merced-ca-95340-C2180911513" data-listing-id="" data-longitude="-120.43886" data-mls="MC18181607" data-source-id="98cfab92-7688-475e-8710-81abbd9564f5" data-zip="95340">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/kxm50fmmjsa54s67yzfzxcyjb1i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">71</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/2625-e-north-bear-creek-drive-merced-ca-95340-C2180911513">
#
#
#                 $649,900
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-half-baths">
#  <strong>1</strong> half bath
#           </div>
#  <div class="property-sqft">
#  <strong>3,385</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="2625 E North Bear Creek Drive">
#                 2625 E North Bear Creek Drive
#              </div>
#  <div class="property-city">
#              Merced CA 95340
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911299" data-brand-cd="C21" data-id="C2180911299" data-latitude="33.91568" data-link="/property/14828-ramhurst-drive-la-mirada-ca-90638-C2180911299" data-listing-id="" data-longitude="-118.0154" data-mls="pw18180746" data-source-id="3b56215d-75c9-4b39-a4e9-fab0c2a93137" data-zip="90638">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/kdtbbv8gvvkt4me5bpngvvhqx1i);">
#  <div class="property-image-flag open-house">Open House</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">24</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/14828-ramhurst-drive-la-mirada-ca-90638-C2180911299">
#
#
#                 $615,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,452</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="14828 Ramhurst Drive">
#                 14828 Ramhurst Drive
#              </div>
#  <div class="property-city">
#              La Mirada CA 90638
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Westworld Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911665" data-brand-cd="C21" data-id="C2180911665" data-latitude="37.111" data-link="/property/12376-coleman-avenue-felton-ca-95018-C2180911665" data-listing-id="" data-longitude="-122.04515" data-mls="ML81717156" data-source-id="982824e7-e926-478e-9c9c-35170d281361" data-zip="95018">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/pdmtgm0a3ac3m2j40j72w1cab0i);">
#  <div class="property-image-flag open-house">Open House</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">41</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/12376-coleman-avenue-felton-ca-95018-C2180911665">
#
#
#                 $565,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,324</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="12376 Coleman Avenue">
#                 12376 Coleman Avenue
#              </div>
#  <div class="property-city">
#              Felton CA 95018
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Showcase, REALTORS
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911269" data-brand-cd="C21" data-id="C2180911269" data-latitude="35.60401" data-link="/property/820-saint-andrews-circle-paso-robles-ca-93446-C2180911269" data-listing-id="" data-longitude="-120.66757" data-mls="NS18184911" data-source-id="8392d584-b17e-4083-a3d9-b15f4e26ac5c" data-zip="93446">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/fe7x9kzr86eymq6z7prrkzdaw1i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">1</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/820-saint-andrews-circle-paso-robles-ca-93446-C2180911269">
#
#
#                 $559,950
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,821</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="820 Saint Andrews Circle">
#                 820 Saint Andrews Circle
#              </div>
#  <div class="property-city">
#              Paso Robles CA 93446
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Hometown Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911286" data-brand-cd="C21" data-id="C2180911286" data-latitude="38.80384" data-link="/property/3017-strand-rocklin-ca-95765-C2180911286" data-listing-id="" data-longitude="-121.26919" data-mls="18051794" data-source-id="b9ba3e31-4f6c-4e5c-a5f9-2b0a918151ef" data-zip="95765">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1203i0/f1f5sv7d758m4ee7bqcen8q4a4i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">32</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3017-strand-rocklin-ca-95765-C2180911286">
#
#
#                 $550,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>2,650</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3017 Strand">
#                 3017 Strand
#              </div>
#  <div class="property-city">
#              Rocklin CA 95765
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 MM
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911555" data-brand-cd="C21" data-id="C2180911555" data-latitude="35.32908" data-link="/property/1251-16th-st--los-osos-ca-93402-C2180911555" data-listing-id="" data-longitude="-120.82576" data-mls="SC18183488" data-source-id="e59403eb-9c0a-4449-837e-9fced100a7ea" data-zip="93402">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/x3jchtxd6hnhmwpmywgegg1md7i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">26</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/1251-16th-st--los-osos-ca-93402-C2180911555">
#
#
#                 $545,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,590</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="1251 16th St.">
#                 1251 16th St.
#              </div>
#  <div class="property-city">
#              Los Osos CA 93402
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Hometown Realty
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911566" data-brand-cd="C21" data-id="C2180911566" data-latitude="38.32911" data-link="/property/6575-santero-way-cotati-ca-94931-C2180911566" data-listing-id="" data-longitude="-122.69142" data-mls="21820066" data-source-id="d7d26044-9bd1-4699-af0f-17ea3d33aa6d" data-zip="94931">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/tkvjqgg390sqmet4kk9ts6ghe5i);">
#  <div class="property-image-flag open-house">Open House</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">41</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/6575-santero-way-cotati-ca-94931-C2180911566">
#
#
#                 $529,900
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>4</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>3</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,703</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="6575 Santero Way">
#                 6575 Santero Way
#              </div>
#  <div class="property-city">
#              Cotati CA 94931
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Alliance
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180911546" data-brand-cd="C21" data-id="C2180911546" data-latitude="34.0524874162654" data-link="/property/3852-bostwick-st-los-angeles-ca-90063-C2180911546" data-listing-id="" data-longitude="-118.182296363731" data-mls="318002937" data-source-id="b2f3ec24-52b9-4e6c-bf2a-1c7836fd377a" data-zip="90063">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/1103i0/8xxwwj53zyvd4ta4ngbpafj7r0i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">22</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/3852-bostwick-st-los-angeles-ca-90063-C2180911546">
#
#
#                 $525,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>3</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>1</strong> bath
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,026</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="3852 Bostwick St">
#                 3852 Bostwick St
#              </div>
#  <div class="property-city">
#              Los Angeles CA 90063
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Arroyo Seco
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item property-card clearfix property-card-C2180910401" data-brand-cd="C21" data-id="C2180910401" data-latitude="38.243362" data-link="/property/7-liberty-lane-petaluma-ca-94952-C2180910401" data-listing-id="" data-longitude="-122.648918" data-mls="21819792" data-source-id="4dfd3969-f182-4eff-b459-952c588c652d" data-zip="94952">
#  <div class="property-card-clip"> <div class="property-card-image" style="background-image: url(https://www2.century21.com/c21/photo/maxxmax/c21.azureedge.net/308i0/j3gz5b8qtpsd4c658825e32732i);">
#  <div class="property-image-flag newly-listed">Newly Listed</div>
#  <div class="property-image-count">
#  <div class="image-count-left">&lt;</div>
#  <div class="image-count-current">1</div>
#  <div class="image-count-total">26</div>
#  <div class="image-count-right">&gt;</div>
#  </div>
#  </div>
#  </div>
#  <div class="property-card-primary-info">
#  <div class="pdp-listing-type sale">FOR SALE</div>
#  <a class="listing-price" href="/property/7-liberty-lane-petaluma-ca-94952-C2180910401">
#
#
#                 $520,000
#
#
#
#        </a>
#  <div class="col-wrap-mid">
#  <div class="property-beds">
#  <strong>2</strong> beds
#           </div>
#  <div class="property-baths">
#  <strong>2</strong> baths
#           </div>
#  </div>
#  <div class="col-wrap-last">
#  <div class="property-sqft">
#  <strong>1,092</strong> sq. ft
#           </div>
#  </div>
#  <div class="property-address-info">
#  <div class="property-address" title="7 Liberty Lane">
#                 7 Liberty Lane
#              </div>
#  <div class="property-city">
#              Petaluma CA 94952
#           </div>
#  </div>
#  <div class="property-card-attribution">
#                 Listed By CENTURY 21 Bundesen
#
#           </div>
#  </div>
#  <div class="property-actions">
#  <button class="action-contact" data-usagetrack='{"data": ["Hybrid Mapping", "Property Card", "Contact"]}' title="Contact" type="button"></button>
#  <button class="action-favorite" title="Set as Favorite" type="button"></button>
#  </div>
#  </div>,
#  <div class="infinite-item infinite-clear-fix"></div>]

# %%
#Set up list to hold response info
house_dict = []

# %%
# Loop through x pages of the website with filter of Single House
page_link = 'https://www.century21.com/real-estate/california/LSCA/?sn=5&sk=Y&pt=1&p={}'
for link in [page_link.format(page) for page in range(1,5000)]:
    res = requests.get(link)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('div', class_='infinite-item')

    # Loop through returned results
    for result in new_results:
        # Error handling
        try:
            # Identify and return listing type
            listing_type = result.find('div', class_="pdp-listing-type").text
            # Identify and return price of House
            price = result.find('a', class_="listing-price").text
            # Identify and return number and street address of House
            street = result.find('div', class_="property-address").text
            # Identify and return city, state, and zip code of House
            city = result.find('div', class_="property-city").text
            zip_code = city.strip().replace("\n", "")
            City_state = zip_code[:-6]
            # Identify and return room number of House
            bed = result.find('div', class_="property-beds").find('strong').text
            # Identify and return bath number of House
            bath = result.find('div', class_="property-baths").find('strong').text
            # Identify and return half-bath number of House. If half-bath does not exist, it will return 0
            try:    
                half_bath = result.find('div', class_="property-half-baths").find('strong').text
            except:
                half_bath = "0"
                pass
            # Identify and return sqft of House
            sqft = result.find('div', class_="property-sqft").find('strong').text
            # Identify coordinate

            latitude = result.get("data-latitude")
            longitude = result.get("data-longitude")

            # Print results only if title, price, and link are available
            if (listing_type and price and street and city and bed and bath and sqft and latitude and longitude):
                house_obj = {
                "Listing_type": listing_type,
                "Price": price.strip().replace("\n", ""),
                "Street": street.strip().replace("\n", ""),
                "City": City_state[:-3],
                "State": City_state[-2:],
                "Zip_code": zip_code[-5:],
                "Bed": bed.strip().replace("\n", ""),
                "Half-bath": half_bath.strip().replace("\n", ""),
                "Bath": bath.strip().replace("\n", ""),
                "Square_Feet": sqft.strip().replace("\n", ""),
                "House_type": "Single Family",
                "Latitude": latitude,
                "Longitude": longitude
                }

                #Continue to add data into collection house_dict
                house_dict.append(house_obj)

        except AttributeError as e:
            continue
            # print(e)

print(house_dict)
# Out:
# [{'Listing_type': 'FOR SALE', 'Price': '$1,023,000', 'Street': '2959 Reservoir Dr', 'City': 'Simi Valley', 'State': 'CA', 'Zip_code': '93065', 'Bed': '4', 'Half-bath': '1', 'Bath': '3', 'Square_Feet': '3,964', 'House_type': 'Single Family', 'Latitude': '34.288917', 'Longitude': '-118.739461'}, {'Listing_type': 'FOR SALE', 'Price': '$979,000', 'Street': '1038 Allen Street', 'City': 'Petaluma', 'State': 'CA', 'Zip_code': '94954', 'Bed': '5', 'Half-bath': '1', 'Bath': '3', 'Square_Feet': '2,858', 'House_type': 'Single Family', 'Latitude': '38.247959', 'Longitude': '-122.594025'}, {'Listing_type': 'FOR SALE', 'Price': '$777,000', 'Street': '25123 Belmont Ave', 'City': 'Hayward', 'State': 'CA', 'Zip_code': '94542', 'Bed': '4', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,287', 'House_type': 'Single Family', 'Latitude': '37.65842', 'Longitude': '-122.0718'}, {'Listing_type': 'FOR SALE', 'Price': '$659,500', 'Street': '5320 Queens St', 'City': 'Ventura', 'State': 'CA', 'Zip_code': '93003', 'Bed': '3', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,478', 'House_type': 'Single Family', 'Latitude': '34.27213', 'Longitude': '-119.22216'}, {'Listing_type': 'FOR SALE', 'Price': '$615,000', 'Street': '14828 Ramhurst Drive', 'City': 'La Mirada', 'State': 'CA', 'Zip_code': '90638', 'Bed': '3', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,452', 'House_type': 'Single Family', 'Latitude': '33.91568', 'Longitude': '-118.0154'}, {'Listing_type': 'FOR SALE', 'Price': '$565,000', 'Street': '12376 Coleman Avenue', 'City': 'Felton', 'State': 'CA', 'Zip_code': '95018', 'Bed': '2', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,324', 'House_type': 'Single Family', 'Latitude': '37.111', 'Longitude': '-122.04515'}, {'Listing_type': 'FOR SALE', 'Price': '$545,000', 'Street': '1251 16th St.', 'City': 'Los Osos', 'State': 'CA', 'Zip_code': '93402', 'Bed': '3', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,590', 'House_type': 'Single Family', 'Latitude': '35.32908', 'Longitude': '-120.82576'}, {'Listing_type': 'FOR SALE', 'Price': '$529,900', 'Street': '6575 Santero Way', 'City': 'Cotati', 'State': 'CA', 'Zip_code': '94931', 'Bed': '4', 'Half-bath': '0', 'Bath': '3', 'Square_Feet': '1,703', 'House_type': 'Single Family', 'Latitude': '38.32911', 'Longitude': '-122.69142'}, {'Listing_type': 'FOR SALE', 'Price': '$525,000', 'Street': '3852 Bostwick St', 'City': 'Los Angeles', 'State': 'CA', 'Zip_code': '90063', 'Bed': '3', 'Half-bath': '0', 'Bath': '1', 'Square_Feet': '1,026', 'House_type': 'Single Family', 'Latitude': '34.0524874162654', 'Longitude': '-118.182296363731'}, {'Listing_type': 'FOR SALE', 'Price': '$459,000', 'Street': '1305 W Cedar St', 'City': 'Oxnard', 'State': 'CA', 'Zip_code': '93033', 'Bed': '3', 'Half-bath': '0', 'Bath': '1', 'Square_Feet': '1,050', 'House_type': 'Single Family', 'Latitude': '34.185', 'Longitude': '-119.19289'}, {'Listing_type': 'FOR SALE', 'Price': '$425,000', 'Street': '1532 Michael Pl', 'City': 'Porterville', 'State': 'CA', 'Zip_code': '93257', 'Bed': '5', 'Half-bath': '0', 'Bath': '3', 'Square_Feet': '3,124', 'House_type': 'Single Family', 'Latitude': '36.09358', 'Longitude': '-119.0603'}, {'Listing_type': 'FOR SALE', 'Price': '$369,000', 'Street': '737 Dean Way', 'City': 'Arnold', 'State': 'CA', 'Zip_code': '95223', 'Bed': '3', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,704', 'House_type': 'Single Family', 'Latitude': '38.25347', 'Longitude': '-120.33495'}, {'Listing_type': 'FOR SALE', 'Price': '$358,800', 'Street': '28161 Cannon Drive', 'City': 'Sun City', 'State': 'CA', 'Zip_code': '92585', 'Bed': '4', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '1,892', 'House_type': 'Single Family', 'Latitude': '33.71221', 'Longitude': '-117.17583'}, {'Listing_type': 'FOR SALE', 'Price': '$348,000', 'Street': '11341 Seventh Avenue', 'City': 'Hesperia', 'State': 'CA', 'Zip_code': '92345', 'Bed': '4', 'Half-bath': '0', 'Bath': '2', 'Square_Feet': '2,100', 'House_type': 'Single Family', 'Latitude': '34.45702739673 ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#      Bath Bed              City Half-bath     House_type          Latitude  \
# 0       3   4       Simi Valley         1  Single Family         34.288917
# 1       3   5          Petaluma         1  Single Family         38.247959
# 2       2   4           Hayward         0  Single Family          37.65842
# 3       2   3           Ventura         0  Single Family          34.27213
# 4       2   3         La Mirada         0  Single Family          33.91568
# 5       2   2            Felton         0  Single Family            37.111
# 6       2   3          Los Osos         0  Single Family          35.32908
# 7       3   4            Cotati         0  Single Family          38.32911
# 8       1   3       Los Angeles         0  Single Family  34.0524874162654
# 9       1   3            Oxnard         0  Single Family            34.185
# 10      3   5       Porterville         0  Single Family          36.09358
# 11      2   3            Arnold         0  Single Family          38.25347
# 12      2   4          Sun City         0  Single Family          33.71221
# 13      2   4          Hesperia         0  Single Family  34.4570273967373
# 14      2   3           Visalia         0  Single Family          36.31859
# 15      2   3       Victorville         0  Single Family          34.51539
# 16      2   3          La Jolla         0  Single Family          32.82999
# 17      3   4        Dana Point         1  Single Family            33.464
# 18      4   5     Monterey Park         1  Single Family           34.0519
# 19      4   5          Richmond         1  Single Family           37.9292
# 20      3   5         Livermore         1  Single Family           37.6526
# 21      2   2      San Clemente         0  Single Family           33.4139
# 22      4   5       Lake Forest         0  Single Family           33.6738
# 23      2   4       Studio City         1  Single Family           34.1478
# 24      3   5  Huntington Beach         0  Single Family          33.71629
# 25      6   6            Exeter         1  Single Family         36.305599
# 26      2   3           Arcadia         0  Single Family           34.1158
# 27      3   5     Thousand Oaks         0  Single Family         34.214117
# 28      3   4            Irvine         0  Single Family           33.6983
# 29      3   5  Huntington Beach         0  Single Family           33.6623
# ...   ...  ..               ...       ...            ...               ...
# 8834    2   3  Twentynine Palms         0  Single Family           34.1499
# 8835    2   2     Crescent City         0  Single Family           41.8147
# 8836    1   3            Burney         0  Single Family         40.874632
# 8837    2   3           Redding         1  Single Family         40.523523
# 8838    2   4     Crescent City         0  Single Family           41.7611
# 8839    2   4          Adelanto         0  Single Family           34.5106
# 8840    2   3         Helendale         0  Single Family           34.7399
# 8841    2   3     Crescent City         0  Single Family           41.7826
# 8842    2   3           Barstow         0  Single Family           34.8779
# 8843    2   3       Shasta Lake         0  Single Family          40.68146
# 8844    2   3      Apple Valley         0  Single Family           34.5209
# 8845    1   2     Crescent city         0  Single Family           41.7532
# 8846    1   2           Barstow         0  Single Family           34.8883
# 8847    2   4           Barstow         0  Single Family           34.8954
# 8848    1   2           Barstow         0  Single Family           34.8821
# 8849    1   4          Adelanto         0  Single Family           34.5781
# 8850    1   3           Redding         0  Single Family         40.580948
# 8851    2   3            Burney         0  Single Family         40.879365
# 8852    2   2  Twentynine Palms         0  Single Family           34.1531
# 8853    1   2             Orick         0  Single Family            41.292
# 8854    1   2          Rosamond         0  Single Family           34.9216
# 8855    2   3         Groveland         0  Single Family           37.8628
# 8856    2   3     Crescent City         0  Single Family           41.7622
# 8857    1   2           Barstow         0  Single Family            34.887
# 8858    1   3            Bieber         0  Single Family         41.122102
# 8859    1   2         Red Bluff         0  Single Family           40.1853
# 8860    1   2           Barstow         0  Single Family           34.8973
# 8861    1   2           Barstow         0  Single Family           34.8869
# 8862    2   4           Barstow         2  Single Family           34.8964
# 8863    2   2       Victorville         0  Single Family           34.5398
#
#      Listing_type          Longitude       Price Square_Feet State  \
# 0        FOR SALE        -118.739461  $1,023,000       3,964    CA
# 1        FOR SALE        -122.594025    $979,000       2,858    CA
# 2        FOR SALE          -122.0718    $777,000       1,287    CA
# 3        FOR SALE         -119.22216    $659,500       1,478    CA
# 4        FOR SALE          -118.0154    $615,000       1,452    CA
# 5        FOR SALE         -122.04515    $565,000       1,324    CA
# 6        FOR SALE         -120.82576    $545,000       1,590    CA
# 7        FOR SALE         -122.69142    $529,900       1,703    CA
# 8        FOR SALE  -118.182296363731    $525,000       1,026    CA
# 9        FOR SALE         -119.19289    $459,000       1,050    CA
# 10       FOR SALE          -119.0603    $425,000       3,124    CA
# 11       FOR SALE         -120.33495    $369,000       1,704    CA
# 12       FOR SALE         -117.17583    $358,800       1,892    CA
# 13       FOR SALE  -117.312185466025    $348,000       2,100    CA
# 14       FOR SALE         -119.27841    $297,999       1,752    CA
# 15       FOR SALE         -117.34837    $212,500         994    CA
# 16       FOR SALE         -117.27608  $1,448,000       1,350    CA
# 17       FOR SALE            -117.67  $1,429,000       3,308    CA
# 18       FOR SALE           -118.148  $1,388,000       4,016    CA
# 19       FOR SALE           -122.395  $1,325,000       5,014    CA
# 20       FOR SALE           -121.789  $1,325,000       3,573    CA
# 21       FOR SALE           -117.605  $1,299,000       1,840    CA
# 22       FOR SALE           -117.679  $1,285,000       2,697    CA
# 23       FOR SALE           -118.393  $1,279,000       2,022    CA
# 24       FOR SALE          -118.0608  $1,275,000       2,361    CA
# 25       FOR SALE        -119.088486  $1,250,000       8,201    CA
# 26       FOR SALE           -118.053  $1,250,000       2,186    CA
# 27       FOR SALE         -118.81274  $1,249,000       2,896    CA
# 28       FOR SALE           -117.761  $1,238,000       2,419    CA
# 29       FOR SALE           -117.961  $1,229,900       2,772    CA
# ...           ...                ...         ...         ...   ...
# 8834     FOR SALE           -116.091    $159,000       1,176    CA
# 8835     FOR SALE           -124.156    $159,000       1,099    CA
# 8836     FOR SALE        -121.652921    $159,000       1,050    CA
# 8837     FOR SALE        -122.381273    $158,000      13,939    CA
# 8838     FOR SALE           -124.212    $158,000       1,542    CA
# 8839     FOR SALE           -117.408    $158,000       1,516    CA
# 8840     FOR SALE           -117.342    $157,500       1,290    CA
# 8841     FOR SALE           -124.177    $134,900       1,296    CA
# 8842     FOR SALE             -117.1    $132,500       1,440    CA
# 8843     FOR SALE        -122.363905    $130,000       1,412    CA
# 8844     FOR SALE           -117.181    $130,000       1,229    CA
# 8845     FOR SALE           -124.198    $130,000       1,155    CA
# 8846     FOR SALE           -117.026    $130,000         956    CA
# 8847     FOR SALE           -117.017    $129,900       1,554    CA
# 8848     FOR SALE           -117.029    $129,900       1,169    CA
# 8849     FOR SALE           -117.402    $129,900       1,159    CA
# 8850     FOR SALE        -122.309028    $129,900       1,008    CA
# 8851     FOR SALE        -121.661159    $129,000       1,349    CA
# 8852     FOR SALE           -116.093    $129,000         976    CA
# 8853     FOR SALE           -124.057    $129,000         880    CA
# 8854     FOR SALE           -118.393     $98,000       1,406    CA
# 8855     FOR SALE           -120.225     $97,759       1,321    CA
# 8856     FOR SALE           -124.207     $97,000       1,128    CA
# 8857     FOR SALE           -117.106     $95,000       1,771    CA
# 8858     FOR SALE        -121.141586     $95,000       1,552    CA
# 8859     FOR SALE           -122.209     $95,000         800    CA
# 8860     FOR SALE           -117.022     $94,900       1,809    CA
# 8861     FOR SALE           -117.027     $91,500         962    CA
# 8862     FOR SALE           -117.028     $50,000       1,675    CA
# 8863     FOR SALE           -117.289     $48,500       1,248    CA
#
#                                    Street Zip_code
# 0                       2959 Reservoir Dr    93065
# 1                       1038 Allen Street    94954
# 2                       25123 Belmont Ave    94542
# 3                          5320 Queens St    93003
# 4                    14828 Ramhurst Drive    90638
# 5                    12376 Coleman Avenue    95018
# 6                           1251 16th St.    93402
# 7                        6575 Santero Way    94931
# 8                        3852 Bostwick St    90063
# 9                         1305 W Cedar St    93033
# 10                        1532 Michael Pl    93257
# 11                           737 Dean Way    95223
# 12                     28161 Cannon Drive    92585
# 13                   11341 Seventh Avenue    92345
# 14                     1321 S Pinnacle Ct    93292
# 15                  14426 Windmill Circle    92394
# 16                            6762 Tyrian    92037
# 17                   26365 Via California    92624
# 18                  869 Ridgecrest Street    91754
# 19                          770 Ocean Ave    94801
# 20                      691 Trinity Hills    94550
# 21                   152 W Avenida Ramona    92672
# 22                             29 Forster    92630
# 23                     4222 Gentry Avenue    91604
# 24                  3881 Finisterre Drive    92649
# 25                  363 Valley View Drive    93221
# 26                  2014 S Baldwin Avenue    91007
# 27                 2576 Cobblecreek Court    91362
# 28                              60 Bamboo    92620
# 29                   9562 Netherway Drive    92646
# ...                                   ...      ...
# 8834                 5685 Cahuilla Avenue    92277
# 8835                           141 Mobile    95531
# 8836                    37409 Oak View St    96013
# 8837                   2341 Sacramento Dr    96001
# 8838                         440 Humboldt    95531
# 8839                   11732 Begonia Road    92301
# 8840                  14784 Aberdeen Lane    92342
# 8841                          145 Miracle    95531
# 8842                  25677 Bejoal Street    92311
# 8843                      1528 Median Ave    96019
# 8844                 14820 Nanticoke Road    92307
# 8845                              838 4th    95531
# 8846                     841 S 2nd Avenue    92311
# 8847                   325 Melissa Avenue    92311
# 8848                   270 Juniper Street    92311
# 8849                 18035 Concord Street    92301
# 8850                        20143 Jill Ln    96003
# 8851                      20315 Hudson St    96013
# 8852          71937 Siesta Drive Unit: 29    92277
# 8853                   121281 Highway 101    95555
# 8854                  14700 Champagne AVE    93560
# 8855                    19327 Ferretti 70    95321
# 8856                        545 Calaveras    95531
# 8857                     25461 Pebble Way    92311
# 8858                           106 1st St    96009
# 8859                         10 Colony Rd    96080
# 8860        504 E Williams Street Unit: 2    92311
# 8861                     1031 Coyote Lane    92311
# 8862               112 W Fredricks Street    92311
# 8863  15940 Stoddard Wells Road Unit: 120    92395
#
# [8864 rows x 13 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Q2-2018_Single_Family_Data.csv", index=False, header=True)
