# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
#Testing
scrape_link = 'https://www.apartments.com/houses/ca/'

response = requests.get(scrape_link)
soup = BeautifulSoup(response.text, 'html.parser')
result = soup.find_all('div', class_="placardContainer")
result
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-2a9092603814> in <module>
#       2 scrape_link = 'https://www.apartments.com/houses/ca/'
#       3
# ----> 4 response = requests.get(scrape_link)
#       5 soup = BeautifulSoup(response.text, 'html.parser')
#       6 result = soup.find_all('div', class_="placardContainer")
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# c:\users\hongk\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     493
#     494         except (ProtocolError, socket.error) as err:
# --> 495             raise ConnectionError(err, request=request)
#     496
#     497         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))

# %%
#Set up list to hold response info
link_dict = []
all_property = []

# %%
# Loop through x pages of the website with filter of Single House
for scrape_links in [scrape_link.format(page) for page in range(1,2)]:
    res = requests.get(scrape_links)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('article', class_="placard")
    
    # Loop through returned results
    for result in new_results:
        find_tag = result.find('a')['href']
        link_dict.append(find_tag)

for property_link in link_dict:
    res = requests.get(property_link)
    new_soup = BeautifulSoup(res.text, 'html.parser')
    new_results = new_soup.find_all('div', class_="mainWrapper")
    
    
    for result in new_results:
        try:
            # Identify and return property name of Rental Place
            property_name = result.find('h1', class_="propertyName")
            # Identify and return address information of Rental Place
            clean_property_name = property_name.text.strip().replace("\n", "")
            street_data = result.find('div', class_="propertyAddress")
            street = street_data.text.strip().replace("\n", "").replace("\r", "")
            street_address = street.split(",")
            city = " ".join(street_address[0].split())
            state = " ".join(street_address[1].split())[:2]
            zip_code = " ".join(street_address[1].split())[2:7]
            # Identify and return number of bedroom and price of Rental Place
            bedroom_container = result.find('div', class_="rentRollupContainer")
            all_the_rents = bedroom_container.findAll('span', class_="rentRollup")
            
            bedroom_info = []
            for rent_block in all_the_rents:
                
                bedroom_type = rent_block.find('span', class_="longText").text
                try:
                    print(rent_block.text)
                    price = re.search('(?<!\.|\d)(\d+)', rent_block.text)
                    print(price)
                    price = price.group(3)
                except:
                    price = ""
                
                bedroom_info.append({
                    'bedroom_type': bedroom_type,
                    'price': price
                })
            
            rent_obj = {
                "Property_Name_Rent": clean_property_name,
                "City_Rent": city,
                "Type": "House",
                "State_Rent": state,
                "Zip_code": zip_code,
                "Bedroom_Info": bedroom_info,
                
            }
            
            for item in bedroom_info:
                rent_obj[item["bedroom_type"]] = item["price"]
                

        
            all_property.append(rent_obj)
        except AttributeError as e:
            print(e)

print(all_property)

# %%
house_data = pd.DataFrame(all_property)
house_data
# Out:
#                                           2 Bedrooms  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 732                                              NaN
# 733                                              NaN
# 734  <_sre.SRE_Match object; span=(1, 2), match='2'>
# 735                                              NaN
# 736                                              NaN
# 737                                              NaN
# 738                                              NaN
# 739                                              NaN
# 740  <_sre.SRE_Match object; span=(1, 2), match='2'>
# 741                                              NaN
# 742                                              NaN
# 743                                              NaN
# 744                                              NaN
# 745                                              NaN
# 746                                              NaN
# 747  <_sre.SRE_Match object; span=(1, 2), match='2'>
# 748                                              NaN
# 749                                              NaN
# 750                                              NaN
# 751                                              NaN
# 752                                              NaN
# 753                                              NaN
# 754                                              NaN
# 755                                              NaN
# 756                                              NaN
# 757                                              NaN
# 758                                              NaN
# 759  <_sre.SRE_Match object; span=(1, 2), match='2'>
# 760                                              NaN
# 761                                              NaN
#
#                                           3 Bedrooms  \
# 0                                                NaN
# 1                                                NaN
# 2
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14
# 15                                               NaN
# 16
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20
# 21
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 732                                              NaN
# 733                                              NaN
# 734                                              NaN
# 735  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 736                                              NaN
# 737                                              NaN
# 738                                              NaN
# 739  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 740                                              NaN
# 741  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 742                                              NaN
# 743                                              NaN
# 744                                              NaN
# 745  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 746  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 747                                              NaN
# 748                                              NaN
# 749                                              NaN
# 750                                              NaN
# 751                                              NaN
# 752  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 753                                              NaN
# 754                                              NaN
# 755                                              NaN
# 756                                              NaN
# 757                                              NaN
# 758                                              NaN
# 759                                              NaN
# 760  <_sre.SRE_Match object; span=(1, 2), match='3'>
# 761                                              NaN
#
#                                           4 Bedrooms  \
# 0
# 1
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5
# 6
# 7
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17
# 18
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23
# 24
# 25
# 26
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 732  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 733                                              NaN
# 734                                              NaN
# 735                                              NaN
# 736                                              NaN
# 737                                              NaN
# 738  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 739                                              NaN
# 740                                              NaN
# 741                                              NaN
# 742  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 743  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 744                                              NaN
# 745                                              NaN
# 746                                              NaN
# 747                                              NaN
# 748  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 749  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 750  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 751  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 752                                              NaN
# 753                                              NaN
# 754                                              NaN
# 755  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 756  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 757  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 758                                              NaN
# 759                                              NaN
# 760                                              NaN
# 761                                              NaN
#
#                                          4+ Bedrooms  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3
# 4
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9
# 10                                               NaN
# 11
# 12
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28
# 29
# ..                                               ...
# 732                                              NaN
# 733  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 734                                              NaN
# 735                                              NaN
# 736  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 737  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 738                                              NaN
# 739                                              NaN
# 740                                              NaN
# 741                                              NaN
# 742                                              NaN
# 743                                              NaN
# 744  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 745                                              NaN
# 746                                              NaN
# 747                                              NaN
# 748                                              NaN
# 749                                              NaN
# 750                                              NaN
# 751                                              NaN
# 752                                              NaN
# 753  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 754  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 755                                              NaN
# 756                                              NaN
# 757                                              NaN
# 758  <_sre.SRE_Match object; span=(1, 2), match='4'>
# 759                                              NaN
# 760                                              NaN
# 761  <_sre.SRE_Match object; span=(1, 2), match='4'>
#
#                                           Bedroom_Info       City_Rent  \
# 0        [{'bedroom_type': '4 Bedrooms', 'price': ''}]          Tustin
# 1        [{'bedroom_type': '4 Bedrooms', 'price': ''}]    Frazier Park
# 2        [{'bedroom_type': '3 Bedrooms', 'price': ''}]     Los Angeles
# 3       [{'bedroom_type': '4+ Bedrooms', 'price': ''}]     Yorba Linda
# 4       [{'bedroom_type': '4+ Bedrooms', 'price': ''}]     Canyon Lake
# 5        [{'bedroom_type': '4 Bedrooms', 'price': ''}]     Yorba Linda
# 6        [{'bedroom_type': '4 Bedrooms', 'price': ''}]         Anaheim
# 7        [{'bedroom_type': '4 Bedrooms', 'price': ''}]          Tustin
# 8        [{'bedroom_type': '3 Bedrooms', 'price': ''}]     Chino Hills
# 9       [{'bedroom_type': '4+ Bedrooms', 'price': ''}]        Palmdale
# 10       [{'bedroom_type': '2 Bedrooms', 'price': ''}]       San Pedro
# 11      [{'bedroom_type': '4+ Bedrooms', 'price': ''}]           Chino
# 12      [{'bedroom_type': '4+ Bedrooms', 'price': ''}]          Duarte
# 13       [{'bedroom_type': '4 Bedrooms', 'price': ''}]     Yorba Linda
# 14       [{'bedroom_type': '3 Bedrooms', 'price': ''}]     Palm Desert
# 15       [{'bedroom_type': '2 Bedrooms', 'price': ''}]    Agoura Hills
# 16       [{'bedroom_type': '3 Bedrooms', 'price': ''}]          Malibu
# 17       [{'bedroom_type': '4 Bedrooms', 'price': ''}]     Los Angeles
# 18       [{'bedroom_type': '4 Bedrooms', 'price': ''}]      San Marcos
# 19      [{'bedroom_type': '4+ Bedrooms', 'price': ''}]     Yorba Linda
# 20       [{'bedroom_type': '3 Bedrooms', 'price': ''}]     Los Angeles
# 21       [{'bedroom_type': '3 Bedrooms', 'price': ''}]          Malibu
# 22       [{'bedroom_type': '2 Bedrooms', 'price': ''}]     Los Angeles
# 23       [{'bedroom_type': '4 Bedrooms', 'price': ''}]  Trabuco Canyon
# 24       [{'bedroom_type': '4 Bedrooms', 'price': ''}]          Irvine
# 25       [{'bedroom_type': '4 Bedrooms', 'price': ''}]          Tustin
# 26       [{'bedroom_type': '4 Bedrooms', 'price': ''}]    Frazier Park
# 27       [{'bedroom_type': '3 Bedrooms', 'price': ''}]     Los Angeles
# 28      [{'bedroom_type': '4+ Bedrooms', 'price': ''}]     Yorba Linda
# 29      [{'bedroom_type': '4+ Bedrooms', 'price': ''}]     Canyon Lake
# ..                                                 ...             ...
# 732  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...          Tustin
# 733  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...        Palmdale
# 734  [{'bedroom_type': '2 Bedrooms', 'price': <_sre...       San Pedro
# 735  [{'bedroom_type': '3 Bedrooms', 'price': <_sre...     Chino Hills
# 736  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...           Chino
# 737  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...          Duarte
# 738  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...     Yorba Linda
# 739  [{'bedroom_type': '3 Bedrooms', 'price': <_sre...     Palm Desert
# 740  [{'bedroom_type': '2 Bedrooms', 'price': <_sre...    Agoura Hills
# 741  [{'bedroom_type': '3 Bedrooms', 'price': <_sre...          Malibu
# 742  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...     Los Angeles
# 743  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...      San Marcos
# 744  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...     Yorba Linda
# 745  [{'bedroom_type': '3 Bedrooms', 'price': <_sre...     Los Angeles
# 746  [{'bedroom_type': '3 Bedrooms', 'price': <_sre...          Malibu
# 747  [{'bedroom_type': '2 Bedrooms', 'price': <_sre...     Los Angeles
# 748  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...  Trabuco Canyon
# 749  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...          Irvine
# 750  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...          Tustin
# 751  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...    Frazier Park
# 752  [{'bedroom_type': '3 Bedrooms', 'price': <_sre...     Los Angeles
# 753  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...     Yorba Linda
# 754  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...     Canyon Lake
# 755  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...     Yorba Linda
# 756  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...         Anaheim
# 757  [{'bedroom_type': '4 Bedrooms', 'price': <_sre...          Tustin
# 758  [{'bedroom_type': '4+ Bedrooms', 'price': <_sr...        Palmdale
