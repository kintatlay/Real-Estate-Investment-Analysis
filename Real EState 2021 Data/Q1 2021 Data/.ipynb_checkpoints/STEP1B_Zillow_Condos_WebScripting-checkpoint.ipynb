# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(16, 21):
    linked = 'https://www.zillow.com/ca/condos/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-153.847663625,"east":-84.765632375,"south":12.777434491046959,"north":56.013075839104054},"mapZoom":4,"regionSelection":[{"regionId":9,"regionType":2}],"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"},"isSingleFamily":{"value":false}},"isListVisible":true,"isMapVisible":true}'
    user_agent = 'Mozilla/5.0 (Windows NT 5.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
            # Identify and return housing weblink
            house_website = str(result.a.get('href'))
            print(house_website)
            # Identify and return house data
            listing_type = result.find('div', class_="list-card-footer").text;
            price = result.find('div', class_="list-card-price").text
#             print(price)
            full_address = result.find('address', class_="list-card-addr").text
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
            try:
                city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
            except IndexError:
                city = 'null'
            try:
                state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
            except IndexError:
                state = 'null'
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
            except IndexError:
                zip_code = 'null'
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
            # Loop inside each house website and get more house data
            loop_response = requests.get(house_website, headers=headers)
            loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
            loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
            loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")

            lot = 'null';
            house_type = 'null';
            year_build = 'null';
            parking = 'null';
            hoa = 'null';
            lot_conversion_to_sqft = 'null';
            zillow_price_per_sqft = 'null';
            
            for content in loop_result2:
                if "Lot" in content.text.split(":")[0]:
                    lot = content.text.split(":")[1];
                if "Type" in content.text.split(":")[0]:
                    house_type = content.text.split(":")[1];
                if "Year built" in content.text.split(":")[0]:
                    year_build = content.text.split(":")[1];
                if "Parking" in content.text.split(":")[0]:
                    parking = content.text.split(":")[1];
                if "HOA" in content.text.split(":")[0]:
                    hoa = content.text.split(":")[1];
                if "Price/sqft" in content.text.split(":")[0]:
                    zillow_price_per_sqft = content.text.split(":")[1];
                    
            try:
                if (str(lot.split(" ")[1]) == "sqft"):
                    lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre") or (str(lot.split(" ")[1]) == "Acres") or (str(lot.split(" ")[1]) == "Acre")):
                    lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                elif (lot == "No Data"):
                    lot_conversion_to_sqft = 'null'
                else:
                    lot_conversion_to_sqft = 'null'
            except IndexError:
                lot_conversion_to_sqft = 'null'
                
            try:
                zestimate = loop_soup.findAll('span', class_="Text-c11n-8-33-0__aiai24-0 LoSpP")[0].text
            except:
                zestimate = 'null'
            try:
                rent_zestimate = loop_soup.findAll('span', class_="Text-c11n-8-33-0__aiai24-0 LoSpP")[1].text
                
            except:
                rent_zestimate = 'null'
            if (zestimate[0] != '$'):
                zestimate = 'null';
            print('zestimate', zestimate)
            print('rent zestimate', rent_zestimate)

            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
            house_obj = {
                "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "Lot": lot,
                "Lot_conversion_to_sqft": lot_conversion_to_sqft,
                "House_type": house_type,
                "Year_build": year_build,
                "Parking": parking,
                "HOA": hoa,
                "Zestimate": zestimate,
                "Rent_zestimate": rent_zestimate,
                "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
            }

            #Continue to add data into collection house_dict
            house_dict.append(house_obj)
            time.sleep(3)
            
        except AttributeError as e:
            continue

print(house_dict)
# Out:
# https://www.zillow.com/homedetails/2013-E-Bard-Rd-Oxnard-CA-93033/16408944_zpid/
# zestimate $439,596
# rent zestimate $2,700/mo
# https://www.zillow.com/homedetails/8276-Chappellet-Pl-Rancho-Cucamonga-CA-91730/17295706_zpid/
# zestimate $412,350
# rent zestimate $2,050/mo
# https://www.zillow.com/homedetails/45452-Sunset-Ln-7-Palm-Desert-CA-92260/17749105_zpid/
# zestimate $210,002
# rent zestimate $2,400/mo
# https://www.zillow.com/homedetails/12436-Bay-Hill-Ct-67-Garden-Grove-CA-92843/2071586568_zpid/
# zestimate $421,944
# rent zestimate null
# https://www.zillow.com/homedetails/846-Cotati-Ter-UNIT-1-Sunnyvale-CA-94085/325805662_zpid/
# zestimate $1,671,782
# rent zestimate null
# https://www.zillow.com/homedetails/8801-Willis-Ave-59-Panorama-City-CA-91402/20135084_zpid/
# zestimate $290,002
# rent zestimate $2,100/mo
# https://www.zillow.com/homedetails/100-Atlantic-Ave-APT-402-Long-Beach-CA-90802/111373019_zpid/
# zestimate $337,392
# rent zestimate $1,700/mo
# https://www.zillow.com/homedetails/46-Stone-St-UNIT-16-Salinas-CA-93901/19312812_zpid/
# zestimate $329,002
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/325-Kitty-Hawk-Rd-UNIT-301-Alameda-CA-94501/24868445_zpid/
# zestimate $608,627
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/1121-40th-St-APT-5405-Emeryville-CA-94608/68030571_zpid/
# zestimate $429,402
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/1200-Moon-Cir-UNIT-1226-Folsom-CA-95630/79553353_zpid/
# zestimate $434,376
# rent zestimate $2,195/mo
# https://www.zillow.com/homedetails/1432-Yale-St-APT-1-Santa-Monica-CA-90404/20470482_zpid/
# zestimate $963,541
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/125-Surf-Way-APT-337-Monterey-CA-93940/19336630_zpid/
# zestimate $593,889
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/78451-Montego-Bay-Cir-Indio-CA-92203/18063411_zpid/
# zestimate $272,729
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/982-Sweetbriar-Ln-UNIT-A-Azusa-CA-91702/119972581_zpid/
# zestimate $587,834
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/1-Hawthorne-St-UNIT-24D-San-Francisco-CA-94105/123596993_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/4832-Whitsett-Ave-UNIT-302-Los-Angeles-CA-91607/70393976_zpid/
# zestimate $623,980
# rent zestimate $2,550/mo
# https://www.zillow.com/homedetails/8550-Holloway-Dr-APT-107-West-Hollywood-CA-90069/20517439_zpid/
# zestimate $852,893
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/8873-Grandville-Cir-62-Westminster-CA-92683/25740747_zpid/
# zestimate $556,174
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/5435-Makati-Cir-San-Jose-CA-95123/19829708_zpid/
# zestimate $615,812
# rent zestimate $2,570/mo
# https://www.zillow.com/homedetails/5710-Baltimore-Dr-UNIT-433-La-Mesa-CA-91942/16990582_zpid/
# zestimate $445,033
# rent zestimate $2,195/mo
# https://www.zillow.com/homedetails/7309-Franklin-Ave-APT-403-Los-Angeles-CA-90046/20803487_zpid/
# zestimate $885,165
# rent zestimate $3,200/mo
# https://www.zillow.com/homedetails/11433-Excelsior-Dr-UNIT-C-Norwalk-CA-90650/244500392_zpid/
# zestimate $582,896
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/2233-Martin-APT-208-Irvine-CA-92612/25733927_zpid/
# zestimate $479,599
# rent zestimate $2,215/mo
# https://www.zillow.com/homedetails/428-Alice-St-APT-510-Oakland-CA-94607/79543150_zpid/
# zestimate $947,468
# rent zestimate $3,100/mo
# https://www.zillow.com/homedetails/5371-Punta-Alta-UNIT-1C-Laguna-Woods-CA-92637/25691686_zpid/
# zestimate $480,982
# rent zestimate $2,550/mo
# https://www.zillow.com/homedetails/12700-Newport-Ave-APT-53-Tustin-CA-92780/25688390_zpid/
# zestimate $553,657
# rent zestimate $2,450/mo
# https://www.zillow.com/homedetails/82567-Avenue-48-APT-12-Indio-CA-92201/18067050_zpid/
# zestimate $199,001
# rent zestimate $1,550/mo
# https://www.zillow.com/homedetails/826-Lakeview-Blvd-542-1849-Mammoth-Lakes-CA-93546/2072519289_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/3443-Pepperwood-Ter-APT-203-Fremont-CA-94536/25014774_zpid/
# zestimate $550,174
# rent zestimate $2,550/mo
# https://www.zillow.com/homedetails/111-N-2nd-St-UNIT-212-Alhambra-CA-91801/89143973_zpid/
# zestimate $441,292
# rent zestimate $2,200/mo
# https://www.zillow.com/homedetails/117-Alberti-Aisle-315-Irvine-CA-92614/25741561_zpid/
# zestimate $469,514
# rent zestimate $2,200/mo
# https://www.zillow.com/homedetails/5446-8th-St-APT-27-Carpinteria-CA-93013/130992543_zpid/
# zestimate $507,577
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/2546-Folsom-St-San-Francisco-CA-94110/2139655929_zpid/
# zestimate $2,337,136
# rent zestimate $5,499/mo
# https://www.zillow.com/homedetails/11755-Montana-Ave-APT-102-Los-Angeles-CA-90049/20535532_zpid/
# zestimate $964,408
# rent zestimate $3,850/mo
# https://www.zillow.com/homedetails/435-Lakeview-Blvd-35-Mammoth-Lakes-CA-93546/95723687_zpid/
# zestimate $621,403
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/3604-W-Estates-Ln-UNIT-209-Palos-Verdes-CA-90274/21344907_zpid/
# zestimate $436,157
# rent zestimate $2,238/mo
# https://www.zillow.com/homedetails/82-Marinero-Cir-Tiburon-CA-94920/19267526_zpid/
# zestimate $1,050,086
# rent zestimate $6,177/mo
# https://www.zillow.com/homedetails/4332-Pacific-Ave-APT-75-Stockton-CA-95207/2081757492_zpid/
# zestimate $1,325/mo
# rent zestimate null
# https://www.zillow.com/homedetails/5460-White-Oak-Ave-UNIT-C321-Los-Angeles-CA-91316/19979168_zpid/
# zestimate $293,066
# rent zestimate $1,695/mo
# https://www.zillow.com/homedetails/123-San-Jose-Ave-C-San-Francisco-CA-94110/2071543786_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/1440-23rd-St-APT-204-Santa-Monica-CA-90404/20474001_zpid/
# zestimate $790,816
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/1532-Olive-St-Santa-Barbara-CA-93101/96051757_zpid/
# zestimate $1,734,834
# rent zestimate $5,500/mo
# https://www.zillow.com/homedetails/1036-Magnolia-Ave-APT-103-Gardena-CA-90247/20983857_zpid/
# zestimate $371,365
# rent zestimate $2,295/mo
# https://www.zillow.com/homedetails/801-Nash-Rd-UNIT-E7-Hollister-CA-95023/2071691219_zpid/
# zestimate $404,766
# rent zestimate null
# https://www.zillow.com/homedetails/4900-E-Chapman-Ave-UNIT-98-Orange-CA-92869/25438417_zpid/
# zestimate $353,769
# rent zestimate $1,960/mo
# https://www.zillow.com/homedetails/470-N-Villa-Ct-UNIT-115-Palm-Springs-CA-92262/18022437_zpid/
# zestimate $182,104
# rent zestimate $1,700/mo
# https://www.zillow.com/homedetails/455-E-Ocean-Blvd-APT-512-Long-Beach-CA-90802/21241328_zpid/
# zestimate $289,000
# rent zestimate $1,400/mo
# https://www.zillow.com/homedetails/4341-Merced-Ave-Baldwin-Park-CA-91706/21596976_zpid/
# zestimate $728,856
# rent zestimate $2,900/mo
# https://www.zillow.com/homedetails/1631-Pierce-St-San-Francisco-CA-94115/303806155_zpid/
# zestimate $1,748,090
# rent zestimate $4,995/mo
# https://www.zillow.com/homedetails/401-Castiano-St-Camarillo-CA-93012/300035981_zpid/
# zestimate $635,192
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/12270-Corte-Sabio-UNIT-6103-San-Diego-CA-92128/2071548199_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/880-E-Fremont-Ave-APT-412-Sunnyvale-CA-94087/69302676_zpid/
# zestimate $663,586
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/2316-7th-Ave-Santa-Cruz-CA-95062/16124740_zpid/
# zestimate $300,060
# rent zestimate $2,495/mo
# https://www.zillow.com/homedetails/24520-Outlook-Dr-APT-25-Carmel-CA-93923/19345554_zpid/
# zestimate $905,523
# rent zestimate $3,350/mo
# https://www.zillow.com/homedetails/1-W-Century-Dr-PH-40-Los-Angeles-CA-90067/2083285221_zpid/
# zestimate $22,410,256
# rent zestimate $116,239/mo
# https://www.zillow.com/homedetails/13600-Marina-Pointe-Dr-UNIT-303-Venice-CA-90292/54948368_zpid/
# zestimate $1,088,562
# rent zestimate $4,200/mo
# https://www.zillow.com/homedetails/1240-W-Lambert-Rd-UNIT-74-La-Habra-CA-90631/25665936_zpid/
# zestimate $374,805
# rent zestimate $1,950/mo
# https://www.zillow.com/homedetails/200-E-Alessandro-Blvd-UNIT-120-Riverside-CA-92508/69292245_zpid/
# zestimate $312,448
# rent zestimate $1,750/mo
# https://www.zillow.com/homedetails/1402-Palm-Ave-APT-C-San-Gabriel-CA-91776/20724054_zpid/
# zestimate $681,325
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/233-Koch-Rd-Corte-Madera-CA-94925/19254494_zpid/
# zestimate $1,004,910
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/709-San-Conrado-Ter-UNIT-6-Sunnyvale-CA-94085/2072363168_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/13920-Moorpark-St-APT-206-Los-Angeles-CA-91423/19986759_zpid/
# zestimate $777,001
# rent zestimate $2,995/mo
# https://www.zillow.com/homedetails/80-Fairymoss-Irvine-CA-92620/124718944_zpid/
# zestimate $685,997
# rent zestimate $2,850/mo
# https://www.zillow.com/homedetails/507-Wickson-Ave-APT-106-Oakland-CA-94610/2071533486_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/1004-W-Balboa-Blvd-B-Newport-Beach-CA-92661/119684705_zpid/
# zestimate $2,503,131
# rent zestimate $8,472/mo
# https://www.zillow.com/homedetails/9760-Mesa-Springs-Way-UNIT-39-San-Diego-CA-92126/16833769_zpid/
# zestimate $2,200/mo
# rent zestimate null
# https://www.zillow.com/homedetails/15716-S-Normandie-Ave-APT-5-Gardena-CA-90247/20983352_zpid/
# zestimate $480,438
# rent zestimate $2,599/mo
# https://www.zillow.com/homedetails/4732-Park-Granada-UNIT-223-Calabasas-CA-91302/19895721_zpid/
# zestimate $577,980
# rent zestimate $2,400/mo
# https://www.zillow.com/homedetails/2554-Olive-Dr-APT-11-Palmdale-CA-93550/20270622_zpid/
# zestimate $201,381
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/315-Spruce-St-UNIT-4-Santa-Cruz-CA-95060/16106213_zpid/
# zestimate $611,663
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/54746-Inverness-Way-La-Quinta-CA-92253/18155088_zpid/
# zestimate $699,006
# rent zestimate $7,000/mo
# https://www.zillow.com/homedetails/15860-Green-Haven-Ct-Ramona-CA-92065/16755025_zpid/
# zestimate $447,644
# rent zestimate $2,695/mo
# https://www.zillow.com/homedetails/5460-White-Oak-Ave-UNIT-C114-Los-Angeles-CA-91316/19979008_zpid/
# zestimate $328,620
# rent zestimate $2,200/mo
# https://www.zillow.com/homedetails/3238-Ashford-St-UNIT-D-San-Diego-CA-92111/16929768_zpid/
# zestimate $341,297
# rent zestimate $1,900/mo
# https://www.zillow.com/homedetails/21-City-Stroll-Irvine-CA-92620/119683996_zpid/
# zestimate $970,686
# rent zestimate $3,400/mo
# https://www.zillow.com/homedetails/1218-Leavenworth-St-APT-1-San-Francisco-CA-94109/89239880_zpid/
# zestimate $3,295/mo
# rent zestimate null
# https://www.zillow.com/homedetails/1133-Douglas-Ave-APT-103-Burlingame-CA-94010/2139777480_zpid/
# zestimate $3,450/mo
# rent zestimate null
# https://www.zillow.com/homedetails/6979-Palm-Ct-APT-342-N-Riverside-CA-92506/2074276497_zpid/
# zestimate $240,042
# rent zestimate null
# https://www.zillow.com/homedetails/737-2nd-St-APT-207-Oakland-CA-94607/89031888_zpid/
# zestimate $729,688
# rent zestimate $2,535/mo
# https://www.zillow.com/homedetails/100-S-Doheny-Dr-APT-706-Los-Angeles-CA-90048/20515430_zpid/
# zestimate $766,595
# rent zestimate $3,100/mo
# https://www.zillow.com/homedetails/23232-Copante-64-Mission-Viejo-CA-92692/25742130_zpid/
# zestimate $525,184
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/52-Via-Madera-Rancho-Santa-Margarita-CA-92688/25702235_zpid/
# zestimate $532,401
# rent zestimate $2,350/mo
# https://www.zillow.com/homedetails/20702-El-Toro-Rd-APT-40-Lake-Forest-CA-92630/25754896_zpid/
# zestimate $412,018
# rent zestimate $2,100/mo
# https://www.zillow.com/homedetails/1381-S-Walnut-St-UNIT-2103-Anaheim-CA-92802/25698682_zpid/
# zestimate $2,300/mo
# rent zestimate null
# https://www.zillow.com/homedetails/1776-E-Avenida-De-Las-Flores-Thousand-Oaks-CA-91362/16432086_zpid/
# zestimate $516,521
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/650-Cole-St-San-Francisco-CA-94117/59700240_zpid/
# zestimate $1,386,540
# rent zestimate $4,450/mo
# https://www.zillow.com/homedetails/1650-Veteran-Ave-APT-304-Los-Angeles-CA-90024/20504051_zpid/
# zestimate $995,009
# rent zestimate $3,350/mo
# https://www.zillow.com/homedetails/26118-Hillsford-Pl-Lake-Forest-CA-92630/25746663_zpid/
# zestimate $539,771
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/881-Corbett-Ave-1-San-Francisco-CA-94131/79844619_zpid/
# zestimate $1,889,433
# rent zestimate $4,675/mo
# https://www.zillow.com/homedetails/3018-Beachwood-Bluff-Way-San-Diego-CA-92117/2071560355_zpid/
# zestimate $799,267
# rent zestimate null
# https://www.zillow.com/homedetails/216-Currlin-Cir-Milpitas-CA-95035/124743105_zpid/
# zestimate $1,048,949
# rent zestimate $3,469/mo
# https://www.zillow.com/homedetails/1682-Circa-Del-Lago-UNIT-A102-San-Marcos-CA-92078/2077920756_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/11988-Rancho-Bernardo-Rd-UNIT-E-San-Diego-CA-92128/2071584377_zpid/
# zestimate $494,287
# rent zestimate null
# https://www.zillow.com/homedetails/1510-S-Camino-Real-APT-314A-Palm-Springs-CA-92264/18028615_zpid/
# zestimate $243,192
# rent zestimate $1,600/mo
# https://www.zillow.com/homedetails/2001-Eastwood-Dr-APT-8-Vacaville-CA-95687/2071557460_zpid/
# zestimate $275,105
# rent zestimate null
# https://www.zillow.com/homedetails/4256-Bodega-Bay-Way-Oceanside-CA-92058/16589674_zpid/
# zestimate $475,810
# rent zestimate $2,300/mo
# https://www.zillow.com/homedetails/4682-Warner-Ave-APT-A103-Huntington-Beach-CA-92649/25768263_zpid/
# zestimate $665,057
# rent zestimate $2,770/mo
# https://www.zillow.com/homedetails/71-Redding-Rd-Campbell-CA-95008/19672703_zpid/
# zestimate $730,664
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/3865-Albatross-St-APT-8-San-Diego-CA-92103/16970159_zpid/
# zestimate $619,313
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/3950-Ohio-St-UNIT-327-San-Diego-CA-92104/72149467_zpid/
# zestimate $599,314
# rent zestimate $2,595/mo
# https://www.zillow.com/homedetails/8800-Cedros-Ave-APT-103-Los-Angeles-CA-91402/20134255_zpid/
# zestimate $230,186
# rent zestimate $1,995/mo
# https://www.zillow.com/homedetails/7515-Sheldon-Rd-UNIT-5102-Elk-Grove-CA-95758/82891847_zpid/
# zestimate $350,820
# rent zestimate $1,782/mo
# https://www.zillow.com/homedetails/1770-Avenida-Del-Mundo-UNIT-1006-Coronado-CA-92118/2087455826_zpid/
# zestimate $6,500/mo
# rent zestimate null
# https://www.zillow.com/homedetails/615-Vine-St-UNIT-22-Oceanside-CA-92054/63774026_zpid/
# zestimate $337,433
# rent zestimate $1,825/mo
# https://www.zillow.com/homedetails/3010-Colt-Way-UNIT-196-Fullerton-CA-92833/25775401_zpid/
# zestimate $519,566
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/343-W-Central-Ave-APT-N-Monrovia-CA-91016/21579516_zpid/
# zestimate $531,578
# rent zestimate $2,495/mo
# https://www.zillow.com/homedetails/2202-Golden-Oaks-Ln-Monterey-CA-93940/19311873_zpid/
# zestimate $398,954
# rent zestimate $2,050/mo
# https://www.zillow.com/homedetails/1788-Clay-St-APT-208-San-Francisco-CA-94109/124397834_zpid/
# zestimate $1,333,151
# rent zestimate $3,995/mo
# https://www.zillow.com/homedetails/3-Pebblewood-Irvine-CA-92604/25488472_zpid/
# zestimate $747,663
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/3285-Ocean-View-Blvd-UNIT-24-San-Diego-CA-92113/65239764_zpid/
# zestimate $404,897
# rent zestimate $2,195/mo
# https://www.zillow.com/homedetails/155-Canal-St-APT-2-San-Rafael-CA-94901/19248872_zpid/
# zestimate $365,000
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/3126-Scott-St-APT-1-San-Francisco-CA-94123/15071223_zpid/
# zestimate $1,779,441
# rent zestimate $5,500/mo
# https://www.zillow.com/homedetails/3-Commodore-Dr-UNIT-158-Emeryville-CA-94608/2083848110_zpid/
# zestimate $3,300/mo
# rent zestimate null
# https://www.zillow.com/homedetails/2019-Sand-Point-Rd-Discovery-Bay-CA-94505/18276636_zpid/
# zestimate $415,761
# rent zestimate $2,400/mo
# https://www.zillow.com/homedetails/4111-Illinois-St-UNIT-104-San-Diego-CA-92104/241608014_zpid/
# zestimate $485,487
# rent zestimate $2,295/mo
# https://www.zillow.com/homedetails/1983-San-Luis-Ave-APT-20-Mountain-View-CA-94043/19512444_zpid/
# zestimate $1,382,297
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/824-Tangerine-St-Corona-CA-92879/17774113_zpid/
# zestimate $408,019
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/601-Larkridge-Irvine-CA-92618/25717572_zpid/
# zestimate $716,335
# rent zestimate $2,950/mo
# https://www.zillow.com/homedetails/15-Galilee-Ln-APT-2-San-Francisco-CA-94115/64972135_zpid/
# zestimate $752,032
# rent zestimate $4,000/mo
# https://www.zillow.com/homedetails/855-Victor-Ave-APT-308-Inglewood-CA-90302/20334034_zpid/
# zestimate $419,846
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/7304-Richfield-St-UNIT-103-Paramount-CA-90723/21044308_zpid/
# zestimate $363,835
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/35-Dolores-St-APT-310-San-Francisco-CA-94103/2071527393_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/50-Lansing-St-UNIT-413-San-Francisco-CA-94105/71670261_zpid/
# zestimate $337,742
# rent zestimate $2,855/mo
# https://www.zillow.com/homedetails/7634-Hollister-Ave-UNIT-125-Goleta-CA-93117/15917571_zpid/
# zestimate $612,823
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/700-Promontory-Point-Ln-APT-1307-Foster-City-CA-94404/15633820_zpid/
# zestimate $1,315,947
# rent zestimate $5,000/mo
# https://www.zillow.com/homedetails/6-Buckelew-St-Sausalito-CA-94965/2113276349_zpid/
# zestimate $439,001
# rent zestimate $2,695/mo
# https://www.zillow.com/homedetails/1750-Radiance-Cmn-101-F9-Fremont-CA-94539/2071513835_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/784-Via-Los-Altos-UNIT-O-Laguna-Woods-CA-92637/2084648162_zpid/
# zestimate $149,900
# rent zestimate $2,087/mo
# https://www.zillow.com/homedetails/5082-Lemon-Grove-Ave-Los-Angeles-CA-90029/20789905_zpid/
# zestimate $482,730
# rent zestimate $2,700/mo
# https://www.zillow.com/homedetails/370-De-Haro-St-B5-San-Francisco-CA-94103/80746401_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/16081-Lancet-Dr-Whittier-CA-90603/95650149_zpid/
# zestimate $403,329
# rent zestimate $2,200/mo
# https://www.zillow.com/homedetails/3776-Alabama-St-UNIT-C214-San-Diego-CA-92104/16972915_zpid/
# zestimate $311,739
# rent zestimate $1,900/mo
# https://www.zillow.com/homedetails/663-Arneill-Rd-Camarillo-CA-93010/16368379_zpid/
# zestimate $441,757
# rent zestimate $2,250/mo
# https://www.zillow.com/homedetails/939-Coast-Blvd-UNIT-14H-La-Jolla-CA-92037/16847755_zpid/
# zestimate $2,004,579
# rent zestimate $7,663/mo
# https://www.zillow.com/homedetails/88-Calle-Aragon-C-Laguna-Woods-CA-92637/2071763116_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/8020-Walerga-Rd-UNIT-1222-Antelope-CA-95843/51597139_zpid/
# zestimate $294,666
# rent zestimate $1,595/mo
# https://www.zillow.com/homedetails/1020-S-Marengo-Ave-UNIT-10-Alhambra-CA-91803/20712637_zpid/
# zestimate $559,272
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/1965-Wellington-Ln-UNIT-6-Vista-CA-92081/16663820_zpid/
# zestimate $349,935
# rent zestimate $1,900/mo
# https://www.zillow.com/community/linden/2071523955_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/community/linden/2071523956_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/1566-Pine-Ave-APT-103A-Long-Beach-CA-90813/21235110_zpid/
# zestimate $374,533
# rent zestimate $1,850/mo
# https://www.zillow.com/homedetails/1629-Majestic-Pines-Dr-41-Mammoth-Lakes-CA-93546/68995334_zpid/
# zestimate $492,973
# rent zestimate $2,200/mo
# https://www.zillow.com/homedetails/1343-Massachusetts-Ave-APT-204-Riverside-CA-92507/79489414_zpid/
# zestimate $180,001
# rent zestimate $1,380/mo
# https://www.zillow.com/homedetails/9085-Alcosta-Blvd-APT-351-San-Ramon-CA-94583/18445746_zpid/
# zestimate $471,850
# rent zestimate $2,300/mo
# https://www.zillow.com/homedetails/10021-Tabor-St-APT-101-Los-Angeles-CA-90034/20496167_zpid/
# zestimate $818,052
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/366-Larkspur-Plaza-Dr-Larkspur-CA-94939/19251792_zpid/
# zestimate $620,338
# rent zestimate $2,995/mo
# https://www.zillow.com/homedetails/3089-Via-Serena-N-UNIT-B-Laguna-Woods-CA-92637/25681191_zpid/
# zestimate $383,002
# rent zestimate $2,350/mo
# https://www.zillow.com/homedetails/8888-Cuyamaca-St-Corona-CA-92883/69292419_zpid/
# zestimate $419,043
# rent zestimate $2,250/mo
# https://www.zillow.com/homedetails/5910-Cypress-Point-Ave-Long-Beach-CA-90808/79798505_zpid/
# zestimate $755,492
# rent zestimate $3,100/mo
# https://www.zillow.com/homedetails/16421-Westbrook-Ln-Cerritos-CA-90703/21108856_zpid/
# zestimate $699,476
# rent zestimate $2,850/mo
# https://www.zillow.com/homedetails/311-2nd-St-APT-602-Oakland-CA-94607/2071514494_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/425-14th-St-APT-2-San-Francisco-CA-94103/59779664_zpid/
# zestimate $1,313,020
# rent zestimate $3,550/mo
# https://www.zillow.com/homedetails/388-Fulton-St-UNIT-301-San-Francisco-CA-94102/241585854_zpid/
# zestimate $416,021
# rent zestimate $3,195/mo
# https://www.zillow.com/homedetails/3266-Ptarmigan-Dr-APT-4A-Walnut-Creek-CA-94595/18424349_zpid/
# zestimate $931,129
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/4337-Marina-City-Dr-UNIT-839-Marina-Del-Rey-CA-90292/294938763_zpid/
# zestimate $579,012
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/3958-Louisiana-St-UNIT-6-San-Diego-CA-92104/16956552_zpid/
# zestimate $415,038
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/13421-Del-Monte-Dr-24A-M14-Seal-Beach-CA-90740/2071577417_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/1069-James-Way-Arroyo-Grande-CA-93420/15395098_zpid/
# zestimate $466,288
# rent zestimate $2,300/mo
# https://www.zillow.com/homedetails/2135-Bellevue-Ave-8-Los-Angeles-CA-90026/2072289330_zpid/
# zestimate $460,546
# rent zestimate null
# [{'Listing_type': 'REALTY WORLD GOLDEN ERA', 'Price': '$435,000', 'Full_address': '2013 E Bard Rd, Oxnard, CA 93033', 'Street': '2013 E Bard Rd', 'City': 'Oxnard', 'State': 'CA', 'Zip_code': '93033', 'Bed': '3', 'Bath': '3', 'Square_Feet': '1,289', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Condo', 'Year_build': '1980', 'Parking': 'Garage, Garage Door Opener, On Street', 'HOA': '$300 monthly', 'Zestimate': '$439,596', 'Rent_zestimate': '$2,700/mo', 'Zillow_price/sqft': '$337', 'House_website': 'https://www.zillow.com/homedetails/2013-E-Bard-Rd-Oxnard-CA-93033/16408944_zpid/'}, {'Listing_type': 'REALTY MASTERS & ASSOCIATES, I', 'Price': '$400,000', 'Full_address': '8276 Chappellet Pl, Rancho Cucamonga, CA 91730', 'Street': '8276 Chappellet Pl', 'City': 'RanchoCucamonga', 'State': 'CA', 'Zip_code': '91730', 'Bed': '2', 'Bath': '3', 'Square_Feet': '984', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Condo', 'Year_build': '1989', 'Parking': 'Garage - Attached', 'HOA': '$275 monthly', 'Zestimate': '$412,350', 'Rent_zestimate': '$2,050/mo', 'Zillow_price/sqft': '$407', 'House_website': 'https://www.zillow.com/homedetails/8276-Chappellet-Pl-Rancho-Cucamonga-CA-91730/17295706_zpid/'}, {'Listing_type': 'JACOB, CHRISTOPHER & LEE RLTY', 'Price': '$210,000', 'Full_address': '45452 Sunset Ln #7, Palm Desert, CA 92260', 'Street': '45452 Sunset Ln #7', 'City': 'PalmDesert', 'State': 'CA', 'Zip_code': '92260', 'Bed': '1', 'Bath': '2', 'Square_Feet': '996', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Condo', 'Year_build': '1961', 'Parking': 'Attached Carport', 'HOA': '$290 monthly', 'Zestimate': '$210,002', 'Rent_zestimate': '$2,400/mo', 'Zillow_price/sqft': '$211', 'House_website': 'https://www.zillow.com/homedetails/45452-Sunset-Ln-7-Palm-Desert-CA-92260/17749105_zpid/'}, {'Listing_type': 'THE ASSOCIATES REALTY GROUP', 'Price': '$412,000', 'Full_address': '12436 Bay Hill Ct #67, Garden Grove, CA 92843', 'Street': '12436 Bay Hill Ct #67', 'City': 'GardenGrove', 'State': 'CA', 'Zip_code': '92843', 'Bed': '2', 'Bath': '2', 'Square_Feet': '900', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Condo', 'Year_build': '1989', 'Parking': 'Garage Door Opener, Gated, Parking Space, Permit Required', 'HOA': '$395 monthly', 'Zestimate': '$421,944', 'Rent_zestimate': 'null', 'Zillow_price/sqft': '$458', 'House_website': 'https://www.zillow.com/homedetails/12436-Bay-Hill-Ct-67-Garden-Grove-CA-92843/2071586568_zpid/'}, {'Listing_type': '', 'Price': '$1,599,888', 'Full_address': '846 Cotati Ter UNIT 1, Sunnyvale, CA 94085', 'Street': '846 Cotati Ter UNIT 1', 'City': 'Sunnyvale', 'State': 'CA', 'Zip_code': '94085', 'Bed': '4', 'Bath': '4', 'Square_Feet': '1,903', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Condo', 'Year_build': '2019', 'Parking': 'Garage - Attached', 'HOA': '$304 monthly', 'Zestimate': '$1,671,782', 'Rent_zestimate': 'null', 'Zillow_price/sqft': '$841', 'House_website': 'https://www.zillow.com/homedetails/846-Cotati-Ter-UNIT-1-Sunnyvale-CA-94085/325805662_zpid/'}, {'Listing_type': 'COMPASS', 'Price': '$290,000', 'Full_address': '8801 Willis Ave #59, Panorama City, CA 91402', 'Street': '8801 Willis Ave #59', 'City': 'PanoramaCity', 'State': 'CA', 'Zip_code': '91402', 'Bed': '2', 'Bath': '1', 'Square_Feet': '798', 'Lot': 'null', 'Lot_conversion_to_sqft': 'null', 'House_type': 'Condo', 'Year_build': '1978', 'Parking': 'Detached Carport', 'HOA': '$258 monthly', 'Zestimate': '$290,002', 'Rent_zestimate': '$2,100/mo', 'Zillow_price/sqft': '$363', 'House_website': 'https://www.zillow.com/homedetails/8801-Willis-Ave-59-Panorama-City-CA-91402/20135084_zpid/'}, {'Listing_type': 'VYLLA HOME, INC.', 'Price': '$335,000', 'Full_address': '100 Atlantic Ave APT 402, Long Beach, CA 90802', 'Street': '100 Atlantic Ave APT 402', 'City': 'LongBeach', 'State': 'CA', 'Zip_code': '90802', 'Bed': '1', 'Bath': '1', 'Square_Feet': '600', 'Lot': 'null', 'Lot_conversion_to_sqf ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#                              Listing_type       Price  \
# 0                 REALTY WORLD GOLDEN ERA    $435,000
# 1          REALTY MASTERS & ASSOCIATES, I    $400,000
# 2           JACOB, CHRISTOPHER & LEE RLTY    $210,000
# 3             THE ASSOCIATES REALTY GROUP    $412,000
# 4                                          $1,599,888
# ..                                    ...         ...
# 155              EILEEN MCCARTHY R.E. INC    $579,000
# 156                  PALISADE REALTY, INC    $410,000
# 157          LEISURE LIVING RESALES, INC.    $325,000
# 158  KELLER WILLIAMS REALTY CENTRAL COAST    $439,900
# 159              TRG REALTY COMPANY, INC.    $439,000
#
#                                           Full_address  \
# 0                     2013 E Bard Rd, Oxnard, CA 93033
# 1       8276 Chappellet Pl, Rancho Cucamonga, CA 91730
# 2            45452 Sunset Ln #7, Palm Desert, CA 92260
# 3        12436 Bay Hill Ct #67, Garden Grove, CA 92843
# 4           846 Cotati Ter UNIT 1, Sunnyvale, CA 94085
# ..                                                 ...
# 155  4337 Marina City Dr UNIT 839, Marina Del Rey, ...
# 156      3958 Louisiana St UNIT 6, San Diego, CA 92104
# 157  13421 Del Monte Dr #24A-M14, Seal Beach, CA 90740
# 158            1069 James Way, Arroyo Grande, CA 93420
# 159        2135 Bellevue Ave #8, Los Angeles, CA 90026
#
#                            Street             City State Zip_code Bed Bath  \
# 0                  2013 E Bard Rd           Oxnard    CA    93033   3    3
# 1              8276 Chappellet Pl  RanchoCucamonga    CA    91730   2    3
# 2              45452 Sunset Ln #7       PalmDesert    CA    92260   1    2
# 3           12436 Bay Hill Ct #67      GardenGrove    CA    92843   2    2
# 4           846 Cotati Ter UNIT 1        Sunnyvale    CA    94085   4    4
# ..                            ...              ...   ...      ...  ..  ...
# 155  4337 Marina City Dr UNIT 839     MarinaDelRey    CA    90292   2    2
# 156      3958 Louisiana St UNIT 6         SanDiego    CA    92104   2    2
# 157   13421 Del Monte Dr #24A-M14        SealBeach    CA    90740   2    1
# 158                1069 James Way     ArroyoGrande    CA    93420   2    2
# 159          2135 Bellevue Ave #8       LosAngeles    CA    90026   1    1
#
#     Square_Feet   Lot Lot_conversion_to_sqft   House_type Year_build  \
# 0         1,289  null                   null        Condo       1980
# 1           984  null                   null        Condo       1989
# 2           996  null                   null        Condo       1961
# 3           900  null                   null        Condo       1989
# 4         1,903  null                   null        Condo       2019
# ..          ...   ...                    ...          ...        ...
# 155          --  null                   null        Condo    No Data
# 156         782  null                   null        Condo       1982
# 157         950  null                   null  Cooperative       1963
# 158       1,320  null                   null        Condo       1980
# 159         640  null                   null        Condo       1959
#
#                                                Parking             HOA  \
# 0                Garage, Garage Door Opener, On Street    $300 monthly
# 1                                    Garage - Attached    $275 monthly
# 2                                     Attached Carport    $290 monthly
# 3    Garage Door Opener, Gated, Parking Space, Perm...    $395 monthly
# 4                                    Garage - Attached    $304 monthly
# ..                                                 ...             ...
# 155                                           Assigned  $1,020 monthly
# 156                                             Garage    $350 monthly
# 157                           Assigned, Carport, Gated    $388 monthly
# 158                                  Garage Faces Rear    $180 monthly
# 159                                           Assigned    $287 monthly
#
#       Zestimate Rent_zestimate Zillow_price/sqft  \
# 0      $439,596      $2,700/mo              $337
# 1      $412,350      $2,050/mo              $407
# 2      $210,002      $2,400/mo              $211
# 3      $421,944           null              $458
# 4    $1,671,782           null              $841
# ..          ...            ...               ...
# 155    $579,012      $2,800/mo              null
# 156    $415,038      $2,150/mo              $524
# 157        null           null              $342
# 158    $466,288      $2,300/mo              $333
# 159    $460,546           null              $686
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/2013-E-Bard...
# 1    https://www.zillow.com/homedetails/8276-Chappe...
# 2    https://www.zillow.com/homedetails/45452-Sunse...
# 3    https://www.zillow.com/homedetails/12436-Bay-H...
# 4    https://www.zillow.com/homedetails/846-Cotati-...
# ..                                                 ...
# 155  https://www.zillow.com/homedetails/4337-Marina...
# 156  https://www.zillow.com/homedetails/3958-Louisi...
# 157  https://www.zillow.com/homedetails/13421-Del-M...
# 158  https://www.zillow.com/homedetails/1069-James-...
# 159  https://www.zillow.com/homedetails/2135-Bellev...
#
# [160 rows x 20 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q1-2021_Condo_Data_page16-20.csv", index=False, header=True)
