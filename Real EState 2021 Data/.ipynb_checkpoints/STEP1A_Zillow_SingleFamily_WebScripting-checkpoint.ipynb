# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(1, 5):
    linked = 'https://www.zillow.com/ca/houses/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-130.9521558125,"east":-107.6611401875,"south":28.570940002914515,"north":45.333552921012235},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":5,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
    user_agent = 'Mozilla/5.0 (Windows NT 5.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
            # Identify and return housing weblink
            house_website = str(result.a.get('href'))
            print(house_website)
            # Identify and return house data
            listing_type = result.find('div', class_="list-card-footer").text;
            price = result.find('div', class_="list-card-price").text
#             print(price)
            full_address = result.find('address', class_="list-card-addr").text
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
            try:
                city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
            except IndexError:
                city = 'null'
            try:
                state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
            except IndexError:
                state = 'null'
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
            except IndexError:
                zip_code = 'null'
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
            # Loop inside each house website and get more house data
            loop_response = requests.get(house_website, headers=headers)
            loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
            loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
            loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")

            lot = 'null';
            house_type = 'null';
            year_build = 'null';
            parking = 'null';
            hoa = 'null';
            lot_conversion_to_sqft = 'null';
            zillow_price_per_sqft = 'null';
            
            for content in loop_result2:
                if "Lot" in content.text.split(":")[0]:
                    lot = content.text.split(":")[1];
                if "Type" in content.text.split(":")[0]:
                    house_type = content.text.split(":")[1];
                if "Year built" in content.text.split(":")[0]:
                    year_build = content.text.split(":")[1];
                if "Parking" in content.text.split(":")[0]:
                    parking = content.text.split(":")[1];
                if "HOA" in content.text.split(":")[0]:
                    hoa = content.text.split(":")[1];
                if "Price/sqft" in content.text.split(":")[0]:
                    zillow_price_per_sqft = content.text.split(":")[1];
                    
            try:
                if (str(lot.split(" ")[1]) == "sqft"):
                    lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre") or (str(lot.split(" ")[1]) == "Acres") or (str(lot.split(" ")[1]) == "Acre")):
                    lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                elif (lot == "No Data"):
                    lot_conversion_to_sqft = 'null'
                else:
                    lot_conversion_to_sqft = 'null'
            except IndexError:
                lot_conversion_to_sqft = 'null'
                
            try:
                zestimate = loop_soup.findAll('span', class_="Text-c11n-8-33-0__aiai24-0 LoSpP")[0].text
            except:
                zestimate = 'null'
            try:
                rent_zestimate = loop_soup.findAll('span', class_="Text-c11n-8-33-0__aiai24-0 LoSpP")[1].text
                
            except:
                rent_zestimate = 'null'
            if (zestimate[0] != '$'):
                zestimate = 'null';
            print('zestimate', zestimate)
            print('rent zestimate', rent_zestimate)

            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
            house_obj = {
                "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "Lot": lot,
                "Lot_conversion_to_sqft": lot_conversion_to_sqft,
                "House_type": house_type,
                "Year_build": year_build,
                "Parking": parking,
                "HOA": hoa,
                "Zestimate": zestimate,
                "Rent_zestimate": rent_zestimate,
                "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
            }

            #Continue to add data into collection house_dict
            house_dict.append(house_obj)
            time.sleep(3)
            
        except AttributeError as e:
            continue

print(house_dict)
# Out:
# https://www.zillow.com/homedetails/13950-Hidden-Valley-Rd-Victorville-CA-92395/17480779_zpid/
# zestimate $326,910
# rent zestimate $1,695/mo
# https://www.zillow.com/homedetails/781-La-Loma-Ln-Corona-CA-92879/17799083_zpid/
# zestimate $630,888
# rent zestimate $2,700/mo
# https://www.zillow.com/homedetails/5109-Locust-Ave-Carmichael-CA-95608/26026721_zpid/
# zestimate $715,566
# rent zestimate $2,650/mo
# https://www.zillow.com/homedetails/5143-Baywood-Cir-Oceanside-CA-92056/16595517_zpid/
# zestimate $704,443
# rent zestimate $2,995/mo
# https://www.zillow.com/homedetails/3-Cardinal-Ave-Aliso-Viejo-CA-92656/25543412_zpid/
# zestimate $789,002
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/27741-Narcissa-Ct-Escondido-CA-92026/66657627_zpid/
# zestimate $743,456
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/11720-Mount-Cambridge-Ct-Rancho-Cucamonga-CA-91737/17308932_zpid/
# zestimate $724,174
# rent zestimate $3,163/mo
# https://www.zillow.com/homedetails/5990-Blythe-St-Highland-CA-92346/17368491_zpid/
# zestimate $419,754
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/408-W-235th-St-Carson-CA-90745/21256768_zpid/
# zestimate $795,044
# rent zestimate $3,150/mo
# https://www.zillow.com/homedetails/36645-Quito-Way-Palmdale-CA-93550/65244892_zpid/
# zestimate $446,755
# rent zestimate $2,300/mo
# https://www.zillow.com/homedetails/1012-Cordova-Ct-Chula-Vista-CA-91910/17180459_zpid/
# zestimate $874,907
# rent zestimate $3,400/mo
# https://www.zillow.com/homedetails/11146-Berryknoll-St-San-Diego-CA-92126/16781135_zpid/
# zestimate $662,723
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/120-S-Tablerock-Pl-Anaheim-CA-92807/25415054_zpid/
# zestimate $1,213,405
# rent zestimate $3,950/mo
# https://www.zillow.com/homedetails/567-Fernshaw-Dr-La-Verne-CA-91750/21531730_zpid/
# zestimate $924,776
# rent zestimate $2,850/mo
# https://www.zillow.com/homedetails/6330-Oakcreek-Way-Citrus-Heights-CA-95621/26022658_zpid/
# zestimate $552,984
# rent zestimate $2,200/mo
# https://www.zillow.com/homedetails/23835-Sycamore-Dr-Mission-Viejo-CA-92691/25539457_zpid/
# zestimate $899,143
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/619-S-Pepper-St-Anaheim-CA-92802/25129348_zpid/
# zestimate $809,342
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/9458-Cathywood-Dr-Santee-CA-92071/16880235_zpid/
# zestimate $646,383
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/6548-E-Circulo-Dali-Anaheim-CA-92807/25416495_zpid/
# zestimate $775,512
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/2054-5th-St-Lincoln-CA-95648/59366303_zpid/
# zestimate $2,325/mo
# rent zestimate null
# https://www.zillow.com/homedetails/3656-N-Lily-Dr-Rialto-CA-92377/17327144_zpid/
# zestimate $566,343
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/10495-Lenelle-Ln-Truckee-CA-96161/19432587_zpid/
# zestimate $615,528
# rent zestimate $3,500/mo
# https://www.zillow.com/homedetails/20171-Hill-Spring-Rd-Wildomar-CA-92595/17943119_zpid/
# zestimate $526,052
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/14155-Placid-Dr-Whittier-CA-90604/21379363_zpid/
# zestimate $684,879
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/1069-Shadybrook-Ln-Napa-CA-94558/19420368_zpid/
# zestimate $3,268,171
# rent zestimate $12,000/mo
# https://www.zillow.com/homedetails/19345-Collier-St-Tarzana-CA-91356/19940289_zpid/
# zestimate $4,778,213
# rent zestimate $11,750/mo
# https://www.zillow.com/homedetails/14151-Hillsborough-Dr-Victorville-CA-92392/17639168_zpid/
# zestimate $337,672
# rent zestimate $1,800/mo
# https://www.zillow.com/homedetails/36418-Ramona-Rd-Palmdale-CA-93550/20268297_zpid/
# zestimate $491,666
# rent zestimate $2,345/mo
# https://www.zillow.com/homedetails/908-Bel-Air-Rd-Los-Angeles-CA-90077/20529646_zpid/
# zestimate $83,865,430
# rent zestimate $50,000/mo
# https://www.zillow.com/homedetails/35191-Rincon-Springs-Rd-Pauma-Valley-CA-92061/16576221_zpid/
# zestimate $605,563
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/2731-3rd-St-Bakersfield-CA-93304/18884582_zpid/
# zestimate $254,900
# rent zestimate $1,450/mo
# https://www.zillow.com/homedetails/2033-San-Luis-Way-Stockton-CA-95209/15278748_zpid/
# zestimate $342,648
# rent zestimate $1,895/mo
# https://www.zillow.com/homedetails/15470-Orange-St-Lake-Elsinore-CA-92530/17949980_zpid/
# zestimate $361,329
# rent zestimate $2,145/mo
# https://www.zillow.com/homedetails/1620-Lawrence-Rd-Danville-CA-94506/18436085_zpid/
# zestimate $2,750,387
# rent zestimate $3,400/mo
# https://www.zillow.com/homedetails/2601-S-Fulgham-St-Visalia-CA-93277/16250104_zpid/
# zestimate $335,157
# rent zestimate $1,600/mo
# https://www.zillow.com/homedetails/61-Oxbow-Creek-Ln-Laguna-Hills-CA-92653/25546525_zpid/
# zestimate $662,878
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/3629-Kennedy-Ave-Bakersfield-CA-93309/19027831_zpid/
# zestimate $279,952
# rent zestimate $1,600/mo
# https://www.zillow.com/homedetails/18118-Main-St-Hesperia-CA-92345/82804715_zpid/
# zestimate $289,001
# rent zestimate $2,100/mo
# https://www.zillow.com/homedetails/514-De-Flores-Cir-Rio-Vista-CA-94571/15651115_zpid/
# zestimate $436,719
# rent zestimate $2,025/mo
# https://www.zillow.com/homedetails/1627-Rainier-Ave-Napa-CA-94558/19407600_zpid/
# zestimate $1,136,760
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/12018-Fairford-Ave-Norwalk-CA-90650/21373977_zpid/
# zestimate $681,334
# rent zestimate $2,995/mo
# https://www.zillow.com/homedetails/9804-Calle-Esplanade-Riverside-CA-92503/17860113_zpid/
# zestimate $656,251
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/1371-Marinette-Rd-Pacific-Palisades-CA-90272/20545210_zpid/
# zestimate $8,287,500
# rent zestimate $9,504/mo
# https://www.zillow.com/homedetails/14728-Westward-Dr-Fontana-CA-92337/17326779_zpid/
# zestimate $458,685
# rent zestimate $2,350/mo
# https://www.zillow.com/homedetails/1389-Bozeman-Dr-South-Lake-Tahoe-CA-96150/18575671_zpid/
# zestimate $568,904
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/1111-N-Stevenson-St-Visalia-CA-93291/16236705_zpid/
# zestimate $264,356
# rent zestimate $1,295/mo
# https://www.zillow.com/homedetails/833-Yolo-St-West-Sacramento-CA-95605/16514242_zpid/
# zestimate $390,001
# rent zestimate $2,100/mo
# https://www.zillow.com/homedetails/2982-Mary-St-Riverside-CA-92506/17856946_zpid/
# zestimate $524,606
# rent zestimate $2,300/mo
# https://www.zillow.com/homedetails/37076-Almond-Cir-Murrieta-CA-92563/79831845_zpid/
# zestimate $613,798
# rent zestimate $2,650/mo
# https://www.zillow.com/homedetails/13488-Idaho-Maryland-Rd-Nevada-City-CA-95959/19450073_zpid/
# zestimate $621,460
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/931-Astonvilla-Way-Corona-CA-92880/82814738_zpid/
# zestimate $531,865
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/5319-Sunburst-Ct-Bakersfield-CA-93313/19048505_zpid/
# zestimate $302,414
# rent zestimate $1,650/mo
# https://www.zillow.com/homedetails/35603-Desert-Rose-Way-Lake-Elsinore-CA-92532/95861886_zpid/
# zestimate $636,108
# rent zestimate $2,750/mo
# https://www.zillow.com/homedetails/12436-Retrato-St-Felton-CA-95018/16153898_zpid/
# zestimate $715,261
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/9124-Lawlor-St-Oakland-CA-94605/24807336_zpid/
# zestimate $822,156
# rent zestimate $3,175/mo
# https://www.zillow.com/homedetails/5658-Riverside-Dr-West-Linda-CA-95961/16555143_zpid/
# zestimate $355,000
# rent zestimate $1,980/mo
# https://www.zillow.com/homedetails/4964-Begonia-Rd-Adelanto-CA-92342/17642680_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/15791-Hercules-St-Hesperia-CA-92345/17440177_zpid/
# zestimate $330,788
# rent zestimate $1,850/mo
# https://www.zillow.com/homedetails/16102-Sandy-Ln-Encino-CA-91436/19995281_zpid/
# zestimate $6,290,164
# rent zestimate $17,000/mo
# https://www.zillow.com/homedetails/3030-Knollwood-Dr-Shingle-Springs-CA-95682/18601786_zpid/
# zestimate $502,400
# rent zestimate $2,545/mo
# https://www.zillow.com/homedetails/39839-Savanna-Way-Murrieta-CA-92563/54965733_zpid/
# zestimate $681,451
# rent zestimate $2,900/mo
# https://www.zillow.com/homedetails/1433-W-Burgundy-Ct-Hanford-CA-93230/114163178_zpid/
# zestimate $297,979
# rent zestimate $1,685/mo
# https://www.zillow.com/homedetails/16298-Pearson-Ln-Fort-Bragg-CA-95437/19203220_zpid/
# zestimate $790,020
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/14876-Navajo-Rd-Apple-Valley-CA-92307/63125502_zpid/
# zestimate $325,333
# rent zestimate $1,800/mo
# https://www.zillow.com/homedetails/18000-Kings-Creek-Rd-Boulder-Creek-CA-95006/2071576881_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/708-Caddie-St-Beaumont-CA-92223/59417731_zpid/
# zestimate $509,215
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/35830-Sierra-Linda-Dr-Wishon-CA-93669/19146405_zpid/
# zestimate $199,648
# rent zestimate $2,100/mo
# https://www.zillow.com/homedetails/2517-Rowe-Pl-Fairfield-CA-94533/54660234_zpid/
# zestimate $552,631
# rent zestimate $2,695/mo
# https://www.zillow.com/homedetails/10313-Harvest-Ave-Santa-Fe-Springs-CA-90670/21369352_zpid/
# zestimate $633,402
# rent zestimate $2,950/mo
# https://www.zillow.com/homedetails/43179-Johnston-Ave-Hemet-CA-92544/18044013_zpid/
# zestimate $361,119
# rent zestimate $1,950/mo
# https://www.zillow.com/homedetails/16810-Bunny-Ln-Anderson-CA-96007/15246567_zpid/
# zestimate $123,528
# rent zestimate $925/mo
# https://www.zillow.com/homedetails/910-N-Rexford-Dr-Beverly-Hills-CA-90210/20522547_zpid/
# zestimate $19,283,178
# rent zestimate $55,000/mo
# https://www.zillow.com/homedetails/7621-Delta-Pointe-Way-Sacramento-CA-95823/25851560_zpid/
# zestimate $313,629
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/2006-Maycrest-Ave-South-Pasadena-CA-91030/20691927_zpid/
# zestimate $794,523
# rent zestimate $3,300/mo
# https://www.zillow.com/homedetails/25942-Via-Viento-Mission-Viejo-CA-92691/25610912_zpid/
# zestimate $931,341
# rent zestimate $4,800/mo
# https://www.zillow.com/homedetails/5155-Montana-Del-Oro-Dr-Mariposa-CA-95338/97293389_zpid/
# zestimate $650,004
# rent zestimate $3,200/mo
# https://www.zillow.com/homedetails/7046-Camellia-Ln-Pico-Rivera-CA-90660/51591742_zpid/
# zestimate $627,993
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/1108-Wallace-Rdg-Beverly-Hills-CA-90210/20534658_zpid/
# zestimate $51,074,934
# rent zestimate $66,068/mo
# https://www.zillow.com/homedetails/1774-Hammonton-Smartville-Rd-Linda-CA-95901/16555943_zpid/
# zestimate $350,002
# rent zestimate $1,700/mo
# https://www.zillow.com/homedetails/1054-Angelo-Dr-Los-Angeles-CA-90210/20524067_zpid/
# zestimate $16,475,421
# rent zestimate null
# https://www.zillow.com/homedetails/5012-Lombardi-Dr-26-Mokelumne-Hill-CA-95245/2071541089_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/25156-Old-Farm-St-Moreno-Valley-CA-92553/18002593_zpid/
# zestimate $306,835
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/737-Central-Ave-Martinez-CA-94553/18493856_zpid/
# zestimate $427,273
# rent zestimate $2,700/mo
# https://www.zillow.com/homedetails/10561-N-Shelton-Rd-Linden-CA-95236/300738306_zpid/
# zestimate $571,383
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/410-W-K-St-Benicia-CA-94510/15684490_zpid/
# zestimate $696,821
# rent zestimate $2,900/mo
# https://www.zillow.com/homedetails/2497-William-Ave-South-Lake-Tahoe-CA-96150/18579607_zpid/
# zestimate $499,003
# rent zestimate $3,100/mo
# https://www.zillow.com/homedetails/18862-Meadowlark-Ct-Penn-Valley-CA-95946/19445697_zpid/
# zestimate $390,906
# rent zestimate $2,100/mo
# https://www.zillow.com/homedetails/4908-Apple-Farm-Ln-Salida-CA-95368/53159295_zpid/
# zestimate $455,221
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/1287-S-Althea-Ave-Rialto-CA-92376/17211958_zpid/
# zestimate $405,015
# rent zestimate $2,301/mo
# https://www.zillow.com/homedetails/1222-La-Mesa-Ave-Spring-Valley-CA-91977/17117936_zpid/
# zestimate $714,969
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/1827-Polson-Ave-Clovis-CA-93611/18793049_zpid/
# zestimate $377,166
# rent zestimate $1,895/mo
# https://www.zillow.com/homedetails/3369-Dwight-Ave-Riverside-CA-92507/17839634_zpid/
# zestimate $408,304
# rent zestimate $2,195/mo
# https://www.zillow.com/homedetails/19688-N-Elm-St-Lockeford-CA-95237/15257635_zpid/
# zestimate $456,281
# rent zestimate $1,750/mo
# https://www.zillow.com/homedetails/8802-Sandlock-St-Pico-Rivera-CA-90660/21094879_zpid/
# zestimate $647,391
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/3555-N-Berlin-Ave-Fresno-CA-93722/18655571_zpid/
# zestimate $336,410
# rent zestimate $1,750/mo
# https://www.zillow.com/homedetails/25565-Tamarisk-Dr-Madera-CA-93638/19132495_zpid/
# zestimate $322,953
# rent zestimate $2,070/mo
# https://www.zillow.com/homedetails/31308-Ashmill-Ct-Temecula-CA-92591/18191546_zpid/
# zestimate $586,522
# rent zestimate $2,695/mo
# https://www.zillow.com/homedetails/16214-Lower-Colfax-Rd-Grass-Valley-CA-95945/19442999_zpid/
# zestimate $475,022
# rent zestimate $2,000/mo
# https://www.zillow.com/homedetails/6608-Merito-Ave-San-Bernardino-CA-92404/17358754_zpid/
# zestimate $434,152
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/3719-Sandpoint-Ct-Carlsbad-CA-92010/52505772_zpid/
# zestimate $1,051,228
# rent zestimate $4,000/mo
# https://www.zillow.com/homedetails/311-Pineridge-St-Brea-CA-92821/25365062_zpid/
# zestimate $821,969
# rent zestimate $3,200/mo
# https://www.zillow.com/homedetails/6642-Mountain-Ranch-Rd-8-Mountain-Ranch-CA-95246/2071563033_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/612-E-Sierra-Ave-Woodlake-CA-93286/95066095_zpid/
# zestimate $265,439
# rent zestimate $1,495/mo
# https://www.zillow.com/homedetails/1005-Calle-Del-Sol-Brawley-CA-92227/18860118_zpid/
# zestimate $345,077
# rent zestimate null
# https://www.zillow.com/homedetails/3628-Lankershim-Way-North-Highlands-CA-95660/25960236_zpid/
# zestimate $404,793
# rent zestimate $1,950/mo
# https://www.zillow.com/homedetails/1303-Needham-Dr-Vacaville-CA-95687/15718365_zpid/
# zestimate $485,150
# rent zestimate $2,475/mo
# https://www.zillow.com/homedetails/474-Armstrong-Ave-Clovis-CA-93611/18792895_zpid/
# zestimate $357,105
# rent zestimate $1,695/mo
# https://www.zillow.com/homedetails/2237-S-Greenwood-Pl-UNIT-B-Ontario-CA-91761/17584885_zpid/
# zestimate $384,000
# rent zestimate $1,995/mo
# https://www.zillow.com/homedetails/8404-Stara-St-Elk-Grove-CA-95758/250745838_zpid/
# zestimate $644,064
# rent zestimate null
# https://www.zillow.com/homedetails/1828-Via-Arturo-Oceano-CA-93445/61205494_zpid/
# zestimate $808,835
# rent zestimate $2,900/mo
# https://www.zillow.com/homedetails/5136-Peacock-Ln-Riverside-CA-92505/17800727_zpid/
# zestimate $495,483
# rent zestimate $2,250/mo
# https://www.zillow.com/homedetails/5290-Canyon-Rd-Willits-CA-95490/72547553_zpid/
# zestimate $346,201
# rent zestimate $2,495/mo
# https://www.zillow.com/homedetails/22729-Garzota-Dr-Santa-Clarita-CA-91354/20192595_zpid/
# zestimate $561,214
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/1-County-Line-Rd-Lewiston-CA-96052/2075380471_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/1080-Marion-Ave-Hemet-CA-92543/17983683_zpid/
# zestimate $281,813
# rent zestimate $1,800/mo
# https://www.zillow.com/homedetails/2567-Angela-St-Simi-Valley-CA-93065/16460646_zpid/
# zestimate $600,895
# rent zestimate $2,750/mo
# https://www.zillow.com/homedetails/2528-Fairglen-Pl-Corona-CA-92881/52468065_zpid/
# zestimate $856,870
# rent zestimate $3,426/mo
# https://www.zillow.com/homedetails/30742-Alston-Ln-Menifee-CA-92584/95812972_zpid/
# zestimate $487,608
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/14283-Monterey-Ave-Kerman-CA-93630/249308009_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/62-White-St-Watsonville-CA-95076/16116367_zpid/
# zestimate $627,367
# rent zestimate $2,700/mo
# https://www.zillow.com/homedetails/9800-Yoakum-Dr-Beverly-Hills-CA-90210/20532652_zpid/
# zestimate $2,202,441
# rent zestimate $11,000/mo
# https://www.zillow.com/homedetails/1265-N-Fircroft-Ave-Covina-CA-91722/21538790_zpid/
# zestimate $619,075
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/3248-Black-Bart-Blvd-43-Arnold-CA-95223/2071575849_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/9461-Ben-Way-Cazadero-CA-95421/15823255_zpid/
# zestimate $513,837
# rent zestimate $2,700/mo
# https://www.zillow.com/homedetails/497-Mountain-Dr-Santa-Barbara-CA-93103/15884813_zpid/
# zestimate $2,882,329
# rent zestimate $14,000/mo
# https://www.zillow.com/homedetails/540-Country-Club-Dr-San-Luis-Obispo-CA-93401/15422762_zpid/
# zestimate $1,204,556
# rent zestimate $3,375/mo
# https://www.zillow.com/homedetails/2571-Wallingford-Dr-Beverly-Hills-CA-90210/20532066_zpid/
# zestimate $66,477,909
# rent zestimate $118,813/mo
# https://www.zillow.com/homedetails/36437-Sparta-Ave-Madera-CA-93636/19137680_zpid/
# zestimate $401,961
# rent zestimate $1,850/mo
# https://www.zillow.com/homedetails/20749-Waterman-Rd-Lakehead-CA-96051/2128279209_zpid/
# zestimate $207,296
# rent zestimate $1,695/mo
# https://www.zillow.com/homedetails/210-Las-Lomas-Dr-Watsonville-CA-95076/19360868_zpid/
# zestimate $520,219
# rent zestimate $2,950/mo
# https://www.zillow.com/homedetails/2063-Wallaby-Ranch-Way-Plumas-Lake-CA-95961/68571856_zpid/
# zestimate $539,001
# rent zestimate $2,327/mo
# https://www.zillow.com/homedetails/245-Withington-Ave-Rio-Linda-CA-95673/25990298_zpid/
# zestimate $375,348
# rent zestimate $1,810/mo
# https://www.zillow.com/homedetails/1269-Victoria-Ct-Yuba-City-CA-95991/16096604_zpid/
# zestimate $333,777
# rent zestimate $1,905/mo
# https://www.zillow.com/homedetails/9929-Valley-Pines-Dr-Folsom-CA-95630/25987578_zpid/
# zestimate $745,360
# rent zestimate $2,720/mo
# https://www.zillow.com/homedetails/1592-Tadpole-Way-Linda-CA-95901/16554798_zpid/
# zestimate $360,002
# rent zestimate $1,980/mo
# https://www.zillow.com/homedetails/369-Pueblo-Way-Vallejo-CA-94591/15673371_zpid/
# zestimate $484,646
# rent zestimate $2,300/mo
# https://www.zillow.com/homedetails/23759-Suncrest-Ave-Moreno-Valley-CA-92553/17893739_zpid/
# zestimate $427,961
# rent zestimate $2,150/mo
# https://www.zillow.com/homedetails/2635-Condor-Cir-Corona-CA-92882/17775124_zpid/
# zestimate $518,489
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/692-E-L-St-Benicia-CA-94510/15686650_zpid/
# zestimate $764,829
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/8300-Moss-Ct-Granite-Bay-CA-95746/17669198_zpid/
# zestimate $10,000,076
# rent zestimate $2,795/mo
# https://www.zillow.com/homedetails/19535-Tunnel-Rd-Redding-CA-96003/15250606_zpid/
# zestimate $276,245
# rent zestimate $1,425/mo
# https://www.zillow.com/homedetails/23915-Shake-Ridge-Rd-Volcano-CA-95689/18203451_zpid/
# zestimate $256,449
# rent zestimate $1,995/mo
# https://www.zillow.com/homedetails/1692-Eucalyptus-St-Atwater-CA-95301/19154373_zpid/
# zestimate $308,893
# rent zestimate $1,500/mo
# https://www.zillow.com/homedetails/904-Columbia-St-Redlands-CA-92374/17260653_zpid/
# zestimate $390,105
# rent zestimate $1,900/mo
# https://www.zillow.com/homedetails/6737-Alamar-Way-Elk-Grove-CA-95758/25915260_zpid/
# zestimate $464,307
# rent zestimate $2,140/mo
# https://www.zillow.com/homedetails/1490-Riva-Trigoso-Dr-Manteca-CA-95337/111088564_zpid/
# zestimate $1,022,412
# rent zestimate $3,100/mo
# https://www.zillow.com/homedetails/2105-Becard-Ct-Union-City-CA-94587/24920464_zpid/
# zestimate $946,836
# rent zestimate $3,100/mo
# https://www.zillow.com/homedetails/734-San-Marco-Ave-Madera-CA-93637/97408800_zpid/
# zestimate $301,014
# rent zestimate $2,550/mo
# https://www.zillow.com/homedetails/4845-Old-Gulch-Rd-3-San-Andreas-CA-95249/2071537995_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/4845-Old-Gulch-Rd-San-Andreas-CA-95249/300737229_zpid/
# zestimate $2,500/mo
# rent zestimate null
# https://www.zillow.com/homedetails/1730-Licho-Way-Oxnard-CA-93030/52465366_zpid/
# zestimate $573,913
# rent zestimate $2,800/mo
# https://www.zillow.com/homedetails/38242-Hampton-Ave-Mill-Creek-CA-96061/2078914717_zpid/
# zestimate $166,851
# rent zestimate null
# https://www.zillow.com/homedetails/19025-Laurel-Way-Cottonwood-CA-96022/16167023_zpid/
# zestimate $299,901
# rent zestimate $1,750/mo
# https://www.zillow.com/homedetails/6359-Big-Oak-Rd-Sanger-CA-93657/18644314_zpid/
# zestimate $380,003
# rent zestimate $1,800/mo
# https://www.zillow.com/homedetails/3644-N-Laverne-Ave-Fresno-CA-93727/61496494_zpid/
# zestimate $456,923
# rent zestimate $1,995/mo
# https://www.zillow.com/homedetails/31549-Delaware-Rd-Coarsegold-CA-93614/19142044_zpid/
# zestimate $330,143
# rent zestimate $2,299/mo
# https://www.zillow.com/homedetails/4661-Bedel-St-Woodland-Hills-CA-91364/19944813_zpid/
# zestimate $904,117
# rent zestimate $3,799/mo
# https://www.zillow.com/homedetails/2635-Sycamore-Ln-Palmdale-CA-93551/20241574_zpid/
# zestimate $560,819
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/312-Capistrano-St-Placentia-CA-92870/25382028_zpid/
# zestimate $690,720
# rent zestimate $3,000/mo
# https://www.zillow.com/homedetails/73-Franklin-Cir-San-Juan-Bautista-CA-95045/15051891_zpid/
# zestimate $739,957
# rent zestimate $2,800/mo
# [{'Listing_type': '', 'Price': '$345,900', 'Full_address': '13950 Hidden Valley Rd, Victorville, CA 92395', 'Street': '13950 Hidden Valley Rd', 'City': 'Victorville', 'State': 'CA', 'Zip_code': '92395', 'Bed': '3', 'Bath': '2', 'Square_Feet': '1,453', 'Lot': '7,405 sqft', 'Lot_conversion_to_sqft': 7405.0, 'House_type': 'SingleFamily', 'Year_build': '1987', 'Parking': 'Garage Attached', 'HOA': '$285 quarterly', 'Zestimate': '$326,910', 'Rent_zestimate': '$1,695/mo', 'Zillow_price/sqft': '$238', 'House_website': 'https://www.zillow.com/homedetails/13950-Hidden-Valley-Rd-Victorville-CA-92395/17480779_zpid/'}, {'Listing_type': '', 'Price': '$567,900', 'Full_address': '781 La Loma Ln, Corona, CA 92879', 'Street': '781 La Loma Ln', 'City': 'Corona', 'State': 'CA', 'Zip_code': '92879', 'Bed': '4', 'Bath': '3', 'Square_Feet': '1,969', 'Lot': '6,098 sqft', 'Lot_conversion_to_sqft': 6098.0, 'House_type': 'SingleFamily', 'Year_build': '1988', 'Parking': 'Garage Attached', 'HOA': 'null', 'Zestimate': '$630,888', 'Rent_zestimate': '$2,700/mo', 'Zillow_price/sqft': '$288', 'House_website': 'https://www.zillow.com/homedetails/781-La-Loma-Ln-Corona-CA-92879/17799083_zpid/'}, {'Listing_type': '', 'Price': '$662,900', 'Full_address': '5109 Locust Ave, Carmichael, CA 95608', 'Street': '5109 Locust Ave', 'City': 'Carmichael', 'State': 'CA', 'Zip_code': '95608', 'Bed': '4', 'Bath': '3', 'Square_Feet': '2,566', 'Lot': '10,018 sqft', 'Lot_conversion_to_sqft': 10018.0, 'House_type': 'SingleFamily', 'Year_build': '1959', 'Parking': 'Garage', 'HOA': 'null', 'Zestimate': '$715,566', 'Rent_zestimate': '$2,650/mo', 'Zillow_price/sqft': '$258', 'House_website': 'https://www.zillow.com/homedetails/5109-Locust-Ave-Carmichael-CA-95608/26026721_zpid/'}, {'Listing_type': '', 'Price': '$689,900', 'Full_address': '5143 Baywood Cir, Oceanside, CA 92056', 'Street': '5143 Baywood Cir', 'City': 'Oceanside', 'State': 'CA', 'Zip_code': '92056', 'Bed': '4', 'Bath': '3', 'Square_Feet': '1,722', 'Lot': '4,356 sqft', 'Lot_conversion_to_sqft': 4356.0, 'House_type': 'SingleFamily', 'Year_build': '1988', 'Parking': 'Garage Attached', 'HOA': '$45 monthly', 'Zestimate': '$704,443', 'Rent_zestimate': '$2,995/mo', 'Zillow_price/sqft': '$401', 'House_website': 'https://www.zillow.com/homedetails/5143-Baywood-Cir-Oceanside-CA-92056/16595517_zpid/'}, {'Listing_type': '', 'Price': '$824,900', 'Full_address': '3 Cardinal Ave, Aliso Viejo, CA 92656', 'Street': '3 Cardinal Ave', 'City': 'AlisoViejo', 'State': 'CA', 'Zip_code': '92656', 'Bed': '3', 'Bath': '3', 'Square_Feet': '1,838', 'Lot': '3,071 sqft', 'Lot_conversion_to_sqft': 3071.0, 'House_type': 'SingleFamily', 'Year_build': '1994', 'Parking': 'Garage Attached', 'HOA': '$826 quarterly', 'Zestimate': '$789,002', 'Rent_zestimate': '$3,500/mo', 'Zillow_price/sqft': '$449', 'House_website': 'https://www.zillow.com/homedetails/3-Cardinal-Ave-Aliso-Viejo-CA-92656/25543412_zpid/'}, {'Listing_type': '', 'Price': '$731,900', 'Full_address': '27741 Narcissa Ct, Escondido, CA 92026', 'Street': '27741 Narcissa Ct', 'City': 'Escondido', 'State': 'CA', 'Zip_code': '92026', 'Bed': '4', 'Bath': '3', 'Square_Feet': '2,750', 'Lot': '5,000 sqft', 'Lot_conversion_to_sqft': 5000.0, 'House_type': 'SingleFamily', 'Year_build': '2004', 'Parking': 'Garage Attached', 'HOA': '$180 monthly', 'Zestimate': '$743,456', 'Rent_zestimate': '$3,500/mo', 'Zillow_price/sqft': '$266', 'House_website': 'https://www.zillow.com/homedetails/27741-Narcissa-Ct-Escondido-CA-92026/66657627_zpid/'}, {'Listing_type': '', 'Price': '$693,900', 'Full_address': '11720 Mount Cambridge Ct, Rancho Cucamonga, CA 91737', 'Street': '11720 Mount Cambridge Ct', 'City': 'RanchoCucamonga', 'State': 'CA', 'Zip_code': '91737', 'Bed': '4', 'Bath': '3', 'Square_Feet': '2,072', 'Lot': '5,183 sqft', 'Lot_conversion_to_sqft': 5183.0, 'House_type': 'SingleFamily', 'Year_build': '1988', 'Parking': 'Garage Attached', 'HOA': 'null', 'Zestimate': '$724,174', 'Rent_zestimate': '$3,163/mo', 'Zillow_price/ ...

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#                        Listing_type     Price  \
# 0                                    $345,900
# 1                                    $567,900
# 2                                    $662,900
# 3                                    $689,900
# 4                                    $824,900
# ..                              ...       ...
# 155                                  $330,000
# 156                         COMPASS  $849,000
# 157                                  $580,000
# 158  T.N.G. REAL ESTATE CONSULTANTS  $650,000
# 159                                  $739,950
#
#                                       Full_address                  Street  \
# 0    13950 Hidden Valley Rd, Victorville, CA 92395  13950 Hidden Valley Rd
# 1                 781 La Loma Ln, Corona, CA 92879          781 La Loma Ln
# 2            5109 Locust Ave, Carmichael, CA 95608         5109 Locust Ave
# 3            5143 Baywood Cir, Oceanside, CA 92056        5143 Baywood Cir
# 4            3 Cardinal Ave, Aliso Viejo, CA 92656          3 Cardinal Ave
# ..                                             ...                     ...
# 155        31549 Delaware Rd, Coarsegold, CA 93614       31549 Delaware Rd
# 156        4661 Bedel St, Woodland Hills, CA 91364           4661 Bedel St
# 157           2635 Sycamore Ln, Palmdale, CA 93551        2635 Sycamore Ln
# 158         312 Capistrano St, Placentia, CA 92870       312 Capistrano St
# 159   73 Franklin Cir, San Juan Bautista, CA 95045         73 Franklin Cir
#
#                 City State Zip_code Bed Bath Square_Feet          Lot  \
# 0        Victorville    CA    92395   3    2       1,453   7,405 sqft
# 1             Corona    CA    92879   4    3       1,969   6,098 sqft
# 2         Carmichael    CA    95608   4    3       2,566  10,018 sqft
# 3          Oceanside    CA    92056   4    3       1,722   4,356 sqft
# 4         AlisoViejo    CA    92656   3    3       1,838   3,071 sqft
# ..               ...   ...      ...  ..  ...         ...          ...
# 155       Coarsegold    CA    93614   3    2       1,650   1.34 Acres
# 156    WoodlandHills    CA    91364   3    3       2,496   4,155 sqft
# 157         Palmdale    CA    93551   3    3       2,244   8,164 sqft
# 158        Placentia    CA    92870   4    2       1,310   5,000 sqft
# 159  SanJuanBautista    CA    95045   3    2       1,630   6,534 sqft
#
#      Lot_conversion_to_sqft    House_type Year_build  \
# 0                    7405.0  SingleFamily       1987
# 1                    6098.0  SingleFamily       1988
# 2                   10018.0  SingleFamily       1959
# 3                    4356.0  SingleFamily       1988
# 4                    3071.0  SingleFamily       1994
# ..                      ...           ...        ...
# 155                 58370.4  SingleFamily       1990
# 156                  4155.0  SingleFamily       1983
# 157                  8164.0  SingleFamily       1990
# 158                  5000.0  SingleFamily       1971
# 159                  6534.0  SingleFamily       1964
#
#                                            Parking             HOA Zestimate  \
# 0                                  Garage Attached  $285 quarterly  $326,910
# 1                                  Garage Attached            null  $630,888
# 2                                           Garage            null  $715,566
# 3                                  Garage Attached     $45 monthly  $704,443
# 4                                  Garage Attached  $826 quarterly  $789,002
# ..                                             ...             ...       ...
# 155                            Garage - Attached,             null  $330,143
# 156         Driveway, On Street, Garage - Two Door            null  $904,117
# 157     Attached, Direct Access, RV Access/Parking            null  $560,819
# 158  Garage, On Site, RV Access/Parking, On Street            null  $690,720
# 159                   Garage - Attached, On-street            null  $739,957
#
#     Rent_zestimate Zillow_price/sqft  \
# 0        $1,695/mo              $238
# 1        $2,700/mo              $288
# 2        $2,650/mo              $258
# 3        $2,995/mo              $401
# 4        $3,500/mo              $449
# ..             ...               ...
# 155      $2,299/mo              $200
# 156      $3,799/mo              $340
# 157      $2,500/mo              $258
# 158      $3,000/mo              $496
# 159      $2,800/mo              $454
#
#                                          House_website
# 0    https://www.zillow.com/homedetails/13950-Hidde...
# 1    https://www.zillow.com/homedetails/781-La-Loma...
# 2    https://www.zillow.com/homedetails/5109-Locust...
# 3    https://www.zillow.com/homedetails/5143-Baywoo...
# 4    https://www.zillow.com/homedetails/3-Cardinal-...
# ..                                                 ...
# 155  https://www.zillow.com/homedetails/31549-Delaw...
# 156  https://www.zillow.com/homedetails/4661-Bedel-...
# 157  https://www.zillow.com/homedetails/2635-Sycamo...
# 158  https://www.zillow.com/homedetails/312-Capistr...
# 159  https://www.zillow.com/homedetails/73-Franklin...
#
# [160 rows x 20 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q1-2021_Single_Family_Data_page1-4.csv", index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-34b1dd1dedcd> in <module>
#       1 # Export file as a CSV, without the Pandas index, but with the header
# ----> 2 house_data.to_csv("Output/Zillow/Q1-2021_Single_Family_Data_page1-4.csv", index=False, header=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Output/Zillow/Q1-2021_Single_Family_Data_page1-4.csv'
