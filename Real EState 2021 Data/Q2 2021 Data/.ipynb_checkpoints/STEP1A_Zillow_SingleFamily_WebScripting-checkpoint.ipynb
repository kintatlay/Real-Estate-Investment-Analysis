# %%
# Dependencies
from bs4 import BeautifulSoup, SoupStrainer
import requests
import pandas as pd
from pprint import pprint
import re
import time

# %%
house_dict = []

for page in range(6, 11):
    linked = 'https://www.zillow.com/ca/houses/' + str(page) + '_p/?searchQueryState={"pagination":{"currentPage":' + str(page) + '},"usersSearchTerm":"ca","mapBounds":{"west":-130.9521558125,"east":-107.6611401875,"south":28.570940002914515,"north":45.333552921012235},"regionSelection":[{"regionId":9,"regionType":2}],"isMapVisible":true,"mapZoom":5,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isCondo":{"value":false},"isMultiFamily":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isTownhouse":{"value":false},"isApartment":{"value":false},"isComingSoon":{"value":false},"isAuction":{"value":false},"doz":{"value":"90"}},"isListVisible":true}'
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0'
    headers = {'User-Agent': user_agent}
    response = requests.get(linked, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('article', class_='list-card')
    print('page: ', page)
    
    # Loop through returned results
    for result in results:
        # Error handling
        try:
            # Identify and return housing weblink
            house_website = str(result.a.get('href'))
            print(house_website)
            # Identify and return house data
#             listing_type = result.find('div', class_="list-card-footer").text;
            price = result.find('div', class_="list-card-price").text
#             print(price)
            full_address = result.find('address', class_="list-card-addr").text
            street = result.find('address', class_="list-card-addr").text.split(",")[0]
            try:
                city = result.find('address', class_="list-card-addr").text.split(",")[1].replace(" ", "")
            except IndexError:
                city = 'null'
            try:
                state = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[1]
            except IndexError:
                state = 'null'
            try:
                zip_code = result.find('address', class_="list-card-addr").text.split(",")[2].split(" ")[2]
            except IndexError:
                zip_code = 'null'
            bed = result.find('ul', class_="list-card-details").find('li').text.split(" ")[0]
            bath = result.find('ul', class_="list-card-details").select('li')[1].text.split(" ")[0]
            house_square_feet = result.find('ul', class_="list-card-details").select('li')[2].text.split(" ")[0]
            # Loop inside each house website and get more house data
            loop_response = requests.get(house_website, headers=headers)
            loop_soup = BeautifulSoup(loop_response.text, 'html.parser')
            loop_result1 = loop_soup.find('ul', class_="ds-home-fact-list")
            loop_result2 = loop_soup.findAll('li', class_="ds-home-fact-list-item")

            lot = 'null';
            house_type = 'null';
            year_build = 'null';
            parking = 'null';
            hoa = 'null';
            lot_conversion_to_sqft = 'null';
            zillow_price_per_sqft = 'null';
            
            for content in loop_result2:
                if "Lot" in content.text.split(":")[0]:
                    lot = content.text.split(":")[1];
                if "Type" in content.text.split(":")[0]:
                    house_type = content.text.split(":")[1];
                if "Year built" in content.text.split(":")[0]:
                    year_build = content.text.split(":")[1];
                if "Parking" in content.text.split(":")[0]:
                    parking = content.text.split(":")[1];
                if "HOA" in content.text.split(":")[0]:
                    hoa = content.text.split(":")[1];
                if "Price/sqft" in content.text.split(":")[0]:
                    zillow_price_per_sqft = content.text.split(":")[1];
                    
            try:
                if (str(lot.split(" ")[1]) == "sqft"):
                    lot_conversion_to_sqft = float(lot.split(" ")[0].replace(',', ""));
                elif ((str(lot.split(" ")[1]) == "acres") or (str(lot.split(" ")[1]) == "acre") or (str(lot.split(" ")[1]) == "Acres") or (str(lot.split(" ")[1]) == "Acre")):
                    lot_conversion_to_sqft = round(float(lot.split(" ")[0].replace(',', "")) * 43560, 2);
                elif (lot == "No Data"):
                    lot_conversion_to_sqft = 'null'
                else:
                    lot_conversion_to_sqft = 'null'
            except IndexError:
                lot_conversion_to_sqft = 'null'
            if (len(loop_soup.findAll('span', class_="Text-c11n-8-38-0__aiai24-0 cMFTfb")) < 3):
                zestimate = 'null'
                rent_zestimate = 'null'
            else:
                zestimate = loop_soup.findAll('span', class_="Text-c11n-8-38-0__aiai24-0 cMFTfb")[0].text
                rent_zestimate = loop_soup.findAll('span', class_="Text-c11n-8-38-0__aiai24-0 cMFTfb")[2].text
            if (zestimate[0] != '$'):
                zestimate = 'null';
            print('zestimate', zestimate)
            print('rent zestimate', rent_zestimate)

            # Store data to house object if all elements are available
#             if (house_website and listing_type and price and full_address and street and city and state and zip_code and bed and bath and house_square_feet and house_type and year_build):
            house_obj = {
#                 "Listing_type": listing_type,
                "Price": price,
                "Full_address": full_address,
                "Street": street,
                "City": city,
                "State": state,
                "Zip_code": zip_code,
                "Bed": bed,
                "Bath": bath,
                "Square_Feet": house_square_feet,
                "Lot": lot,
                "Lot_conversion_to_sqft": lot_conversion_to_sqft,
                "House_type": house_type,
                "Year_build": year_build,
                "Parking": parking,
                "HOA": hoa,
                "Zestimate": zestimate,
                "Rent_zestimate": rent_zestimate,
                "Zillow_price/sqft": zillow_price_per_sqft,
                "House_website": house_website
            }

            #Continue to add data into collection house_dict
            house_dict.append(house_obj)
            time.sleep(5)
            
        except AttributeError as e:
            continue

# print(house_dict)
# Out:
# page:  6
# https://www.zillow.com/homedetails/3030-Nile-St-San-Diego-CA-92104/16976281_zpid/
# zestimate $984,680
# rent zestimate $2,999/mo
# https://www.zillow.com/homedetails/2105-Johnson-Ave-San-Luis-Obispo-CA-93401/15386867_zpid/
# zestimate $1,875,000
# rent zestimate $4,095/mo
# https://www.zillow.com/homedetails/25-Willow-Way-Chester-CA-96020/2079614380_zpid/
# zestimate $71,900
# rent zestimate $1,060/mo
# https://www.zillow.com/homedetails/24845-Fortune-Bay-Ln-Moreno-Valley-CA-92551/17907701_zpid/
# zestimate $529,300
# rent zestimate $2,900/mo
# https://www.zillow.com/homedetails/4755-Pebble-Ct-Riverside-CA-92504/17850216_zpid/
# zestimate $625,100
# rent zestimate $2,880/mo
# https://www.zillow.com/homedetails/11845-Glouchester-Dr-Rancho-Cucamonga-CA-91730/52976729_zpid/
# zestimate $699,460
# rent zestimate $2,999/mo
# https://www.zillow.com/homedetails/236-W-Birch-Ave-Hanford-CA-93230/19060224_zpid/
# zestimate $381,839
# rent zestimate $2,496/mo
# https://www.zillow.com/homedetails/1830-N-Orange-Ave-Ontario-CA-91764/17205746_zpid/
# zestimate $600,300
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/2491-Cheyenne-Way-Arnold-CA-95223/52441508_zpid/
# zestimate $317,048
# rent zestimate $1,494/mo
# page:  7
# https://www.zillow.com/homedetails/40747-Mountain-Pride-Dr-Murrieta-CA-92562/18181730_zpid/
# zestimate $590,549
# rent zestimate $2,929/mo
# https://www.zillow.com/homedetails/31671-Pepper-Tree-St-Winchester-CA-92596/59406629_zpid/
# zestimate $826,400
# rent zestimate $3,294/mo
# https://www.zillow.com/homedetails/3943-W-Menlo-Ave-Hemet-CA-92545/17976155_zpid/
# zestimate $490,400
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/1502-E-57th-St-Long-Beach-CA-90805/21153745_zpid/
# zestimate $612,000
# rent zestimate $2,250/mo
# https://www.zillow.com/homedetails/261-Charles-Elmore-Dr-El-Centro-CA-92243/89141330_zpid/
# zestimate $392,200
# rent zestimate $1,500/mo
# https://www.zillow.com/homedetails/7174-Copper-Sky-Eastvale-CA-92880/2098468013_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/6240-Hillside-Dr-El-Sobrante-CA-94803/68041937_zpid/
# zestimate $759,800
# rent zestimate $3,596/mo
# https://www.zillow.com/homedetails/1087-Mirada-Dr-Perris-CA-92571/17895277_zpid/
# zestimate $464,800
# rent zestimate $2,323/mo
# https://www.zillow.com/homedetails/560-Candela-Cir-Sacramento-CA-95835/67824705_zpid/
# zestimate $583,540
# rent zestimate $2,382/mo
# page:  8
# https://www.zillow.com/homedetails/1405-Old-Winery-Ct-Sonoma-CA-95476/15828055_zpid/
# zestimate $2,653,600
# rent zestimate $5,999/mo
# https://www.zillow.com/homedetails/5173-Collett-Ave-Encino-CA-91436/19981468_zpid/
# zestimate $3,785,300
# rent zestimate $12,528/mo
# https://www.zillow.com/homedetails/7575-Lemoran-Ave-Pico-Rivera-CA-90660/21100165_zpid/
# zestimate $547,200
# rent zestimate $2,500/mo
# https://www.zillow.com/homedetails/7210-Doris-Ave-Winton-CA-95388/19191745_zpid/
# zestimate $214,793
# rent zestimate $1,834/mo
# https://www.zillow.com/homedetails/7431-Franklin-Ave-Los-Angeles-CA-90046/20803447_zpid/
# zestimate $4,740,254
# rent zestimate $17,249/mo
# https://www.zillow.com/homedetails/60213-Katie-Cir-La-Quinta-CA-92253/69277461_zpid/
# zestimate $361,100
# rent zestimate $3,800/mo
# https://www.zillow.com/homedetails/12726-Valentano-Ave-Bakersfield-CA-93312/63110667_zpid/
# zestimate $346,700
# rent zestimate $1,950/mo
# https://www.zillow.com/homedetails/917-Amador-Ave-Galt-CA-95632/25956975_zpid/
# zestimate $449,600
# rent zestimate $1,898/mo
# https://www.zillow.com/homedetails/3515-Camino-Purisima-Arroyo-Grande-CA-93420/114452335_zpid/
# zestimate $2,940,000
# rent zestimate $7,677/mo
# page:  9
# https://www.zillow.com/homedetails/3245-Hoen-Ave-Santa-Rosa-CA-95405/15762537_zpid/
# zestimate $435,000
# rent zestimate $2,600/mo
# https://www.zillow.com/homedetails/12188-Welch-Rd-Wilton-CA-95693/25950293_zpid/
# zestimate $899,006
# rent zestimate $2,894/mo
# https://www.zillow.com/homedetails/609-N-Edinburgh-Ave-Los-Angeles-CA-90048/20786049_zpid/
# zestimate $4,876,474
# rent zestimate $18,421/mo
# https://www.zillow.com/homedetails/81779-Dalea-Ave-Indio-CA-92201/18062142_zpid/
# zestimate $386,178
# rent zestimate $2,199/mo
# https://www.zillow.com/homedetails/13287-Wells-Fargo-Dr-Groveland-CA-95321/16205502_zpid/
# zestimate null
# rent zestimate null
# https://www.zillow.com/homedetails/8561-Golden-Ridge-Rd-Lakeside-CA-92040/16888815_zpid/
# zestimate $716,100
# rent zestimate $3,195/mo
# https://www.zillow.com/homedetails/1743-Harrison-Ave-Hanford-CA-93230/19064917_zpid/
# zestimate $252,491
# rent zestimate $1,300/mo
# https://www.zillow.com/homedetails/8377-Old-Ranch-Rd-Orangevale-CA-95662/26071441_zpid/
# zestimate $365,430
# rent zestimate $2,195/mo
# https://www.zillow.com/homedetails/185-N-Kelly-Dr-Dinuba-CA-93618/16216974_zpid/
# zestimate $292,934
# rent zestimate $1,641/mo
# page:  10
# https://www.zillow.com/homedetails/1851-Old-Franke-Mine-Rd-Murphys-CA-95247/300739302_zpid/
# zestimate $426,376
# rent zestimate $1,474/mo
# https://www.zillow.com/homedetails/14090-Winnie-St-Walnut-Grove-CA-95690/82890956_zpid/
# zestimate $254,676
# rent zestimate $2,518/mo
# https://www.zillow.com/homedetails/19118-Merion-Dr-Porter-Ranch-CA-91326/20200565_zpid/
# zestimate $1,331,500
# rent zestimate $6,099/mo
# https://www.zillow.com/homedetails/74111-Setting-Sun-Trl-Palm-Desert-CA-92260/18079929_zpid/
# zestimate $895,008
# rent zestimate $4,500/mo
# https://www.zillow.com/homedetails/1741-Alta-Vista-Dr-Vista-CA-92084/16633705_zpid/
# zestimate $635,100
# rent zestimate $2,599/mo
# https://www.zillow.com/homedetails/14350-Flathead-Rd-Apple-Valley-CA-92307/17464930_zpid/
# zestimate $305,600
# rent zestimate $1,599/mo
# https://www.zillow.com/homedetails/13488-Delta-Rd-Santa-Margarita-CA-93453/15451282_zpid/
# zestimate $390,600
# rent zestimate $2,400/mo
# https://www.zillow.com/homedetails/85-Barton-Flats-Trl-Angelus-Oaks-CA-92305/299166536_zpid/
# zestimate $85,000
# rent zestimate $1,669/mo
# https://www.zillow.com/homedetails/780-Birch-St-Brawley-CA-92227/18857635_zpid/
# zestimate $294,500
# rent zestimate $1,374/mo

# %%
house_data = pd.DataFrame(house_dict)
house_data
# Out:
#          Price                                  Full_address  \
# 0     $440,000        1331 Grendel Way, Sacramento, CA 95833
# 1     $582,900            2199 Kellogg Ave, Corona, CA 92879
# 2     $561,900        36728 Red Oak St, Winchester, CA 92596
# 3     $483,100             1424 Poppy Ct, Beaumont, CA 92223
# 4     $626,900        25434 Blackwood Rd, Murrieta, CA 92563
# 5     $792,900     1916 E Workman Ave, West Covina, CA 91791
# 6     $697,900         39727 Barbados Dr, Murrieta, CA 92563
# 7     $583,200  34292 Chaparossa Dr, Lake Elsinore, CA 92532
# 8     $667,900         31930 Browning St, Murrieta, CA 92563
# 9     $451,900           2144 55th Ave, Sacramento, CA 95822
# 10    $669,900        10527 Flora Verda Ct, Santee, CA 92071
# 11    $749,900           2410 Earl Ave, Long Beach, CA 90806
# 12    $724,900         1129 W Vermont Ave, Anaheim, CA 92802
# 13    $799,900        1353 Timberpond Dr, El Cajon, CA 92019
# 14    $486,500         7381 Marani Way, Sacramento, CA 95831
# 15    $569,900      3399 Flowerfield Dr, Riverside, CA 92503
# 16    $327,900               1 Sumo Ct, Sacramento, CA 95828
# 17    $643,900        2312 Migration Ct, Elk Grove, CA 95757
# 18    $599,900          41209 47th St W, Lancaster, CA 93536
# 19    $969,900      3405 Via Cabo Verde, Escondido, CA 92029
# 20    $859,900        1313 S Pembrooke Ln, Anaheim, CA 92804
# 21    $749,900              2728 Field Ct, Rocklin, CA 95765
# 22    $649,500         1709 Tamarme Ter, Escondido, CA 92025
# 23  $1,319,000   11202 Culver Park Dr, Culver City, CA 90230
# 24    $824,900        3344 Organdy Ln, Chino Hills, CA 91709
# 25    $834,900         14727 Leadwell St, Van Nuys, CA 91405
# 26    $709,900          1123 Benjamin Pl, El Cajon, CA 92020
# 27    $428,800         9233 Chablis Way, Elk Grove, CA 95624
# 28    $738,900              529 W 215th St, Carson, CA 90745
# 29    $549,900      40328 Sagewood Dr, Palm Desert, CA 92260
# 30    $553,900            6904 Fall Way, Elk Grove, CA 95758
# 31    $695,000             16420 Wikiup Rd, Ramona, CA 92065
# 32    $455,900           49142 Barrymore St, Indio, CA 92201
# 33    $489,900         9386 Rampton Ct, Sacramento, CA 95829
# 34    $632,900         6549 Turnstone Way, Rocklin, CA 95765
# 35    $878,900       2612 Fontezuela Dr, La Puente, CA 91745
# 36    $740,900            14445 Rath St, La Puente, CA 91744
# 37    $626,900          5700 Knapwood Ct, Antelope, CA 95843
# 38    $735,200             260 Barnhill Dr, Folsom, CA 95630
# 39    $845,900         4946 Wildwood Dr, Oceanside, CA 92057
# 40    $526,900           4015 Landau Ct, Riverside, CA 92501
# 41    $624,900               6827 Cosmos St, Chino, CA 91710
# 42    $815,900              1929 W Elm Pl, Anaheim, CA 92804
# 43    $719,000            29385 Eagle Dr, Murrieta, CA 92563
# 43  10,019 sqft                 10019.0  Single Family Residence       2000
# 44   3,000 sqft                  3000.0  Single Family Residence       1996
#
#                      Parking            HOA   Zestimate Rent_zestimate  \
# 0           2 Parking spaces           null    $456,958      $2,300/mo
# 1            2 Garage spaces           null    $600,332      $2,594/mo
# 2            3 Garage spaces  $120 annually    $512,000      $2,664/mo
# 3            2 Garage spaces    $42 monthly    $501,200      $2,749/mo
# 4            3 Garage spaces           null    $647,904      $2,900/mo
# 5           2 Parking spaces           null    $821,732      $3,099/mo
# 6            4 Garage spaces           null    $725,815      $2,999/mo
# 7            2 Garage spaces   $119 monthly    $573,700      $3,127/mo
# 8            2 Garage spaces    $40 monthly    $668,345      $2,999/mo
# 9            2 Garage spaces           null    $457,216      $2,199/mo
# 10          2 Parking spaces   $190 monthly    $699,900      $3,200/mo
# 11           2 Garage spaces           null    $780,937      $3,294/mo
# 12           2 Garage spaces           null    $757,000      $3,300/mo
# 13           2 Garage spaces   $340 monthly    $818,921      $3,394/mo
# 14           2 Garage spaces           null    $500,467      $2,154/mo
# 15           2 Garage spaces   $210 monthly    $580,400      $2,766/mo
# 16            1 Garage space           null    $342,804      $1,649/mo
# 17           2 Garage spaces    $64 monthly    $705,700      $2,429/mo
# 18           2 Garage spaces           null    $626,100      $2,999/mo
# 19           3 Garage spaces   $210 monthly  $1,021,600      $3,670/mo
# 20           2 Garage spaces           null    $900,200      $3,499/mo
# 21           3 Garage spaces           null    $794,400      $3,049/mo
# 22           2 Garage spaces           null    $667,700      $3,200/mo
# 23           2 Garage spaces           null  $1,292,700      $3,764/mo
# 24           2 Garage spaces           null    $841,418      $2,849/mo
# 25           2 Garage spaces           null    $904,000      $3,460/mo
# 26           2 Garage spaces           null    $718,500      $3,449/mo
# 27           2 Garage spaces           null    $448,290      $1,900/mo
# 28            1 Garage space           null    $765,289      $2,900/mo
# 29           2 Garage spaces   $100 monthly    $549,905      $3,599/mo
# 30          2 Parking spaces           null    $578,300      $2,100/mo
# 31           2 Garage spaces   $124 monthly    $705,029      $3,670/mo
# 32           2 Garage spaces   $274 monthly    $460,848      $2,534/mo
# 33          2 Parking spaces           null    $551,300      $2,094/mo
# 34           3 Garage spaces           null    $650,603      $2,963/mo
# 35           2 Garage spaces           null    $906,516      $3,294/mo
# 36          2 Carport spaces           null    $664,300      $2,999/mo
# 37           3 Garage spaces           null    $678,030      $2,799/mo
# 38           2 Garage spaces    $95 monthly    $757,287      $2,795/mo
# 39          2 Parking spaces           null    $869,561      $3,200/mo
# 40           2 Garage spaces   $195 monthly    $537,992      $2,549/mo
# 41           2 Garage spaces   $125 monthly    $656,970      $2,650/mo
# 42           2 Garage spaces           null    $836,955      $3,270/mo
# 43  3 Attached Garage spaces           null    $777,300      $3,494/mo
# 44  2 Attached Garage spaces           null    $218,200      $3,128/mo
#
#    Zillow_price/sqft                                      House_website
# 0               $266  https://www.zillow.com/homedetails/1331-Grende...
# 1               $375  https://www.zillow.com/homedetails/2199-Kellog...
# 2               $325  https://www.zillow.com/homedetails/36728-Red-O...
# 3               $216  https://www.zillow.com/homedetails/1424-Poppy-...
# 4               $290  https://www.zillow.com/homedetails/25434-Black...
# 5               $448  https://www.zillow.com/homedetails/1916-E-Work...
# 6               $258  https://www.zillow.com/homedetails/39727-Barba...
# 7               $223  https://www.zillow.com/homedetails/34292-Chapa...
# 8               $243  https://www.zillow.com/homedetails/31930-Brown...
# 9               $288  https://www.zillow.com/homedetails/2144-55th-A...
# 10              $401  https://www.zillow.com/homedetails/10527-Flora...
# 11              $504  https://www.zillow.com/homedetails/2410-Earl-A...
# 12              $541  https://www.zillow.com/homedetails/1129-W-Verm...
# 13              $373  https://www.zillow.com/homedetails/1353-Timber...
# 14              $407  https://www.zillow.com/homedetails/7381-Marani...
# 15              $323  https://www.zillow.com/homedetails/3399-Flower...
# 16              $340  https://www.zillow.com/homedetails/1-Sumo-Ct-S...
# 17              $354  https://www.zillow.com/homedetails/2312-Migrat...
# 18              $284  https://www.zillow.com/homedetails/41209-47th-...
# 19              $441  https://www.zillow.com/homedetails/3405-Via-Ca...
# 20              $438  https://www.zillow.com/homedetails/1313-S-Pemb...
# 21              $311  https://www.zillow.com/homedetails/2728-Field-...
# 22              $371  https://www.zillow.com/homedetails/1709-Tamarm...
# 23            $1,237  https://www.zillow.com/homedetails/11202-Culve...
# 24              $498  https://www.zillow.com/homedetails/3344-Organd...
# 25              $490  https://www.zillow.com/homedetails/14727-Leadw...
# 26              $412  https://www.zillow.com/homedetails/1123-Benjam...
# 27              $407  https://www.zillow.com/homedetails/9233-Chabli...
# 28              $478  https://www.zillow.com/homedetails/529-W-215th...
# 29              $297  https://www.zillow.com/homedetails/40328-Sagew...
# 30              $403  https://www.zillow.com/homedetails/6904-Fall-W...
# 31              $279  https://www.zillow.com/homedetails/16420-Wikiu...
# 32              $257  https://www.zillow.com/homedetails/49142-Barry...
# 33              $422  https://www.zillow.com/homedetails/9386-Rampto...
# 34              $338  https://www.zillow.com/homedetails/6549-Turnst...
# 35              $475  https://www.zillow.com/homedetails/2612-Fontez...
# 36              $477  https://www.zillow.com/homedetails/14445-Rath-...
# 37              $283  https://www.zillow.com/homedetails/5700-Knapwo...
# 38              $366  https://www.zillow.com/homedetails/260-Barnhil...
# 39              $423  https://www.zillow.com/homedetails/4946-Wildwo...
# 40              $316  https://www.zillow.com/homedetails/4015-Landau...
# 41              $420  https://www.zillow.com/homedetails/6827-Cosmos...
# 42              $543  https://www.zillow.com/homedetails/1929-W-Elm-...
# 43              $206  https://www.zillow.com/homedetails/29385-Eagle...
# 44              $195  https://www.zillow.com/homedetails/19763-North...

# %%
# Export file as a CSV, without the Pandas index, but with the header
house_data.to_csv("Output/Zillow/Q2-2021_Single_Family_page6-10.csv", index=False, header=True)
